# %% [markdown]
# # Introduction to Python 3
# ### Geospatial Data Analytics (GEOG 389)
#
#
#
# <br>
# Instructor: Yi Qiang
#
# Email: yi.qiang@hawaii.edu

# %% [markdown]
# # 1. Recap of Python Basics
#
# ### Declare a variable
# - integer
# - float (double)
# - string
# - Operations between the variables ( `+` for numbers and string)

# %% [markdown]
# ### Python Collections

# %% [markdown]
# - list
# - tuple
# - dictionary

# %% [markdown]
# ### Accessing data in a list

# %%
a=[2,4,6,8,10,12,14]

# %% [markdown]
# Accessing values in a list

# %%
# Get the value of the 3rd element

# %%
# Get the value of the 2nd element counting from the end

# %% [markdown]
# Slicing (subsetting a list)

# %%
# Get a subset of the list from the 2nd to the 4th element

# %%
# Adding an element to the end of a list

# %%
# Change the value of the 4th element to 0

# %%
# delete the 3rd element

# %%
# create an empty list

# %% [markdown]
# ### If, then, else
#
# Write a program to ask students to input their numerical grade. The program will translate the numerical grade to A, B, C or Pass.

# %%
# Inputing the grade
grade = input('Please input your grade: ')

# %%
''' 
Write a if statement to 
- If the grade is >= 90, print 'A'.
- If the grade is >=80 and <90, print 'B'.
- If the grade is >=70 and <80, print 'C'.
- Otherwise, print 'Pass'.
'''

# %% [markdown]
# ### For loop

# %%
# Find names that start with 'A' or 'a' in the following list and put them in a new list.
names=['Mike','John','Allen','Frank','Aaron','Amy']

# %%
# Use range() to create a list of numbers

# %%
# Create a list of number from 0 to 100

# %% [markdown]
# ### Function

# %% [markdown]
# A wrap of program that can be re-used without re-writing the program

# %%
ls=[]
for i in range(0,1000):
    if (i % 13) == 0:
        ls.append(i)

print(sum(ls))

# %%
 # Wrap the above program into a function num13(start_num,end_num), which calculate the sum of numbers that can be 

def num13...


num13(1,1000)

# %% [markdown]
# ### Two types of functions:  global function vs class function

# %% [markdown]
# **Global function**: Globally defined, not belong to a class.
#
# Directly calling the function and put objects in the parentheses

# %%
len(names) # an global function, the input is in parentheses

# %% [markdown]
# **Class function**: Defined in a class, only applies to a specific class of objects
#
# Called with the object, e.g. object.function()

# %%
names.append() # a class function, use a '.' after the variable to call the function

# %% [markdown]
# # 2. Numpy Array

# %% [markdown]
# - A numpy array is a grid of values, all of the same type, and is indexed by a tuple of nonnegative integers.
# - An array can be 1-dimensional, 2-dimensional or n-dimensional. For instance, a raster is essentially a geo-coordinated 2D array.
# - Arrays support element-wise operations that is not supported by other python data collections (e.g. list)

# %% [markdown]
# ### 2.1 Creating an array
# Create a list

# %%
num_ls=[69,88,73,90,82,73]
type(num_ls)

# %% [markdown]
# You can't do arithmatic operations directly to list.

# %%
num_ls+5

# %% [markdown]
# Convert the list to a numpy array

# %%
import numpy as np # as numpy is not a built-in package in python, you need to import it before using
num_array =  np.array(num_ls)

# %%
type(num_array)

# %% [markdown]
# Apply element-wise operations to the array

# %%
num_array / 2.0

# %% [markdown]
# Create a 2D array

# %%
array2d=np.array([[11,12,13],[21,22,23],[31,32,33]])

# %%
# get the shape of the array
array2d.shape

# %% [markdown]
# Create an 2D array of zeros

# %%
a=np.zeros((4,4)) # the input of the zero function is a tuple of the array dimension.
a

# %% [markdown]
# ### 2.2 Get values in an array
# - Use a tuple index to get values at specific positions in an array
# - For instance, array[a,b] will obtain the value at the (a+1)th row and (b+1)th column

# %% [markdown]
# Create an 5*4 array with random numbers

# %%
a = np.random.rand(5,4)
print(a)

# %%
a = a*100 # times 100

# %% [markdown]
# Use `astype()` to conver to integers - get rid of the decimals

# %%
# Note: this is different from the way of converting other variables to integer, e.g. int(string1)
a.astype(int)

# %%
a[1]

# %%
a[1,3]

# %% [markdown]
# ### 2.3 Boolean selection (indexing)

# %%
a>50 # comparison operator for an array

# %%
# Return a 1D array contain all elements that meet the condition.
a[a>50]

# %%
# Change all numbers above 50 to 0

# %% [markdown]
# Do the homework using numpy array
#
# Get the summation of all numbers from 1 to 1000 that can be divided by 13 with 0 remainder.

# %%
a=range(1,1001) #create a list of number from 0 to 1000
a=np.array(a) # convert the list to np array

# %%
a[a%13==0]

# %% [markdown]
# ### 2.4 Slicing (subseeting) an array

# %% [markdown]
# Get the part of the array from the 1st to 3rd row, from the 1st to the 4th column
# Inline-style:
# ![alt text](images/fig1.jpg "Logo Title Text 1")

# %%
a[,]

# %% [markdown]
# ### 2.5 Element-wise operation

# %%
# Generate a 2 x 4 array of integers between 0 and 9, inclusive:

a = np.random.randint(10, size=(4, 4))
a

# %%
# Generate another 2 x 4 array of integers between 0 and 4, inclusive:

b = np.random.randint(5, size=(4, 4))
b

# %%
a * b

# %% [markdown]
# # 3. Data Frame

# %% [markdown]
# - Built on 2D numpy array.
# - A data structure designed for spreadsheet and tables
# - A column in a dataframe is a 1-dimensional labeled array

# %% [markdown]
# ### 3.1 Importing dataframe from spreadsheet
# Read a spreadsheet in your computer

# %%
# import the package of pandas
import pandas as pd

# read the spreadsheet
df=pd.read_csv('other/sales.csv')

# %%
df.head()

# %% [markdown]
# ### 3.2 Get items

# %% [markdown]
# Accessing items using `iloc[row index, column index]`

# %%
# Get the first row
df[0:6]

# %%
# Get the first 4 rows

# %% [markdown]
# Getting a column

# %%
# Get the column (series) of 'Item'
df.Item

# %%
# Another way to get the column (series) of 'Item'
df['Item']

# %%
# Get several columns by the column names
df[['Item','Units','Unit Cost']]

# %%
df.iloc[0:5,2:6]

# %% [markdown]
# ### 3.3 Subsetting data frame

# %% [markdown]
# Selecting rows that meet specific conditions

# %%
# Select all records of Jones
df[df.Rep=='Jones']

# %% [markdown]
# You can use & (and), | (or) and ~ (not) to combine conditions to sebset records
#
# ** Note: you should and, or and not to combine conditions in an if, elif, else statement **

# %%
# Selecting all records of pencils bought by Jones
df[(df.Rep=='Jones') & (df.Item=='Pencil')]

# %%
# Calculate the total income of pencils sold by Jone

# %% [markdown]
# If all units' price increase 5% and the purchased unit number decrease 10%, what's the next year's total cost?

# %%
# Update the unit cost
new_price=(df[['Unit Cost']]*0.95)

# Update the unit number
new_num=df[['Unit Cost']]*1.1

# Update the total cost for each record
new_total=new_price*new_num

# %% [markdown]
# # 4. Reading Spatial Data
#
# ## 4.1 Vector data
#
# ### Elements of vector data
# - Geometries (points, lines and polygons)
# - Geometries are all built on points.
# - Attributes (names, population, temperature, income...)
# - Attributes are organized in tables
# - Each geometry is associated with a set of attributes (a row in the attribute table)

# %% [markdown]
# #### Read a shapefile from the local drive.

# %%
# Load an external package before using it
import geopandas

# %%
# read the shapefile stored in my computer using the absolute (full) path
data = geopandas.read_file("other/conus.shp")

# %% [markdown]
# Shapefile is based on a distributed structure, which stores geometries, attributes, and other information in separate files.
#
# This is how a shapefile looks like in the file system.
#
# <img src="images/fig2.JPG" alt="Drawing" style="width: 800px;"/>

# %%
# plot the data
import matplotlib.pyplot as plt

# turn on the interactive mode of matplotlib
plt.ion()


# change the figure size
plt.rcParams['figure.figsize'] = [45, 45]

# %%
# plot the shapefile
data.plot()

# %%
# print the type of data
print(type(data))

# %%
# show the first 5 lines in the attribute table
data.head()

# %%
# plot California
fl=data[data.NAME=='Florida']
fl.plot()

# %%
# plot states that are larger than California
fl = data[data.NAME=='Florida']

fl_area=fl.ALAND.iloc[0]


states_larger_than_fl.plot()

# %% [markdown]
# ## 4.2 Raster data
#
# ### Element of raster data
# - A 2D matrix
# - Spatial referenc (coordinate) system
# - Top-left corner coordinates
# - Cell-size (resolution)

# %%
# import needed packages
import rasterio as rio
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [45, 45]

raster = rio.open("other/dem_oahu.tif")
rio.plot.show(raster)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-f3ec48125ec6> in <module>()
#       6
#       7 raster = rio.open("other/dem_oahu.tif")
# ----> 8 rio.plot.show(raster)
#
# AttributeError: 'module' object has no attribute 'plot'

# %%
raster.profile

# %%
# Get the first band, which is the only band.
array=raster.read(1)

# %%
# Change all pixels with a value <500 to no data.
array[array<500]=np.nan
show(array)

# %% [markdown]
# Estimate areas that will be innundated if sea level rise for 1 meter, based on the bathtub model

# %%
array=raster.read(1)
array[array<-1000]=np.nan
array[array<=1]=1
array[array>1]=0
show(array)

# %% [markdown]
# ## Readings
#
# - The demonstrations in class (Laulima -> Resource -> Class demonstration)
# - Cheatsheet of Numpy Array https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Numpy_Python_Cheat_Sheet.pdf
# - Cheatsheet of Data Frame https://s3.amazonaws.com/assets.datacamp.com/blog_assets/PandasPythonForDataScience.pdf
