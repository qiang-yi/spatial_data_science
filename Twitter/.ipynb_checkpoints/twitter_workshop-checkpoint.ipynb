# %% [markdown]
# ## Spatial Data Science (GIS6307/GEO4930)
#
#
# <br>
# Instructor: Yi Qiang (qiangy@usf.edu)<br>
# Teaching Assistant: Jinwen Xu (jinwenxu@usf.edu)
#
# ---
#
# # Workshop on Spatial Analysis of Twitter
#
# This workshop will help you to get started with the acquisition, processing, and analysis of Twitter data using data science techniques. Specifically, you will learn:
#
# - Streaming real-time tweets using Twitter Developer APIs.
# - Processing the raw tweets into an analyzable form.
# - Basic mapping, spatial analysis and natural language processing for Twitter data.
#
# ### Prerequisite
# - Install Anaconda in your computer.
# - Activation of Twitter Developer Account and approved **Elevated Access** before the workshop.
# - Basic programming skills are recommended, but not required.

# %% [markdown]
# ## 1. Install Python Libraries
#
# We will need two new libraries [tweepy](https://www.tweepy.org/) and [folium](https://plotly.com/python/) for this lab. Please do the following steps to install these two libarries.
#
# 1. Open or create a new conda environment `geo`.
# - For students in courses GIS6307 and GEO4930, please open Anaconda Prompt, and use the command `conda activate geo` to activate the "geo" environment that you created in the previous lab.
#
# - For workshop participatns, please run the following code to create a new conda environment `geo` and then activate it.
#
#     - `conda create --name geo`
#
#     - `conda activate geo`
#
# 2. Install tweepy using the following command:
#
#     `conda install -c conda-forge tweepy`
#
# 3. Install contextily using the following command:
#
#     `conda install -c conda-forge folium`
#
# 4. Run the following code to import the installed libraries and other needed libraries. If the code runs through, the libraries are installed successfully.

# %%
# Run the following lines if there is an error loading basemap
# import os
# os.environ['PROJ_LIB'] = '~your anaconda 3 path/Anaconda3/Library/share/'

import tweepy
import folium
import pandas as pd

#from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Set-Up the Connection to Twitter APIs
#
# Go to Twitter Developer Portal (https://developer.twitter.com/en/apps). Click the App you created in account activation.
#
# If you haven't created an App when you created the account, you can create one in the project.
#
# Click `Sign up`.
#
# ![](../image/twitter/signup3.jpg)
#
# Turn on `OAuth 1.0a` and keep `OAuth 2.0` off.
#
# ![](../image/twitter/OAuth.jpg)
#
# Select "Read and write and Direct message". You can use "http://127.0.0.1:8080" as Callback URL. Add any website as the website URL (e.g. your personal website or https://google.com).
#
# ![](../image/twitter/setting.jpg)
#
# Copy the API keys you have saved when you activated your Developer account, and paste them to replace "......" below. If you can't find them, you can **regenerate** the keys and tokens in your Developer Portal.
#
# ![](../image/twitter/keys2.jpg)
#
# Generate your Access Token and Secret and paste them below.

# %%
# paste your API keys and tokens to replace ......

# API_key = 'aOLqeAcCKvMRhKLZBIKADW2rW'
# API_key_secret = 'b1lOWTIy3Vfb5C2OS4S9wXP3BYzugrPs50i4oIqWmn1tcdORaT'
# access_token = '1508096832806731780-wIo5pKdrys6o1qoX7LETloH1tRirkS'
# access_token_secret = 'U4g0XQiGxGXnwN2Y5T2ePqKdxhS91jcHy2Zc5jqBEJ9V8'

API_key = 'As0PGxFkLLgXKyqnGCre08UNz'
API_key_secret = '6rzlzIBqgURxZd2PKjo4QTj4iYNiwINHDWDCMWW3zlxUU9xr23'
access_token = '1509606550134038533-TpQM7b6U3nlvewate1hJqqbMuHSl5p'
access_token_secret = 'jTMIxiyKndnxMAI1vJScVC8diddUgHO2EJvNbb4nozU8L'

# %% [markdown]
# Set up for Twitter authentication.

# %%
auth = tweepy.OAuthHandler(API_key, API_key_secret)
auth.set_access_token(access_token, access_token_secret)

# %% [markdown]
# Set up tweepy API and set rate limit to be true.

# %%
api = tweepy.API(auth, wait_on_rate_limit = True)

# %% [markdown]
# ---

# %% [markdown]
# ## 3. Simple Operation with Twitter APIs
#
# Now, your working environment is set up for Twitter analysis. Let's first try a few simple operations to acquire Twitter data in a programmatic way.
#
# The full functionalities of Twitter API and Tweepy can be found in:
#
# - [Twitter APIs](https://developer.twitter.com/en/docs.html)
# - [Tweepy documentation](http://docs.tweepy.org/en/v4.8.0/)

# %% [markdown]
# ### 3.1 Posting/Deleting a Tweet
#
# First, let's post a message in your Twitter account.
#
# **Note**: if you don't want to disturb your followers with a meanless tweet, don't run the following block of code.

# %%
# Post a tweet from Python
test_tweet = api.update_status("DRILL: I'm creating a robot to tweet!")

# %% [markdown]
# Check your Twitter account, and you'll see the above message is posted.
#
# ![](../image/twitter/tweet.jpg)
#
# Tweets are encoded in a JSON (JavaScript Object Notation) format. You can run the following code to check the content of the tweet you just posted.

# %%
test_tweet._json
# Out:
# {'created_at': 'Sun Apr 03 19:35:54 +0000 2022',
#  'id': 1510702652287594509,
#  'id_str': '1510702652287594509',
#  'text': "DRILL: I'm creating a robot to tweet!",
#  'truncated': False,
#  'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []},
#  'source': '<a href="https://twitter.com" rel="nofollow">twitter_workshop2</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 1509606550134038533,
#   'id_str': '1509606550134038533',
#   'name': 'Alex Zhang',
#   'screen_name': 'AlexZha37291293',
#   'location': '',
#   'description': 'Data scientist',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 0,
#   'friends_count': 1,
#   'listed_count': 0,
#   'created_at': 'Thu Mar 31 19:00:34 +0000 2022',
#   'favourites_count': 0,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 1,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#   'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': True,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none',
#   'withheld_in_countries': []},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'is_quote_status': False,
#  'retweet_count': 0,
#  'favorite_count': 0,
#  'favorited': False,
#  'retweeted': False,
#  'lang': 'en'}

# %% [markdown]
# `_json` returns a dictionary object. So you could access specific attributes using keys in the dictionary. The code below gets the posting time of the tweets.

# %%
test_tweet._json['created_at']
# Out:
# 'Sun Apr 03 19:35:54 +0000 2022'

# %% [markdown]
# Alternative, you can also use the built-in attribute of the tweepy status object to access the attribute. All attributes of a tweet can be found [here](https://developer.twitter.com/en/docs/twitter-api/v1/data-dictionary/object-model/tweet).

# %%
test_tweet.created_at
# Out:
# datetime.datetime(2022, 4, 3, 19, 35, 54, tzinfo=datetime.timezone.utc)

# %% [markdown]
# You can run the following code to delete the drill tweet you just posted.

# %%
api.destroy_status(test_tweet.id_str)
# Out:
# Status(_api=<tweepy.api.API object at 0x000001EC49EFEE20>, _json={'created_at': 'Sun Apr 03 19:35:54 +0000 2022', 'id': 1510702652287594509, 'id_str': '1510702652287594509', 'text': "DRILL: I'm creating a robot to tweet!", 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://twitter.com" rel="nofollow">twitter_workshop2</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1509606550134038533, 'id_str': '1509606550134038533', 'name': 'Alex Zhang', 'screen_name': 'AlexZha37291293', 'location': '', 'description': 'Data scientist', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 0, 'friends_count': 1, 'listed_count': 0, 'created_at': 'Thu Mar 31 19:00:34 +0000 2022', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 1, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': True, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2022, 4, 3, 19, 35, 54, tzinfo=datetime.timezone.utc), id=1510702652287594509, id_str='1510702652287594509', text="DRILL: I'm creating a robot to tweet!", truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, source='twitter_workshop2', source_url='https://twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x000001EC49EFEE20>, _json={'id': 1509606550134038533, 'id_str': '1509606550134038533', 'name': 'Alex Zhang', 'screen_name': 'AlexZha37291293', 'location': '', 'description': 'Data scientist', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 0, 'friends_count': 1, 'listed_count': 0, 'created_at': 'Thu Mar 31 19:00:34 +0000 2022', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 1, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': True, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': [] ...

# %% [markdown]
# ### 3.2 Getting Trending Tweets

# %% [markdown]
# Get the list of cities where trends are available

# %%
city_ls = api.available_trends()

# %% [markdown]
# Convert the list (in JSON format) into a dataframe (i.e. a table). Print the number of cities where trends are available.

# %%
df_city = pd.DataFrame(city_ls)

print (str(len(df_city)) + " cities have trends.")
# Out:
# 467 cities have trends.

# %% [markdown]
# Preview 10 cities where trends are available

# %%
df_city.head(10)
# Out:
#          name                          placeType  \
# 0   Worldwide  {'code': 19, 'name': 'Supername'}
# 1    Winnipeg        {'code': 7, 'name': 'Town'}
# 2      Ottawa        {'code': 7, 'name': 'Town'}
# 3      Quebec        {'code': 7, 'name': 'Town'}
# 4    Montreal        {'code': 7, 'name': 'Town'}
# 5     Toronto        {'code': 7, 'name': 'Town'}
# 6    Edmonton        {'code': 7, 'name': 'Town'}
# 7     Calgary        {'code': 7, 'name': 'Town'}
# 8   Vancouver        {'code': 7, 'name': 'Town'}
# 9  Birmingham        {'code': 7, 'name': 'Town'}
#
#                                          url  parentid         country  woeid  \
# 0      http://where.yahooapis.com/v1/place/1         0                      1
# 1   http://where.yahooapis.com/v1/place/2972  23424775          Canada   2972
# 2   http://where.yahooapis.com/v1/place/3369  23424775          Canada   3369
# 3   http://where.yahooapis.com/v1/place/3444  23424775          Canada   3444
# 4   http://where.yahooapis.com/v1/place/3534  23424775          Canada   3534
# 5   http://where.yahooapis.com/v1/place/4118  23424775          Canada   4118
# 6   http://where.yahooapis.com/v1/place/8676  23424775          Canada   8676
# 7   http://where.yahooapis.com/v1/place/8775  23424775          Canada   8775
# 8   http://where.yahooapis.com/v1/place/9807  23424775          Canada   9807
# 9  http://where.yahooapis.com/v1/place/12723  23424975  United Kingdom  12723
#
#   countryCode
# 0        None
# 1          CA
# 2          CA
# 3          CA
# 4          CA
# 5          CA
# 6          CA
# 7          CA
# 8          CA
# 9          GB

# %% [markdown]
# Get the record of Tampa. The `woeid` is a unique ID for each place.

# %%
df_city[df_city['name']=='New York']
# Out:
#          name                    placeType  \
# 373  New York  {'code': 7, 'name': 'Town'}
#
#                                              url  parentid        country  \
# 373  http://where.yahooapis.com/v1/place/2459115  23424977  United States
#
#        woeid countryCode
# 373  2459115          US

# %% [markdown]
# Store the `woeid` of Tampa in tampa_id.

# %%
tampa_id = df_city[df_city['name']=='New York']['woeid']
# Out:
# Stream encountered HTTP error: 420
# Stream encountered HTTP error: 420
# Stream encountered HTTP error: 420
# Stream encountered HTTP error: 420
# Stream encountered HTTP error: 420
# Stream encountered HTTP error: 420
# Stream encountered HTTP error: 420

# %% [markdown]
# Return the trends in Tampa.
#
# Note: you need to convert the city_id from a pandas series object into an integer.

# %%
# make Tampa as an example
trends_tampa = api.get_place_trends(int(tampa_id))

# %% [markdown]
# Print the trends in JSON format

# %%
# print the top 20 trends in Tampa
trends_tampa[0:20]
# Out:
# [{'trends': [{'name': 'Luka',
#     'url': 'http://twitter.com/search?q=Luka',
#     'promoted_content': None,
#     'query': 'Luka',
#     'tweet_volume': 26906},
#    {'name': 'Spurs',
#     'url': 'http://twitter.com/search?q=Spurs',
#     'promoted_content': None,
#     'query': 'Spurs',
#     'tweet_volume': 46579},
#    {'name': 'Rodriguez',
#     'url': 'http://twitter.com/search?q=Rodriguez',
#     'promoted_content': None,
#     'query': 'Rodriguez',
#     'tweet_volume': 28338},
#    {'name': 'Panthers',
#     'url': 'http://twitter.com/search?q=Panthers',
#     'promoted_content': None,
#     'query': 'Panthers',
#     'tweet_volume': None},
#    {'name': 'olivia',
#     'url': 'http://twitter.com/search?q=olivia',
#     'promoted_content': None,
#     'query': 'olivia',
#     'tweet_volume': 79940},
#    {'name': 'Padres',
#     'url': 'http://twitter.com/search?q=Padres',
#     'promoted_content': None,
#     'query': 'Padres',
#     'tweet_volume': 57513},
#    {'name': 'Sacramento',
#     'url': 'http://twitter.com/search?q=Sacramento',
#     'promoted_content': None,
#     'query': 'Sacramento',
#     'tweet_volume': 56655},
#    {'name': 'Grammys',
#     'url': 'http://twitter.com/search?q=Grammys',
#     'promoted_content': None,
#     'query': 'Grammys',
#     'tweet_volume': 944887},
#    {'name': 'BTS BTS BTS',
#     'url': 'http://twitter.com/search?q=%22BTS+BTS+BTS%22',
#     'promoted_content': None,
#     'query': '%22BTS+BTS+BTS%22',
#     'tweet_volume': 2145606},
#    {'name': '#RenewOurFlagMeansDeath',
#     'url': 'http://twitter.com/search?q=%23RenewOurFlagMeansDeath',
#     'promoted_content': None,
#     'query': '%23RenewOurFlagMeansDeath',
#     'tweet_volume': None},
#    {'name': 'Russell Wilson',
#     'url': 'http://twitter.com/search?q=%22Russell+Wilson%22',
#     'promoted_content': None,
#     'query': '%22Russell+Wilson%22',
#     'tweet_volume': 15247},
#    {'name': 'Ciara',
#     'url': 'http://twitter.com/search?q=Ciara',
#     'promoted_content': None,
#     'query': 'Ciara',
#     'tweet_volume': 19635},
#    {'name': '#ThingsYouCantSayAnymore',
#     'url': 'http://twitter.com/search?q=%23ThingsYouCantSayAnymore',
#     'promoted_content': None,
#     'query': '%23ThingsYouCantSayAnymore',
#     'tweet_volume': None},
#    {'name': '#atmoscollectorsclub',
#     'url': 'http://twitter.com/search?q=%23atmoscollectorsclub',
#     'promoted_content': None,
#     'query': '%23atmoscollectorsclub',
#     'tweet_volume': None},
#    {'name': 'Titan',
#     'url': 'http://twitter.com/search?q=Titan',
#     'promoted_content': None,
#     'query': 'Titan',
#     'tweet_volume': 89270},
#    {'name': '#COYS',
#     'url': 'http://twitter.com/search?q=%23COYS',
#     'promoted_content': None,
#     'query': '%23COYS',
#     'tweet_volume': None},
#    {'name': 'Sunday Funday',
#     'url': 'http://twitter.com/search?q=%22Sunday+Funday%22',
#     'promoted_content': None,
#     'query': '%22Sunday+Funday%22',
#     'tweet_volume': 14028},
#    {'name': 'Dwight Powell',
#     'url': 'http://twitter.com/search?q=%22Dwight+Powell%22',
#     'promoted_content': None,
#     'query': '%22Dwight+Powell%22',
#     'tweet_volume': None},
#    {'name': 'Bucha',
#     'url': 'http://twitter.com/search?q=Bucha',
#     'promoted_content': None,
#     'query': 'Bucha',
#     'tweet_volume': 948109},
#    {'name': 'Abel',
#     'url': 'http://twitter.com/search?q=Abel',
#     'promoted_content': None,
#     'query': 'Abel',
#     'tweet_volume': 40651},
#    {'name': 'Mickey Moniak',
#     'url': 'http://twitter.com/search?q=%22Mickey+Moniak%22',
#     'promoted_content': None,
#     'query': '%22Mickey+Moniak%22',
#     'tweet_volume': None},
#    {'name': 'Newcastle',
#     'url': 'http://twitter.com/search?q=Newcastle',
#     'promoted_content': None,
#     'query': 'Newcastle',
#     'tweet_volume': 51895},
#    {'name': '#CampingWorldinAmerica',
#     'url': 'http://twitter.com/search?q=%23CampingWorldinAmerica',
#     'promoted_content': None,
#     'query': '%23CampingWorldinAmerica',
#     'tweet_volume': None},
#    {'name': 'Wordle 288 X',
#     'url': 'http://twitter.com/search?q=%22Wordle+288+X%22',
#     'promoted_content': None,
#     'query': '%22Wordle+288+X%22',
#     'tweet_volume': None},
#    {'name': 'Carlos Alcaraz',
#     'url': 'http://twitter.com/search?q=%22Carlos+Alcaraz%22',
#     'promoted_content': None,
#     'query': '%22Carlos+Alcaraz%22',
#     'tweet_volume': 13096},
#    {'name': 'Tottenham',
#     'url': 'http://twitter.com/search?q=Tottenham',
#     'promoted_content': None,
#     'query': 'Tottenham',
#     'tweet_volume': 35681},
#    {'name': 'Letterboxd',
#     'url': 'http://twitter.com/search?q=Letterboxd',
#     'promoted_content': None,
#     'query': 'Letterboxd',
#     'tweet_volume': 17914},
#    {'name': 'The Final Season',
#     'url': 'http://twitter.com/search?q=%22The+Final+Season%22',
#     'promoted_content': None,
#     'query': '%22The+Final+Season%22',
#     'tweet_volume': 88035},
#    {'name': 'Jeremy Peña',
#     'url': 'http://twitter.com/search?q=%22Jeremy+Pe%C3%B1a%22',
#     'promoted_content': None,
#     'query': '%22Jeremy+Pe%C3%B1a%22',
#     'tweet_volume': None},
#    {'name': 'Randy Quaid',
#     'url': 'http://twitter.com/search?q=%22Randy+Quaid%22',
#     'promoted_content': None,
#     'query': '%22Randy+Quaid%22',
#     'tweet_volume': None},
#    {'name': 'Conte',
#     'url': 'http://twitter.com/search?q=Conte',
#     'promoted_content': None,
#     'query': 'Conte',
#     'tweet_volume': 26887},
#    {'name': 'Doherty',
#     'url': 'http://twitter.com/search?q=Doherty',
#     'promoted_content': None,
#     'query': 'Doherty',
#     'tweet_volume': None},
#    {'name': 'Manaea',
#     'url': 'http://twitter.com/search?q=Manaea',
#     'promoted_content': None,
#     'query': 'Manaea',
#     'tweet_volume': None},
#    {'name': 'Bin Laden',
#     'url': 'http://twitter.com/search?q=%22Bin+Laden%22',
#     'promoted_content': None,
#     'query': '%22Bin+Laden%22',
#     'tweet_volume': 33183},
#    {'name': 'Cooks',
#     'url': 'http://twitter.com/search?q=Cooks',
#     'promoted_content': None,
#     'query': 'Cooks',
#     'tweet_volume': None},
#    {'name': 'George Hill',
#     'url': 'http://twitter.com/search?q=%22George+Hill%22',
#     'promoted_content': None,
#     'query': '%22George+Hill%22',
#     'tweet_volume': None},
#    {'name': 'Roy Blunt',
#     'url': 'http://twitter.com/search?q=%22Roy+Blunt%22',
#     'promoted_content': None,
#     'query': '%22Roy+Blunt%22',
#     'tweet_volume': None},
#    {'name': 'Mappa',
#     'url': 'http://twitter.com/search?q=Mappa',
#     'promoted_content': None,
#     'query': 'Mappa',
#     'tweet_volume': 20082},
#    {'name': 'Jaylen Brown',
#     'url': 'http://twitter.com/search?q=%22Jaylen+Brown%22',
#     'promoted_content': None,
#     'query': '%22Jaylen+Brown%22',
#     'tweet_volume': None},
#    {'name': 'Thad Matta',
#     'url': 'http://twitter.com/search?q=%22Thad+Matta%22',
#     'promoted_content': None,
#     'query': '%22Thad+Matta%22',
#     'tweet_volume': None},
#    {'name': 'Frank Gore',
#     'url': 'http://twitter.com/search?q=%22Frank+Gore%22',
#     'promoted_content': None,
#     'query': '%22Frank+Gore%22',
#     'tweet_volume': 11038},
#    {'name': 'Tokarski',
#     'url': 'http://twitter.com/search?q=Tokarski',
#     'promoted_content': None,
#     'query': 'Tokarski',
#     'tweet_volume': None},
#    {'name': 'Ish Smith',
#     'url': 'http://twitter.com/search?q=%22Ish+Smith%22',
#     'promoted_content': None,
#     'query': '%22Ish+Smith%22',
#     'tweet_volume': None},
#    {'name': 'Castro',
#     'url': 'http://twitter.com/search?q=Castro',
#     'promoted_content': None,
#     'query': 'Castro',
#     'tweet_volume': 25956},
#    {'name': 'Ruud',
#     'url': 'http://twitter.com/search?q=Ruud',
#     'promoted_content': None,
#     'query': 'Ruud',
#     'tweet_volume': 12867},
#    {'name': 'Part 3',
#     'url': 'http://twitter.com/search?q=%22Part+3%22',
#     'promoted_content': None,
#     'query': '%22Part+3%22',
#     'tweet_volume': 62116},
#    {'name': 'Lautaro',
#     'url': 'http://twitter.com/search?q=Lautaro',
#     'promoted_content': None,
#     'query': 'Lautaro',
#     'tweet_volume': None},
#    {'name': 'Montas',
#     'url': 'http://twitter.com/search?q=Montas',
#     'promoted_content': None,
#     'query': 'Montas',
#     'tweet_volume': None},
#    {'name': 'Adrian',
#     'url': 'http://twitter.com/search?q=Adrian',
#     'promoted_content': None,
#     'query': 'Adrian',
#     'tweet_volume': 38064},
#    {'name': 'Gabriel',
#     'url': 'http://twitter.com/search?q=Gabriel',
#     'promoted_content': None,
#     'query': 'Gabriel',
#     'tweet_volume': 96166}],
#   'as_of': '2022-04-03T19:19:16Z',
#   'created_at': '2022-04-01T13:46:14Z',
#   'locations': [{'name': 'New York', 'woeid': 2459115}]}]

# %% [markdown]
# Organize the Tampa trends in a dataframe.

# %%
trend_ls = [[trend['name'], trend['url'], trend['tweet_volume']] for trend in trends_tampa[0]['trends']]

df_trends = pd.DataFrame(trend_ls,columns=['name','url','tweet_volume'])

# %% [markdown]
# Sort the trends by tweet volumn in a descending order and print the top 10 trends with the most tweeting volumne.

# %%
# Sort the trends by tweet volumn in a descending order
df_trends.sort_values("tweet_volume", inplace = True, ascending = False)

# Print the top 10 trends ranked by tweet volumne
df_trends.head(10)
# Out:
#                 name                                                url  \
# 8        BTS BTS BTS      http://twitter.com/search?q=%22BTS+BTS+BTS%22
# 18             Bucha                  http://twitter.com/search?q=Bucha
# 7            Grammys                http://twitter.com/search?q=Grammys
# 49           Gabriel                http://twitter.com/search?q=Gabriel
# 14             Titan                  http://twitter.com/search?q=Titan
# 27  The Final Season  http://twitter.com/search?q=%22The+Final+Seaso...
# 4             olivia                 http://twitter.com/search?q=olivia
# 45            Part 3           http://twitter.com/search?q=%22Part+3%22
# 5             Padres                 http://twitter.com/search?q=Padres
# 6         Sacramento             http://twitter.com/search?q=Sacramento
#
#     tweet_volume
# 8      2145606.0
# 18      948109.0
# 7       944887.0
# 49       96166.0
# 14       89270.0
# 27       88035.0
# 4        79940.0
# 45       62116.0
# 5        57513.0
# 6        56655.0

# %% [markdown]
# The table shows the popular topics people are tweeting about in Tampa.

# %% [markdown]
# ### Question 1: Please modify the code above to get the top 20 trending topics in New York City.

# %%
# ......

# %% [markdown]
# ---

# %% [markdown]
# ## 4. Acquiring Tweets using the Search API

# %% [markdown]
# ### 4.1 Search Tweets using Keywords
#
# In this step, you will use Python program to search tweets that contain a specific keyword. "Will Smith" was quite a hot topic when I created the tutorial. Next, I will search for Tweets that contain "Will Smith".

# %%
tweets = api.search_tweets("Will Smith",count=100)

print("Total retweet retrieved: "+ str(len(tweets)))
# Out:
# Total retweet retrieved: 100

# %% [markdown]
# Store the user name, user location, posting time, and tweet text in a Pandas dataframe.

# %%
tweets_pd = pd.DataFrame([[tweet.user.name, tweet.user.location,tweet.created_at, tweet.text] for tweet in tweets], 
                         columns = ['user_name','user_loc','creation_time','text'])

tweets_pd
# Out:
#                    user_name                  user_loc  \
# 0   not from manchester🧍🏻‍♀️       Manchester, England
# 1                        JMC                Galena, IL
# 2   Szymon Brycki 🦊🐾♀️🏳️‍🌈🇪🇺  Jelenia Góra, Poland, EU
# 3                       kris                   he/they
# 4          Hasan Basri Özcan            Aydın, Türkiye
# ..                       ...                       ...
# 95                  Je’nay 🌼
# 96  Oni_Azul (aka Amuro Rei)                      🇺🇲 🗽
# 97                pretty mf.
# 98                Tyler Rose                Texas, USA
# 99           Guardian Eterno                   Galaxia
#
#                creation_time  \
# 0  2022-04-03 19:20:19+00:00
# 1  2022-04-03 19:20:19+00:00
# 2  2022-04-03 19:20:19+00:00
# 3  2022-04-03 19:20:19+00:00
# 4  2022-04-03 19:20:19+00:00
# ..                       ...
# 95 2022-04-03 19:20:00+00:00
# 96 2022-04-03 19:19:59+00:00
# 97 2022-04-03 19:19:59+00:00
# 98 2022-04-03 19:19:59+00:00
# 99 2022-04-03 19:19:59+00:00
#
#                                                  text
# 0   RT @AdrianaInBloom: I know Will Smith slapped ...
# 1   RT @StevieVanZandt: Will Smith needs to thank ...
# 2   RT @MichaelHargrov1: If Will Smith is a bad ro...
# 3   RT @AdrianaInBloom: I know Will Smith slapped ...
# 4                               Larin &gt; Will Smith
# ..                                                ...
# 95  RT @AdrianaInBloom: I know Will Smith slapped ...
# 96  RT @are0h: Notice how all the folks who were ‘...
# 97  RT @AdrianaInBloom: I know Will Smith slapped ...
# 98  RT @edckbar: Hollywood silently trying to blac...
# 99  RT @RadioPirataOP: ¡Ya está disponible el podc...
#
# [100 rows x 4 columns]

# %% [markdown]
# The `search_tweets` funciton can retrieve max 100 tweets at one time. If you want to get more tweets, you can use the `cursor`.
#
# The following code use cursor to retrieve more tweets containing a keyword. Here we still retrieve 100 tweets to save your search quota for the following steps. You could increase the `num` variable if you want to get more tweets.
#
# > Note: Twitter only allows you to retrieve a limited number of tweets per 15 minutes. If the retrieved tweets exceed the limit, the program will pause for a certain amount time. If you can't wait, you can doublepress `i` on your keyboard to interrupt the process.

# %%
# Number of tweets to be retrieved.
num = 100

# define the search keyword
keyword = "Will Smith"

# use cursor to send your request with parameters
tweets = tweepy.Cursor(api.search_tweets,
                   q = keyword,
                   count = num,
                   lang="en").items(num)

# restore the results as a list
tweet_ls = [[tweet.user.name, tweet.user.location,tweet.created_at, tweet.text] for tweet in tweets]

# Store the retrieved tweets in a dataframe
tweets_pd_full = pd.DataFrame(tweet_ls, 
                         columns = ['user_name','user_loc','creation_time','text'])

# Print the dataframe
tweets_pd_full
# Out:
#                 user_name                    user_loc  \
# 0   c i c i • c a n e l a
# 1                       👑  Johannesburg, South Africa
# 2               um……..yea         North Carolina, USA
# 3           Isabella Hope         North Carolina, USA
# 4                    Saki
# ..                    ...                         ...
# 95              Wuan Wuan                 Mankato, MN
# 96                     ☁️                      France
# 97              christian
# 98               Maddnezz
# 99                 Dxvo🖤🥀            Toronto, Ontario
#
#                creation_time  \
# 0  2022-04-03 19:21:41+00:00
# 1  2022-04-03 19:21:41+00:00
# 2  2022-04-03 19:21:41+00:00
# 3  2022-04-03 19:21:40+00:00
# 4  2022-04-03 19:21:40+00:00
# ..                       ...
# 95 2022-04-03 19:21:12+00:00
# 96 2022-04-03 19:21:12+00:00
# 97 2022-04-03 19:21:12+00:00
# 98 2022-04-03 19:21:11+00:00
# 99 2022-04-03 19:21:09+00:00
#
#                                                  text
# 0   RT @Ormaga: I googled Will Smith’s net worth. ...
# 1   RT @AdrianaInBloom: I know Will Smith slapped ...
# 2   RT @Ormaga: I googled Will Smith’s net worth. ...
# 3   RT @AdrianaInBloom: I know Will Smith slapped ...
# 4   RT @AdrianaInBloom: I know Will Smith slapped ...
# ..                                                ...
# 95  RT @Ormaga: I googled Will Smith’s net worth. ...
# 96  RT @AdrianaInBloom: I know Will Smith slapped ...
# 97  Okay so it’s the Grammys can we see Lady Gaga ...
# 98  RT @frankieA_99: How exactly did Will Smith sl...
# 99  RT @MrSkinnyGenes: If Will Smith hadn’t slappe...
#
# [100 rows x 4 columns]

# %% [markdown]
# ### 4.2 Removing Retweets
# The retrieved tweets include original tweets and retweets. The textual content of retweets are almost identical. You can set up a filter to eliminate the retweets and keep only the original tweets.

# %%
new_keyword = "Will Smith" + " -filter:retweets"
new_keyword
# Out:
# 'Will Smith -filter:retweets'

# %% [markdown]
# Now, you can see only original tweets are retrieved.

# %% [markdown]
# Print to see the list.

# %%
# Number of tweets to be retrieved.
num = 100

# use cursor to send your request with parameters
tweets = tweepy.Cursor(api.search_tweets,
                   q = new_keyword,
                   count = num,
                   lang="en").items(num)

# restore the results as a list
tweet_ls = [[tweet.user.name, tweet.user.location,tweet.created_at, tweet.text] for tweet in tweets]

# Store the retrieved tweets in a dataframe
tweets_pd_full = pd.DataFrame(tweet_ls, 
                         columns = ['user_name','user_loc','creation_time','text'])

# Print the dataframe
tweets_pd_full
# Out:
#                   user_name                      user_loc  \
# 0                Asim Buday           Melbourne, Victoria
# 1          MORINGA MANSA 🇯🇲              Toronto, Ontario
# 2               Ramazan Çam
# 3                         4                 Salisbury, NC
# 4                G, Esq. ⚖️
# ..                      ...                           ...
# 95  SteffenBennett 🤬 🇲🇽🇩🇰🇬🇷               Portland Oregon
# 96                     Emre  astral seyahatte değilsem 34
# 97                  𝐋𝐎𝐒𝐓𝐁𝐎𝐘                   Windsor, CA
# 98              Juan Eibrow                Western Canada
# 99          You-Tube Videos                        Canada
#
#                creation_time  \
# 0  2022-04-03 19:21:58+00:00
# 1  2022-04-03 19:21:57+00:00
# 2  2022-04-03 19:21:50+00:00
# 3  2022-04-03 19:21:45+00:00
# 4  2022-04-03 19:21:44+00:00
# ..                       ...
# 95 2022-04-03 19:18:22+00:00
# 96 2022-04-03 19:18:21+00:00
# 97 2022-04-03 19:18:18+00:00
# 98 2022-04-03 19:18:13+00:00
# 99 2022-04-03 19:18:09+00:00
#
#                                                  text
# 0                       Larin “Will Smith” Larin #BJK
# 1   Bro if you still saying Will Smith is wrong I ...
# 2                  @HalilSoyletmez Larin will Smith 😀
# 3   Will Smith blackballed himself. He gone bounce...
# 4   Maybe it’s me, but these people are dragging t...
# ..                                                ...
# 95  The amount of hyped publicity surrounding the ...
# 96  CYLE WILL SMITH LARIN AMK https://t.co/onWOdvY5ZP
# 97         Fuck Will Smith, he’s a little cuck bitch.
# 98  @hultmark_mark Only if Will "Slappy" Smith is ...
# 99  Why Actor Paul Rodriguez Won’t Ever Again Work...
#
# [100 rows x 4 columns]

# %% [markdown]
# ### 4.3 Search Tweets using locations

# %% [markdown]
# Query for a popular trend keyword in Tampa (200 miles range).
#
# First, let's check what are the top 10 trending topics in the selected city (Tampa).

# %% [markdown]
# The following code may take a few minutes to run to collect the tweets, depending on the number of tweets.

# %%
# Number of tweets to be retrieved.
num = 200

# define the search keyword
keyword = "Will Smith"

# use cursor to send your request with parameters
tweets = tweepy.Cursor(api.search_tweets,
                   q=keyword,
                   geocode = "28.0619,-82.4146,20mi",
                   count = num,
                   lang="en").items(num)

# restore the results as a list
tweet_ls = [[tweet.user.name, tweet.user.location, tweet.place, tweet.created_at, tweet.text] for tweet in tweets]

# Store the retrieved tweets in a dataframe
tweets_pd_geo = pd.DataFrame(tweet_ls, 
                         columns = ['user_name','user_loc','geotag','creation_time','text'])

# Print the dataframe
tweets_pd_geo
# Out:
#                      user_name        user_loc  \
# 0                    WFLA NEWS       Tampa, FL
# 1                Aaron Rolston       Tampa, FL
# 2    Catherine Durkin Robinson       Tampa, FL
# 3                 clark brooks  Tampa, Florida
# 4                 Kaleb Rupe⭕️       Tampa, FL
# ..                         ...             ...
# 195              Brian Roberts       Tampa, FL
# 196                      Caleb       Tampa, FL
# 197         Foxman (Brian Fox)       Tampa, FL
# 198              Hunter Wilder       Tampa, FL
# 199             Carine Oupelle       Tampa, FL
#
#                                                 geotag  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3    Place(_api=<tweepy.api.API object at 0x0000026...
# 4                                                 None
# ..                                                 ...
# 195                                               None
# 196                                               None
# 197                                               None
# 198                                               None
# 199                                               None
#
#                 creation_time  \
# 0   2022-04-03 18:41:00+00:00
# 1   2022-04-03 18:39:19+00:00
# 2   2022-04-03 18:29:06+00:00
# 3   2022-04-03 18:19:18+00:00
# 4   2022-04-03 17:33:09+00:00
# ..                        ...
# 195 2022-04-01 02:45:34+00:00
# 196 2022-04-01 02:26:39+00:00
# 197 2022-04-01 02:11:59+00:00
# 198 2022-04-01 02:03:22+00:00
# 199 2022-04-01 01:35:21+00:00
#
#                                                   text
# 0    Chris Rock's brother slams Will Smith for Osca...
# 1    Guarantee there's a huge portion of the US pop...
# 2    Never thought I'd live to see the day when Sno...
# 3    “Will Smith needs therapy”\n“Kanye needs thera...
# 4    @__TheGale__ Not going to lie. I’m against pul...
# ..                                                 ...
# 195  #CancelWillSmith\nDoes anybody have a list of ...
# 196  Jada Smith's Narcissistic Influence Over Will ...
# 197  #ChrisRock insisted he did not want to press c...
# 198  @Le202nard Ted Cruz is just as irresponsible a...
# 199  I need will smith to slap the shit out of me r...
#
# [200 rows x 5 columns]

# %% [markdown]
# Check how many tweets have geotags.

# %%
all = len(tweets_pd_geo[tweets_pd_geo['geotag'].notna()]) # all retrieved tweets
geo = len(tweets_pd_geo) # tweets that actually have geotags.

print("%s out of the %s retrieved tweets actually have geotags" % (all, geo))
# Out:
# 15 out of the 200 retrieved tweets actually have geotags

# %% [markdown]
# #### Copy tweets with geotags to a new dataframe called "geotags"

# %%
geo_tweets = tweets_pd_geo.loc[tweets_pd_geo['geotag'].notna()].copy()
# Out:
# Stream encountered HTTP error: 420
# Stream encountered HTTP error: 420

# %% [markdown]
# #### get their place and view where first 5 tweets are from

# %%
# extract place name from the geotags
geo_tweets['place_name'] = geo_tweets.geotag.apply(lambda s:s.name)

# Print updated geo_tweets
geo_tweets
# Out:
#                 user_name             user_loc  \
# 3            clark brooks       Tampa, Florida
# 16       Gigi Chrysostomo         Florida, USA
# 20          Go With Goley    St Petersburg, FL
# 34   Tampa Movie Guy 🇺🇸✝️            Tampa, FL
# 38                 Todd B            Largo, FL
# 75                chris✌🏼            Tampa, FL
# 77                  spwog       Clearwater, FL
# 92       Gigi Chrysostomo         Florida, USA
# 105      Gigi Chrysostomo         Florida, USA
# 111       🍢🍢FSUspineDOC🍢🍢    Nolecity Florida
# 120                   444         Florida, USA
# 121      Gigi Chrysostomo         Florida, USA
# 132                  Doug             the burg
# 156             Samuel KW  NEW PORT RICHEY, FL
# 163                Debbie            Tampa, FL
#
#                                                 geotag  \
# 3    Place(_api=<tweepy.api.API object at 0x0000026...
# 16   Place(_api=<tweepy.api.API object at 0x0000026...
# 20   Place(_api=<tweepy.api.API object at 0x0000026...
# 34   Place(_api=<tweepy.api.API object at 0x0000026...
# 38   Place(_api=<tweepy.api.API object at 0x0000026...
# 75   Place(_api=<tweepy.api.API object at 0x0000026...
# 77   Place(_api=<tweepy.api.API object at 0x0000026...
# 92   Place(_api=<tweepy.api.API object at 0x0000026...
# 105  Place(_api=<tweepy.api.API object at 0x0000026...
# 111  Place(_api=<tweepy.api.API object at 0x0000026...
# 120  Place(_api=<tweepy.api.API object at 0x0000026...
# 121  Place(_api=<tweepy.api.API object at 0x0000026...
# 132  Place(_api=<tweepy.api.API object at 0x0000026...
# 156  Place(_api=<tweepy.api.API object at 0x0000026...
# 163  Place(_api=<tweepy.api.API object at 0x0000026...
#
#                 creation_time  \
# 3   2022-04-03 18:19:18+00:00
# 16  2022-04-03 13:36:33+00:00
# 20  2022-04-03 06:50:41+00:00
# 34  2022-04-03 02:47:18+00:00
# 38  2022-04-02 23:33:13+00:00
# 75  2022-04-02 13:57:51+00:00
# 77  2022-04-02 13:43:11+00:00
# 92  2022-04-02 11:41:55+00:00
# 105 2022-04-02 02:51:09+00:00
# 111 2022-04-02 01:51:46+00:00
# 120 2022-04-02 00:38:19+00:00
# 121 2022-04-02 00:35:32+00:00
# 132 2022-04-01 23:38:47+00:00
# 156 2022-04-01 19:51:52+00:00
# 163 2022-04-01 18:11:32+00:00
#
#                                                   text       place_name
# 3    “Will Smith needs therapy”\n“Kanye needs thera...            Tampa
# 16   @chillsqueezly @StevieVanZandt I’m a HUGE fan ...    Seven Springs
# 20   4 guys thought my joke about another guy havin...    Safety Harbor
# 34   Currently watching Will Smith in King Richard....   Lake Magdalene
# 38   WILL SMITH NEVER FORGOT: CHRIS ROCK vs WILL SM...            Largo
# 75   what do you want will smith to do about that l...            Tampa
# 77   @MikeRinder @johnsweeneyroar Seems like Will S...       Clearwater
# 92   @Moonla63916228 @samia96380671 @ScottyDoesStat...    Seven Springs
# 105  @CheriJacobus Also breaking, more people dying...    Seven Springs
# 111  If a guy like this can become a cuck \n\nSocie...        Westchase
# 120  Will Smith Slapped the black out of Chris Rock...            Tampa
# 121  @McKechnieE @EventuallyTruth @CheriJacobus If ...    Seven Springs
# 132            LOVE the Will Smith music after a fight            Tampa
# 156  #DBL  What's going to happen are  people will ...  New Port Richey
# 163  @DanLinden @GMA @tjholmes Just like anywhere e...            Tampa

# %% [markdown]
# Check detailed information in the geotag. The location of the geotag is in a bounding box defined by the four coordinate pairs.

# %%
geo_tweets.iloc[0].geotag
# Out:
# Place(_api=<tweepy.api.API object at 0x0000026D3C0776D0>, id='dc62519fda13b4ec', url='https://api.twitter.com/1.1/geo/id/dc62519fda13b4ec.json', place_type='city', name='Tampa', full_name='Tampa, FL', country_code='US', country='United States', contained_within=[], bounding_box=BoundingBox(_api=<tweepy.api.API object at 0x0000026D3C0776D0>, type='Polygon', coordinates=[[[-82.620093, 27.821353], [-82.2652945, 27.821353], [-82.2652945, 28.171836], [-82.620093, 28.171836]]]), attributes={})

# %% [markdown]
# Get coordinates of the bounding box

# %%
geo_tweets.iloc[0].geotag.bounding_box.coordinates[0]
# Out:
# [[-82.620093, 27.821353],
#  [-82.2652945, 27.821353],
#  [-82.2652945, 28.171836],
#  [-82.620093, 28.171836]]

# %% [markdown]
# Create a column in the dataframe to store coordinates of the bounding boxes

# %%
# store bounding box coordinates to a new column
geo_tweets['bounding_box'] = geo_tweets.geotag.apply(lambda s:s.bounding_box.coordinates[0])

# print the geotag
geo_tweets.head()
# Out:
#                user_name           user_loc  \
# 3           clark brooks     Tampa, Florida
# 16      Gigi Chrysostomo       Florida, USA
# 20         Go With Goley  St Petersburg, FL
# 34  Tampa Movie Guy 🇺🇸✝️          Tampa, FL
# 38                Todd B          Largo, FL
#
#                                                geotag  \
# 3   Place(_api=<tweepy.api.API object at 0x0000026...
# 16  Place(_api=<tweepy.api.API object at 0x0000026...
# 20  Place(_api=<tweepy.api.API object at 0x0000026...
# 34  Place(_api=<tweepy.api.API object at 0x0000026...
# 38  Place(_api=<tweepy.api.API object at 0x0000026...
#
#                creation_time  \
# 3  2022-04-03 18:19:18+00:00
# 16 2022-04-03 13:36:33+00:00
# 20 2022-04-03 06:50:41+00:00
# 34 2022-04-03 02:47:18+00:00
# 38 2022-04-02 23:33:13+00:00
#
#                                                  text      place_name  \
# 3   “Will Smith needs therapy”\n“Kanye needs thera...           Tampa
# 16  @chillsqueezly @StevieVanZandt I’m a HUGE fan ...   Seven Springs
# 20  4 guys thought my joke about another guy havin...   Safety Harbor
# 34  Currently watching Will Smith in King Richard....  Lake Magdalene
# 38  WILL SMITH NEVER FORGOT: CHRIS ROCK vs WILL SM...           Largo
#
#                                          bounding_box
# 3   [[-82.620093, 27.821353], [-82.2652945, 27.821...
# 16  [[-82.699083, 28.179615], [-82.627204, 28.1796...
# 20  [[-82.712772, 27.977811], [-82.675347, 27.9778...
# 34  [[-82.506967, 28.054599], [-82.452059, 28.0545...
# 38  [[-82.849182, 27.865251], [-82.696478, 27.8652...

# %% [markdown]
# We will use the centroids of the bounding boxes to map the tweets. The following code calculate the lat, lon of centroids and store them in two new columns.

# %%
geo_tweets['point']  = geo_tweets['bounding_box'].apply(lambda s: [(s[0][1]+s[2][1])/2,(s[0][0]+s[2][0])/2])

geo_tweets['lat']  = geo_tweets['bounding_box'].apply(lambda s: (s[0][1]+s[2][1])/2)

geo_tweets['lon']  = geo_tweets['bounding_box'].apply(lambda s: (s[0][0]+s[2][0])/2)

# %% [markdown]
# Print to see the dataframe again.
#
# You'll see the centroids, latitude, and longitude are added as columns in the dataframe.
#
# Note: the point column is an redundancy of the lat and lon columns. We create all these columns just for demonstration of mapping in the next step.

# %%
geo_tweets.head()
# Out:
#                user_name           user_loc  \
# 3           clark brooks     Tampa, Florida
# 16      Gigi Chrysostomo       Florida, USA
# 20         Go With Goley  St Petersburg, FL
# 34  Tampa Movie Guy 🇺🇸✝️          Tampa, FL
# 38                Todd B          Largo, FL
#
#                                                geotag  \
# 3   Place(_api=<tweepy.api.API object at 0x0000026...
# 16  Place(_api=<tweepy.api.API object at 0x0000026...
# 20  Place(_api=<tweepy.api.API object at 0x0000026...
# 34  Place(_api=<tweepy.api.API object at 0x0000026...
# 38  Place(_api=<tweepy.api.API object at 0x0000026...
#
#                creation_time  \
# 3  2022-04-03 18:19:18+00:00
# 16 2022-04-03 13:36:33+00:00
# 20 2022-04-03 06:50:41+00:00
# 34 2022-04-03 02:47:18+00:00
# 38 2022-04-02 23:33:13+00:00
#
#                                                  text      place_name  \
# 3   “Will Smith needs therapy”\n“Kanye needs thera...           Tampa
# 16  @chillsqueezly @StevieVanZandt I’m a HUGE fan ...   Seven Springs
# 20  4 guys thought my joke about another guy havin...   Safety Harbor
# 34  Currently watching Will Smith in King Richard....  Lake Magdalene
# 38  WILL SMITH NEVER FORGOT: CHRIS ROCK vs WILL SM...           Largo
#
#                                          bounding_box  \
# 3   [[-82.620093, 27.821353], [-82.2652945, 27.821...
# 16  [[-82.699083, 28.179615], [-82.627204, 28.1796...
# 20  [[-82.712772, 27.977811], [-82.675347, 27.9778...
# 34  [[-82.506967, 28.054599], [-82.452059, 28.0545...
# 38  [[-82.849182, 27.865251], [-82.696478, 27.8652...
#
#                                        point        lat        lon
# 3           [27.9965945, -82.44269374999999]  27.996595 -82.442694
# 16                 [28.2182495, -82.6631435]  28.218249 -82.663144
# 20  [28.013468500000002, -82.69405950000001]  28.013469 -82.694060
# 34                 [28.08767485, -82.479513]  28.087675 -82.479513
# 38                    [27.904263, -82.77283]  27.904263 -82.772830

# %% [markdown]
# ---

# %% [markdown]
# ## 5. Mapping Geotagged Tweets

# %% [markdown]
# Finally, we will use folium to create an interactive map for the geotagged tweets.

# %%
# Create a base map
maptweet = folium.Map()

# Add the tweets into the basemap
for i, row in geo_tweets.iterrows():
    folium.Marker(row.point,popup = row.text).add_to(maptweet)
    
# Zoom to the bounding box including the tweets
maptweet.fit_bounds([[min(geo_tweets.lat),min(geo_tweets.lon)],[max(geo_tweets.lat),max(geo_tweets.lon)]])

# Show the map
display(maptweet)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_44bc145addd148cfa204ad0c1a0263cb%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_44bc145addd148cfa204ad0c1a0263cb%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_44bc145addd148cfa204ad0c1a0263cb%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_44bc145addd148cfa204ad0c1a0263cb%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B0%2C%200%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs%3A%2 ...
# Stream encountered HTTP error: 420
# Stream encountered HTTP error: 420
# Stream encountered HTTP error: 420

# %% [markdown]
# ## 6. Streaming with Tweepy
#
# Unlike the Search API, the Streaming API utilizes Twitter's HTTP protocol to deliver data through an open, streaming API connection. A single streaming connection is opened between your app and the API, with new results being sent through that connection whenever new matches occur. This results in a low-latency delivery mechanism that can support very high throughput. For further information, see https://developer.twitter.com/en/docs/tutorials/consuming-streaming-data.
#
# Depending on the filter (the speed of retrieval), the streaming API is also subject to a limit per 15 minutes. If the retrieved tweets exceed the limit, your program will pause for the next 15 minutes cycle.
#
# Run the following code to start streaming. The text messages are printed. You can double press `I` to interrupt the streaming.

# %%
stream = tweepy.Stream(API_key, API_key_secret, access_token, access_token_secret)

stream.filter(track=["Putin"], threaded=True)

class stream_csv(tweepy.Stream):
    def on_status(self, status):
        print([status.user.name, status.user.created_at, status.place, status.text, status.user.location])


printer = stream_csv(API_key, API_key_secret, access_token, access_token_secret)
printer.sample()
# Out:
# ['Fanny 🖤🍊', datetime.datetime(2010, 12, 29, 20, 41, 38, tzinfo=datetime.timezone.utc), None, 'Aparte no sé que onda, hoy se siente un aire muy diferente xd', 'México']
# ['ريحانة', datetime.datetime(2022, 2, 9, 23, 12, 40, tzinfo=datetime.timezone.utc), None, 'سامي الجعوني - \nفريق الفـرات-\n-\n\nفريق الفـرات\n-\n\nفريق الفـرات\n-\n\nفريق الفـرات\n\n #الميركه82\n.', None]
# ['ふぇー@道・ROAD・道路', datetime.datetime(2010, 7, 13, 16, 42, 26, tzinfo=datetime.timezone.utc), None, 'おはようございます。\n5:00に起床しました。', '日本']
# ['Dejan', datetime.datetime(2015, 12, 27, 4, 3, 19, tzinfo=datetime.timezone.utc), None, 'Gooaaallllll Pedri', None]
# ['~``Sadık``~', datetime.datetime(2021, 8, 25, 17, 18, 18, tzinfo=datetime.timezone.utc), None, '@Kubraayim balıkkkk', None]
# ['🎼Cholly_M티oDy III🎼', datetime.datetime(2014, 9, 2, 3, 53, 52, tzinfo=datetime.timezone.utc), None, 'RT @prachatai: พี่สาววันเฉลิม จะเข้ายื่นหนังสือผู้แทน UN ในวาระการเปิดรอบทบทวนสถานการณ์ครั้งที่ 22 การบังคับบุคคลให้สูญหายในกัมพูชา 4 เม.ย.…', None]
# ['Axisia', datetime.datetime(2022, 1, 19, 7, 51, 25, tzinfo=datetime.timezone.utc), None, 'RT @erdMoonMission: To celebrate our upcoming Pre-sale @DragonsArena_io has prepared a giveaway for you! \n\nPrizes:\n- 1 Dragons Arena EGG\n-…', None]
# ['Isaac 🐺', datetime.datetime(2010, 5, 28, 21, 43, 46, tzinfo=datetime.timezone.utc), None, 'PEEEEEEEEEEEEEEEEEEEEDRIIIIIIIIIIIIIIIII DIOS MIO DE MI PUTISIMA VIDA', 'Huelva / España']
# ['Robvprime🌊🌱', datetime.datetime(2014, 6, 30, 3, 35, 21, tzinfo=datetime.timezone.utc), None, 'RT @scipionow: @AdamParkhomenko You may be right, but, he forgets about what is now being discovered about his genocide and Ukrainians may…', None]
# ['palomito', datetime.datetime(2018, 4, 2, 20, 10, 45, tzinfo=datetime.timezone.utc), None, 'RT @p4rtygmewetter: i love funny people ( me lol )', None]
# ['Rozha', datetime.datetime(2022, 2, 7, 12, 38, 27, tzinfo=datetime.timezone.utc), None, 'RT @CryptoBergenhus: LFG #MarvinInu $Marvin #1000xGem \n\nAre you still sleeping on @Marvin_Inu ?\n\nGo Get a bag we are just starting, this wi…', None]
# ['kv.｡.:*♡', datetime.datetime(2019, 5, 25, 11, 6, 49, tzinfo=datetime.timezone.utc), None, 'RT @lcheeryart: jungkook https://t.co/wYIbdHjIxs', '🇯🇵']
# ['Sad Vols Fan', datetime.datetime(2014, 3, 26, 15, 21, 59, tzinfo=datetime.timezone.utc), None, 'RT @wackovol: BROOMS OUT', None]
# ['daryl', datetime.datetime(2015, 6, 17, 7, 58, tzinfo=datetime.timezone.utc), None, 'PEDRI IS A FKIN BALLER', 'Singapore']
# ['nn2347288@gmail.com', datetime.datetime(2018, 12, 14, 5, 30, 46, tzinfo=datetime.timezone.utc), None, 'RT @RvV2JTOylC5Z271: “LOOKSEE内裤”（内裤由“LOOKSEE内裤”品牌赞助)，舒服度较高，适合健身运动穿着 https://t.co/HCn4dBR065', 'Garden Grove, CA']
# ['The Cultural Hall', datetime.datetime(2009, 5, 6, 15, 44, 19, tzinfo=datetime.timezone.utc), None, '@computx I was disappointed his middle name, Ayodeji, didn’t have a U in it.', 'On the back row.']
# ['The Stepn Cat 🇨🇵', datetime.datetime(2022, 4, 2, 8, 7, 44, tzinfo=datetime.timezone.utc), None, 'RT @ClubSTEPNFrance: ⚡️RECAP AMA 02/04⚡️\n\nAu sommaire : \n-Stats de Stepn\n-Ce qui est prévu pour Avril\n-Infos générales\n-GMT', 'Val-de-Marne, Ile-de-France']
# ['🇮🇨Lolita_Pluma🇮🇨', datetime.datetime(2015, 3, 1, 23, 24, 17, tzinfo=datetime.timezone.utc), None, 'VISCA TEGUESTE', 'Awime']
# ['じんけい', datetime.datetime(2010, 2, 1, 15, 59, 42, tzinfo=datetime.timezone.utc), None, '@6808sanacoco おはようございます☀️\nいい写真😉👍️\n花粉。昨日も結構来てたけど今日もキツいでしょうね😅\nしっかり対策して月曜日始めましょ🎵\n今週もヨロシクお願いします😃', None]
# ['valentine', datetime.datetime(2011, 5, 1, 12, 33, 30, tzinfo=datetime.timezone.utc), None, 'Hier après midi je me suis cassé la figure dans les escaliers je me suis éraflé le coude j’ai trop mal', None]
# ['GEORGE', datetime.datetime(2020, 5, 12, 10, 29, 36, tzinfo=datetime.timezone.utc), None, '@crazynairobean @Realge0rge', None]
# ['Lion Glass', datetime.datetime(2021, 2, 9, 18, 29, 30, tzinfo=datetime.timezone.utc), None, '@The__1958 👍🏽👍🏽👍🏽👍🏽👍🏽👍🏽', None]
# ['Romy', datetime.datetime(2012, 4, 8, 17, 39, 31, tzinfo=datetime.timezone.utc), None, '@JusteTara Ik zweer, ga “Hotel Romy” op me hoofd hangen', 'Antwerpen, België']
# ['val ⱽ 방탄소년단 💜', datetime.datetime(2018, 5, 12, 18, 22, 27, tzinfo=datetime.timezone.utc), None, 'RT @spaceforv: grammy taehyung https://t.co/7e1pal7lgk', 'army ot7']
# ['babel愛', datetime.datetime(2019, 12, 15, 0, 43, 55, tzinfo=datetime.timezone.utc), None, 'RT @picsnjr: https://t.co/AfwSl3FQvn', 'Blumenau, Brasil']
# ['ine know 🇧🇸', datetime.datetime(2009, 2, 7, 17, 2, 35, tzinfo=datetime.timezone.utc), None, 'Pedriiiiiii', 'Grand Bahama']
# ['piyan', datetime.datetime(2019, 9, 9, 15, 27, 59, tzinfo=datetime.timezone.utc), None, '@eaoni ooo maap nanya muluu', 'Buddy']
# ['🧲THEJUICESQUARTER💡', datetime.datetime(2022, 2, 24, 10, 20, 37, tzinfo=datetime.timezone.utc), None, 'RT @PIMPNAMEWILLEY2: RT &amp; FWM💡\n\nMy 2 Thick Long Dick Homies Slutted Me Out Am &amp; PM.. \nMy GUSHY CREAMY BOI PUSSY❗️\n\nYo 😈 Guess How Many Warm…', None]
# ["Johnny 'Flyboy' Verosko", datetime.datetime(2018, 10, 18, 20, 13, 24, tzinfo=datetime.timezone.utc), None, '@DisneyDude_71 Kungaloosh!', 'Gainesville, FL']
# ['ی آدم معمولی', datetime.datetime(2019, 5, 7, 9, 28, 49, tzinfo=datetime.timezone.utc), None, '@M_3NR کم سعادتی داداش 😂', 'مشهد ']
# ['ynsemre1907', datetime.datetime(2022, 3, 17, 17, 9, 40, tzinfo=datetime.timezone.utc), None, "RT @Farogiardino1: Oysa 3 Temmuz'un Isparta suikastinden, aselsan cinayetlerinden, Balyoz'dan, Ergenekon'dan hiçbir farkı yok. Hepsi bir am…", 'İstanbul, Türkiye']
# ['Osman Demir', datetime.datetime(2022, 3, 19, 6, 43, tzinfo=datetime.timezone.utc), None, 'RT @AmalRam85275866: Daha #çorlu Onunla onun Çok https://t.co/iK69SQ7AlE', None]
# ['je', datetime.datetime(2021, 9, 19, 14, 41, 26, tzinfo=datetime.timezone.utc), None, '@namxxkento IYA KAN LNGSUNG BILANG I LIKE YOU SUSAH AMAT', 'she/her']
# ['Ashlea', datetime.datetime(2012, 2, 9, 13, 29, 59, tzinfo=datetime.timezone.utc), None, '@cmenke1 @MattGlantz I hope not. DeSantis 2024', 'Nevada, USA']
# ['Geo Tools to help you plan & travel - Distantias', datetime.datetime(2014, 5, 31, 7, 11, 7, tzinfo=datetime.timezone.utc), None, 'Towns within 30 miles (48.27 km) of Jackson #Jackson #UnitedStates #Michigan   https://t.co/bvjSPnwfyG', 'Everywhere']
# ['JoyRukanza', datetime.datetime(2019, 10, 2, 18, 13, 17, tzinfo=datetime.timezone.utc), None, 'RT @Yao_duchess: Dark-skinned huns worldwide😚 https://t.co/vr6OzBa8BT', 'Bulawayo, Zimbabwe']
# ['𝑺𝒂𝒉𝒃 ¹³ | 𝖩𝖨𝖬𝖨𝖭 𝖮𝖲𝖳 𝖢𝖮𝖬𝖨𝖭𝖦', datetime.datetime(2021, 5, 20, 6, 0, 18, tzinfo=datetime.timezone.utc), None, 'RT @levijjk: Y si hacen  una combinación de ON y Butter ? Los gringos se caen de cul0', '•-----» 𝘚𝘦𝘳𝘦𝘯𝘥𝘪𝘱𝘪𝘵𝘺']
# ['Rahmi Ayas', datetime.datetime(2020, 9, 25, 18, 20, 37, tzinfo=datetime.timezone.utc), None, 'RT @fulden_guney: "Hepiniz birer Türk Bayrağısınız; Lekelemeyin, kirletmeyin, yere düşürmeyin."\nBüyük insan Başbuğu saygı ve rahmetle anıyo…', 'Elazığ, Türkiye']
# ['the curly one', datetime.datetime(2020, 7, 7, 11, 0, 46, tzinfo=datetime.timezone.utc), None, 'RT @funkjhs: a gente precisa desvincular urgentemente a bandeira do Brasil, blusa do Brasil e emoji do Brasil como algo que representa o bo…', None]
# ['المتمـــــيز 2', datetime.datetime(2011, 8, 23, 4, 24, 5, tzinfo=datetime.timezone.utc), None, 'RT @e4i24: فعاليه سريعه   100ريال 💰\n\nتابع @BrkatAlzubidi \n\nالسحب من  الرتويت الكتروني     📽', 'المملكه العربيه السعوديه ']
# ['ELA 🤍', datetime.datetime(2018, 12, 27, 23, 27, 29, tzinfo=datetime.timezone.utc), None, '@luvchmn Ojalá pero españita dice: No 🥺', 'Chimon']
# ['JustMe', datetime.datetime(2021, 5, 13, 14, 9, 50, tzinfo=datetime.timezone.utc), None, "No Doni. It/He is a fuqqin' joke!", 'Here, There & Everywhere']
# ['yahia', datetime.datetime(2021, 12, 6, 14, 4, 4, tzinfo=datetime.timezone.utc), None, 'RT @hhradi: فليحفَظ الله وجهًا ما نَظَرتُ له\nإلا وأشرقَ في أنفاسِي الأمَل.', None]
# ['はっかうさぎ@bot', datetime.datetime(2010, 1, 3, 5, 50, 31, tzinfo=datetime.timezone.utc), None, '@peacock3530 おはようございます♪ 今日は4/4(Mon)、いま5:33です～今日も1日がんばるぞいっ！', '弁当箱の中']
# ['Cristiano Antonino', datetime.datetime(2012, 5, 19, 10, 1, 52, tzinfo=datetime.timezone.utc), None, 'RT @emerglive: Drugs For Slimming: What They Are And What To Know\nhttps://t.co/UIZtcg3tNX', 'Parma']
# ['Todd M Sholtis 🇺🇸🇺🇦', datetime.datetime(2010, 4, 4, 18, 46, 10, tzinfo=datetime.timezone.utc), None, 'RT @RonFilipkowski: You have to watch what you eat while pillaging. https://t.co/TTDOqXoDgw', 'Cape Coral, FL']
# ['Becky •vendo pack e chamada de vídeo•', datetime.datetime(2022, 2, 14, 22, 19, 45, tzinfo=datetime.timezone.utc), None, 'Comprei minha marconha', 'Curitiba, Brasil']
# ['Elmer Quintan', datetime.datetime(2019, 6, 8, 20, 55, 26, tzinfo=datetime.timezone.utc), None, 'Golazooo de Pedri!!', 'Los Angeles, CA']
# ['✨', datetime.datetime(2020, 3, 23, 19, 34, 12, tzinfo=datetime.timezone.utc), None, 'Sim kkkkkk', 'Paris, France']
# ["De'Andre Andrews", datetime.datetime(2010, 9, 22, 1, 12, 52, tzinfo=datetime.timezone.utc), None, 'RT @BillsMafiaBabes: MVP in our hearts.', None]
# ['Shelly', datetime.datetime(2021, 8, 23, 13, 14, 57, tzinfo=datetime.timezone.utc), None, 'sıcak #sanalshow #ſanalſex sohbet https://t.co/miuQ3Ej3Tg', None]
# ['Waleria Jones', datetime.datetime(2020, 4, 1, 18, 5, 21, tzinfo=datetime.timezone.utc), None, 'RT @trinityimani_: over by lucky daye has me in the strongest chokehold', 'Seattle, WA']
# ['Healthy Family Project', datetime.datetime(2009, 4, 15, 21, 1, 14, tzinfo=datetime.timezone.utc), None, 'Buddha Bowls are a great way to throw a healthy, nutritious meal together in a pinch! 🥗 Literally anything goes as… https://t.co/gJkAHCqfBl', 'Orlando']
# ['Habib Nassar', datetime.datetime(2013, 4, 25, 20, 56, 38, tzinfo=datetime.timezone.utc), None, 'Bucha, Ukraine. This is the “just, democratic world order” Serguei Lavrov has promised to build with China… https://t.co/aRdQ5wJmnq', 'Amsterdam, The Netherlands']
# ['Styles', datetime.datetime(2014, 12, 24, 20, 18, 15, tzinfo=datetime.timezone.utc), None, 'PEDRIII 🎩🎩', None]
# ['\U0001faf6🏻\U0001faf0🏻\U0001faf6🏻', datetime.datetime(2011, 3, 4, 4, 29, 14, tzinfo=datetime.timezone.utc), None, 'RT @PTATRT_: https://t.co/dmsnoYQfiP', None]
# ['A', datetime.datetime(2011, 4, 15, 23, 10, 56, tzinfo=datetime.timezone.utc), None, 'Mtcheewww 😭', 'Nigeria - Lagos']
# ['Alexander 🥷🏽', datetime.datetime(2016, 12, 29, 9, 1, 54, tzinfo=datetime.timezone.utc), None, 'Siento q me voy a morir, q chimba', 'Bogotá,Colombia ']
# ['mikolina felineso', datetime.datetime(2010, 12, 8, 13, 34, 8, tzinfo=datetime.timezone.utc), None, 'RT @JesicaDigParker: https://t.co/7Z733q4D0i  Turkey Beach Is a Dream Come True\n\n#beach #vacations #holidays  #summer #dream #turkey #aegea…', 'UK']
# ['mari :/', datetime.datetime(2019, 11, 4, 16, 48, 47, tzinfo=datetime.timezone.utc), None, 'icon bacana, depois vou arrumar o resto', 'ela/dela']
# ['G', datetime.datetime(2019, 9, 18, 19, 55, 44, tzinfo=datetime.timezone.utc), None, 'برشلونه الاول محظوظين في بيدري', 'للاعلانات خاص ']
# ['حامد الكليب', datetime.datetime(2011, 12, 18, 17, 13, 43, tzinfo=datetime.timezone.utc), None, 'RT @EstQfarr: استغفرالله العظيم الذي\nلا اله إلاّ هو الحي القيوم واتوب إليه', None]
# ['QLA | LIV MORGAN 🤍💙', datetime.datetime(2021, 1, 27, 13, 5, 11, tzinfo=datetime.timezone.utc), None, 'BONO VA TE FAIRE VOIR', None]
# ['OSahari', datetime.datetime(2022, 2, 26, 23, 7, 14, tzinfo=datetime.timezone.utc), None, 'RT @juliaioffe: The Russian government is already denouncing the clear evidence of war crimes we’re seeing come out of Bucha as “fake.” It’…', None]
# ['John Nevels', datetime.datetime(2016, 12, 7, 19, 27, 6, tzinfo=datetime.timezone.utc), None, 'RT @JAEbberts: If the church is not declaring and promoting the standards of the Celestial Kingdom, no one is.\n\nYou can claim whatever king…', 'AZ, CA, UT, ID, MO']
# ['アレン・ウォーカー', datetime.datetime(2010, 10, 18, 9, 7, 55, tzinfo=datetime.timezone.utc), None, 'さすが・・・っ', '黒の教団']
# ['🖤💙', datetime.datetime(2020, 7, 2, 7, 18, 19, tzinfo=datetime.timezone.utc), None, '@scent_og ㅠ 훌ㅈ덕.........', None]
# ['pilarmunozrdguez', datetime.datetime(2021, 3, 3, 15, 43, 58, tzinfo=datetime.timezone.utc), None, '@lauymikel Hija mía,que supuesta eres y qué mala leche y envidiosa,siempre dices las cosas con doble sentido,se te nota y tú lo sabes', None]
# ['Doodles 🇺🇸 🐕', datetime.datetime(2019, 1, 4, 22, 8, 37, tzinfo=datetime.timezone.utc), None, '@PouncerNC_USA 🤣', 'California ']
# ['عدني كول', datetime.datetime(2022, 4, 1, 18, 24, 43, tzinfo=datetime.timezone.utc), None, 'RT @MAXLovegayz: انا و فحلي دي يونج 😭🍑 بعد المباراه لازم يرتاح https://t.co/9tVD6uGmRJ', None]
# ['Buse Heybet', datetime.datetime(2022, 3, 19, 12, 5, 20, tzinfo=datetime.timezone.utc), None, 'RT @Dilrba83443076: İstekleriniyortular #alsancak #karsıyaka kaç kaç ** https://t.co/4EVO1RSDXS', None]
# ['purbakantho.com', datetime.datetime(2016, 6, 11, 18, 24, 14, tzinfo=datetime.timezone.utc), None, 'মেহেরপুরে মোটরসাইকেল দুর্ঘটনায় স্কুলছাত্রের মৃত্যু https://t.co/d9MnJb5Ap5', 'Netrakona, Bangladesh']
# ['جود', datetime.datetime(2021, 8, 26, 22, 11, 40, tzinfo=datetime.timezone.utc), None, '@wa7lv وجه خير عليه وعلينا', 'بليهي بارك ']
# ['ari ツ || tyong ☂️', datetime.datetime(2020, 10, 17, 13, 38, 7, tzinfo=datetime.timezone.utc), None, '@odetohvnsol va bhe prima o poi lo farò', 'vivi 🤍 tyong']
# ['Yessir🇬🇭', datetime.datetime(2020, 1, 13, 0, 35, 5, tzinfo=datetime.timezone.utc), None, "RT @Cedric_Akiums: What's really wrong with me... Buying tons of shoes and cloths... And i don't even go out that much or wear them... 😂😂…", 'Tema, Ghana']
# ['Rᴀᴡᴀɴ .🦋', datetime.datetime(2018, 12, 6, 16, 49, 32, tzinfo=datetime.timezone.utc), None, '@mizlempackage @justfatoomy @EsraKhalil7 @Ragda72182934 @besho50283446', 'Khartoum']
# ['Fedora', datetime.datetime(2021, 4, 28, 17, 9, 27, tzinfo=datetime.timezone.utc), None, 'RT @Zedd_Sol: Shill me the strongest community and stable floor on $sol nfts that worth to get sweep 🧹🤝🧹🤝', None]
# ['LykoS💉💉💉💉Οἰκουμένη in #Covid19&#Klimakrise🇺🇦', datetime.datetime(2010, 1, 19, 0, 39, 10, tzinfo=datetime.timezone.utc), None, 'RT @EndoUndCo: In Anlehnung an den Nutri-Score wurde neu der Soli-Score eingeführt. https://t.co/ESRbDWM5h8', 'Terra/Sol/Galaxy/.../Universe']
# ['Opemipo Olawale Adeniyi', datetime.datetime(2018, 10, 15, 14, 55, 23, tzinfo=datetime.timezone.utc), None, 'Unknown Gunmen Kill Two FRSC Officials In Anambra\xa0State https://t.co/Bh8UtmkLnL', 'Ilorin, Nigeria']
# ['silvia', datetime.datetime(2021, 8, 16, 23, 32, 12, tzinfo=datetime.timezone.utc), None, 'PEDRI ES MÁGICO ES EL PADRE DLE BARÇA', 'alexia ']
# ['Tristan Pimental', datetime.datetime(2021, 12, 24, 18, 32, 13, tzinfo=datetime.timezone.utc), None, 'RT @overtimemegan: i miss miami https://t.co/1W9PzOduHz', None]
# ['Hanta Sero//', datetime.datetime(2021, 5, 21, 6, 0, 54, tzinfo=datetime.timezone.utc), None, '*he wraps an arm around her*', None]
# ['SYOT', datetime.datetime(2018, 4, 19, 5, 58, 12, tzinfo=datetime.timezone.utc), None, 'メッシかよ', 'ヨミハラ']
# ['こたつ幼稚園 みかん組 組長 🥦', datetime.datetime(2020, 12, 4, 15, 11, 31, tzinfo=datetime.timezone.utc), None, '@PoteToAE21 お？今日は徹夜コースか？', None]
# ['kat', datetime.datetime(2022, 1, 14, 13, 1, 24, tzinfo=datetime.timezone.utc), None, '@hllndxq sweet dreams love', 'she/her']
# ['Emine Yakar', datetime.datetime(2022, 3, 22, 8, 51, 2, tzinfo=datetime.timezone.utc), None, 'RT @0CfPvuB4qr3ZUv3: ax  erken Bekaretini #buca https://t.co/TRNfuni84m', None]
# ['Helio', datetime.datetime(2021, 9, 30, 13, 38, 20, tzinfo=datetime.timezone.utc), None, '#BSW #Biswap', None]
# ['kimmy⁷', datetime.datetime(2012, 10, 24, 9, 27, 18, tzinfo=datetime.timezone.utc), None, 'NOT THE TABLE ON HIS BACKSJDJS', 'she/her ‘99']
# ['Frank', datetime.datetime(2022, 4, 3, 15, 56, 38, tzinfo=datetime.timezone.utc), None, '@DCLBlogger 💎MetaloopTech💎✅Fullydoxed team and techrate audited.✅Listed on CG,CMC and Pancakeswap.✅NFTs and P2E gam… https://t.co/OIq4b5cadN', None]
# ['عماد الدين خليفة', datetime.datetime(2021, 1, 22, 10, 0, 47, tzinfo=datetime.timezone.utc), None, 'حال مرتزقة ابليس عقب الحلقة 3 من الاختيار 😂😂😂😂😂😂 https://t.co/4gcpLYwTdT', 'الهرم جيزة مصر🇪🇬✌💪']
# ['CeDeROM', datetime.datetime(2010, 2, 14, 14, 53, 28, tzinfo=datetime.timezone.utc), None, '@Jaycan911 @CanadianForces https://t.co/QXYpTa9kXL', None]
# ['Edward.E', datetime.datetime(2021, 3, 14, 0, 1, 56, tzinfo=datetime.timezone.utc), None, '@AppaSamurai Endeavor wants to know your location https://t.co/T3juJKxVWr', None]
# ['arroba sergi🚀🪐 #A522', datetime.datetime(2016, 1, 5, 15, 3, 28, tzinfo=datetime.timezone.utc), None, 'Está loco', None]
# ['جوزييييف 🇧🇷', datetime.datetime(2012, 2, 24, 16, 51, 38, tzinfo=datetime.timezone.utc), None, 'قووووووووووووووووووووووووووووووووووووووووووووووووول', None]
# ['𝖕𝖊𝖗𝖊𝖎𝖗𝖆', datetime.datetime(2021, 4, 4, 1, 50, 3, tzinfo=datetime.timezone.utc), None, 'Um gol pra cada mundial do sp', 'su quarto mi quarto']
# ['Philip Kim', datetime.datetime(2019, 7, 20, 1, 23, 46, tzinfo=datetime.timezone.utc), None, 'RT @ThiccRadChad: Do you agree with him? https://t.co/uCadDyAean', None]
# ['Manel', datetime.datetime(2021, 2, 26, 4, 31, 21, tzinfo=datetime.timezone.utc), None, 'GOLAAAAÇOOO FIO', 'Governador Valadares, Brasil']
# ['ケン', datetime.datetime(2019, 11, 18, 4, 56, 58, tzinfo=datetime.timezone.utc), None, 'RT @i8791: ／\nフォロー＆RTで当たる\n参加賞は抽選でAmazonギフト券\n＼\n\n#母の日 花クイズキャンペーン💐\n\nクイズの答えをリプライして\n正解するとAmazonギフト券\n5000円のチャンス😊\n\n応募方法\n①@i8791をフォロー\n②4/4 11:59迄にこの…', None]
# ['Mental', datetime.datetime(2021, 8, 3, 4, 23, 52, tzinfo=datetime.timezone.utc), None, 'ペドリ遊んでるよ', '#与田祐希 #西野七瀬 #岩本蓮加']
# ['geesaint', datetime.datetime(2021, 4, 24, 0, 53, 12, tzinfo=datetime.timezone.utc), None, '@RWNJ_ For some odd reason I feel like going camping!', 'Portland, OR']
# ['Fingore', datetime.datetime(2016, 6, 7, 23, 33, 56, tzinfo=datetime.timezone.utc), None, 'RT @VorosTwins: This dog wants to hangout! https://t.co/Q0TNexgAdD', 'harbl_hotel']
# ['TheR0nin #JEDSTAR #OMI (3,3)', datetime.datetime(2011, 2, 6, 22, 21, 34, tzinfo=datetime.timezone.utc), None, 'RT @BelugaJpegWhale: First 1000 people to retweet gets free #NFTs #NFT #NFTCommunity\nI promise everyone will get something. Keep your DMs o…', None]
# ['NA', datetime.datetime(2012, 2, 16, 0, 42, 18, tzinfo=datetime.timezone.utc), None, "RT @Huffzz: @AlecoNFT @TheStonerApes Let's go!!!", 'USA']
# ['ray', datetime.datetime(2021, 12, 27, 13, 57, 46, tzinfo=datetime.timezone.utc), None, 'q chatice', None]
# ['DEVORA INCA😈🍑🍬', datetime.datetime(2021, 5, 27, 18, 34, 46, tzinfo=datetime.timezone.utc), None, 'RT @devoradorinca24: 🚕 El taxita hetero 🥵\nLo veia muy estrezado y lo invite entrar al hotel que me dejaba ..no sabia que tenia novia 😱 pero…', None]
# ['ᴡʜᴀʟᴇ⁷', datetime.datetime(2019, 11, 19, 12, 1, 18, tzinfo=datetime.timezone.utc), None, 'RT @kingshadowtae: BTS BTS BTS\n\nListen to #BTS_Butter the 2021 SOTY by #BTS\xa0is the best song @BTS_twt', 'she/her •btspopper']
# ['الحمد لله على كل حال 🌺', datetime.datetime(2013, 2, 27, 21, 19, 11, tzinfo=datetime.timezone.utc), None, 'RT @Ammaraghaalkala: خريف \nمن أعمالي زيتي على خشب\n#آغا_القلعة https://t.co/9e7P8b5NFi', 'İstanbul, Türkiye']
# ['Alkım Elverdi', datetime.datetime(2022, 3, 19, 7, 48, 59, tzinfo=datetime.timezone.utc), None, 'RT @Dilrba83443076: İstekleriniyortular #alsancak #karsıyaka kaç kaç ** https://t.co/4EVO1RSDXS', None]
# ['cule💙❤️#kroosAcl', datetime.datetime(2020, 11, 22, 13, 48, 24, tzinfo=datetime.timezone.utc), None, 'RT @BarcaUniversal: GOAAAAAAAALLLLLLLLLL PEDRRIIIIII 1-0', "Pendu's basement"]
# ['bia', datetime.datetime(2020, 11, 28, 13, 46, 25, tzinfo=datetime.timezone.utc), None, '@ana_zinhak ai quero ir tb', None]
# ['َ', datetime.datetime(2022, 1, 30, 6, 1, 32, tzinfo=datetime.timezone.utc), None, '@__yil9 فيييي', 'Abu Dhabi']
# ['Por Mexico', datetime.datetime(2021, 10, 11, 23, 40, 35, tzinfo=datetime.timezone.utc), None, 'RT @zapata_arriba: Digan lo que quieran xhairos rabiosos ,pero en ningun video de las marchas de hoy verán "frutsis y tortas de huevo" no s…', None]
# ['⭒꙳ Aware b☆t ⭒✮', datetime.datetime(2021, 10, 31, 20, 49, 10, tzinfo=datetime.timezone.utc), None, 'RT @AwareEsp: We offered you to join, Your third emoji is your reaction.. 👀', 'KR1LL AKEN0 MEEP QEEZY']
# ['Almeem', datetime.datetime(2022, 3, 17, 10, 50, 41, tzinfo=datetime.timezone.utc), None, 'سامي الجعوني لوجستي.\n\n #الميركه82', None]
# ['Real Lerka🇺🇦💪❤️', datetime.datetime(2021, 2, 5, 12, 40, 40, tzinfo=datetime.timezone.utc), None, 'RT @m_mar_mar_101: @bellalilli161 @helena_mar19 G night Eleonora and Helena 🌟🌃🤗🌃🌟🤗🌟🌃🌟🤗🌟🌃🌟🤗 https://t.co/dfAsKT4PWw', 'Moscow Russia']
# ['Baby Ever', datetime.datetime(2022, 3, 21, 19, 10, 24, tzinfo=datetime.timezone.utc), None, "@playarcadeland @PlayMetaGods Wow🔥🔥..my day just got better .I'm definitely in✅ #Arcadeland #MetaGods", None]
# ['yousseef', datetime.datetime(2020, 7, 25, 21, 33, 25, tzinfo=datetime.timezone.utc), None, '@canonlly ah be kankam..', 'mersin falan']
# ['Sergio López', datetime.datetime(2022, 3, 15, 11, 29, 41, tzinfo=datetime.timezone.utc), None, '@ManiThawani Padreando', None]
# ['r h f \u200f𓃮', datetime.datetime(2013, 4, 12, 20, 14, 23, tzinfo=datetime.timezone.utc), None, 'بييييييييييييييييدررررررررررري 🤩❤️❤️', 'life goes on .. ']
# ['💣🚀KANDIDAT ZA PREDSEDNIKA !!! 🇷🇺💣', datetime.datetime(2015, 4, 7, 11, 14, 43, tzinfo=datetime.timezone.utc), None, '@VladimirStev @KontraMile Utesno, a ?', 'Kruševac, Srbija']
# ['ابو مشاري🇸🇦', datetime.datetime(2022, 4, 3, 14, 37, 17, tzinfo=datetime.timezone.utc), None, '@Alhilal_FC (*💉لـقـاح كــورونا بـدون حــضور💉*)\n\n(*💉لـقـاح كــورونا بـدون حــضور💉*) \n\n(الــجــرعــه اولى(1)\n(الــجــ… https://t.co/ZBYoNacvyy', 'المملكة العربية السعودية']
# ['جلال العمري', datetime.datetime(2022, 2, 16, 22, 33, 59, tzinfo=datetime.timezone.utc), None, '@dlwttz2 تعالي', None]
# ['🔥 Wong Jowo 🌟', datetime.datetime(2021, 12, 17, 10, 56, 23, tzinfo=datetime.timezone.utc), None, 'RT @TheRylai: $350 l Ends in 3 Days \n\n🟩 RT &amp; Follow \n@twistedbears_ +\n@TwistedAlexnft +\n@Loganjonestb \n🟩 RT, Like &amp; tag friends on their pi…', None]
# ['Luis Miguel Echegaray', datetime.datetime(2012, 10, 13, 21, 25, 26, tzinfo=datetime.timezone.utc), None, 'RT @QueGolazoPod: LIVE - Weekend Recap &amp; Analysis\n\n🇮🇹 Controversy in the #DerbydItalia \n📉 Everton in real relegation danger\n📝 #UCL QF first…', 'New York, NY']
# ['Tom', datetime.datetime(2021, 5, 13, 13, 32, 48, tzinfo=datetime.timezone.utc), None, '@SportsiCohn If komets win today they need 1 more point, unless I did my math wrong.', None]
# ['けいこ❤', datetime.datetime(2013, 7, 13, 0, 20, 19, tzinfo=datetime.timezone.utc), None, '恋愛スイーツ()な友達の恋愛相談聞いてたんだけど「前カレがくれたペアリングは５万円だったのに今カレがくれたペアリングが3000円でマジありえない」とか愚痴言ってて3000円でも十分すぎるだろと思ったけど周りも「ありえなーい」「ひどいねー」とか賛同してて喪女には分からない世界だった', None]
# ['Robson', datetime.datetime(2020, 1, 29, 13, 16, 9, tzinfo=datetime.timezone.utc), None, '@RadoslawNawrot Matko bosko !', 'Pyrlandia']
# ['amelia', datetime.datetime(2016, 3, 25, 21, 6, 5, tzinfo=datetime.timezone.utc), None, 'RT @cmbyn_bot: Is it better to speak or die?', 'she/her | 17 | Δ']
# ['Meiko', datetime.datetime(2018, 10, 10, 19, 34, 16, tzinfo=datetime.timezone.utc), None, 'RT @calicoandblack_: seriously? https://t.co/k3QNXZPwqF', 'You know. I know.']
# ['Jeff', datetime.datetime(2022, 1, 12, 23, 14, 18, tzinfo=datetime.timezone.utc), None, '@ghostserag @PPsm0ke @Jerry5Wiley @JoyceWhiteVance Provide me documentation that MLK is banned somewhere. Lying POS', None]
# ['نصراوي جدا', datetime.datetime(2014, 8, 5, 18, 59, 22, tzinfo=datetime.timezone.utc), None, '@alqsim_f @AlNasrFCDXB مثيره ؟\nتتكلم جد؟\nمباراة من طرف واحد\nشتاااان بين مباراتنا ويا الشارجه فالدور الأول بقيادة دي… https://t.co/9qcxxolGmF', None]
# ['دح', datetime.datetime(2022, 3, 15, 16, 7, 31, tzinfo=datetime.timezone.utc), None, '@wriilp اخير', '❤️سعود❤️  | ❤️عبدالله❤️']
# ['SRN', datetime.datetime(2010, 8, 9, 19, 41, 13, tzinfo=datetime.timezone.utc), None, 'RT @SdqJaan: نہیں...یہ فروغ نسیم صاحب کی آواز نہیں ہے', None]
# ['Duquesa♕ 🌶️', datetime.datetime(2014, 1, 16, 21, 9, 22, tzinfo=datetime.timezone.utc), None, 'O que ela esta fazendo aqui? eu esqueço que de Goias para Brasília um pulo', None]
# ['louis frillman', datetime.datetime(2009, 5, 15, 5, 33, 42, tzinfo=datetime.timezone.utc), None, 'Yes', 'MSP, SEA, ']
# ['Carlos Andrés', datetime.datetime(2013, 8, 18, 0, 6, 54, tzinfo=datetime.timezone.utc), None, 'dios mío pedri https://t.co/iCWg8TzHJR', 'Honduras']
# ['Cam Holt', datetime.datetime(2018, 3, 31, 23, 12, 54, tzinfo=datetime.timezone.utc), None, '@VandyBoys SWEEP…Sorry ‘bout that “little bro.”😏🧹🧹🧹\n#GBO🍊⚾️ https://t.co/ACcRbOEHju', 'Chattanooga, TN']
# ['💗⛓Ozzy Mandias ⛓💗', datetime.datetime(2020, 11, 30, 7, 7, 36, tzinfo=datetime.timezone.utc), None, 'good tidings from your favorite cryptid 🖤 https://t.co/dH69Sa0rCC', None]
# ['Aaliya ❤️', datetime.datetime(2018, 1, 13, 7, 55, 5, tzinfo=datetime.timezone.utc), None, 'RT @munawarmic: I love how good he is at analysing people , the way he is so strong headed that nothing can influence him ,I love this guy…', None]
# ['𝖇𝖊𝖑 🐍', datetime.datetime(2015, 10, 19, 22, 59, 37, tzinfo=datetime.timezone.utc), None, 'acabei de ver um vídeo com uma brockhampton, isso nunca me aconteceu', None]
# ['matashinha', datetime.datetime(2018, 12, 11, 0, 10, 48, tzinfo=datetime.timezone.utc), None, 'ma gente sair de pb p passar vergonha vao se tratar', 'Francisco Beltrão, Brasil']
# ['BAS🇨🇮', datetime.datetime(2019, 6, 16, 1, 23, 35, tzinfo=datetime.timezone.utc), None, 'ペドリいいいいいいいい', None]
# ['Scorpious', datetime.datetime(2012, 10, 29, 18, 26, 43, tzinfo=datetime.timezone.utc), None, 'RT @UltimaShadowX: Ranni group cosplay except it’s two people strapped to each other in order to accurately recreate the second pair of han…', 'Nocturneon']
# ['𝐌𝐨𝐡𝐚𝐦𝐞𝐝 𝑬𝒎𝒂𝒎☕︎ ..', datetime.datetime(2021, 12, 2, 7, 46, 19, tzinfo=datetime.timezone.utc), None, 'تلعب بي الكلمه وي تفصيلها...!✨', None]
# ['aninha', datetime.datetime(2021, 1, 15, 18, 57, 12, tzinfo=datetime.timezone.utc), None, 'Não acredito que o sp tá perdendo de 3 a 0 não', '🧡🤞🏻']
# ['Syazna Min Min', datetime.datetime(2021, 1, 26, 3, 19, 30, tzinfo=datetime.timezone.utc), None, 'RT @weareoneEXO: "2022 Debut Anniversary Fan Event: EXO" Ticket🐱🎫 \n\n✈️ XIUMIN AIRLINES \n\nFROM : EARTH \nTO : EXO PLANET\n\n👨\u200d✈️ EXO 1248 항공편을…', None]
# ['Moyvv', datetime.datetime(2017, 7, 11, 20, 30, tzinfo=datetime.timezone.utc), None, 'RT @fdobonilla: Llegan imágenes en directo del movimiento #TerminasyTeVas #ALasCalles3DeAbril https://t.co/De47w5RiKU', None]
# ['El Grosero Culé ⚽', datetime.datetime(2010, 6, 4, 22, 42, 57, tzinfo=datetime.timezone.utc), None, 'RT @UNIVERSO_1899: GOOOOOOOOOOOL PEDRI GOLAZOOOOOOO DIOOOOOS', 'Barcelona, España']
# ['Arif', datetime.datetime(2014, 6, 8, 11, 48, 43, tzinfo=datetime.timezone.utc), None, 'RT @vfescritor: As pessoas acham que o amor é feito de gestos enormes, mas a verdade é que ele é feito de pequenos momentos rotineiros. São…', 'Hogwarts']
# ['mei LYLO DAY!!!!!!!!!! | 3/5', datetime.datetime(2022, 2, 19, 6, 53, 20, tzinfo=datetime.timezone.utc), None, '@langosky eu ri com respeito ok', 'any pronouns - minor']
# ['Itoro', datetime.datetime(2020, 9, 20, 10, 11, 26, tzinfo=datetime.timezone.utc), None, '@67Kelechi Senior Man!', None]
# ['Bella Stone', datetime.datetime(2020, 3, 30, 15, 23, 4, tzinfo=datetime.timezone.utc), None, 'RT @wetkittyluvr_: @wetkittyluvr @18XTC @AdultBrazil POV b/g content🔥FREE to subscribe https://t.co/p3wS03brxZ RTf 💦@wetkittyluvr_ @18XTC h…', "Don't own any content posted"]
# ['Billi Sybyl', datetime.datetime(2022, 4, 3, 11, 45, 57, tzinfo=datetime.timezone.utc), None, 'RT @Michell60483417: #ankaratraveﬅi ateş küre keselenmek mehter takımı kobalt bombası metotsuz https://t.co/xPiLDrXHnc', None]
# ['まこもこ♡', datetime.datetime(2020, 4, 19, 4, 20, 16, tzinfo=datetime.timezone.utc), None, '@yamiRyouma おっはよぉ', '💌✖︎😢']
# ['Thunchanokp', datetime.datetime(2014, 3, 26, 1, 31, 38, tzinfo=datetime.timezone.utc), None, 'RT @sfkkfs_: แม่ไม่เคยมาแชทหาแบบนี้เลย ชอบน้องพีๆจริงจังมาก 55555555 https://t.co/EPwXGSaedR', 'Hat Yai, Thailand']
# ['🅿️asco💛💙', datetime.datetime(2020, 11, 10, 20, 17, 18, tzinfo=datetime.timezone.utc), None, '@Faxbicp Nahhh bro, bin doch kein Anfänger', None]
# ['Michael Kotacka', datetime.datetime(2012, 6, 11, 21, 59, 51, tzinfo=datetime.timezone.utc), None, '@danandshayfanwi We love you! 🤗🤗❤️❤️❤️🤗🤗', None]
# ['THEWIZARD ( beware scammers )', datetime.datetime(2021, 8, 30, 17, 17, 29, tzinfo=datetime.timezone.utc), None, '@cryptoslut69 Say hi 👋 on telegram to join my mentorship program for trades \nhttps://t.co/iT1OFtILfz', 'No financial advice']
# ['jml', datetime.datetime(2020, 3, 30, 21, 40, 13, tzinfo=datetime.timezone.utc), None, 'Pedriiiii', 'Everywhere']
# ['Brenna', datetime.datetime(2021, 8, 28, 13, 14, 57, tzinfo=datetime.timezone.utc), None, '@TobiasParker13 Ma...  anche ora puoi!!', None]
# ['Alassane🇸🇳', datetime.datetime(2020, 2, 20, 21, 0, 33, tzinfo=datetime.timezone.utc), None, 'RT @brfootball: Mbappé, Neymar and Messi have 𝒇𝒊𝒏𝒂𝒍𝒍𝒚 all scored in the same match for PSG 🎆 https://t.co/RhjVOX27ny', 'Depressed lands']
# ['Darth_Smokey', datetime.datetime(2014, 7, 12, 1, 34, 17, tzinfo=datetime.timezone.utc), None, '@TheNBACentral @lizwagstafff ohhhh', 'Shady Park']
# ['Clare Gerada', datetime.datetime(2010, 6, 13, 15, 6, 28, tzinfo=datetime.timezone.utc), None, '@DrSteveTaylor 20000 GPs short.', 'England']
# ['duda ⓟ', datetime.datetime(2018, 5, 27, 19, 27, 30, tzinfo=datetime.timezone.utc), None, 'Gol do meu Barça', 'Valparaíso, Brasil']
# ['Milen', datetime.datetime(2021, 10, 6, 11, 33, 15, tzinfo=datetime.timezone.utc), None, '@ye6eun Sanirim', "Yoshi'nin yanı"]
# ['B', datetime.datetime(2020, 4, 25, 22, 45, 53, tzinfo=datetime.timezone.utc), None, 'RT @1amorbenfica: Só Fernando Santos é que não vê ! 👀🦅 https://t.co/7hw9NvSAHR', None]
# ['Zelma', datetime.datetime(2022, 3, 22, 21, 52, 29, tzinfo=datetime.timezone.utc), None, 'RT @Mohamed91404117: geçtiğini #izmir görmüş. Ikisinin https://t.co/FCwgoysv9R', None]
# ['Mi 🇵🇸🇵🇼🇷🇸🇹🇯🇸🇾🇵🇫🇱🇾🇨🇳🇷🇺', datetime.datetime(2021, 7, 17, 11, 6, 11, tzinfo=datetime.timezone.utc), None, '@ErikMarquardt Hmm klaro ABC Waffen im Irak, Brutkasten in Kuwait und Tonkin in Vietnam wo waren die Sanktionen geg… https://t.co/lW2rxHeONr', None]
# ['🥇✨ 𝒥𝒪𝒪𝒟 ✨🥇', datetime.datetime(2021, 11, 2, 21, 10, 17, tzinfo=datetime.timezone.utc), None, '@W_Z_4 @az123azoo الله يوفقكم ويكتب اجركم ونفرح بإكتمال الوقف ..', None]
# ['Maddie Hanna', datetime.datetime(2009, 10, 15, 18, 52, 45, tzinfo=datetime.timezone.utc), None, '@NFTkish @Acfonixx @SUS_VERSE @0x31POLO @JordanJohnLill1 @thudao76 @JetskiNFT @BenJsin @KyleNFTss @cyber_spac3… https://t.co/R1MTPURVIE', 'Philadelphia, PA']
# ['thv', datetime.datetime(2017, 1, 4, 1, 27, 12, tzinfo=datetime.timezone.utc), None, 'RT @smeraldofansub: BTS: GRAMMY AWARDS - 03/04/2022 🇧🇷\n \nIndicação: Best Pop Duo/Group Performance\nBTS irá se apresentar!\n\nPremiere Ceremon…', None]
# ['ND⁷', datetime.datetime(2019, 6, 21, 22, 39, 52, tzinfo=datetime.timezone.utc), None, 'RT @sugamvs: Jungkook jump from the ceiling to the stage to start his verse lights goin crazy the ground start shaking usher pop out when h…', '20 ']
# ['Matheus Fernandes', datetime.datetime(2012, 9, 15, 2, 37, 58, tzinfo=datetime.timezone.utc), None, 'RT @lapatina_: After seeing Bucha, I am terrified to my core to even imagine what we will see in Mariupol.', 'Natal, Brasil']
# ['gi loves des!🪁', datetime.datetime(2021, 8, 10, 21, 53, 25, tzinfo=datetime.timezone.utc), None, 'damn i was like 27 chapters into my wattpad fic and my oc and sapnap barely even talked', 'he/it/xe/aer\n17!\nic ; @gggttrri']
# ['Sandra Riddell', datetime.datetime(2010, 1, 27, 20, 56, 8, tzinfo=datetime.timezone.utc), None, 'Spivs', 'Edinburgh']
# ['Claire', datetime.datetime(2020, 5, 25, 9, 28, 22, tzinfo=datetime.timezone.utc), None, "Putin's agents in America used to be covert, now they're overt.", None]
# ['madu', datetime.datetime(2021, 2, 16, 13, 37, 56, tzinfo=datetime.timezone.utc), None, 'RT @soucrises: eu amo o conceito de "já chorei demais por isso  não vou me submeter a isso dnovo"  5 min depois tu ta la se submetendo dnovo', 'São Gonçalo, Brasil']
# ['moyin', datetime.datetime(2012, 11, 17, 17, 27, 28, tzinfo=datetime.timezone.utc), None, 'Bro that kid special', 'Nigeria']
# ['as it was.', datetime.datetime(2019, 4, 9, 19, 5, 26, tzinfo=datetime.timezone.utc), None, '@copyofwaIIs amg vc vai que dia msm', 'braves']
# ['Ivan Hurtado', datetime.datetime(2011, 10, 7, 2, 15, 38, tzinfo=datetime.timezone.utc), None, 'RT @geniuslawyer: Putin anuncia el comienzo del fin del dólar como moneda de reserva y dice que el mundo avanza hacia "reservas reales" que…', None]
# ['اشرف Ashraf', datetime.datetime(2019, 10, 16, 15, 22, 8, tzinfo=datetime.timezone.utc), None, '@AymanNo39921434 😂😂🌹🌹🌹🌹', None]
# ['ود إقبال في مجال! 😴🏴\U000e0067\U000e0062\U000e0065\U000e006e\U000e0067\U000e007f', datetime.datetime(2019, 10, 5, 8, 22, 30, tzinfo=datetime.timezone.utc), None, '@Amin32741125 @NB1871 @vrrows9 يامان انت بتجيب في القصص دي من وين؟', None]
# ['Willy_3507#@', datetime.datetime(2021, 12, 24, 20, 9, 33, tzinfo=datetime.timezone.utc), None, 'RT @BABYDOLLX____: ✨বাগানি @lowercaseguy__ https://t.co/EXYK0jGkj6', None]
# ['🇺🇦 Shannon 🇺🇦', datetime.datetime(2019, 2, 23, 5, 20, 20, tzinfo=datetime.timezone.utc), None, '@AnitaMcKelvey2 @TheRickWilson Disastrous Helsinki incident, trade debacle that destroyed small farmers, move to le… https://t.co/EXFm32Aamw', None]
# ['MJ', datetime.datetime(2010, 7, 30, 5, 2, 38, tzinfo=datetime.timezone.utc), None, '@TrashPandaJedi @deerlady83 @Nettie_Bergin @RedactedSeaCow https://t.co/zk0bgeCNiv', 'Virginia, USA']
# ['Stocks tweets', datetime.datetime(2009, 4, 15, 9, 8, 17, tzinfo=datetime.timezone.utc), None, "Netflix's 'Inventing Anna' leads streaming for third week, while Disney's 'Encanto' sings on https://t.co/0nI3YsRrKi https://t.co/cvFHw7Nc99", 'Amsterdam']
# ['Cleiton', datetime.datetime(2022, 4, 3, 20, 8, 16, tzinfo=datetime.timezone.utc), None, '#NewProfilePic https://t.co/286IkjjULL', 'Belford Roxo, Brasil']
# ['vaal // - 42 // AS IT WAS', datetime.datetime(2021, 2, 14, 5, 26, 20, tzinfo=datetime.timezone.utc), None, 'CTMMMM TE AMO LOUIS', 'I need you... and you need me']
# ['8', datetime.datetime(2020, 3, 13, 16, 19, 37, tzinfo=datetime.timezone.utc), Place(_api=None, id='01bf5c1e56ac186d', url='https://api.twitter.com/1.1/geo/id/01bf5c1e56ac186d.json', place_type='city', name='Riyadh', full_name='Riyadh, Kingdom of Saudi Arabia', country_code='SA', country='Kingdom of Saudi Arabia', bounding_box=BoundingBox(_api=None, type='Polygon', coordinates=[[[46.304398, 24.332068], [46.304398, 25.111819], [47.065756, 25.111819], [47.065756, 24.332068]]]), attributes={}), 'الجوكر😢😢😢😢😢', 'الرياض']
# ['Alliss¡!🎸^🇵🇦| AS IT WAS!!!', datetime.datetime(2020, 1, 18, 6, 15, 8, tzinfo=datetime.timezone.utc), None, 'QUE BUEN SHOW JODER', 'Zayn¡!']
# ['Salvita Payá🤟🏼', datetime.datetime(2018, 12, 30, 17, 5, 20, tzinfo=datetime.timezone.utc), None, 'Soy oficialmente Pedrisexual', None]
# ['医療崩壊の大阪で出された大阪維新の会議員団の意見書の中身が「5類にしろ！」でした', datetime.datetime(2018, 6, 25, 0, 27, 39, tzinfo=datetime.timezone.utc), None, 'RT @nasukoB: 「性能がよい抗原定性検査キットもあるので、うまく活用していくべきだ」発言をしていた分科会の舘田一博氏は、ご自身が感染し抗原検査で発見が遅れ重症化。「今、冷静に考えると、なぜもっと早め早めに、PCR検査をやらなかったのかと思う」と後悔されていました。 #…', None]
# ['wade_williams', datetime.datetime(2019, 7, 16, 21, 13, 54, tzinfo=datetime.timezone.utc), None, 'PEDRI ES EL MEJOR JUGADOR DE LA HISTORIA, SEXO', 'Dunder Mifflin, Scranton, PA']
# ['Serena', datetime.datetime(2017, 10, 30, 0, 37, 15, tzinfo=datetime.timezone.utc), None, 'Saudades da academia', 'Rio de Janeiro, Brasil']
# ['Mike🕷', datetime.datetime(2017, 12, 5, 1, 4, 11, tzinfo=datetime.timezone.utc), None, 'RT @prettyboynavi: listen apple when i turn my brightness down don’t turn that shit back up', None]
# ['ahmettoydemir', datetime.datetime(2019, 8, 23, 14, 7, 8, tzinfo=datetime.timezone.utc), None, 'Ben güzele güzel demem güzel benim olmadıkça', 'Türkiye']
# ['habib07', datetime.datetime(2012, 1, 27, 12, 34, 20, tzinfo=datetime.timezone.utc), None, 'التايم لاين بوفيه مفتوح كل حد يتكلم عن مباراه دار رأسي 😂', 'السيب ']
# ['Yadi 🧋', datetime.datetime(2011, 12, 22, 19, 8, 51, tzinfo=datetime.timezone.utc), None, 'un besito para donde sea que esté', 'Ñ']
# ['Kanye OutWest', datetime.datetime(2010, 12, 27, 22, 8, 40, tzinfo=datetime.timezone.utc), None, 'The boy wonder!!!!', 'Chicago']
# ['MaryPee', datetime.datetime(2013, 11, 17, 20, 17, 6, tzinfo=datetime.timezone.utc), None, 'RT @hugolowell: New: Jan. 6 committee member Jamie Raskin says on CBS that public hearings should come in May: “The hearings should be in e…', 'United States']
# ['🕳', datetime.datetime(2020, 4, 15, 0, 17, 38, tzinfo=datetime.timezone.utc), None, '@Hop3Andr3 The tears I see coming \nOmdssss', None]
# ['Leanne Curran', datetime.datetime(2011, 8, 8, 22, 35, 12, tzinfo=datetime.timezone.utc), None, 'RT @WhiteKesa: During the @GNET_research @TheARConsortium workshop tomorrow I’ll be discussing white nationalist/supremacy accelerationist…', 'England, United Kingdom']
# ['裏垢ゆう', datetime.datetime(2021, 2, 11, 7, 50, 16, tzinfo=datetime.timezone.utc), None, 'RT @siokonbu24: 真面目モードの幼馴染 https://t.co/fCNSWkHZvg', '日本']
# ['CERTIFIED HAPPY BOY', datetime.datetime(2019, 7, 17, 9, 43, 1, tzinfo=datetime.timezone.utc), None, 'PEDRIIIIFBFIFBFOFFNFOF MON FRÈRE PUTAIN JE T’AIME', None]
# ['DAWG of 🇨🇦 ✗𝘖', datetime.datetime(2017, 3, 10, 21, 18, 29, tzinfo=datetime.timezone.utc), None, 'RT @blaccmajek: At least I won’t be seeing snapchat ads from that man again.', 'In your head living rent free']
# ['Muhammad Rafique', datetime.datetime(2017, 8, 1, 16, 0, 44, tzinfo=datetime.timezone.utc), None, 'RT @KingKamix: @KhawajaMAsif اب چور اور ڈاکو عوام کے حقوق کی باتیں کریں گے ۔\nاب یہ سب باتیں ایک دوسروں کو سناو، عوام اب نہیں سنے والے ۔', 'Punjab, Pakistan']
# ['Liliana💚', datetime.datetime(2020, 4, 18, 0, 35, 29, tzinfo=datetime.timezone.utc), None, 'RT @ClaudioLibano: Lo de Atria y su familia es verdaderamente verogonzoso y violento. Los que dudaban de quien es en verdad Atria me imagin…', None]
# ['Shouq🌙', datetime.datetime(2014, 4, 24, 23, 20, 36, tzinfo=datetime.timezone.utc), None, '@xu4cl الثاني ان شاءالله للشباب🙏🏼', 'you’re loved']
# ['西蒙', datetime.datetime(2017, 11, 18, 8, 33, tzinfo=datetime.timezone.utc), None, "Y'all should start deleting your drafts.", 'Around The Corner. ']
# ['Jay', datetime.datetime(2013, 1, 17, 22, 29, 24, tzinfo=datetime.timezone.utc), None, 'PEDRI ES UN DIOS', 'Moroleón, Guanajuato']
# ['Andria', datetime.datetime(2022, 3, 21, 16, 20, 22, tzinfo=datetime.timezone.utc), None, 'RT @Mohamed91404117: geçtiğini #izmir görmüş. Ikisinin https://t.co/FCwgoysv9R', None]
# ['she calls me everyday at 7', datetime.datetime(2020, 8, 12, 15, 19, 58, tzinfo=datetime.timezone.utc), None, 'RT @phenomenaludo: See I don die man😭😭😭😭😭😭😭 https://t.co/y1hfWzJ1kz', 'JHB']
# ['Stephy💜🦈💜bts,shinee... many more', datetime.datetime(2016, 11, 21, 3, 34, 12, tzinfo=datetime.timezone.utc), None, 'Now MINE are 😭😭😭 omg', 'Queensland, Australia']
# ['Melanie (Moose Family)', datetime.datetime(2012, 3, 29, 23, 1, tzinfo=datetime.timezone.utc), None, 'RT @FangasmSPN: .@jarpad and @JensenAckles fist bump and thank the fans #SPNIndy https://t.co/Mmk4uEXkvr', 'North of Hell, South of Heaven']
# ['秋山幹光', datetime.datetime(2020, 5, 15, 14, 23, 45, tzinfo=datetime.timezone.utc), None, '@9GefNbQ0sTFzYRN おはようございます。', '日本']
# ['Simber Madridista', datetime.datetime(2021, 11, 7, 14, 58, 41, tzinfo=datetime.timezone.utc), None, "RT @donsummerone: What's going on here? \nMr Edmund Ackah in there https://t.co/k89CCZZFtx", 'Accra, Ghana']
# ['lali', datetime.datetime(2021, 8, 30, 22, 47, 5, tzinfo=datetime.timezone.utc), None, '@aerispallet Vixiii', '18']
# ['Nea Rose', datetime.datetime(2021, 4, 29, 14, 42, 5, tzinfo=datetime.timezone.utc), None, 'RT @breaktheesystem: @01Btsxarmy @BTS_twt remember to engage too! Like, comment, RETWEET! \n\nBTS PAVED THE WAY        stream, Shazam, and li…', 'Nouvelle-Calédonie']
# ['Robert M. Swanson', datetime.datetime(2011, 8, 18, 2, 25, 48, tzinfo=datetime.timezone.utc), None, 'RT @richsignorelli: Boycott @CBSNews until they fire @MickMulvaney. I am also calling on employees to mutiny their network until this low l…', 'Tacoma, Washington USA']
# ['Billie Eilish Poland', datetime.datetime(2020, 10, 13, 15, 22, 10, tzinfo=datetime.timezone.utc), None, 'Możecie obejrzeć to rozdanie na oficjalnym kanale YouTube Grammys: https://t.co/hjGXR1okf5', 'she/her • she/her • she/they']
# ['Lexer M.', datetime.datetime(2014, 5, 31, 1, 58, 20, tzinfo=datetime.timezone.utc), None, 'RT @UnGunner: Mis dos mejores amigos están juntos en Chile 🥺🥺🥺🥺🥺🥺🥺🥺🥺🥺🥺🥺🥺 @lexerm28 @perezlongoo', 'Santiago, Chile']
# ['Cristian Camilo', datetime.datetime(2019, 10, 9, 3, 54, 59, tzinfo=datetime.timezone.utc), None, 'RT @Rodrigo_Lara_: Guarumo, encuestadora que fuera de @Vicmunro , director del @ContactoDapre . Encuestas confeccionadas en los salones del…', None]
# ['Blanca Orellana PURASANGRE', datetime.datetime(2014, 4, 10, 19, 57, tzinfo=datetime.timezone.utc), None, '.@MymeOcio @esCesarVidal\n\nNo falla, 3 jeringas.\n\nHay que jeringarse.', 'La realidad']
# ['محىمد', datetime.datetime(2021, 6, 2, 17, 31, tzinfo=datetime.timezone.utc), None, '٣ اهداف وترتيبه ٨٨ و يقول لا تشك ادمن معاق زيه', 'ياليل']
# ['Kimmiejoe', datetime.datetime(2013, 2, 13, 2, 12, 42, tzinfo=datetime.timezone.utc), None, '@EllieRod8 @woacborclue She has accused this group of just about every crime imaginable! What’s next? Murder? How d… https://t.co/KfhpX0tmBV', 'Wichita, KS']
# ['bubb', datetime.datetime(2018, 11, 2, 15, 44, 5, tzinfo=datetime.timezone.utc), None, 'Yk I dream about having cancer when I was a kid tbh ewan siguro kasi sa atensyon lmao pero seeing how they inject s… https://t.co/Fh6E12dJOZ', None]
# ['Barbara Gunn', datetime.datetime(2011, 12, 12, 1, 10, 28, tzinfo=datetime.timezone.utc), None, 'Wordle 289 5/6\n\n🟩🟨⬜⬜⬜\n⬜⬜⬜⬜⬜\n🟩🟩🟩⬜⬜\n🟩🟩🟩⬜⬜\n🟩🟩🟩🟩🟩 phew', 'Australia']
# ['joe', datetime.datetime(2021, 3, 6, 10, 38, 53, tzinfo=datetime.timezone.utc), None, 'https://t.co/d5b2vx3fOp', 'London, England']
# ['ぐっさん@4%メガネおっさんBUMPer', datetime.datetime(2014, 8, 25, 14, 57, 29, tzinfo=datetime.timezone.utc), None, 'おはよう月曜🥱\n4時30分起きさみぃー💦\nカッコに困るわねぇ。\n7℃って😅\n\n嫁が昨夜帰りが遅くて寝るのが遅かったお二人さん。\n寝直すわって感じで見送られました。\nにゃぁこさんが「枕が居なくなった」\nみたいな不満ヅラでした🙄\n\n後… https://t.co/CtTqyNC5HO', '福岡の片隅で⚪︎×△']
# KeyboardInterrupt

# %% [markdown]
# Before starting the next streaming, you need to disconnect the previous one.

# %%
printer.disconnect()

# %% [markdown]
# The following cell of code will stream tweets for 1 minute and save the tweets in a csv file.

# %%
import time
import csv

stream = tweepy.Stream(API_key, API_key_secret, access_token, access_token_secret)

stream.filter(track=["Putin"], threaded=True)

time_limit = 60

output_file = "tweets.csv"

f = open(output_file, "w", encoding="utf-8",newline='')  # file to open
writer = csv.writer(f)

# Do not contain retweet and favourite_count in streaming data
writer.writerow(["username","created_at", "tweet", "geotag", "user_location"])

class stream_csv(tweepy.Stream):
    def on_status(self, status):
        line = [status.user.name, status.user.created_at, status.text, status.place, status.user.location]
        print(line)
        writer.writerow(line)

printer = stream_csv(API_key, API_key_secret, access_token, access_token_secret)
printer.sample()

time.sleep(time_limit) #halts the control for runtime seconds

printer.disconnect() #disconnect the stream and stop streaming
f.close()
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\IPython\core\interactiveshell.py", line 3524, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\yi\AppData\Local\Temp\ipykernel_9088\414234829.py", line 24, in <cell line: 24>
#     printer.sample()
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\tweepy\streaming.py", line 389, in sample
#     self._connect(method, endpoint, params=params)
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\tweepy\streaming.py", line 261, in _connect
#     super()._connect(method, url, auth=auth, **kwargs)
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\tweepy\streaming.py", line 87, in _connect
#     for line in resp.iter_lines(
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\requests\models.py", line 804, in iter_lines
#     for chunk in self.iter_content(chunk_size=chunk_size, decode_unicode=decode_unicode):
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\requests\models.py", line 760, in generate
#     for chunk in self.raw.stream(chunk_size, decode_content=True):
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\urllib3\response.py", line 572, in stream
#     for line in self.read_chunked(amt, decode_content=decode_content):
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\urllib3\response.py", line 764, in read_chunked
#     self._update_chunk_length()
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\urllib3\response.py", line 694, in _update_chunk_length
#     line = self._fp.fp.readline()
#   File "C:\Users\yi\.conda\envs\geo\lib\socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\yi\.conda\envs\geo\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\yi\.conda\envs\geo\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\IPython\core\interactiveshell.py", line 2088, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\yi\.conda\envs\geo\lib\inspect.py", line 1541, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\yi\.conda\envs\geo\lib\inspect.py", line 1503, in getframeinfo
#     lines, lnum = findsource(frame)
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\IPython\core\ultratb.py", line 182, in findsource
#     lines = linecache.getlines(file, globals_dict)
#   File "C:\Users\yi\.conda\envs\geo\lib\linecache.py", line 46, in getlines
#     return updatecache(filename, module_globals)
#   File "C:\Users\yi\.conda\envs\geo\lib\linecache.py", line 136, in updatecache
#     with tokenize.open(fullname) as fp:
#   File "C:\Users\yi\.conda\envs\geo\lib\tokenize.py", line 392, in open
#     buffer = _builtin_open(filename, 'rb')
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\IPython\core\interactiveshell.py", line 3524, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\yi\AppData\Local\Temp\ipykernel_9088\414234829.py", line 24, in <cell line: 24>
#     printer.sample()
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\tweepy\streaming.py", line 389, in sample
#     self._connect(method, endpoint, params=params)
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\tweepy\streaming.py", line 261, in _connect
#     super()._connect(method, url, auth=auth, **kwargs)
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\tweepy\streaming.py", line 87, in _connect
#     for line in resp.iter_lines(
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\requests\models.py", line 804, in iter_lines
#     for chunk in self.iter_content(chunk_size=chunk_size, decode_unicode=decode_unicode):
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\requests\models.py", line 760, in generate
#     for chunk in self.raw.stream(chunk_size, decode_content=True):
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\urllib3\response.py", line 572, in stream
#     for line in self.read_chunked(amt, decode_content=decode_content):
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\urllib3\response.py", line 764, in read_chunked
#     self._update_chunk_length()
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\urllib3\response.py", line 694, in _update_chunk_length
#     line = self._fp.fp.readline()
#   File "C:\Users\yi\.conda\envs\geo\lib\socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\yi\.conda\envs\geo\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\yi\.conda\envs\geo\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\IPython\core\interactiveshell.py", line 2088, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\IPython\core\interactiveshell.py", line 3444, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\IPython\core\interactiveshell.py", line 3541, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\IPython\core\interactiveshell.py", line 2090, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\IPython\core\ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\IPython\core\ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\IPython\core\ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\IPython\core\interactiveshell.py", line 2088, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\yi\.conda\envs\geo\lib\inspect.py", line 1541, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\yi\.conda\envs\geo\lib\inspect.py", line 1499, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\yi\.conda\envs\geo\lib\inspect.py", line 709, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\yi\.conda\envs\geo\lib\inspect.py", line 755, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "C:\Users\yi\.conda\envs\geo\lib\ntpath.py", line 647, in realpath
#     path = _getfinalpathname(path)
# KeyboardInterrupt
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\IPython\core\interactiveshell.py", line 3524, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\yi\AppData\Local\Temp\ipykernel_9088\414234829.py", line 24, in <cell line: 24>
#     printer.sample()
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\tweepy\streaming.py", line 389, in sample
#     self._connect(method, endpoint, params=params)
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\tweepy\streaming.py", line 261, in _connect
#     super()._connect(method, url, auth=auth, **kwargs)
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\tweepy\streaming.py", line 87, in _connect
#     for line in resp.iter_lines(
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\requests\models.py", line 804, in iter_lines
#     for chunk in self.iter_content(chunk_size=chunk_size, decode_unicode=decode_unicode):
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\requests\models.py", line 760, in generate
#     for chunk in self.raw.stream(chunk_size, decode_content=True):
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\urllib3\response.py", line 572, in stream
#     for line in self.read_chunked(amt, decode_content=decode_content):
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\urllib3\response.py", line 764, in read_chunked
#     self._update_chunk_length()
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\urllib3\response.py", line 694, in _update_chunk_length
#     line = self._fp.fp.readline()
#   File "C:\Users\yi\.conda\envs\geo\lib\socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\yi\.conda\envs\geo\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\yi\.conda\envs\geo\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\IPython\core\interactiveshell.py", line 2088, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\IPython\core\interactiveshell.py", line 3444, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\IPython\core\interactiveshell.py", line 3541, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\IPython\core\interactiveshell.py", line 2090, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\IPython\core\ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\IPython\core\ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\IPython\core\ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\IPython\core\interactiveshell.py", line 2088, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\IPython\core\interactiveshell.py", line 3003, in _run_cell
#     return runner(coro)
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\IPython\core\async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\IPython\core\interactiveshell.py", line 3228, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\IPython\core\interactiveshell.py", line 3463, in run_ast_nodes
#     self.showtraceback()
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\IPython\core\interactiveshell.py", line 2090, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\IPython\core\ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\IPython\core\ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\IPython\core\ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\IPython\core\interactiveshell.py", line 2088, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\yi\.conda\envs\geo\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\yi\.conda\envs\geo\lib\inspect.py", line 1541, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\yi\.conda\envs\geo\lib\inspect.py", line 1499, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\yi\.conda\envs\geo\lib\inspect.py", line 709, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\yi\.conda\envs\geo\lib\inspect.py", line 755, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "C:\Users\yi\.conda\envs\geo\lib\ntpath.py", line 647, in realpath
#     path = _getfinalpathname(path)
# KeyboardInterrupt
