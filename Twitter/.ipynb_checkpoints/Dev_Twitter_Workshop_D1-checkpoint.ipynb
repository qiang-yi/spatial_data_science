# %% [markdown]
# ## Spatial Data Science (GIS6307/GEO4930)
#
#
# <br>
# Instructor: Yi Qiang (qiangy@usf.edu)<br>
# Teaching Assistant: Jinwen Xu (jinwenxu@usf.edu)
#
# ---
#
# # Workshop on Spatial Analysis of Twitter (Day 1)
#
# This workshop will help you to get started with the acquisition, processing, and analysis of Twitter data using data science techniques. Specifically, you will learn:
#
# - Streaming real-time tweets using Twitter Developer APIs.
# - Processing the raw tweets into an analyzable form.
# - Basic mapping, spatial analysis and natural language processing for Twitter data.
#
# ### Prerequisite
# - Install Anaconda in your computer.
# - Activation of Twitter Developer Account and approved **Elevated Access** before the workshop.
# - Basic programming skills are recommended, but not required.

# %% [markdown]
# ## 1. Install Python Libraries
#
# We will need two new libraries [tweepy](https://www.tweepy.org/) and [folium](https://plotly.com/python/) for this lab. Please do the following steps to install these two libarries.
#
# 1. Open or create a new conda environment `geo`.
# - For students in courses GIS6307 and GEO4930, please open Anaconda Prompt, and use the command `conda activate geo` to activate the "geo" environment that you created in the previous lab.
#
# - For workshop participatns, please run the following code to create a new conda environment `geo` and then activate it.
#
#     - `conda create --name geo`
#
#     - `conda activate geo`
#
# 2. Install tweepy, folium and Jupyter Lab using the following command (GIS6307/GEO4930 students only need to install tweepy):
#
#     `conda install -c conda-forge tweepy folium jupyterlab matplotlib`
#
#
# 3. Install pandas and nltk using the following command (GIS6307/GEO4930 students only need to install nltk):
#
#     `conda install -c anaconda pandas nltk`
#
#
# 4. Launch Jupyter Notebook using the following command:
#
#     `jupyter notebook`
#
#
# 5. Create a code cell in Jupyter Notebook. Copy and paste the following code in the cell. Run the cell import the installed libraries and other needed libraries. If the code runs through, the libraries are installed successfully.

# %%
# Run the following lines if there is an error loading basemap
# import os
# os.environ['PROJ_LIB'] = '~your anaconda 3 path/Anaconda3/Library/share/'

import tweepy
import folium
import pandas as pd

#from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Getting to Know Jupyter Notebook
#
# Keyboard shortcuts will save you lots of time. Jupyter stores a list of keybord shortcuts under the menu at the top: Help > Keyboard Shortcuts, or by pressing `H` in command mode (more on that later). It’s worth checking this each time you update Jupyter, as more shortcuts are added all the time.
#
# Another way to access keyboard shortcuts, and a handy way to learn them is to use the command palette: `Cmd + Shift + P` (or `Ctrl + Shift + P` on Linux and Windows). This dialog box helps you run any command by name – useful if you don’t know the keyboard shortcut for an action or if what you want to do does not have a keyboard shortcut. The functionality is similar to Spotlight search on a Mac, and once you start using it you’ll wonder how you lived without it!
#
# Some of my favorite shortcuts (in command mode):
#
# - `ESC`: exit cell editing and enter to command mode
# - `A`: add a cell above the current cell
# - `B`: add a cell below the current cell
# - `C`: copy the current cell
# - `X`: cut the current cell
# - `V`: paste the copied cell below the current cell
# - `DD`: delete the current cell
# - `M`: change cell to MarkDown code (must exit editing first)
# - `Y`: change cell to Python code (must exit editing first)
# - `Ctrl + Enter`: Run code in the current cell.
# - `Shift + Enter`: Run code in the current cell and move to the next cell.

# %% [markdown]
# ## 3. Set-Up the Connection to Twitter
#
# Go to Twitter Developer Portal (https://developer.twitter.com/en/apps). Click the App you created in account activation.
#
# If you haven't created an App when you created the account, you can create one in the project.
#
# Click `Set up` to set up User authentification settings.
#
# ![](../image/twitter/signup3.jpg)
#
# Turn on `OAuth 1.0a` and keep `OAuth 2.0` off.
#
# ![](../image/twitter/OAuth.jpg)
#
# Select "Read and write and Direct message". You can use "http://127.0.0.1:8080" as Callback URL. Add any website as the website URL (e.g. your personal website or https://twitter.com).
#
# ![](../image/twitter/setting.jpg)
#
# Copy the API keys you have saved when you activated your Developer account, and paste them to replace "......" below. If you can't find them, you can **regenerate** the keys and tokens in your Developer Portal.
#
# ![](../image/twitter/keys2.jpg)
#
# Generate your Access Token and Secret and paste them below.

# %%
API_key = 'As0PGxFkLLgXKyqnGCre08UNz'
API_key_secret = '6rzlzIBqgURxZd2PKjo4QTj4iYNiwINHDWDCMWW3zlxUU9xr23'
access_token = '1509606550134038533-TpQM7b6U3nlvewate1hJqqbMuHSl5p'
access_token_secret = 'jTMIxiyKndnxMAI1vJScVC8diddUgHO2EJvNbb4nozU8L'

# %% [markdown]
# Set up for Twitter authentication.

# %%
auth = tweepy.OAuthHandler(API_key, API_key_secret)
auth.set_access_token(access_token, access_token_secret)

# %% [markdown]
# Set up tweepy API and set rate limit to be true.

# %%
api = tweepy.API(auth, wait_on_rate_limit = True)

# %% [markdown]
# ---

# %% [markdown]
# ## 4. Simple Operation with Twitter APIs
#
# Now, your working environment is set up for Twitter analysis. Let's first try a few simple operations to acquire Twitter data in a programmatic way.
#
# The full functionalities of Twitter API and Tweepy can be found in:
#
# - [Twitter APIs](https://developer.twitter.com/en/docs.html)
# - [Tweepy documentation](http://docs.tweepy.org/en/v4.8.0/)

# %% [markdown]
# ### 4.1 Posting/Deleting a Tweet
#
# First, let's post a message in your Twitter account.
#
# **Note**: if you don't want to disturb your followers with a meanless tweet, don't run the following block of code.

# %%
# Post a tweet from Python
test_tweet = api.update_status("DRILL: I'm creating a robot to tweet!")

# %% [markdown]
# Check your Twitter account, and you'll see the above message is posted.
#
# ![](../image/twitter/tweet.jpg)
#
# Tweets are encoded in a JSON (JavaScript Object Notation) format. You can run the following code to check the content of the tweet you just posted.

# %%
test_tweet._json
# Out:
# {'created_at': 'Sat Apr 16 21:14:12 +0000 2022',
#  'id': 1515438433849774086,
#  'id_str': '1515438433849774086',
#  'text': "DRILL: I'm creating a robot to tweet!",
#  'truncated': False,
#  'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []},
#  'source': '<a href="https://twitter.com" rel="nofollow">twitter_workshop2</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 1509606550134038533,
#   'id_str': '1509606550134038533',
#   'name': 'Alex Zhang',
#   'screen_name': 'AlexZha37291293',
#   'location': '',
#   'description': 'Data scientist',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 0,
#   'friends_count': 1,
#   'listed_count': 0,
#   'created_at': 'Thu Mar 31 19:00:34 +0000 2022',
#   'favourites_count': 0,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 1,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#   'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': True,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none',
#   'withheld_in_countries': []},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'is_quote_status': False,
#  'retweet_count': 0,
#  'favorite_count': 0,
#  'favorited': False,
#  'retweeted': False,
#  'lang': 'en'}

# %% [markdown]
# `_json` returns a dictionary object. So you could access specific attributes using keys in the dictionary. The code below gets the posting time of the tweets.

# %%
test_tweet._json['created_at']
# Out:
# 'Sat Apr 16 21:14:12 +0000 2022'

# %% [markdown]
# Alternative, you can also use the built-in attribute of the tweepy status object to access the attribute. All attributes of a tweet can be found [here](https://developer.twitter.com/en/docs/twitter-api/v1/data-dictionary/object-model/tweet).

# %%
test_tweet.created_at
# Out:
# datetime.datetime(2022, 4, 16, 21, 14, 12, tzinfo=datetime.timezone.utc)

# %% [markdown]
# You can run the following code to delete the drill tweet you just posted.

# %%
api.destroy_status(test_tweet.id_str)
# Out:
# Status(_api=<tweepy.api.API object at 0x000001E1A0FD4400>, _json={'created_at': 'Sat Apr 16 21:14:12 +0000 2022', 'id': 1515438433849774086, 'id_str': '1515438433849774086', 'text': "DRILL: I'm creating a robot to tweet!", 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://twitter.com" rel="nofollow">twitter_workshop2</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1509606550134038533, 'id_str': '1509606550134038533', 'name': 'Alex Zhang', 'screen_name': 'AlexZha37291293', 'location': '', 'description': 'Data scientist', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 0, 'friends_count': 1, 'listed_count': 0, 'created_at': 'Thu Mar 31 19:00:34 +0000 2022', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 1, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': True, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2022, 4, 16, 21, 14, 12, tzinfo=datetime.timezone.utc), id=1515438433849774086, id_str='1515438433849774086', text="DRILL: I'm creating a robot to tweet!", truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, source='twitter_workshop2', source_url='https://twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x000001E1A0FD4400>, _json={'id': 1509606550134038533, 'id_str': '1509606550134038533', 'name': 'Alex Zhang', 'screen_name': 'AlexZha37291293', 'location': '', 'description': 'Data scientist', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 0, 'friends_count': 1, 'listed_count': 0, 'created_at': 'Thu Mar 31 19:00:34 +0000 2022', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 1, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': True, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': [ ...

# %% [markdown]
# ### 4.2 Getting Trending Tweets

# %% [markdown]
# In Twitter, you can find trends in different places in the Explore tab.
#
# ![](../image/twitter/trends.jpg)
#
# Next, we are going to retrieve trends in Python. The following code get a list of places where trends are available. These places include countries and cities.

# %%
place_ls = api.available_trends()

# %% [markdown]
# Convert the list (in JSON format) into a dataframe (i.e. a table). Print the number of cities where trends are available.

# %%
df_place = pd.DataFrame(place_ls)

print (str(len(df_place)) + " places have trends.")
# Out:
# 467 places have trends.

# %% [markdown]
# Preview 10 places where trends are available

# %%
df_place.head(10)
# Out:
#          name                          placeType  \
# 0   Worldwide  {'code': 19, 'name': 'Supername'}
# 1    Winnipeg        {'code': 7, 'name': 'Town'}
# 2      Ottawa        {'code': 7, 'name': 'Town'}
# 3      Quebec        {'code': 7, 'name': 'Town'}
# 4    Montreal        {'code': 7, 'name': 'Town'}
# 5     Toronto        {'code': 7, 'name': 'Town'}
# 6    Edmonton        {'code': 7, 'name': 'Town'}
# 7     Calgary        {'code': 7, 'name': 'Town'}
# 8   Vancouver        {'code': 7, 'name': 'Town'}
# 9  Birmingham        {'code': 7, 'name': 'Town'}
#
#                                          url  parentid         country  woeid  \
# 0      http://where.yahooapis.com/v1/place/1         0                      1
# 1   http://where.yahooapis.com/v1/place/2972  23424775          Canada   2972
# 2   http://where.yahooapis.com/v1/place/3369  23424775          Canada   3369
# 3   http://where.yahooapis.com/v1/place/3444  23424775          Canada   3444
# 4   http://where.yahooapis.com/v1/place/3534  23424775          Canada   3534
# 5   http://where.yahooapis.com/v1/place/4118  23424775          Canada   4118
# 6   http://where.yahooapis.com/v1/place/8676  23424775          Canada   8676
# 7   http://where.yahooapis.com/v1/place/8775  23424775          Canada   8775
# 8   http://where.yahooapis.com/v1/place/9807  23424775          Canada   9807
# 9  http://where.yahooapis.com/v1/place/12723  23424975  United Kingdom  12723
#
#   countryCode
# 0        None
# 1          CA
# 2          CA
# 3          CA
# 4          CA
# 5          CA
# 6          CA
# 7          CA
# 8          CA
# 9          GB

# %% [markdown]
# Get the record of Tampa. The `woeid` is a unique ID for each place.

# %%
df_place[df_place['name']=='New York']
# Out:
#          name                    placeType  \
# 373  New York  {'code': 7, 'name': 'Town'}
#
#                                              url  parentid        country  \
# 373  http://where.yahooapis.com/v1/place/2459115  23424977  United States
#
#        woeid countryCode
# 373  2459115          US

# %% [markdown]
# Store the `woeid` of Tampa in tampa_id.

# %%
tampa_id = df_place[df_place['name']=='Tampa']['woeid']

# %% [markdown]
# Return the trends in Tampa.
#
# Note: you need to convert the city_id from a pandas series object into an integer.

# %%
# make Tampa as an example
trends_tampa = api.get_place_trends(int(tampa_id))

# %% [markdown]
# Print the trends in JSON format

# %%
# print the top 20 trends in Tampa
trends_tampa[0:20]
# Out:
# [{'trends': [{'name': 'Anthony Edwards',
#     'url': 'http://twitter.com/search?q=%22Anthony+Edwards%22',
#     'promoted_content': None,
#     'query': '%22Anthony+Edwards%22',
#     'tweet_volume': None},
#    {'name': 'Minnesota',
#     'url': 'http://twitter.com/search?q=Minnesota',
#     'promoted_content': None,
#     'query': 'Minnesota',
#     'tweet_volume': 16084},
#    {'name': 'Spring Game',
#     'url': 'http://twitter.com/search?q=%22Spring+Game%22',
#     'promoted_content': None,
#     'query': '%22Spring+Game%22',
#     'tweet_volume': 20390},
#    {'name': '#ChargeOn',
#     'url': 'http://twitter.com/search?q=%23ChargeOn',
#     'promoted_content': None,
#     'query': '%23ChargeOn',
#     'tweet_volume': None},
#    {'name': 'Steffen',
#     'url': 'http://twitter.com/search?q=Steffen',
#     'promoted_content': None,
#     'query': 'Steffen',
#     'tweet_volume': 31756},
#    {'name': '#gocanes',
#     'url': 'http://twitter.com/search?q=%23gocanes',
#     'promoted_content': None,
#     'query': '%23gocanes',
#     'tweet_volume': None},
#    {'name': 'Arsenal',
#     'url': 'http://twitter.com/search?q=Arsenal',
#     'promoted_content': None,
#     'query': 'Arsenal',
#     'tweet_volume': 228960},
#    {'name': 'Liverpool',
#     'url': 'http://twitter.com/search?q=Liverpool',
#     'promoted_content': None,
#     'query': 'Liverpool',
#     'tweet_volume': 251861},
#    {'name': 'Gators',
#     'url': 'http://twitter.com/search?q=Gators',
#     'promoted_content': None,
#     'query': 'Gators',
#     'tweet_volume': None},
#    {'name': 'Warriors',
#     'url': 'http://twitter.com/search?q=Warriors',
#     'promoted_content': None,
#     'query': 'Warriors',
#     'tweet_volume': 82302},
#    {'name': '#AMEC2022',
#     'url': 'http://twitter.com/search?q=%23AMEC2022',
#     'promoted_content': None,
#     'query': '%23AMEC2022',
#     'tweet_volume': None},
#    {'name': 'ESPN',
#     'url': 'http://twitter.com/search?q=ESPN',
#     'promoted_content': None,
#     'query': 'ESPN',
#     'tweet_volume': 81693},
#    {'name': 'Grizzlies',
#     'url': 'http://twitter.com/search?q=Grizzlies',
#     'promoted_content': None,
#     'query': 'Grizzlies',
#     'tweet_volume': 27104},
#    {'name': 'Mavs',
#     'url': 'http://twitter.com/search?q=Mavs',
#     'promoted_content': None,
#     'query': 'Mavs',
#     'tweet_volume': 28302},
#    {'name': 'Memphis',
#     'url': 'http://twitter.com/search?q=Memphis',
#     'promoted_content': None,
#     'query': 'Memphis',
#     'tweet_volume': 27406},
#    {'name': 'Luka',
#     'url': 'http://twitter.com/search?q=Luka',
#     'promoted_content': None,
#     'query': 'Luka',
#     'tweet_volume': 52967},
#    {'name': '#MINvsMEM',
#     'url': 'http://twitter.com/search?q=%23MINvsMEM',
#     'promoted_content': None,
#     'query': '%23MINvsMEM',
#     'tweet_volume': None},
#    {'name': 'Stephen A',
#     'url': 'http://twitter.com/search?q=%22Stephen+A%22',
#     'promoted_content': None,
#     'query': '%22Stephen+A%22',
#     'tweet_volume': 17528},
#    {'name': 'Ja Morant',
#     'url': 'http://twitter.com/search?q=%22Ja+Morant%22',
#     'promoted_content': None,
#     'query': '%22Ja+Morant%22',
#     'tweet_volume': None},
#    {'name': 'Wolves',
#     'url': 'http://twitter.com/search?q=Wolves',
#     'promoted_content': None,
#     'query': 'Wolves',
#     'tweet_volume': 30724},
#    {'name': 'Jazz',
#     'url': 'http://twitter.com/search?q=Jazz',
#     'promoted_content': None,
#     'query': 'Jazz',
#     'tweet_volume': 79549},
#    {'name': 'Donovan Mitchell',
#     'url': 'http://twitter.com/search?q=%22Donovan+Mitchell%22',
#     'promoted_content': None,
#     'query': '%22Donovan+Mitchell%22',
#     'tweet_volume': None},
#    {'name': 'Gobert',
#     'url': 'http://twitter.com/search?q=Gobert',
#     'promoted_content': None,
#     'query': 'Gobert',
#     'tweet_volume': 11782},
#    {'name': 'Happy Easter',
#     'url': 'http://twitter.com/search?q=%22Happy+Easter%22',
#     'promoted_content': None,
#     'query': '%22Happy+Easter%22',
#     'tweet_volume': 235151},
#    {'name': 'Lugo',
#     'url': 'http://twitter.com/search?q=Lugo',
#     'promoted_content': None,
#     'query': 'Lugo',
#     'tweet_volume': None},
#    {'name': 'Chomsky',
#     'url': 'http://twitter.com/search?q=Chomsky',
#     'promoted_content': None,
#     'query': 'Chomsky',
#     'tweet_volume': 19365},
#    {'name': 'Brunson',
#     'url': 'http://twitter.com/search?q=Brunson',
#     'promoted_content': None,
#     'query': 'Brunson',
#     'tweet_volume': None},
#    {'name': 'Glen Taylor',
#     'url': 'http://twitter.com/search?q=%22Glen+Taylor%22',
#     'promoted_content': None,
#     'query': '%22Glen+Taylor%22',
#     'tweet_volume': None},
#    {'name': 'Emoni Bates',
#     'url': 'http://twitter.com/search?q=%22Emoni+Bates%22',
#     'promoted_content': None,
#     'query': '%22Emoni+Bates%22',
#     'tweet_volume': None},
#    {'name': 'Tyus Jones',
#     'url': 'http://twitter.com/search?q=%22Tyus+Jones%22',
#     'promoted_content': None,
#     'query': '%22Tyus+Jones%22',
#     'tweet_volume': None},
#    {'name': 'Steven Adams',
#     'url': 'http://twitter.com/search?q=%22Steven+Adams%22',
#     'promoted_content': None,
#     'query': '%22Steven+Adams%22',
#     'tweet_volume': None},
#    {'name': 'Richard Jefferson',
#     'url': 'http://twitter.com/search?q=%22Richard+Jefferson%22',
#     'promoted_content': None,
#     'query': '%22Richard+Jefferson%22',
#     'tweet_volume': None},
#    {'name': 'Utah',
#     'url': 'http://twitter.com/search?q=Utah',
#     'promoted_content': None,
#     'query': 'Utah',
#     'tweet_volume': 39145},
#    {'name': 'Naz Reid',
#     'url': 'http://twitter.com/search?q=%22Naz+Reid%22',
#     'promoted_content': None,
#     'query': '%22Naz+Reid%22',
#     'tweet_volume': None},
#    {'name': 'Chuck Todd',
#     'url': 'http://twitter.com/search?q=%22Chuck+Todd%22',
#     'promoted_content': None,
#     'query': '%22Chuck+Todd%22',
#     'tweet_volume': 18085},
#    {'name': 'Greeny',
#     'url': 'http://twitter.com/search?q=Greeny',
#     'promoted_content': None,
#     'query': 'Greeny',
#     'tweet_volume': None},
#    {'name': 'Tucker',
#     'url': 'http://twitter.com/search?q=Tucker',
#     'promoted_content': None,
#     'query': 'Tucker',
#     'tweet_volume': 51636},
#    {'name': 'Dinwiddie',
#     'url': 'http://twitter.com/search?q=Dinwiddie',
#     'promoted_content': None,
#     'query': 'Dinwiddie',
#     'tweet_volume': None},
#    {'name': 'Dillon Brooks',
#     'url': 'http://twitter.com/search?q=%22Dillon+Brooks%22',
#     'promoted_content': None,
#     'query': '%22Dillon+Brooks%22',
#     'tweet_volume': None},
#    {'name': 'Dallas',
#     'url': 'http://twitter.com/search?q=Dallas',
#     'promoted_content': None,
#     'query': 'Dallas',
#     'tweet_volume': 40181},
#    {'name': 'Will Anderson',
#     'url': 'http://twitter.com/search?q=%22Will+Anderson%22',
#     'promoted_content': None,
#     'query': '%22Will+Anderson%22',
#     'tweet_volume': None},
#    {'name': 'Ant Edwards',
#     'url': 'http://twitter.com/search?q=%22Ant+Edwards%22',
#     'promoted_content': None,
#     'query': '%22Ant+Edwards%22',
#     'tweet_volume': None},
#    {'name': 'Royce',
#     'url': 'http://twitter.com/search?q=Royce',
#     'promoted_content': None,
#     'query': 'Royce',
#     'tweet_volume': None},
#    {'name': 'Columbiana Mall',
#     'url': 'http://twitter.com/search?q=%22Columbiana+Mall%22',
#     'promoted_content': None,
#     'query': '%22Columbiana+Mall%22',
#     'tweet_volume': None},
#    {'name': 'Starling Marte',
#     'url': 'http://twitter.com/search?q=%22Starling+Marte%22',
#     'promoted_content': None,
#     'query': '%22Starling+Marte%22',
#     'tweet_volume': None},
#    {'name': 'Jose Ruiz',
#     'url': 'http://twitter.com/search?q=%22Jose+Ruiz%22',
#     'promoted_content': None,
#     'query': '%22Jose+Ruiz%22',
#     'tweet_volume': None},
#    {'name': 'North Wilkesboro',
#     'url': 'http://twitter.com/search?q=%22North+Wilkesboro%22',
#     'promoted_content': None,
#     'query': '%22North+Wilkesboro%22',
#     'tweet_volume': None},
#    {'name': 'Jahmyr Gibbs',
#     'url': 'http://twitter.com/search?q=%22Jahmyr+Gibbs%22',
#     'promoted_content': None,
#     'query': '%22Jahmyr+Gibbs%22',
#     'tweet_volume': None},
#    {'name': 'Taylor Walls',
#     'url': 'http://twitter.com/search?q=%22Taylor+Walls%22',
#     'promoted_content': None,
#     'query': '%22Taylor+Walls%22',
#     'tweet_volume': None}],
#   'as_of': '2022-04-16T21:14:14Z',
#   'created_at': '2022-04-13T11:48:02Z',
#   'locations': [{'name': 'Tampa', 'woeid': 2503863}]}]

# %% [markdown]
# Organize the Tampa trends in a dataframe.

# %%
# Get trend name, URL, and tweet volume from the JSON data, and store them in a list
trends_tampa_ls = [[trend['name'], trend['url'], trend['tweet_volume']] for trend in trends_tampa[0]['trends']]

# Convert the list to a dataframe
df_trends = pd.DataFrame(trends_tampa_ls,columns=['name','url','tweet_volume'])

# %% [markdown]
# Sort the trends by tweet volumn in a descending order and print the top 10 trends with the most tweeting volumne.

# %%
# Sort the trends by tweet volumn in a descending order
df_trends.sort_values("tweet_volume", inplace = True, ascending = False)

# Print the top 10 trends ranked by tweet volumne
df_trends.head(10)
# Out:
#             name                                             url  tweet_volume
# 7      Liverpool           http://twitter.com/search?q=Liverpool      251861.0
# 23  Happy Easter  http://twitter.com/search?q=%22Happy+Easter%22      235151.0
# 6        Arsenal             http://twitter.com/search?q=Arsenal      228960.0
# 9       Warriors            http://twitter.com/search?q=Warriors       82302.0
# 11          ESPN                http://twitter.com/search?q=ESPN       81693.0
# 20          Jazz                http://twitter.com/search?q=Jazz       79549.0
# 15          Luka                http://twitter.com/search?q=Luka       52967.0
# 36        Tucker              http://twitter.com/search?q=Tucker       51636.0
# 39        Dallas              http://twitter.com/search?q=Dallas       40181.0
# 32          Utah                http://twitter.com/search?q=Utah       39145.0

# %% [markdown]
# The table shows the popular topics people are tweeting about in Tampa.

# %% [markdown]
# ### Question 1: Please modify the code above to get the top 20 trending topics in New York City.

# %%
# ......

# %% [markdown]
# ---

# %% [markdown]
# ## 5. Acquiring Tweets using the Search API

# %% [markdown]
# ### 5.1 Search Tweets using Keywords
#
# In this step, you will use Python program to search tweets that contain a specific keyword. Next, we will search for Tweets that contain "Football".
#
# You can replace the key words to something you are interesting. Please try to choose a popular one so that you can collect sufficient tweets.

# %%
tweets = api.search_tweets("Football", count=100)

print("Total retweet retrieved: "+ str(len(tweets)))
# Out:
# Total retweet retrieved: 100

# %% [markdown]
# Store the user name, user location, posting time, and tweet text in a Pandas dataframe.

# %%
tweets_pd = pd.DataFrame([[tweet.user.name, tweet.user.location,tweet.created_at, tweet.text] for tweet in tweets], 
                         columns = ['user_name','user_loc','creation_time','text'])

tweets_pd
# Out:
#                   user_name                        user_loc  \
# 0                  Chapster  West Yorkshire but work in MCR
# 1                   Jourdan
# 2                Beardo Saz                       Metaverse
# 3                   Ollie🇺🇲           Fort Leonard Wood, MO
# 4            FÃÇTØS BRÃCÉ😎💰
# ..                      ...                             ...
# 95                👑ADINKRA😇                          Earth🌎
# 96  Kriss gin Nuñez Carazas
# 97  Ireland against Fascism                         Ireland
# 98      🅒︎🅡︎7 Ⓕ︎Ⓐ︎Ⓝ︎ 🅑︎🅞︎🅨︎                   Kerala, India
# 99                   Kofi J      Somewhere in the Universe
#
#                creation_time  \
# 0  2022-04-16 21:19:22+00:00
# 1  2022-04-16 21:19:21+00:00
# 2  2022-04-16 21:19:21+00:00
# 3  2022-04-16 21:19:21+00:00
# 4  2022-04-16 21:19:21+00:00
# ..                       ...
# 95 2022-04-16 21:18:44+00:00
# 96 2022-04-16 21:18:44+00:00
# 97 2022-04-16 21:18:43+00:00
# 98 2022-04-16 21:18:43+00:00
# 99 2022-04-16 21:18:42+00:00
#
#                                                  text
# 0   @LedwardAndy @tommo2510 I have said it before ...
# 1   @TFG_Football I would be if playoff basketball...
# 2   RT @IAmENISA: Going to my first Football game ...
# 3   Dudes a fucking 🤡\nOther than catching a footb...
# 4   RT @SaddickAdams: I'm honestly not sure if any...
# ..                                                ...
# 95  RT @Listo_Mens: HT’ Ahly 2-1 Raja Casablanca \...
# 96  RT @blue_roses35: Louis getting given a Belgiu...
# 97  As we've seen since the individual was charged...
# 98  RT @sistoney67: Manchester United 3-2 Norwich ...
# 99  RT @Malachians: Enjoy him now, we'll miss him ...
#
# [100 rows x 4 columns]

# %% [markdown]
# The `search_tweets` funciton can retrieve max 100 tweets at a time. If you want to get more tweets, you can use a `cursor`.
#
# The following code use a cursor to retrieve more tweets containing a keyword. Here we still retrieve 100 tweets to save your search quota for the following steps. You could increase the `num` variable if you want to get more tweets.
#
# > Note: Twitter only allows you to retrieve a limited number of tweets per 15 minutes. If the retrieved tweets exceed the limit, the program will pause for a certain amount time. If you can't wait, you can doublepress `i` on your keyboard to interrupt the process.

# %%
# Number of tweets to be retrieved.
num = 100

# define the search keyword
keyword = "Football"

# use cursor to send your request with parameters
tweets = tweepy.Cursor(api.search_tweets,
                   q = keyword,
                   count = num,
                   lang="en").items(num)

# restore the results as a list
tweet_ls = [[tweet.user.name, tweet.user.location,tweet.created_at, tweet.text] for tweet in tweets]

# Store the retrieved tweets in a dataframe
tweets_pd_full = pd.DataFrame(tweet_ls, 
                         columns = ['user_name','user_loc','creation_time','text'])

# Print the dataframe
tweets_pd_full
# Out:
#                           user_name  \
# 0                        Sam Minton
# 1          aterg; harry’s house era
# 2                         scarlet88
# 3                         KervSells
# 4            Holy Cross JV Football
# ..                              ...
# 95                          carl00z
# 96                          Torch 💎
# 97           The Arseholics Podcast
# 98                     tim fenander
# 99  Carol ☕ || Late Night Talking 💚
#
#                                              user_loc  \
# 0                                         Peabody, MA
# 1   she ¡! they (any pronouns)\n˗ˋˏsandy milkovich...
# 2
# 3
# 4                             Francis Lewis Boulevard
# ..                                                ...
# 95
# 96                                            Nigeria
# 97
# 98
# 99
#
#                creation_time  \
# 0  2022-04-16 21:19:38+00:00
# 1  2022-04-16 21:19:38+00:00
# 2  2022-04-16 21:19:38+00:00
# 3  2022-04-16 21:19:37+00:00
# 4  2022-04-16 21:19:37+00:00
# ..                       ...
# 95 2022-04-16 21:18:48+00:00
# 96 2022-04-16 21:18:48+00:00
# 97 2022-04-16 21:18:47+00:00
# 98 2022-04-16 21:18:47+00:00
# 99 2022-04-16 21:18:46+00:00
#
#                                                  text
# 0   I don’t want to alarm anyone and I’ll take pic...
# 1   RT @HLDTour: Louis signed a football shirt for...
# 2   RT @AWardSports: In my opinion, C.J. Stroud an...
# 3   RT @pinestbreakers: 🚨PRE-SALE LIVE ON DISCORD🚨...
# 4   🟢⚔️💛⚔️🟢\n•\nWishing a Happy Easter to all our ...
# ..                                                ...
# 95  RT @drgoatz: @football_muscIe @therealtyquendo...
# 96  The Vice Chancellor of the University of Footb...
# 97  RT @northbankninja: At a Craig David concert, ...
# 98  RT @NBCSEdgeFB: Jadeveon Clowney expected to r...
# 99  RT @HLDTour: Louis getting given a Belgium foo...
#
# [100 rows x 4 columns]

# %% [markdown]
# ### 5.2 Filter out Retweets
# The retrieved tweets include both original tweets and retweets. The content of retweets are almost identical and carry little information. You can set up a filter to eliminate the retweets and keep only the original tweets.
#
# To filter out retweets, you can simply add `-filter:retweets` in the search keyword.

# %%
new_keyword = "Football" + " -filter:retweets"
new_keyword
# Out:
# 'Football -filter:retweets'

# %% [markdown]
# The following code retrieve only original tweets that contain the keyword "Football".

# %%
# Number of tweets to be retrieved.
num = 100

# use cursor to send your request with parameters
tweets = tweepy.Cursor(api.search_tweets,
                   q = new_keyword,
                   count = num,
                   lang="en").items(num)

# restore the results as a list
tweet_ls = [[tweet.user.name, tweet.user.location,tweet.created_at, tweet.text] for tweet in tweets]

# Store the retrieved tweets in a dataframe
tweets_pd_full = pd.DataFrame(tweet_ls, 
                         columns = ['user_name','user_loc','creation_time','text'])

# Print the dataframe
tweets_pd_full
# Out:
#                                  user_name                           user_loc  \
# 0                              Obuseh Jude                            Nigeria
# 1                               bethastin✨                 Costa Del Rochdale
# 2                           pruno penandes                      inceltic park
# 3   Alabama Crimson Tide Football Alliance                     Tuscaloosa, AL
# 4                        freddie stevenson                            Purpose
# ..                                     ...                                ...
# 95                         KyleZoomZumbach                  Bullhead City, AZ
# 96                             Jonny Alves  Saint Helier, Bailiwick of Jersey
# 97                     Pennsylvania Sports                  Pennsylvania, USA
# 98                                freedumb                      ur moms house
# 99                      The Soccer Factory
#
#                creation_time  \
# 0  2022-04-16 21:23:44+00:00
# 1  2022-04-16 21:23:43+00:00
# 2  2022-04-16 21:23:37+00:00
# 3  2022-04-16 21:23:35+00:00
# 4  2022-04-16 21:23:34+00:00
# ..                       ...
# 95 2022-04-16 21:21:56+00:00
# 96 2022-04-16 21:21:54+00:00
# 97 2022-04-16 21:21:52+00:00
# 98 2022-04-16 21:21:50+00:00
# 99 2022-04-16 21:21:50+00:00
#
#                                                  text
# 0   @SuperSportTV Whether naysayers want to accept...
# 1   No matter the result football will never spoil...
# 2   @VincentEPhiri @ManCity You really don't know ...
# 3   LOOK: Top images from Alabama Football's A-Day...
# 4   All the @fcflio football games are at the Pull...
# ..                                                ...
# 95  I found it interesting there a ton of HS that ...
# 96  Clearly Portimonense didn’t fancy playing foot...
# 97  Alabama honors university’s first Black footba...
# 98  apparently i have astigmatism really bad and s...
# 99  Coach @keimar.clarke providing the details in ...
#
# [100 rows x 4 columns]

# %% [markdown]
# ### 5.3 Search Tweets using locations
#
# You can also search for tweets around a certain location. The spatial query is based on geotags and/or user locations of the tweets.
#
# The following code will retrieve 200 tweets containing "Football" within a 20 mile radius from USF (28.0619,-82.4146).

# %%
# Number of tweets to be retrieved.
num = 200

# define the search keyword
keyword = "Football"

# use cursor to send your request with parameters
tweets = tweepy.Cursor(api.search_tweets,
                   q=keyword,
                   geocode = "28.0619,-82.4146,20mi",
                   count = num,
                   lang="en").items(num)

# restore the results as a list
tweet_ls = [[tweet.user.name, tweet.user.location, tweet.place, tweet.created_at, tweet.text] for tweet in tweets]

# Store the retrieved tweets in a dataframe
tweets_pd_geo = pd.DataFrame(tweet_ls, 
                         columns = ['user_name','user_loc','geotag','creation_time','text'])

# Print the dataframe
tweets_pd_geo
# Out:
#                      user_name        user_loc  \
# 0                    Rob Maier   Clearwater,Fl
# 1              BADGIRL MELISSA       Tampa, FL
# 2                 Phillybuster  Clearwater, FL
# 3                        Kh813       Tampa, FL
# 4                    Mikey2CTA       Tampa, FL
# ..                         ...             ...
# 195           Thechosenone3488
# 196  Strawberry Crest Football       Dover, FL
# 197        #Fantasy #SKOL Dave       Tampa, FL
# 198                Bruce Wayne       Tampa, FL
# 199            Luke Easterling       Tampa, FL
#
#                                                 geotag  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 195  Place(_api=<tweepy.api.API object at 0x000001E...
# 196                                               None
# 197                                               None
# 198                                               None
# 199                                               None
#
#                 creation_time  \
# 0   2022-04-16 21:22:33+00:00
# 1   2022-04-16 21:18:03+00:00
# 2   2022-04-16 21:03:19+00:00
# 3   2022-04-16 20:56:27+00:00
# 4   2022-04-16 20:53:53+00:00
# ..                        ...
# 195 2022-04-14 18:38:05+00:00
# 196 2022-04-14 18:35:18+00:00
# 197 2022-04-14 18:27:32+00:00
# 198 2022-04-14 18:26:44+00:00
# 199 2022-04-14 18:16:05+00:00
#
#                                                   text
# 0    @ethanhub_ @UCF_Football @CoachHand @CoachGusM...
# 1    So ready for some football @usflonfox opening ...
# 2    🗓 Today (4/16) from 🕓 6pm-9pm\n📍 Womens Footba...
# 3    @ArmyWP_Football He’s Army Strong! A leader wi...
# 4    @NBA Love nba basketball…. Especially playoffs...
# ..                                                 ...
# 195  @DCarr75 @derekcarrqb My dream is lose 130 joi...
# 196  2022 Crest Football Schedule\n@TheSCHSChargers...
# 197  @jstockfive @Official_ACG Yea bro stick to foo...
# 198  @william_nixonTD @UW_Football @KalenDeBoer @Co...
# 199  2022 NFL draft: Nick Cross scouting report htt...
#
# [200 rows x 5 columns]

# %% [markdown]
# Next, we are going to map the tweets using their geotags. However, only a very small proportion (1-2%) of tweets have a geotag. We first check how many of the 200 tweets havea  geotag.

# %%
all = len(tweets_pd_geo[tweets_pd_geo['geotag'].notna()]) # all retrieved tweets
geo = len(tweets_pd_geo) # tweets that actually have geotags.

print("%s out of the %s retrieved tweets actually have a geotag" % (all, geo))
# Out:
# 23 out of the 200 retrieved tweets actually have a geotag

# %% [markdown]
# #### Copy tweets with geotags to a new dataframe called "geotags"

# %%
geo_tweets = tweets_pd_geo.loc[tweets_pd_geo['geotag'].notna()].copy()

# %% [markdown]
# Check detailed data in a geotag. The location of the geotag is in a bounding box defined by the four coordinate pairs.

# %%
geo_tweets.iloc[0].geotag
# Out:
# Place(_api=<tweepy.api.API object at 0x000001E1A0FD4400>, id='07d9df966e080000', url='https://api.twitter.com/1.1/geo/id/07d9df966e080000.json', place_type='poi', name='Tampa Bay Florida', full_name='Tampa Bay Florida', country_code='US', country='United States', contained_within=[], bounding_box=BoundingBox(_api=<tweepy.api.API object at 0x000001E1A0FD4400>, type='Polygon', coordinates=[[[-82.34978505052312, 28.030923683079468], [-82.34978505052312, 28.030923683079468], [-82.34978505052312, 28.030923683079468], [-82.34978505052312, 28.030923683079468]]]), attributes={})

# %% [markdown]
# Get coordinates of the bounding box

# %%
geo_tweets.iloc[0].geotag.bounding_box.coordinates
# Out:
# [[[-82.34978505052312, 28.030923683079468],
#   [-82.34978505052312, 28.030923683079468],
#   [-82.34978505052312, 28.030923683079468],
#   [-82.34978505052312, 28.030923683079468]]]

# %% [markdown]
# Create a column in the dataframe to store coordinates of the bounding boxes

# %%
# store bounding box coordinates to a new column
geo_tweets['bounding_box'] = geo_tweets.geotag.apply(lambda s:s.bounding_box.coordinates[0])

# print the geotag
geo_tweets.head()
# Out:
#                    user_name           user_loc  \
# 10  Sadarian *Yachty* Austin          Tampa, FL
# 16                     Shawn
# 35           BrandonSpikes55      Charlotte, NC
# 43            Xavier Porter🖤          Tampa, FL
# 52                Maggi Cook  St Petersburg, FL
#
#                                                geotag  \
# 10  Place(_api=<tweepy.api.API object at 0x000001E...
# 16  Place(_api=<tweepy.api.API object at 0x000001E...
# 35  Place(_api=<tweepy.api.API object at 0x000001E...
# 43  Place(_api=<tweepy.api.API object at 0x000001E...
# 52  Place(_api=<tweepy.api.API object at 0x000001E...
#
#                creation_time  \
# 10 2022-04-16 19:32:21+00:00
# 16 2022-04-16 18:16:37+00:00
# 35 2022-04-16 14:06:05+00:00
# 43 2022-04-16 12:42:41+00:00
# 52 2022-04-16 10:00:19+00:00
#
#                                                  text  \
# 10  Light weights during the baseball season getti...
# 16  @JamesPalmerTV @wyo_football @nflnetwork Hes g...
# 35  Lmao that league shit was wayyyyyy 2 easy 🤣🤣🤣 ...
# 43  I will be at The University of Central Florida...
# 52  If this was your family member wouldn't you be...
#
#                                          bounding_box
# 10  [[-82.34978505052312, 28.030923683079468], [-8...
# 16  [[-82.712772, 27.977811], [-82.675347, 27.9778...
# 35  [[-82.620093, 27.821353], [-82.2652945, 27.821...
# 43  [[-82.2679052, 27.930926], [-82.0556591, 27.93...
# 52  [[-82.369079, 27.755502], [-82.2443655, 27.755...

# %% [markdown]
# For mapping purpose, we will simplify the bounding boxes to their centroids (points). In such a way, each tweet will be pinned to the centroid of the bounding box in the geotag.
#
# The following code calculate the lat, lon of centroids and store them in two new columns.

# %%
geo_tweets['point']  = geo_tweets['bounding_box'].apply(lambda s: [(s[0][1]+s[2][1])/2,(s[0][0]+s[2][0])/2])

geo_tweets['lat']  = geo_tweets['bounding_box'].apply(lambda s: (s[0][1]+s[2][1])/2)

geo_tweets['lon']  = geo_tweets['bounding_box'].apply(lambda s: (s[0][0]+s[2][0])/2)

# %% [markdown]
# Print to see the dataframe again. You'll see the centroids, latitude, and longitude are added as columns in the dataframe.
#
# Note: the point column is an redundancy of the lat and lon columns. We create all these columns just in case you want to convert the dataframe to a geodataframe (geometry).

# %%
geo_tweets.head()
# Out:
#                    user_name           user_loc  \
# 10  Sadarian *Yachty* Austin          Tampa, FL
# 16                     Shawn
# 35           BrandonSpikes55      Charlotte, NC
# 43            Xavier Porter🖤          Tampa, FL
# 52                Maggi Cook  St Petersburg, FL
#
#                                                geotag  \
# 10  Place(_api=<tweepy.api.API object at 0x000001E...
# 16  Place(_api=<tweepy.api.API object at 0x000001E...
# 35  Place(_api=<tweepy.api.API object at 0x000001E...
# 43  Place(_api=<tweepy.api.API object at 0x000001E...
# 52  Place(_api=<tweepy.api.API object at 0x000001E...
#
#                creation_time  \
# 10 2022-04-16 19:32:21+00:00
# 16 2022-04-16 18:16:37+00:00
# 35 2022-04-16 14:06:05+00:00
# 43 2022-04-16 12:42:41+00:00
# 52 2022-04-16 10:00:19+00:00
#
#                                                  text  \
# 10  Light weights during the baseball season getti...
# 16  @JamesPalmerTV @wyo_football @nflnetwork Hes g...
# 35  Lmao that league shit was wayyyyyy 2 easy 🤣🤣🤣 ...
# 43  I will be at The University of Central Florida...
# 52  If this was your family member wouldn't you be...
#
#                                          bounding_box  \
# 10  [[-82.34978505052312, 28.030923683079468], [-8...
# 16  [[-82.712772, 27.977811], [-82.675347, 27.9778...
# 35  [[-82.620093, 27.821353], [-82.2652945, 27.821...
# 43  [[-82.2679052, 27.930926], [-82.0556591, 27.93...
# 52  [[-82.369079, 27.755502], [-82.2443655, 27.755...
#
#                                        point        lat        lon
# 10  [28.030923683079468, -82.34978505052312]  28.030924 -82.349785
# 16  [28.013468500000002, -82.69405950000001]  28.013469 -82.694060
# 35          [27.9965945, -82.44269374999999]  27.996595 -82.442694
# 43                [28.0121671, -82.16178215]  28.012167 -82.161782
# 52        [27.827367000000002, -82.30672225]  27.827367 -82.306722

# %% [markdown]
# ---

# %% [markdown]
# ## 6. Mapping Geotagged Tweets

# %% [markdown]
# Finally, we will use folium to create an interactive map for the geotagged tweets.

# %%
# Create a base map
maptweet = folium.Map()

# Add the tweets into the basemap
for i, row in geo_tweets.iterrows():
    folium.Marker(row.point,popup = row.text).add_to(maptweet)
    
# Zoom to the bounding box including the tweets
maptweet.fit_bounds([[min(geo_tweets.lat),min(geo_tweets.lon)],[max(geo_tweets.lat),max(geo_tweets.lon)]])

# Show the map
display(maptweet)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_fa3b9aa19dd3443d853b7d3c8a09e8ae%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_fa3b9aa19dd3443d853b7d3c8a09e8ae%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_fa3b9aa19dd3443d853b7d3c8a09e8ae%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_fa3b9aa19dd3443d853b7d3c8a09e8ae%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B0%2C%200%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs%3A%2 ...

# %% [markdown]
# ## 7. Streaming Tweets
#
# Unlike the Search API, the Streaming API utilizes Twitter's HTTP protocol to deliver data through an open, streaming API connection. A single streaming connection is opened between your app and the API, with new results being sent through that connection whenever new matches occur. This results in a low-latency delivery mechanism that can support very high throughput. For further information, see https://developer.twitter.com/en/docs/tutorials/consuming-streaming-data.
#
# Depending on the filter (the speed of retrieval), the streaming API is also subject to a limit per 15 minutes. If the retrieved tweets exceed the limit, your program will pause for the next 15 minutes cycle.
#
# Run the following code to start streaming. The text messages are printed. You can double press `I` to interrupt the streaming.

# %%
import tweepy
import folium
import pandas as pd

#from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

# paste your API keys and tokens to replace ......
API_key = 'As0PGxFkLLgXKyqnGCre08UNz'
API_key_secret = '6rzlzIBqgURxZd2PKjo4QTj4iYNiwINHDWDCMWW3zlxUU9xr23'
access_token = '1509606550134038533-TpQM7b6U3nlvewate1hJqqbMuHSl5p'
access_token_secret = 'jTMIxiyKndnxMAI1vJScVC8diddUgHO2EJvNbb4nozU8L'

auth = tweepy.OAuthHandler(API_key, API_key_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth, wait_on_rate_limit = True)

# %% [markdown]
# You can run the follow code to stream real-time tweets and save them in a CSV file in your computer.

# %%
import csv
# Define path and name of output file
output_file = "tweets_ukraine.csv"

# Open a file to write in streamed tweets
with open(output_file, "w", encoding="utf-8",newline='') as f:
    writer = csv.writer(f)
    
    # Write the headers in the first row
    writer.writerow(["username","created_at", "geotag", "user_location", "lang","tweet"])
    
    # Define a sub-object of tweepy.Stream
    class stream_csv(tweepy.Stream):
        def on_status(self, status):
            # Skip retweets and collect only geotagged tweets
            if (not status.retweeted) and ('RT @' not in status.text) and (status.place is not None):
                # Organize attributes of a tweet in a list
                line = [status.user.name, status.user.created_at, status.place.bounding_box.coordinates[0], status.user.location, status.lang, status.text]
                print(line) # Print the line
                writer.writerow(line) # write the line to csv file

    streamer = stream_csv(API_key, API_key_secret, access_token, access_token_secret)
    streamer.filter(languages=["en"], track=["ukraine"])
    streamer.sample()
# Out:
# ['Dr. John Swanson', datetime.datetime(2021, 2, 14, 20, 29, 4, tzinfo=datetime.timezone.utc), [[-87.940033, 41.644102], [-87.940033, 42.023067], [-87.523993, 42.023067], [-87.523993, 41.644102]], 'Chicago, IL', 'en', 'Does anyone care that there is myriad evidence showing Hunter Biden, along with his aunt and uncle, has enriched th… https://t.co/d0FtnBbkV0']
# ['Sarah Ashton-Cirillo', datetime.datetime(2015, 12, 8, 8, 34, 24, tzinfo=datetime.timezone.utc), [[22.13572, 44.386383], [22.13572, 52.379475], [40.227172, 52.379475], [40.227172, 44.386383]], 'Belgorod, Russia', 'en', 'How are the road conditions in #Ukraine️?\n\nJust  watch out for Russian Smerch rockets. \n\n#StandWithUkraine️ https://t.co/tKSEf6ihnM']
# ['Teri Morris 🧢', datetime.datetime(2009, 4, 22, 9, 12, 47, tzinfo=datetime.timezone.utc), [[-119.781386, 39.511797], [-119.781386, 39.636636], [-119.640003, 39.636636], [-119.640003, 39.511797]], 'Ireland', 'en', 'Pray for Ukraine 🙏🇺🇦🙏']
# ['Techi Weirdo🔴🔴🔴', datetime.datetime(2014, 8, 14, 14, 29, 55, tzinfo=datetime.timezone.utc), [[7.704219, 10.549665], [7.704219, 12.610589], [9.400511, 12.610589], [9.400511, 10.549665]], 'Your prayers! ', 'en', '@Etuks09 @Mustie01 @ThisIsAdemuyiwa So why are we crying foul then for Ukraine? With all the bans on russia et al?… https://t.co/nsTDkBZViI']
# ['Geraldine Collinge', datetime.datetime(2008, 12, 15, 17, 12, 3, tzinfo=datetime.timezone.utc), [[-1.403976, 52.070529], [-1.403976, 52.075537], [-1.390073, 52.075537], [-1.390073, 52.070529]], 'the countryside', 'en', 'Proud to be working on this. Please come. 👇🏻']
# ['Timor El-Dardiry', datetime.datetime(2017, 5, 25, 2, 5, 35, tzinfo=datetime.timezone.utc), [[-77.119401, 38.801826], [-77.119401, 38.99538], [-76.909396, 38.99538], [-76.909396, 38.801826]], 'Washington, DC', 'en', '“We see more clearly than ever the difference between two visions. One is held together by shared values. The other… https://t.co/LMgcqCxHCo']
# ['Jorge Riveras', datetime.datetime(2009, 4, 18, 19, 40, 39, tzinfo=datetime.timezone.utc), [[-71.49717, 42.257263], [-71.49717, 42.352931], [-71.374193, 42.352931], [-71.374193, 42.257263]], 'Boston, MA, USA', 'en', 'Very smart move.']
# ['🔥Adam Eidinger 🌊', datetime.datetime(2009, 4, 17, 14, 11, 24, tzinfo=datetime.timezone.utc), [[22.13572, 44.386383], [22.13572, 52.379475], [40.227172, 52.379475], [40.227172, 44.386383]], 'Washington, DC', 'en', 'Refugee relief hero’s taking a second to celebrate delivery of our supplies. I’m currently in Ukraine but heading b… https://t.co/EbUP0pNMnh']
# ['CHRISTOS ZINGELIS', datetime.datetime(2021, 10, 18, 19, 20, 23, tzinfo=datetime.timezone.utc), [[26.222125, 35.396632], [26.222125, 35.911022], [27.242249, 35.911022], [27.242249, 35.396632]], None, 'en', "@kromark @cxemu I don't trust #journalists from #czech #republic,from #Poland and from #Ukraine.Many of them are… https://t.co/hoM9KoOhTY"]
# ['Shafqat Rasool', datetime.datetime(2017, 10, 18, 5, 9, 28, tzinfo=datetime.timezone.utc), [[69.328873, 27.708226], [69.328873, 34.019989], [75.382124, 34.019989], [75.382124, 27.708226]], 'Islamabad, Pakistan', 'en', 'Russia is\xa0preparing the target for an invasion of Finland. The same mistake was made by Ukraine, just as Ukraine ha… https://t.co/ZjOaq1IZEV']
# ['Lynn Witter', datetime.datetime(2012, 9, 9, 20, 59, 57, tzinfo=datetime.timezone.utc), [[-85.605166, 30.355644], [-85.605166, 35.000771], [-80.742567, 35.000771], [-80.742567, 30.355644]], 'Georgia, USA', 'en', 'I guess that flagship finally went and f*cked itself.']
# ['Alexander Merrick-Tagore', datetime.datetime(2009, 4, 1, 17, 19, 56, tzinfo=datetime.timezone.utc), [[-77.601044, 37.447046], [-77.601044, 37.61272], [-77.385297, 37.61272], [-77.385297, 37.447046]], 'Richmond, Virginia', 'en', '#russia really is batshit crazy enough to use nukes to cover their disgusting assault on Ukraine. The fact the worl… https://t.co/bTDxcuKEmq']
# ['Jim Forsythe Citizens 4 Sound Money #SilverIsMoney', datetime.datetime(2019, 10, 21, 2, 33, 4, tzinfo=datetime.timezone.utc), [[-79.487651, 37.886607], [-79.487651, 39.723622], [-74.986286, 39.723622], [-74.986286, 37.886607]], 'Maryland, USA', 'en', '3331 Civilian deaths in Ukraine … as of 2019.  UN human rights report an interesting read.  Lots of bad stuff done… https://t.co/n7hJSYpE68']
# ['♥️RECONQUÊTE: LES LEGISLATIVES🇷🇺', datetime.datetime(2020, 5, 1, 14, 26, 13, tzinfo=datetime.timezone.utc), [[30.089689, 59.776171], [30.089689, 60.092125], [30.567707, 60.092125], [30.567707, 59.776171]], 'Saint-Pétersbourg - Russie', 'en', 'NATO needs to be dissembled PERIOD 😡\n\nThis war machine has caused too many deaths all over the world for far too ma… https://t.co/RQkZUg5Wo2']
# ['𝙳𝚊𝚗𝚐𝚊𝚕𝚊𝚍𝚒𝚖𝚊◽', datetime.datetime(2019, 1, 16, 17, 59, 55, tzinfo=datetime.timezone.utc), [[6.64002, 12.144721], [6.64002, 12.198644], [6.708463, 12.198644], [6.708463, 12.144721]], 'Nigeria', 'en', 'Us government donate Weapons to Ukraine to fight against Russian INVASIONS, \nAnd Now they Will sales to weapons to… https://t.co/40LzUFxBHv']
# ['Ben 3.5% #FBPE', datetime.datetime(2017, 8, 6, 10, 58, 16, tzinfo=datetime.timezone.utc), [[-1.957296, 50.574606], [-1.957296, 52.196285], [1.451788, 52.196285], [1.451788, 50.574606]], 'South East, England', 'en', 'If @NATO is a worthwhile organisation it would, today, state that #Ukraine️ is now a member. Russia repeatedly thre… https://t.co/ozGGgexSfI']
# ['christophe fournier', datetime.datetime(2012, 6, 12, 7, 41, 40, tzinfo=datetime.timezone.utc), [[6.945492, 46.166696], [6.945492, 46.225303], [7.034593, 46.225303], [7.034593, 46.166696]], None, 'en', '! #TikTok https://t.co/QAZbalnHGy.  After the invasion of Poland and Slovak Czechoslovakia, Adolf Hitler continued… https://t.co/7EYiPuYjko']
# ['Kaye wadland', datetime.datetime(2017, 3, 25, 15, 45, 57, tzinfo=datetime.timezone.utc), [[2.721873, 39.352337], [2.721873, 39.551931], [2.976412, 39.551931], [2.976412, 39.352337]], 'Bournemouth, UK', 'en', "@dana_lytics @PaulRam60679993 @RoryStewartUK Your Twitter name 'free Ukraine' Yet you are a follower of the very pe… https://t.co/Ao1my6h87f"]
# ['Ian Ainsworth', datetime.datetime(2013, 12, 25, 19, 44, 30, tzinfo=datetime.timezone.utc), [[-6.396672, 36.702279], [-6.396672, 36.907201], [-6.203069, 36.907201], [-6.203069, 36.702279]], 'Sanlucar de Barrameda, Spain', 'en', '@paulthomassj @nexta_tv Does it really matter, each one is one less for the Ukraine to take out later! Yes sad for… https://t.co/cooHybUxVe']
# ['Md Sabbir Hossin Sahan', datetime.datetime(2021, 9, 25, 16, 3, 7, tzinfo=datetime.timezone.utc), [[54.893973, 24.618253], [54.893973, 25.368672], [56.208372, 25.368672], [56.208372, 24.618253]], None, 'en', "Don't buy this #britannia Biscuit. One of Worst Think When You Eat. Like Gum on Biscuits. You Won't Eat this Biscui… https://t.co/QXuJYC2R6t"]
# ['Blue dot #StandsWithUkraine', datetime.datetime(2021, 7, 25, 17, 27, 9, tzinfo=datetime.timezone.utc), [[-95.774704, 35.995476], [-95.774704, 40.613641], [-89.098843, 40.613641], [-89.098843, 35.995476]], 'Ava, Missouri', 'en', 'Perhaps they heard the Ukrainians needed tanks and decided to donate theirs.']
# ['💞🚛 🚫 great reset🚫🕊️', datetime.datetime(2021, 12, 5, 12, 56, 48, tzinfo=datetime.timezone.utc), [[-110.033609, 40.27174], [-110.033609, 40.316605], [-109.972891, 40.316605], [-109.972891, 40.27174]], 'Utah, USA', 'en', 'CIA is getting desperate, will soon bomb Ukraine to start WW3']
# ['Pascal Wijler', datetime.datetime(2009, 6, 21, 16, 56, 50, tzinfo=datetime.timezone.utc), [[3.297662, 50.750449], [3.297662, 53.575704], [7.227545, 53.575704], [7.227545, 50.750449]], 'Culemborg, Nederland', 'en', 'Wondering who is gonna tell #Putin #Russia has no chance of winning this ‘special military operation’. - US assesse… https://t.co/c78UBuSsD6']
# ['christophe fournier', datetime.datetime(2012, 6, 12, 7, 41, 40, tzinfo=datetime.timezone.utc), [[6.945492, 46.166696], [6.945492, 46.225303], [7.034593, 46.225303], [7.034593, 46.166696]], None, 'en', '! #TikTok https://t.co/ejmPPUdfjl.  After the invasion of Poland and Slovak Czechoslovakia, Adolf Hitler continued… https://t.co/ucDFhYoT93']
# ['CHG', datetime.datetime(2009, 9, 16, 8, 53, 49, tzinfo=datetime.timezone.utc), [[-1.588652, 54.014049], [-1.588652, 54.029945], [-1.561486, 54.029945], [-1.561486, 54.014049]], None, 'en', "The missiles that definitely didn't hit the ship though right? Because it was sunk by a chip pan fire right? Right?"]
# ['sandra myers', datetime.datetime(2011, 9, 13, 1, 11, 59, tzinfo=datetime.timezone.utc), [[-87.634643, 24.396308], [-87.634643, 31.001056], [-79.974307, 31.001056], [-79.974307, 24.396308]], 'jacksonville fl', 'en', 'Ask Trump he said he was a strong man 😄 😄 😄.']
# ['Bernd 🇺🇦 🇪🇺 Hüttemann #StandWithUkraine', datetime.datetime(2008, 10, 29, 11, 19, 24, tzinfo=datetime.timezone.utc), [[13.088304, 52.338079], [13.088304, 52.675323], [13.760909, 52.675323], [13.760909, 52.338079]], 'Mitte, Berlin | Çukurcuma ', 'en', 'At last, Germany is stepping up its military support for Ukraine and freedom in Europe. #StandUpForUkraine']
# ['LYNNHERNANDEZ', datetime.datetime(2008, 12, 12, 17, 25, 28, tzinfo=datetime.timezone.utc), [[-96.065628, 35.968624], [-96.065628, 36.250159], [-95.761656, 36.250159], [-95.761656, 35.968624]], 'Tulsa, OK USA', 'en', 'YOUR Tulsa Drillers!  \nHere is my weekly @tulsakids article. @TulsaDrillers @circlecinema @1033theeagle #Ukraine Fu… https://t.co/X6p4COjIB4']
# ['shlomo cohen', datetime.datetime(2012, 8, 26, 6, 50, 51, tzinfo=datetime.timezone.utc), [[-2.625614, 53.22682], [-2.625614, 53.247512], [-2.582595, 53.247512], [-2.582595, 53.22682]], None, 'en', 'I’m quite sure how to answer that Brian. It always puzzles me how you can commit horrendous crimes then ask for for… https://t.co/AEPOXJPpd9']
# ['Timor El-Dardiry', datetime.datetime(2017, 5, 25, 2, 5, 35, tzinfo=datetime.timezone.utc), [[-77.119401, 38.801826], [-77.119401, 38.99538], [-76.909396, 38.99538], [-76.909396, 38.801826]], 'Washington, DC', 'en', '“The Hague has plenty of experience in dealing with war criminals. We are doing all we can to support institutions… https://t.co/ZlFaVgag2p']
# ['DailyNews 🇮🇹', datetime.datetime(2022, 2, 9, 7, 43, 20, tzinfo=datetime.timezone.utc), [[101.761437, 3.057213], [101.761437, 3.284394], [101.965355, 3.284394], [101.965355, 3.057213]], 'Italy', 'en', 'Dolly Parton dedicates country music awards show to Ukraine - Free Malaysia Today https://t.co/UMzmWoKBrr']
# ['appanah sanasy', datetime.datetime(2019, 11, 7, 13, 7, 32, tzinfo=datetime.timezone.utc), [[101.576775, 2.979654], [101.576775, 3.086195], [101.730576, 3.086195], [101.730576, 2.979654]], 'Bandar Kuala Lumpur, Wilayah P', 'en', 'Stop Putin war and save Ukrainian civilians killing immediately from evil man Putin https://t.co/rakPAPmB5B']
# ['Dan Kriwitsky', datetime.datetime(2015, 1, 29, 22, 6, 12, tzinfo=datetime.timezone.utc), [[-82.522638, 27.233261], [-82.522638, 27.276742], [-82.497484, 27.276742], [-82.497484, 27.233261]], None, 'en', "Do not buy any Chinese cod or pollock. It's really Russian. \nhttps://t.co/R9Mq7aNyWn"]
# ['Ally Hunter Blair', datetime.datetime(2021, 8, 4, 8, 46, 16, tzinfo=datetime.timezone.utc), [[-3.235601, 51.825903], [-3.235601, 53.22621], [-1.172136, 53.22621], [-1.172136, 51.825903]], 'West Midlands, England', 'en', 'Great idea from @OzOverboots']
# ['NavHazard88', datetime.datetime(2011, 10, 29, 22, 43, 54, tzinfo=datetime.timezone.utc), [[-122.708264, 47.43909], [-122.708264, 47.548799], [-122.603325, 47.548799], [-122.603325, 47.43909]], 'Washington, USA', 'en', 'Ukraine already mostly in rubble:\n\nWe accept! 🙄🤣 https://t.co/xhvBs8YX62']
# ['Teri Morris 🧢', datetime.datetime(2009, 4, 22, 9, 12, 47, tzinfo=datetime.timezone.utc), [[-119.781386, 39.511797], [-119.781386, 39.636636], [-119.640003, 39.636636], [-119.640003, 39.511797]], 'Ireland', 'en', 'Russia is like ... just let us fuck Ukraine over without any consequences']
# ['Noah Arbit 🇺🇦', datetime.datetime(2010, 2, 2, 12, 21, 54, tzinfo=datetime.timezone.utc), [[-83.441942, 42.52605], [-83.441942, 42.617858], [-83.32039, 42.617858], [-83.32039, 42.52605]], 'West Bloomfield, MI', 'en', 'This Passover, my thoughts are with Ukraine, including the nearly 100,000 Ukrainian Jews, in their ongoing, valiant… https://t.co/EPrVB4eije']
# ['jane h dexter', datetime.datetime(2015, 4, 30, 13, 1, 15, tzinfo=datetime.timezone.utc), [[-72.620117, 42.06398], [-72.620117, 42.162145], [-72.471052, 42.162145], [-72.471052, 42.06398]], None, 'en', 'Clear to see how 45 and Co would like to structure America. The putin model']
# ['🎇✨ Claire ✨🎆', datetime.datetime(2013, 7, 9, 18, 34, 2, tzinfo=datetime.timezone.utc), [[-2.136647, 57.175416], [-2.136647, 57.202663], [-2.079704, 57.202663], [-2.079704, 57.175416]], 'Aberdeen🏴\U000e0067\U000e0062\U000e0073\U000e0063\U000e0074\U000e007fSCOTLAND', 'en', '@KyivIndependent I think #Ukraine should wait until this war is over \nThey’re threatening to bomb Kyiv again… https://t.co/T5G1itHMh6']
# ['charles george', datetime.datetime(2014, 11, 22, 23, 24, 57, tzinfo=datetime.timezone.utc), [[-75.64076, 6.104151], [-75.64076, 6.157083], [-75.601881, 6.157083], [-75.601881, 6.104151]], 'Sabaneta, Colombia', 'en', '@DeptofDefense it appears that Ukraine has been handed a gold coin . The Belarus collapse and support for the ukrai… https://t.co/Mm9dt5SReG']
# ['Timor El-Dardiry', datetime.datetime(2017, 5, 25, 2, 5, 35, tzinfo=datetime.timezone.utc), [[-77.119401, 38.801826], [-77.119401, 38.99538], [-76.909396, 38.99538], [-76.909396, 38.801826]], 'Washington, DC', 'en', '“We will see it through for the benefit of our generation and of all the generations to come.” @WBHoekstra closing… https://t.co/TL5eMggMxu']
# ['Aramis Nunez Miller', datetime.datetime(2014, 9, 30, 2, 0, 47, tzinfo=datetime.timezone.utc), [[-106.645646, 25.837092], [-106.645646, 36.500695], [-93.508131, 36.500695], [-93.508131, 25.837092]], None, 'en', 'UKRAINE WILL PREVAIL\n#StandWithUkraine️']
# ['appanah sanasy', datetime.datetime(2019, 11, 7, 13, 7, 32, tzinfo=datetime.timezone.utc), [[101.576775, 2.979654], [101.576775, 3.086195], [101.730576, 3.086195], [101.730576, 2.979654]], 'Bandar Kuala Lumpur, Wilayah P', 'en', "Now after the Putin regime collapsed, don't stop sanction on Russia for good souls of Ukrainian civilians killings… https://t.co/T8TGpW9yCW"]
# ['Mahmud Nawaz 💙', datetime.datetime(2010, 1, 23, 12, 25, 2, tzinfo=datetime.timezone.utc), [[-1.551536, 53.636339], [-1.551536, 53.722056], [-1.465554, 53.722056], [-1.465554, 53.636339]], 'Wakefield, England', 'en', '@Debbie_abrahams Thank you 🙏 \n\nAlarming brutality. Badged up by UK media as ‘clashes’ as if equal force on both sid… https://t.co/P2n92L8FuT']
# ['Markku Tapio Tuomola 🇫🇮🇺🇸🇷🇺🇺🇦🇮🇱', datetime.datetime(2010, 10, 12, 19, 56, 24, tzinfo=datetime.timezone.utc), [[21.02351, 59.675274], [21.02351, 60.49875], [22.5429, 60.49875], [22.5429, 59.675274]], 'Finland', 'en', 'Clip from Kharkov, Ukraine, 2022 -  Oops. From Beirut, Lebanon, 2020,\n\nThe War is real - The News is fake. https://t.co/shfBU5yET6']
# ['Athish Suhas🇮🇳', datetime.datetime(2021, 7, 20, 17, 0, 24, tzinfo=datetime.timezone.utc), [[77.330578, 12.731936], [77.330578, 13.114293], [77.786319, 13.114293], [77.786319, 12.731936]], None, 'en', 'Countries that maintain a neutral stance on the situation in Ukraine could face global isolation — said U.S. Treasu… https://t.co/Set58ur4Cd']
# ['Ginger resists  🌊🌊🌊🌊🏄\u200d♂️', datetime.datetime(2013, 3, 4, 3, 24, 11, tzinfo=datetime.timezone.utc), [[-78.889267, 42.958569], [-78.889267, 42.973238], [-78.853089, 42.973238], [-78.853089, 42.958569]], 'Buffalo, NY', 'en', 'Hell yeah!!!! Go Ukraine!! We stand with Ukraine 💯💯💯🇺🇦']
# ['Michael', datetime.datetime(2014, 5, 10, 13, 31, 36, tzinfo=datetime.timezone.utc), [[-85.186921, 35.065799], [-85.186921, 35.199961], [-85.035296, 35.199961], [-85.035296, 35.065799]], 'Chattanooga, TN', 'en', "UN Security Council hears of Russian atrocities against Ukraine's women and girls: rapes, mass abductions\n\nhttps://t.co/cdKCiQjPYt"]
# ['Joe Grimaldi', datetime.datetime(2012, 1, 12, 17, 53, 26, tzinfo=datetime.timezone.utc), [[-87.634643, 24.396308], [-87.634643, 31.001056], [-79.974307, 31.001056], [-79.974307, 24.396308]], 'Clair Mel City, Florida', 'en', "Does Ukraine have the rocket power to take out Russia's Oil &amp; Gas operations as a last resort if Putin's decision t… https://t.co/1ymraLe3zh"]
# ['CNNWynn', datetime.datetime(2011, 1, 23, 23, 17, 43, tzinfo=datetime.timezone.utc), [[-84.576827, 33.647503], [-84.576827, 33.886886], [-84.289385, 33.886886], [-84.289385, 33.647503]], 'Atlanta', 'en', 'US assesses two Ukrainian missiles struck Russian warship \n#UkraineRussianWar #Ukraine️ #Russia \n https://t.co/lqbG1Bk989']
# ['John Adams', datetime.datetime(2012, 10, 4, 2, 52, tzinfo=datetime.timezone.utc), [[-82.555165, 40.044145], [-82.555165, 40.086227], [-82.46731, 40.086227], [-82.46731, 40.044145]], None, 'en', 'All the more reason for Israel to totally support Ukraine']
# ['Stephen Venn', datetime.datetime(2010, 11, 3, 13, 3, 29, tzinfo=datetime.timezone.utc), [[19.320808, 51.686377], [19.320808, 51.860354], [19.640373, 51.860354], [19.640373, 51.686377]], 'Łódź, Polska', 'en', '@SamRamani2 Maybe Ukraine should consider declaring war on Russia.']
# ['O. P. P. Erator', datetime.datetime(2013, 6, 4, 16, 15, 2, tzinfo=datetime.timezone.utc), [[-97.350366, 49.713679], [-97.350366, 49.993932], [-96.954987, 49.993932], [-96.954987, 49.713679]], 'California, USA', 'en', '@TomCottonAR Pooptin will get more deadly and more dishonest in his bid to take Ukraine...in his bid to make the so… https://t.co/jjNRkNOlLC']
# ['jabs!', datetime.datetime(2018, 1, 10, 13, 41, 18, tzinfo=datetime.timezone.utc), [[-0.336055, 51.527592], [-0.336055, 51.602799], [-0.190226, 51.602799], [-0.190226, 51.527592]], 'England, United Kingdom', 'en', 'When you run a business and you weigh all the pros and cons you’d think about it too!Problem with ppl with pen and… https://t.co/WFCn45lBJm']
# ['Richy X.', datetime.datetime(2009, 7, 25, 16, 34, 46, tzinfo=datetime.timezone.utc), [[-116.637186, 43.523489], [-116.637186, 43.634335], [-116.502031, 43.634335], [-116.502031, 43.523489]], 'Boise, ID', 'en', "If you don't know that Ukraine is a hub for human trafficking than you have been watching much fake news"]
# ['ProudIndian999', datetime.datetime(2013, 10, 18, 16, 2, 28, tzinfo=datetime.timezone.utc), [[-77.641611, 37.666176], [-77.641611, 37.710351], [-77.592347, 37.710351], [-77.592347, 37.666176]], 'Coimbatore, India', 'en', '@balapkamath @Chellaney @WSJ Sale ? How exactly is Ukraine paying ? If not for US and EU help, Russia would have go… https://t.co/ehdEHdcIWz']
# ['O. P. P. Erator', datetime.datetime(2013, 6, 4, 16, 15, 2, tzinfo=datetime.timezone.utc), [[-97.350366, 49.713679], [-97.350366, 49.993932], [-96.954987, 49.993932], [-96.954987, 49.713679]], 'California, USA', 'en', '@HouseGOP ukraine..srilanka..afganastan..north korea.suffer real pain. democracy is fragile, as we witnessed almost… https://t.co/ozAVffVAnz']
# ['Dr. Belete Yilma (Asoc Prof.)', datetime.datetime(2012, 6, 19, 8, 57, 56, tzinfo=datetime.timezone.utc), [[32.997691, 3.404962], [32.997691, 14.894214], [47.999477, 14.894214], [47.999477, 3.404962]], 'LA', 'en', 'The head of @WHO is now blaming racism for world\'s focus on Ukraine over "Tigray crisis," while he is part of a min… https://t.co/Jf9edEC2og']
# ['Ільєсс Ель Кортбі 🇺🇦', datetime.datetime(2016, 8, 24, 10, 14, 57, tzinfo=datetime.timezone.utc), [[6.772567, 50.830287], [6.772567, 51.084947], [7.162373, 51.084947], [7.162373, 50.830287]], 'Berlin, Germany', 'en', 'Today is Easter\n\nChildren collect eggs,\nGermany extracts Coal, \nby destroying homes on its own lands.  \n\nToday is t… https://t.co/tXyUcC5UZp']
# ['CNNWynn', datetime.datetime(2011, 1, 23, 23, 17, 43, tzinfo=datetime.timezone.utc), [[-84.576827, 33.647503], [-84.576827, 33.886886], [-84.289385, 33.886886], [-84.289385, 33.647503]], 'Atlanta', 'en', 'More than 900 bodies of Ukrainian civilians discovered in Kyiv region since Russian withdrawal, police say \n#Kyiv… https://t.co/2yAnny5KDo']
# ['Richy X.', datetime.datetime(2009, 7, 25, 16, 34, 46, tzinfo=datetime.timezone.utc), [[-116.637186, 43.523489], [-116.637186, 43.634335], [-116.502031, 43.634335], [-116.502031, 43.523489]], 'Boise, ID', 'en', "If you don't know that Ukraine is a hub for human trafficking than you have been watching to much fake news"]
# ['CNNWynn', datetime.datetime(2011, 1, 23, 23, 17, 43, tzinfo=datetime.timezone.utc), [[-84.576827, 33.647503], [-84.576827, 33.886886], [-84.289385, 33.886886], [-84.289385, 33.647503]], 'Atlanta', 'en', 'More than 900 bodies of Ukrainian civilians discovered in Kyiv region since Russian withdrawal, police say https://t.co/pwHxjKvXzE']
# ['M Faraz Hakim (محمد فراز حاکم)', datetime.datetime(2016, 2, 27, 20, 56, 50, tzinfo=datetime.timezone.utc), [[74.267586, 31.451222], [74.267586, 31.612417], [74.449387, 31.612417], [74.449387, 31.451222]], 'Bahawalnagar, Pakistan', 'en', 'This is #Islam third holiest site being assaulted in Islam’s holiest month by #Israeli occupation forces. #Europe &amp;… https://t.co/cRpxgQ6jYq']
# ['Chloe Westwood (she/her)', datetime.datetime(2009, 2, 19, 10, 46, 29, tzinfo=datetime.timezone.utc), [[-0.122502, 51.512976], [-0.122502, 51.512976], [-0.122502, 51.512976], [-0.122502, 51.512976]], 'West Sussex', 'en', 'Concert for Ukraine 🇺🇦💙💛 https://t.co/oLMqCxN4dK']
# ['stevemo1966', datetime.datetime(2015, 8, 30, 13, 33, 18, tzinfo=datetime.timezone.utc), [[-90.67755, 38.700023], [-90.67755, 38.815652], [-90.523651, 38.815652], [-90.523651, 38.700023]], '63303', 'en', '@IvoHDaalder @mitchellreports Thank you!    So, US/NATO first level of response is a conventional arms humiliation… https://t.co/LsVqreROvH']
# ['Prue Rayner', datetime.datetime(2017, 2, 23, 21, 25, 25, tzinfo=datetime.timezone.utc), [[-0.74578, 51.448222], [-0.74578, 52.992679], [1.768936, 52.992679], [1.768936, 51.448222]], 'East, England', 'en', 'Just listened to Letter from Ukraine. I will not ever be the same person again. 💝']
# ['Abd.Rahman', datetime.datetime(2012, 9, 21, 13, 30, 17, tzinfo=datetime.timezone.utc), [[95.315328, 5.539385], [95.315328, 5.586661], [95.371285, 5.586661], [95.371285, 5.539385]], 'Banda Aceh', 'en', 'Russian president Vladimir Putin is increasingly beating the drums of World War III, creating regional instability… https://t.co/MwPzlTicfd']
# ['Shari Comiter', datetime.datetime(2018, 6, 12, 15, 59, 57, tzinfo=datetime.timezone.utc), [[-81.276412, 28.510068], [-81.276412, 28.539293], [-81.252405, 28.539293], [-81.252405, 28.510068]], None, 'en', 'Liar for Biden photo optics only and no humanitarian efforts at open borders, only greed of taxpayers money for one… https://t.co/wTCg05trGs']
# ['ezaius', datetime.datetime(2021, 7, 10, 16, 22, 15, tzinfo=datetime.timezone.utc), [[32.671893, -17.12765], [32.671893, -9.367084], [35.92038, -9.367084], [35.92038, -17.12765]], 'Malawi', 'en', 'It is a special operation..']
# ['Christine Enterlein', datetime.datetime(2011, 4, 12, 10, 55, 7, tzinfo=datetime.timezone.utc), [[8.42016, 53.395118], [8.42016, 53.964655], [10.325199, 53.964655], [10.325199, 53.395118]], 'Hamburg', 'en', '#standwithukraine from Liv, 6 years old. \n\n#easter #eastereggs #easter #ukraine #peaceforukraine #peacenotwar… https://t.co/zZ9P2Af4Nx']
# ['Rob Howse', datetime.datetime(2013, 3, 14, 20, 53, 47, tzinfo=datetime.timezone.utc), [[-74.026675, 40.683935], [-74.026675, 40.877483], [-73.910408, 40.877483], [-73.910408, 40.683935]], 'Montauk/New York City', 'en', 'Israeli diamond traders fund Putin’s war machine in Ukraine https://t.co/Y4EbM6CJXh']
# ['@geincolo', datetime.datetime(2010, 11, 28, 7, 32, 47, tzinfo=datetime.timezone.utc), [[-105.147267, 39.894185], [-105.147267, 40.000314], [-104.997195, 40.000314], [-104.997195, 39.894185]], 'Broomfield, Colorado', 'en', 'Watch: Disturbing #FoxNews clip captures Republican Trump boasting about his relationship with Putin as network sho… https://t.co/XgYhbm9PW0']
# ['M Faraz Hakim (محمد فراز حاکم)', datetime.datetime(2016, 2, 27, 20, 56, 50, tzinfo=datetime.timezone.utc), [[74.267586, 31.451222], [74.267586, 31.612417], [74.449387, 31.612417], [74.449387, 31.451222]], 'Bahawalnagar, Pakistan', 'en', "Israel's occupation forces ruthlessly assaulted Aqsa today. The rotten egg kittens of the United Nations make large… https://t.co/LHBgJtV64o"]
# ['كلا والقمر', datetime.datetime(2021, 9, 3, 14, 49, 56, tzinfo=datetime.timezone.utc), [[50.750076, 24.556366], [50.750076, 26.182898], [51.630581, 26.182898], [51.630581, 24.556366]], None, 'en', '#انقضا_التحذير_بالقمر_النذير\n\n#AlMahdiCaliphOfAllah\nAL\nImam Nasser Mohammed Al-Yamani\n\nIslam\nPakistan\n#Ukraine\nlock… https://t.co/0mOPQpuN7H']
# ['Stephen Venn', datetime.datetime(2010, 11, 3, 13, 3, 29, tzinfo=datetime.timezone.utc), [[19.320808, 51.686377], [19.320808, 51.860354], [19.640373, 51.860354], [19.640373, 51.686377]], 'Łódź, Polska', 'en', '@derek_wilson_01 @OstapYarysh @cxemu @SvobodaRadio Or he travels outside Russia. Maybe an arrest warrant in Ukraine.']
# ['McCoy Smith', datetime.datetime(2009, 6, 10, 20, 6, 21, tzinfo=datetime.timezone.utc), [[-122.790065, 45.421863], [-122.790065, 45.650941], [-122.471751, 45.650941], [-122.471751, 45.421863]], 'Oregon, USA', 'en', '@marklemley “Our ship totally sunk on its own. This means war!”\n[To be fair, that sort of worked in the Spanish-Ame… https://t.co/5HpIbtNjBi']
# ['Arnaud ABEL', datetime.datetime(2019, 9, 22, 8, 19, 52, tzinfo=datetime.timezone.utc), [[0.99065, 48.075453], [0.99065, 48.157403], [1.167309, 48.157403], [1.167309, 48.075453]], 'Paris, France', 'en', '«\xa0All the attention given to Ukraine is very important [...], but not even a fraction [of this attention] is given… https://t.co/dnCTcaSSgj']
# ['Bill Slawski ⚓ 🇺🇦', datetime.datetime(2008, 12, 1, 23, 26, 18, tzinfo=datetime.timezone.utc), [[-117.359298, 33.060615], [-117.359298, 33.182353], [-117.216549, 33.182353], [-117.216549, 33.060615]], 'San Diego, CA', 'en', 'Ukraine supplies Matza\n\nhttps://t.co/Hjx7DzmRpb']
# ['LmkReal', datetime.datetime(2012, 4, 19, 23, 9, 14, tzinfo=datetime.timezone.utc), [[-9.938123, 52.557213], [-9.938123, 53.160735], [-8.281976, 53.160735], [-8.281976, 52.557213]], 'lmk', 'en', 'Russia sends Warning to US and NATO to back off and stop sending Arms to #Ukraine or else face unpredictable conseq… https://t.co/GlXudKdD2W']
# ['OLUSOLA/LOVENOTHATE', datetime.datetime(2012, 5, 22, 7, 9, 36, tzinfo=datetime.timezone.utc), [[19.320808, 51.686377], [19.320808, 51.860354], [19.640373, 51.860354], [19.640373, 51.686377]], 'United States', 'en', '@AndreaS53523833 @yermolenko_v @NaUKMA Yes. Ukraine is beautiful. Plenty restaurants you can have lunch and breakfa… https://t.co/f48aUdPJMf']
# ['O. P. P. Erator', datetime.datetime(2013, 6, 4, 16, 15, 2, tzinfo=datetime.timezone.utc), [[-97.350366, 49.713679], [-97.350366, 49.993932], [-96.954987, 49.993932], [-96.954987, 49.713679]], 'California, USA', 'en', '@nypost Time to call putins hand..then take him out.  Hes using airspace above Ukraine to kill children..women..and… https://t.co/rGSLqoxPdh']
# ['APURBA ROY CHOWDHURY', datetime.datetime(2014, 5, 21, 6, 7, 2, tzinfo=datetime.timezone.utc), [[88.094457, 22.269493], [88.094457, 22.955918], [88.610027, 22.955918], [88.610027, 22.269493]], 'Kolkata, India', 'en', 'Putin : You have already gone too far. You must stop right now. You are now left with only adversaries. Even China… https://t.co/K8r4ICM81p']
# ['Chris Jones🏴\U000e0067\U000e0062\U000e0077\U000e006c\U000e0073\U000e007f🏈☠️🏴\u200d☠️', datetime.datetime(2012, 1, 31, 19, 18, 4, tzinfo=datetime.timezone.utc), [[-4.203701, 50.360251], [-4.203701, 50.444179], [-4.082159, 50.444179], [-4.082159, 50.360251]], 'Cwmbran, Torfaen', 'en', 'Drinking an United For Ukraine by @BrewDog @ BrewDog Plymouth — https://t.co/bwpsLseSoM']
# ['CHRISTOS ZINGELIS', datetime.datetime(2021, 10, 18, 19, 20, 23, tzinfo=datetime.timezone.utc), [[26.222125, 35.396632], [26.222125, 35.911022], [27.242249, 35.911022], [27.242249, 35.396632]], None, 'en', '@LetMyPplGoUA_en When the #neonazi of #AzovBattalion killed the #greek #citizens of #Ukraine your mouth was closed.https://t.co/nnSuVLMaoe']
# ['Sheri Shibuya', datetime.datetime(2022, 4, 1, 15, 52, 59, tzinfo=datetime.timezone.utc), [[-158.032127, 21.36976], [-158.032127, 21.399415], [-157.990212, 21.399415], [-157.990212, 21.36976]], None, 'en', '@tsa @DHSgov in my opinion, those who are Russian born in leadership positions in the U.S. Government ought to temp… https://t.co/CroIZzk89E']
# ['Dr. Allison MacDuffee', datetime.datetime(2010, 1, 11, 4, 5, 1, tzinfo=datetime.timezone.utc), [[-79.639319, 43.403221], [-79.639319, 43.855401], [-78.90582, 43.855401], [-78.90582, 43.403221]], 'Toronto, Ontario, Canada', 'en', 'Lovely!  Glad this dog found a friend in Ukraine.🇺🇦']
# ['🎇✨ Claire ✨🎆', datetime.datetime(2013, 7, 9, 18, 34, 2, tzinfo=datetime.timezone.utc), [[-2.136647, 57.175416], [-2.136647, 57.202663], [-2.079704, 57.202663], [-2.079704, 57.175416]], 'Aberdeen🏴\U000e0067\U000e0062\U000e0073\U000e0063\U000e0074\U000e007fSCOTLAND', 'en', '@Podolyak_M Every city in #Ukraine️ will be targeted.. until #russia loses the war \n#SaveCash #BeWary \n\nSpend money… https://t.co/WxPVOfgfwB']
# ['Sarah RN 🌈🩺🩺', datetime.datetime(2017, 8, 31, 3, 19, 32, tzinfo=datetime.timezone.utc), [[-92.889433, 42.491921], [-92.889433, 47.309715], [-86.24955, 47.309715], [-86.24955, 42.491921]], 'Wisconsin, USA', 'en', 'Bless you all. What an incredible organization of amazing human  beings. #ChefsForUkraine']
# ['Jo Anne Foley', datetime.datetime(2017, 5, 19, 16, 18, 20, tzinfo=datetime.timezone.utc), [[-86.178184, 42.812004], [-86.178184, 42.866339], [-86.11236, 42.866339], [-86.11236, 42.812004]], 'West Michigan, USA ', 'en', 'I stand with the owner']
# ['Coco Coindreau S. 🇺🇦', datetime.datetime(2015, 1, 20, 20, 55, 13, tzinfo=datetime.timezone.utc), [[-106.645646, 25.837092], [-106.645646, 36.500695], [-93.508131, 36.500695], [-93.508131, 25.837092]], 'Mexico', 'en', 'Next up on Ukraine’s hit list should be the Admiral Kuznetsov aircraft carrier']
# ["Honey'd Nymph of Evil 🐝", datetime.datetime(2009, 5, 17, 3, 43, 26, tzinfo=datetime.timezone.utc), [[-80.268234, 26.135832], [-80.268234, 26.193897], [-80.192482, 26.193897], [-80.192482, 26.135832]], 'Ft.Lauderdale , Florida', 'en', "While Russia is not telling these families where their boys are, Ukraine e-mailing a snap of their corpse ID'd thro… https://t.co/k90105xCts"]
# ['Tanvir.azad@lostcanto.com', datetime.datetime(2022, 1, 13, 3, 2, 26, tzinfo=datetime.timezone.utc), [[-79.088521, 43.573543], [-79.088521, 43.92266], [-78.807896, 43.92266], [-78.807896, 43.573543]], None, 'en', 'Hi i am donating 100% of profit to UNICEF Ukraine \n\nhttps://t.co/pmNQh6c7mf\n\n#SlavaUkraini #Ukraine #Ukraine #UNICEF']
# ['Rose PArsons', datetime.datetime(2019, 6, 10, 23, 56, 5, tzinfo=datetime.timezone.utc), [[-98.778559, 29.141956], [-98.778559, 29.693046], [-98.302744, 29.693046], [-98.302744, 29.141956]], 'TEXAS', 'en', 'https://t.co/KrlbbhCfBy\n\nUkrainian President Volodymyr Zelensky said “all of the world” should be concerned that Ru… https://t.co/Ms32mS93ep']
# ['🎇✨ Claire ✨🎆', datetime.datetime(2013, 7, 9, 18, 34, 2, tzinfo=datetime.timezone.utc), [[-2.136647, 57.175416], [-2.136647, 57.202663], [-2.079704, 57.202663], [-2.079704, 57.175416]], 'Aberdeen🏴\U000e0067\U000e0062\U000e0073\U000e0063\U000e0074\U000e007fSCOTLAND', 'en', '@Podolyak_M Every city in #Ukraine️ will be targeted.. until #russia loses the war \n#SaveCash #BeWary \n\nSpend money… https://t.co/fEAyYsP3sX']
# ['David Lee', datetime.datetime(2011, 11, 23, 9, 14, 31, tzinfo=datetime.timezone.utc), [[-2.272842, 51.721517], [-2.272842, 51.769296], [-2.190976, 51.769296], [-2.190976, 51.721517]], 'Georgia', 'en', 'Headlines in a supermarket in the UK 🇬🇧 today.\n\nNo mention of Ukraine 🇺🇦\n\n#inflation #StandWithUkraine️ https://t.co/m1ckwa7ZTf']
# ['Christoph Stürmer', datetime.datetime(2020, 8, 10, 19, 24, 38, tzinfo=datetime.timezone.utc), [[11.075701, 49.598663], [11.075701, 49.653965], [11.208079, 49.653965], [11.208079, 49.598663]], 'Frankfurt am Main, Hessen', 'en', '@POTUS It’s actually the day of remembering all #victims of #torture #violence #rape #injustice especially under mi… https://t.co/5aKo1QU4Tf']
# ['💞🚛 🚫 great reset🚫🕊️', datetime.datetime(2021, 12, 5, 12, 56, 48, tzinfo=datetime.timezone.utc), [[-110.033609, 40.27174], [-110.033609, 40.316605], [-109.972891, 40.316605], [-109.972891, 40.27174]], 'Utah, USA', 'en', 'Sums it up 💯']
# ['Zafar Mehmood', datetime.datetime(2022, 3, 27, 23, 0, 41, tzinfo=datetime.timezone.utc), [[69.328873, 27.708226], [69.328873, 34.019989], [75.382124, 34.019989], [75.382124, 27.708226]], None, 'en', 'Ukraine 🇺🇦 News https://t.co/ys5n5dWqek']
# ['Ken Grant', datetime.datetime(2009, 1, 22, 20, 31, 26, tzinfo=datetime.timezone.utc), [[-75.788669, 39.6431], [-75.788669, 39.715087], [-75.723528, 39.715087], [-75.723528, 39.6431]], 'Newark, DE', 'en', 'Loading more supplies for #Ukraine️ from #netde https://t.co/Hdo1QCQSBr']
# ['🦋CazWalker#FastGirl🧢😷🐎🌈🦄🚘🇬🇧', datetime.datetime(2015, 11, 4, 16, 59, 36, tzinfo=datetime.timezone.utc), [[0.037565, 52.441649], [0.037565, 52.467567], [0.064771, 52.467567], [0.064771, 52.441649]], 'East Anglia GB', 'en', 'Gotta laugh!!🤣😂🤣😂🤣😂']
# ['say no to fascism', datetime.datetime(2011, 4, 1, 4, 43, 29, tzinfo=datetime.timezone.utc), [[-115.384091, 36.129459], [-115.384091, 36.336371], [-115.062159, 36.336371], [-115.062159, 36.129459]], None, 'en', "Ukraine has no navy but they still managed to sink the flagship of Russias black sea fleet that's embarrassing"]
# ['@geincolo', datetime.datetime(2010, 11, 28, 7, 32, 47, tzinfo=datetime.timezone.utc), [[-105.147267, 39.894185], [-105.147267, 40.000314], [-104.997195, 40.000314], [-104.997195, 39.894185]], 'Broomfield, Colorado', 'en', 'Without its flagship, Russia loses a key asset in its war against Ukraine\n \nBy incompetence or Ukrainian attack, th… https://t.co/Tp5MUHkGyI']
# ['Heather Ure', datetime.datetime(2013, 8, 19, 2, 8, 23, tzinfo=datetime.timezone.utc), [[-122.1649, 47.626845], [-122.1649, 47.73078], [-121.958642, 47.73078], [-121.958642, 47.626845]], 'Redmond, WA', 'en', 'TW: sexual violence; war crimes.']
# ['Don Wilson', datetime.datetime(2014, 4, 23, 11, 47, 43, tzinfo=datetime.timezone.utc), [[36.664573, -1.389053], [36.664573, -1.160674], [37.062667, -1.160674], [37.062667, -1.389053]], 'kibera', 'en', 'A mural painting created by local Maasai Mbili Artists from Kibera depicts a symbol of love for Ukraine.… https://t.co/ZcIoPpcXqp']
# ['Judy Beveridge 🌻', datetime.datetime(2016, 2, 12, 23, 31, tzinfo=datetime.timezone.utc), [[-2.756638, 51.111919], [-2.756638, 51.133305], [-2.724804, 51.133305], [-2.724804, 51.111919]], None, 'en', '@olgatokariuk This is wonderful to read 🙂 first time in history that a postage stamp has been so celebrated! Demand… https://t.co/ujVVzZtFik']
# ['Diana Daly', datetime.datetime(2021, 8, 25, 0, 58, 57, tzinfo=datetime.timezone.utc), [[-79.220024, 43.554887], [-79.220024, 44.01077], [-78.852434, 44.01077], [-78.852434, 43.554887]], 'Toronto, Ontario', 'en', 'My kitchen window, in Toronto, Canada, is still draped over with the Ukrainian flag in show of our support against… https://t.co/obP5SJ7vEH']
# ['Civics and Civility are essential!😎', datetime.datetime(2012, 4, 6, 14, 46, 32, tzinfo=datetime.timezone.utc), [[-74.255641, 40.495865], [-74.255641, 40.648887], [-74.052253, 40.648887], [-74.052253, 40.495865]], 'NYC', 'en', 'A message from @vkaramurza from a Moscow jail!🙏🔥👇']
# ['Al Kelly', datetime.datetime(2021, 8, 13, 16, 54, 57, tzinfo=datetime.timezone.utc), [[-94.45916, 38.805502], [-94.45916, 39.026684], [-94.297303, 39.026684], [-94.297303, 38.805502]], None, 'en', 'Can someone tell me what happened to the 510 sailors aboard the#Moskva? I heard that Turkey gathered up 50 or so...… https://t.co/tzqWcyPWJp']
# ['Sue Stroud she/her 🍊❤️💪🏼🇺🇦🌻', datetime.datetime(2009, 5, 4, 1, 0, 28, tzinfo=datetime.timezone.utc), [[-123.484088, 48.550064], [-123.484088, 48.613903], [-123.359588, 48.613903], [-123.359588, 48.550064]], 'Brentwood Bay Vancouver Island', 'en', '@EuromaidanPress @Pontifex . @Pontifex @VaticanNews @VaticanIHD @VaticanObserv @CRMedia_Vatican @vaticanlibrary is… https://t.co/miOEdyqAcE']
# ['Dean', datetime.datetime(2009, 7, 4, 8, 31, 19, tzinfo=datetime.timezone.utc), [[-0.033551, 51.436221], [-0.033551, 51.506788], [0.06353, 51.506788], [0.06353, 51.436221]], 'London, England', 'en', 'Already a truth-teller. Absolute champion 🏆']
# ['William', datetime.datetime(2018, 12, 1, 4, 39, 43, tzinfo=datetime.timezone.utc), [[-120.886769, 44.281148], [-120.886769, 44.334188], [-120.806881, 44.334188], [-120.806881, 44.281148]], None, 'en', 'Impeach Joe Biden .']
# ['david moloney', datetime.datetime(2010, 1, 28, 9, 50, 30, tzinfo=datetime.timezone.utc), [[20.852552, 52.097709], [20.852552, 52.367962], [21.271028, 52.367962], [21.271028, 52.097709]], 'dublin', 'en', 'But but but #Ukraine']
# ['John Adams', datetime.datetime(2012, 10, 4, 2, 52, tzinfo=datetime.timezone.utc), [[-82.555165, 40.044145], [-82.555165, 40.086227], [-82.46731, 40.086227], [-82.46731, 40.044145]], None, 'en', 'What about all the other Americans who maintain some devotion to their heritage. Irish, Jews, Germans, Latinos, Ita… https://t.co/7ugTDg0x5P']
# ['Luisa', datetime.datetime(2012, 3, 15, 4, 25, 27, tzinfo=datetime.timezone.utc), [[-94.406743, 32.491967], [-94.406743, 32.571239], [-94.29016, 32.571239], [-94.29016, 32.491967]], None, 'en', '@KJV614 @realchrisrufo No some of it is Russian disinformation.\n\nhttps://t.co/Vm2IaRSmJy']
# ['Marián Sekerák', datetime.datetime(2019, 5, 14, 22, 51, 30, tzinfo=datetime.timezone.utc), [[14.225243, 49.941904], [14.225243, 50.177256], [14.706508, 50.177256], [14.706508, 49.941904]], 'Prague, Czech Republic', 'en', "Let's remark that part of the #Slovak parliamentary opposition (the former PM Robert Fico and the fascists) claims… https://t.co/MU0jjHFg8R"]
# ['Heather Ure', datetime.datetime(2013, 8, 19, 2, 8, 23, tzinfo=datetime.timezone.utc), [[-122.1649, 47.626845], [-122.1649, 47.73078], [-121.958642, 47.73078], [-121.958642, 47.626845]], 'Redmond, WA', 'en', 'TW: sexual violence']
# ['@geincolo', datetime.datetime(2010, 11, 28, 7, 32, 47, tzinfo=datetime.timezone.utc), [[-105.147267, 39.894185], [-105.147267, 40.000314], [-104.997195, 40.000314], [-104.997195, 39.894185]], 'Broomfield, Colorado', 'en', 'Russian state TV throws a tantrum after Ukraine destroyed its beloved Black Sea flagship\n"...it was hard for  Putin… https://t.co/0Babzet3j5']
# ['CARLⓂ️', datetime.datetime(2009, 3, 11, 23, 38, 3, tzinfo=datetime.timezone.utc), [[-88.192715, 43.016458], [-88.192715, 43.104785], [-88.066135, 43.104785], [-88.066135, 43.016458]], 'Brookfield, WI', 'en', 'As I see and read about the skilled Russian army, I see men and women true to their oath to Russia  but in conflict… https://t.co/4kgde3jShM']
# ['The Adventures of Jay Tree', datetime.datetime(2022, 3, 7, 15, 15, 48, tzinfo=datetime.timezone.utc), [[28.632104, 40.802734], [28.632104, 41.239907], [29.378341, 41.239907], [29.378341, 40.802734]], 'Ukraine', 'en', 'Throwback to rogue reporting from the train station in #lviv #ukraine regarding  #Refugees fleeing to Poland. Speci… https://t.co/5XHQCyVREX']
# ['Jay Hill 🇷🇺 Z', datetime.datetime(2012, 10, 31, 23, 37, 51, tzinfo=datetime.timezone.utc), [[0.363246, 52.59227], [0.363246, 52.613338], [0.397483, 52.613338], [0.397483, 52.59227]], 'Downham Market, England', 'en', 'Seeing reports on non British channels that Putin has told Biden (or whoever controls him) to butt out of Ukraine, or else....']
# ['CHRISTOS ZINGELIS', datetime.datetime(2021, 10, 18, 19, 20, 23, tzinfo=datetime.timezone.utc), [[26.222125, 35.396632], [26.222125, 35.911022], [27.242249, 35.911022], [27.242249, 35.396632]], None, 'en', "@DefenceU You are the page #defence of #Ukraine in #tweeter and you don't know that #Ukrainian #ministry of defence… https://t.co/QUtki9VcbJ"]
# ['Dr Shivaji 🌹🇺🇦 #FBPE #RejoinEU', datetime.datetime(2016, 8, 6, 19, 55, 26, tzinfo=datetime.timezone.utc), [[-2.319934, 53.343623], [-2.319934, 53.570282], [-2.147026, 53.570282], [-2.147026, 53.343623]], 'North West, England', 'en', 'Germany is to provide 1 billion Euros to Ukraine to by weapons , well that’s great sum by any stretch of imagination']
# ['Patricia Gonzales', datetime.datetime(2021, 12, 8, 2, 20, 47, tzinfo=datetime.timezone.utc), [[-97.662618, 27.578509], [-97.662618, 27.895793], [-97.202232, 27.895793], [-97.202232, 27.578509]], None, 'en', "@joncoopertweets THE UKRAINIAS WON THAT BADGE OF HONOR  !!  UKRAINE DESTROYED PUTINS/RUSSIA'S SHIP.. 😂🤣😅"]
# ['Occidental 🇷🇸(Санкције ТероруССији)', datetime.datetime(2015, 2, 1, 19, 41, 42, tzinfo=datetime.timezone.utc), [[20.014287, 41.851839], [20.014287, 43.273322], [21.789851, 43.273322], [21.789851, 41.851839]], 'Serbian Oblast of Russia ', 'en', '@TormentedPengu @nexta_tv You obviously lack any knowledge on the matter and what is going on.\nBombing were in 1999… https://t.co/qCDFajghTD']
# ['Rowe 🇺🇦', datetime.datetime(2019, 3, 15, 11, 3, 55, tzinfo=datetime.timezone.utc), [[-1.853157, 52.666602], [-1.853157, 52.702076], [-1.785334, 52.702076], [-1.785334, 52.666602]], None, 'en', '@shymoniuk @cacc86 @OstapYarysh @cxemu @SvobodaRadio Two men local to me, are walking 50km today, dragging a suitca… https://t.co/HNYsnMUKO3']
# ['Stephanie Peace 🇺🇦', datetime.datetime(2019, 5, 8, 1, 52, 55, tzinfo=datetime.timezone.utc), [[-84.682106, 33.801081], [-84.682106, 33.842859], [-84.605425, 33.842859], [-84.605425, 33.801081]], 'Austell, GA', 'en', '🧵 Everyone should Read! Excellent!']
# ['Martha Sekander', datetime.datetime(2020, 9, 8, 18, 49, 34, tzinfo=datetime.timezone.utc), [[-122.579184, 38.775887], [-122.579184, 38.831311], [-122.52015, 38.831311], [-122.52015, 38.775887]], 'Hidden Valley Lake, CA', 'en', 'When are we going to go right to the source of our problems instead of the never ending story of treating the effec… https://t.co/dVRAzEjFSe']
# ['W.Steven Chandler', datetime.datetime(2012, 1, 15, 21, 18, 26, tzinfo=datetime.timezone.utc), [[-88.473228, 30.144425], [-88.473228, 35.008029], [-84.888247, 35.008029], [-84.888247, 30.144425]], None, 'en', 'Please retweet this and ask all of your followers and friends to retweet this. Russia is going down for the last co… https://t.co/bCLgTZGHIs']
# ['Hivefolio', datetime.datetime(2018, 10, 7, 13, 13, 44, tzinfo=datetime.timezone.utc), [[-8.662663, 49.162656], [-8.662663, 60.86165], [1.768926, 60.86165], [1.768926, 49.162656]], 'London', 'en', "Check out @frelissimo's commentary for @TeamSaltyEU event and @Reiki_Kito charity event in support for #Ukraine\n\nWa… https://t.co/m3cBocxnNv"]
# ['☢🎼 NewClearMUSIC ☢', datetime.datetime(2009, 8, 30, 5, 22, 50, tzinfo=datetime.timezone.utc), [[-105.109815, 39.614151], [-105.109815, 39.812975], [-104.734372, 39.812975], [-104.734372, 39.614151]], '♥♫THE MILE HIGH CITY♫♥', 'en', "I'm just saying.. #Putin has got to be close to losing it.. And HE has nothing to lose.. Well, not the way Ru boats… https://t.co/rlx5nGpIuC"]
# ['Amy Barrett 🇺🇦🐈\u200d⬛🎹🖖🏻🍀', datetime.datetime(2008, 12, 13, 1, 35, 56, tzinfo=datetime.timezone.utc), [[-90.320516, 38.533193], [-90.320516, 38.774349], [-90.175132, 38.774349], [-90.175132, 38.533193]], 'St. Louis, MO', 'en', 'This makes me physically ill. We’re basically watching Hitler invade Poland and responding with sanctions and milit… https://t.co/oYYNizOuOy']
# ['Sam Vilain', datetime.datetime(2010, 12, 13, 22, 34, 47, tzinfo=datetime.timezone.utc), [[-84.576827, 33.647503], [-84.576827, 33.886886], [-84.289385, 33.886886], [-84.289385, 33.647503]], 'Atlanta, GA', 'en', '@MuchCoffee Etsy; search for “Ukraine warship stamp”']
# ['Arabella 🍄 🇺🇦🏳️\u200d🌈', datetime.datetime(2021, 6, 26, 22, 37, 12, tzinfo=datetime.timezone.utc), [[-83.200169, 39.832013], [-83.200169, 40.157354], [-82.771375, 40.157354], [-82.771375, 39.832013]], 'Victorian Village, Columbus', 'en', '@sullydish What does Ukraine remaining “ neutral” even mean at this point Andrew. They want to remain a democracy,… https://t.co/6IKA9M7D2x']
# ['Kevin Peterson', datetime.datetime(2008, 11, 13, 8, 12, 9, tzinfo=datetime.timezone.utc), [[144.593742, -38.433859], [144.593742, -37.511274], [145.512529, -37.511274], [145.512529, -38.433859]], 'Australia', 'en', "This war if ended at the beginning, without a single shot fired  ..no one would have died, no refugee's,  no buildi… https://t.co/VlN1SgDulH"]
# ['Al😏!', datetime.datetime(2009, 3, 22, 6, 28, 41, tzinfo=datetime.timezone.utc), [[-79.819677, 40.385071], [-79.819677, 40.46208], [-79.703829, 40.46208], [-79.703829, 40.385071]], 'Pittsburgh', 'en', 'Ukraine is scanning faces of dead Russians, then contacting the mothers https://t.co/TS61WIjkwa']
# ['Sue M', datetime.datetime(2021, 8, 1, 20, 38, 33, tzinfo=datetime.timezone.utc), [[-1.597958, 53.966206], [-1.597958, 54.016256], [-1.485794, 54.016256], [-1.485794, 53.966206]], 'North Yorkshire England.', 'en', 'This is very frightening for anyone, Ukraine, Sweden, Finland where next.']
# ['RESIST!!', datetime.datetime(2009, 6, 20, 2, 13, 32, tzinfo=datetime.timezone.utc), [[-117.944051, 33.691774], [-117.944051, 33.78821], [-117.830826, 33.78821], [-117.830826, 33.691774]], 'Santa Ana, CA', 'en', 'Slava Ukraine! A restaurant manager flew a Ukrainian flag. Hateful messages followed.\n\nhttps://t.co/3crIs7QJgn']
# ['Into Galaxy 🇺🇦', datetime.datetime(2021, 2, 12, 13, 59, 13, tzinfo=datetime.timezone.utc), [[32.269296, 34.562636], [32.269296, 35.708706], [34.606354, 35.708706], [34.606354, 34.562636]], "Your mom's house", 'en', '@Itsrealaryaan Ukraine, but at the moment live in Cyprus']
# ['🌊🌊panamafelix0412🇺🇸🇵🇦🌊🌊', datetime.datetime(2011, 7, 15, 15, 58, 43, tzinfo=datetime.timezone.utc), [[-83.051445, 7.20386], [-83.051445, 9.639486], [-77.13939, 9.639486], [-77.13939, 7.20386]], 'Orlando, FL', 'en', "#StopRussia \n@EU_Commission \n\nBan the purchase of Russian gas, oil and coal. \n\nDry up Putin's war chest and the war… https://t.co/JG8Y6ucWn2"]
# ['Gateusz Motz', datetime.datetime(2011, 8, 30, 20, 46, 39, tzinfo=datetime.timezone.utc), [[19.01082, 50.735923], [19.01082, 50.883678], [19.233027, 50.883678], [19.233027, 50.735923]], None, 'en', '@tassagency_en More than Ukraine Has. Wow. What a moron']
# ['Jurgen Human', datetime.datetime(2014, 9, 10, 6, 30, tzinfo=datetime.timezone.utc), [[27.751856, -26.512649], [27.751856, -26.039628], [28.18434, -26.039628], [28.18434, -26.512649]], None, 'en', "How's the Moskva's repairs coming along?"]
# ['Dan *️⃣', datetime.datetime(2009, 2, 6, 0, 57, 10, tzinfo=datetime.timezone.utc), [[-75.280284, 39.871811], [-75.280284, 40.13792], [-74.955712, 40.13792], [-74.955712, 39.871811]], None, 'en', "@lisabarri2 @SlowNewsDayShow It's really fucking sad if you have a Ukraine muzzle"]
# ['brian adey', datetime.datetime(2009, 10, 3, 23, 53, 57, tzinfo=datetime.timezone.utc), [[4.7289, 52.278227], [4.7289, 52.431229], [5.079207, 52.431229], [5.079207, 52.278227]], 'York-Munich-Amsterdam', 'en', "@travhans @visegrad24 They've done nothing. The arms they've sold Russia since 2014 far outweigh anything they've done for Ukraine."]
# ['William', datetime.datetime(2013, 10, 11, 22, 47, 21, tzinfo=datetime.timezone.utc), [[-0.328914, 52.535472], [-0.328914, 52.631065], [-0.202402, 52.631065], [-0.202402, 52.535472]], 'Gent ', 'en', '@pdela175 @MennengaOncle @FoxNews Tell That to Your kids\nEvery open Minded person knows it a war between the West a… https://t.co/7fxlU2SfUE']
# ['The 16th St Mall 😷 Denver, CO', datetime.datetime(2010, 11, 21, 23, 3, 46, tzinfo=datetime.timezone.utc), [[-105.109815, 39.614151], [-105.109815, 39.812975], [-104.734372, 39.812975], [-104.734372, 39.614151]], '16th St Mall ♡ DENVER COLORADO', 'en', '#OBLASTS.. Oh, like the suburbs?\n#Ukraine is subdivided into twenty-four oblasts (provinces) and one autonomous rep… https://t.co/3JKa0zFuEv']
# ...
# ['Daniel Kurland', datetime.datetime(2012, 12, 31, 21, 10, 53, tzinfo=datetime.timezone.utc), [[-77.233334, 38.792811], [-77.233334, 38.811818], [-77.185617, 38.811818], [-77.185617, 38.792811]], None, 'en', '@ltgrusselhonore @POTUS @VP @USArmy @MSNBC @CNN 🛎🛎🛎🎯\nThere\'s "a time to love and a time to hate,\n\xa0\xa0\xa0\xa0a time for war… https://t.co/0BzWntW2WP']
# ['Lajos F. Szaszdi', datetime.datetime(2012, 10, 10, 21, 15, 43, tzinfo=datetime.timezone.utc), [[-66.059056, 18.411484], [-66.059056, 18.433688], [-66.042895, 18.433688], [-66.042895, 18.411484]], None, 'en', 'Second British fighter in Ukraine is captured by the Russians https://t.co/j0FdMbcEVd @MailOnline']
# ['Daniel A. Zarrilli', datetime.datetime(2010, 2, 6, 18, 47, 43, tzinfo=datetime.timezone.utc), [[-74.255641, 40.495865], [-74.255641, 40.648887], [-74.052253, 40.648887], [-74.052253, 40.495865]], 'New York City', 'en', '“This will not be cost-free. But the tragedy of the Ukraine war will be compounded if the impetus to accelerate the… https://t.co/RkYZrVKofB']
# ['YesJustAl', datetime.datetime(2012, 9, 29, 1, 31, 16, tzinfo=datetime.timezone.utc), [[-76.796517, 39.283539], [-76.796517, 39.327477], [-76.711092, 39.327477], [-76.711092, 39.283539]], 'Baltimore, MD/Metro DC', 'en', 'Crippling gas prices, record inflation, affordable housing crisis and USA is sending trillion dollar stimulus package to Ukraine.']
# ['Grams', datetime.datetime(2018, 12, 8, 0, 25, 15, tzinfo=datetime.timezone.utc), [[-112.312571, 33.565085], [-112.312571, 33.666825], [-112.253653, 33.666825], [-112.253653, 33.565085]], 'Arizona, USA', 'en', 'Good']
# ['Lupinda Wa Lupinda 🇿🇦 🇿🇲', datetime.datetime(2014, 8, 21, 17, 8, 32, tzinfo=datetime.timezone.utc), [[16.447593, -34.834247], [16.447593, -22.124724], [32.892293, -22.124724], [32.892293, -34.834247]], 'Johannesburg, South Africa', 'en', '@spectatorindex Russia must now also target this stupid president of Ukraine Zelensky and bomb his palace. He must leave Ukraine']
# ['TeeMichelle', datetime.datetime(2017, 6, 29, 1, 26, 42, tzinfo=datetime.timezone.utc), [[-87.634643, 24.396308], [-87.634643, 31.001056], [-79.974307, 31.001056], [-79.974307, 24.396308]], 'Florida, US', 'en', 'Invictus Games: Harry says world is united with Ukraine\n\nhttps://t.co/KeXDT133MI']
# ['Nino Brodin', datetime.datetime(2009, 3, 17, 5, 3, 31, tzinfo=datetime.timezone.utc), [[12.453064, 55.613717], [12.453064, 55.731834], [12.652201, 55.731834], [12.652201, 55.613717]], 'London, England', 'en', 'Russian forces resume attacks on Kyiv and western Ukraine after loss of Black Sea flagship https://t.co/miwAMxTAHI via @ForcesNews']
# ['data about data', datetime.datetime(2011, 5, 1, 3, 42, 17, tzinfo=datetime.timezone.utc), [[22.13572, 44.386383], [22.13572, 52.379475], [40.227172, 52.379475], [40.227172, 44.386383]], None, 'en', '20K+ #Google searches 4 The Kitchen 1h old https://t.co/IYAuuLWmnU https://t.co/2duJz4n1iu \n#Ukraine 🌅 6:03 🌆 19:53… https://t.co/xhz3MUfnR4']
# ['Magnum_Silentium🇮🇱', datetime.datetime(2021, 5, 31, 17, 3, 24, tzinfo=datetime.timezone.utc), [[-85.605166, 30.355644], [-85.605166, 35.000771], [-80.742567, 35.000771], [-80.742567, 30.355644]], 'Florida - Israel', 'en', 'the United States has spectacularly failed the people of #Ukraine by not intervening militarily to keep civilian ca… https://t.co/hECTKtsb3y']
# ['Слава Україні🇺🇦', datetime.datetime(2013, 6, 15, 19, 25, 44, tzinfo=datetime.timezone.utc), [[34.266924, 29.393973], [34.266924, 33.290533], [35.669933, 33.290533], [35.669933, 29.393973]], 'Rosh HaAyin/ראש העין/روش هاعين', 'en', '🛑🛑🛑Destroyed #Putin regime terrorists equipment from recent battles near Kherson \n#Ukraine #Russia https://t.co/fqAwENjQ3s']
# ['Ray_Miller_007 : Shaken not Stirred', datetime.datetime(2012, 2, 26, 21, 53, 18, tzinfo=datetime.timezone.utc), [[-73.659326, 41.548653], [-73.659326, 41.5947], [-73.58258, 41.5947], [-73.58258, 41.548653]], 'New York, USA', 'en', '@BrianNormoyle @master_deli Send her to Ukraine and give her a slingshot.']
# ['Odessa_Ukraine', datetime.datetime(2022, 4, 16, 12, 38, 49, tzinfo=datetime.timezone.utc), [[22.13572, 44.386383], [22.13572, 52.379475], [40.227172, 52.379475], [40.227172, 44.386383]], 'Odessa, Ukraine', 'en', 'We would like to announce that we are taking orders. As our bio indicates, all proceeds will go to helping Ukrainia… https://t.co/C2BUMOXsT7']
# ['DailyNews 🇮🇹', datetime.datetime(2022, 2, 9, 7, 43, 20, tzinfo=datetime.timezone.utc), [[-102.051769, 36.99311], [-102.051769, 40.003282], [-94.588081, 40.003282], [-94.588081, 36.99311]], 'Italy', 'en', 'Russia-Ukraine war live updates: Russia may begin new offensive soon, U.S. officials say, as Kyiv hit by strike - N… https://t.co/i4cxKktnLa']
# ['Robert Zień', datetime.datetime(2016, 12, 15, 16, 48, 15, tzinfo=datetime.timezone.utc), [[20.852552, 52.097709], [20.852552, 52.367962], [21.271028, 52.367962], [21.271028, 52.097709]], None, 'en', 'Photo of the Year']
# ['Sue Stroud she/her 🍊❤️💪🏼🇺🇦🌻', datetime.datetime(2009, 5, 4, 1, 0, 28, tzinfo=datetime.timezone.utc), [[-123.5748, 48.402597], [-123.5748, 48.509343], [-123.467963, 48.509343], [-123.467963, 48.402597]], 'Brentwood Bay Vancouver Island', 'en', '@armyinformcomua My heart aches for #Ukraine &amp; all her loved ones. 💔🇺🇦🌻']
# ['Слава Україні🇺🇦', datetime.datetime(2013, 6, 15, 19, 25, 44, tzinfo=datetime.timezone.utc), [[34.266924, 29.393973], [34.266924, 33.290533], [35.669933, 33.290533], [35.669933, 29.393973]], 'Rosh HaAyin/ראש העין/روش هاعين', 'en', '🛑🛑🛑#Kyiv regional administration says that a temporary bridge over the Irpin’ river was set up near the town of Sto… https://t.co/4uDbu8AcTs']
# ['Stewart Mackinlay', datetime.datetime(2011, 2, 4, 0, 33, 3, tzinfo=datetime.timezone.utc), [[-13.882165, 28.838393], [-13.882165, 29.036677], [-13.694032, 29.036677], [-13.694032, 28.838393]], 'Scotland', 'en', '@drogba_ba Those fixtures are no longer correct. The Nations League games against Ukraine will now take place in Se… https://t.co/hiAYOlaSWo']
# ['Allison Johnson', datetime.datetime(2021, 6, 23, 19, 10, 45, tzinfo=datetime.timezone.utc), [[-0.644329, 54.468123], [-0.644329, 54.494443], [-0.593383, 54.494443], [-0.593383, 54.468123]], 'Leeds, England', 'en', '@imminent_news Heartbreaking yet again and makes me feel helpless apart from being able to comment on here but why… https://t.co/APhg3QZbwl']
# ['Muse Scry', datetime.datetime(2020, 3, 17, 21, 37, 11, tzinfo=datetime.timezone.utc), [[-87.634643, 24.396308], [-87.634643, 31.001056], [-79.974307, 31.001056], [-79.974307, 24.396308]], None, 'en', 'We’ll add this here @FOOL_NELSON']
# ['DafukNFTees', datetime.datetime(2022, 4, 15, 20, 34, 34, tzinfo=datetime.timezone.utc), [[-6.387438, 53.298745], [-6.387438, 53.41106], [-6.107805, 53.41106], [-6.107805, 53.298745]], None, 'en', "I think he's wrong, what does everyone else think?\n\n#Ukraine #ireland #irishcomedy #irishcraic #fyp #foryourpage… https://t.co/kGdWJtNWdI"]
# ['LichtAmFahrrad', datetime.datetime(2019, 6, 14, 12, 2, 36, tzinfo=datetime.timezone.utc), [[13.088304, 52.338079], [13.088304, 52.675323], [13.760909, 52.675323], [13.760909, 52.338079]], 'Berlin, Deutschland', 'en', "@Innadrvsh @ntt_ua I know and are absolutely not saying that's not the case or that that's right. But I also don't… https://t.co/zQu7ca77X4"]
# ['Suhniyay', datetime.datetime(2022, 1, 14, 18, 14, 25, tzinfo=datetime.timezone.utc), [[-77.119401, 38.801826], [-77.119401, 38.99538], [-76.909396, 38.99538], [-76.909396, 38.801826]], 'Washington, DC', 'en', 'Outside Russian ambassador house dc #StopRussia #StandWithUkraine️ #ukraine #Russia https://t.co/BKOBs3YbTF']
# ['Nino Brodin', datetime.datetime(2009, 3, 17, 5, 3, 31, tzinfo=datetime.timezone.utc), [[12.453064, 55.613717], [12.453064, 55.731834], [12.652201, 55.731834], [12.652201, 55.613717]], 'London, England', 'en', 'Russia may begin new offensive soon, U.S. officials say, as Ukraine runs through its stock of artillery shells… https://t.co/ayNFyQQYuL']
# ['Magnum_Silentium🇮🇱', datetime.datetime(2021, 5, 31, 17, 3, 24, tzinfo=datetime.timezone.utc), [[-85.605166, 30.355644], [-85.605166, 35.000771], [-80.742567, 35.000771], [-80.742567, 30.355644]], 'Florida - Israel', 'en', 'do not think to yourselves: America has helped #Ukraine so much. because the\nUnited States Greatly Failed Ukraine b… https://t.co/DwZi6HjXn9']
# ['SLKFRM', datetime.datetime(2021, 12, 11, 3, 42, 37, tzinfo=datetime.timezone.utc), [[-118.668404, 33.704538], [-118.668404, 34.337041], [-118.155409, 34.337041], [-118.155409, 33.704538]], 'Los Ángeles, CA', 'en', 'And Russia is only upset cause Ukraine sank their ship and now they’re lying that an explosion sunk their battle sh… https://t.co/ApWXkqrSeQ']
# ['Roger Stevens', datetime.datetime(2020, 4, 24, 12, 21, 21, tzinfo=datetime.timezone.utc), [[-0.142058, 51.518552], [-0.142058, 51.575301], [-0.076305, 51.575301], [-0.076305, 51.518552]], None, 'en', '@SchmitterCecile Somewhat more extreme than Ukraine which receives daily coverage in imperialist nations.']
# ['Nino Brodin', datetime.datetime(2009, 3, 17, 5, 3, 31, tzinfo=datetime.timezone.utc), [[12.453064, 55.613717], [12.453064, 55.731834], [12.652201, 55.731834], [12.652201, 55.613717]], 'London, England', 'en', 'Putin’s Ukraine Gamble Pivots to a Very Different Battlefield https://t.co/ebHnbX9tag via @nytimes']
# ['Rip Holmes', datetime.datetime(2011, 10, 1, 7, 51, 59, tzinfo=datetime.timezone.utc), [[-80.297165, 25.627038], [-80.297165, 25.771859], [-80.245009, 25.771859], [-80.245009, 25.627038]], 'Coral Gables, FL', 'en', "Our USA is ignoring EVIL Putin's threats of horrific consequences if we try to stop his War Crimes. BRAVO @POTUS an… https://t.co/LOpd5r2bBS"]
# ['Jo', datetime.datetime(2017, 7, 18, 23, 57, tzinfo=datetime.timezone.utc), [[-118.017789, 33.788913], [-118.017789, 33.896813], [-117.684389, 33.896813], [-117.684389, 33.788913]], ' Blue County once Red, USA!', 'en', 'May the blessings of Ramadan, of Passover, of Easter &amp; the blessings of all beliefs be with you all &amp; especially wi… https://t.co/1QuXRgWs2I']
# ['Nick D-M', datetime.datetime(2009, 2, 6, 4, 14, 14, tzinfo=datetime.timezone.utc), [[150.520929, -34.118347], [150.520929, -33.578141], [151.343021, -33.578141], [151.343021, -34.118347]], None, 'en', '@WarintheFuture @DefenceHQ Will be very interesting to see what happens at Kherson. If Ukraine prevails the Russia… https://t.co/pTnC1GVvop']
# ['NV', datetime.datetime(2018, 9, 22, 18, 52, 39, tzinfo=datetime.timezone.utc), [[-87.634643, 24.396308], [-87.634643, 31.001056], [-79.974307, 31.001056], [-79.974307, 24.396308]], 'Naples, FL', 'en', '@thehill Well in that case arm Ukraine more.']
# ['🎻🎶🏳️\u200d🌈🏳️\u200d⚧️🇺🇦 floriDUH gaygaygaygaytors', datetime.datetime(2009, 7, 16, 8, 24, 16, tzinfo=datetime.timezone.utc), [[-80.706074, 28.03509], [-80.706074, 28.200658], [-80.593324, 28.200658], [-80.593324, 28.03509]], 'space coast, floriDUH', 'en', '@unsung_son I’m 70, and… maybe.\nThis feels like a WW2 reboot.\nI keep flashing to this tweet from a favorite audiobo… https://t.co/U5b5GuxxsI']
# ['greyhound angel', datetime.datetime(2015, 6, 14, 13, 0, 59, tzinfo=datetime.timezone.utc), [[-82.728681, 27.808138], [-82.728681, 27.826339], [-82.708134, 27.826339], [-82.708134, 27.808138]], 'St Petersburg, FL', 'en', 'I have been donating for all the animals in Ukraine and the surrounding border countries, including turkey, too IFA… https://t.co/NgIen59eGi']
# ['For the Greater Good', datetime.datetime(2016, 6, 2, 19, 27, 13, tzinfo=datetime.timezone.utc), [[-85.605166, 30.355644], [-85.605166, 35.000771], [-80.742567, 35.000771], [-80.742567, 30.355644]], 'Georgia, USA', 'en', 'Ukraine is keeping nearly 7,000 unclaimed dead Russian soldiers in their morgues while Russia digs mass graves for… https://t.co/TolNv1TQ3P']
# ['Kristin*Horsewoman', datetime.datetime(2008, 11, 25, 18, 58, 50, tzinfo=datetime.timezone.utc), [[-80.029518, 35.962623], [-80.029518, 36.218171], [-79.685209, 36.218171], [-79.685209, 35.962623]], 'NC', 'en', '@kylegriffin1 Do you really think the money the Biden Crime Family has stolen from Ukraine and elsewhere is in thos… https://t.co/HUkvfCgYg4']
# ['NavHazard88', datetime.datetime(2011, 10, 29, 22, 43, 54, tzinfo=datetime.timezone.utc), [[-122.708264, 47.43909], [-122.708264, 47.548799], [-122.603325, 47.548799], [-122.603325, 47.43909]], 'Washington, USA', 'en', '@TimRunsHisMouth @PramilaJayapal It’s funny we still complaining about this even though the taxpayers are already p… https://t.co/VIDvgX53Z8']
# ['Dr. Zaher Sahloul', datetime.datetime(2009, 4, 21, 4, 10, 16, tzinfo=datetime.timezone.utc), [[-87.798798, 41.68331], [-87.798798, 41.734598], [-87.720268, 41.734598], [-87.720268, 41.68331]], 'Chicago, USA', 'en', 'Scary indeed']
# ['Fr Alexander Laschuk', datetime.datetime(2013, 1, 31, 23, 44, 4, tzinfo=datetime.timezone.utc), [[-79.639319, 43.403221], [-79.639319, 43.855401], [-78.90582, 43.855401], [-78.90582, 43.403221]], 'Toronto, Ontario', 'en', 'Ivan Federov, mayor of occupied Melitopol, who was kidnapped and tortured by the armed forces of the Russian Federa… https://t.co/HhzH1yKNbb']
# ['Dino Dionne', datetime.datetime(2022, 1, 4, 16, 32, 59, tzinfo=datetime.timezone.utc), [[-80.203991, 26.320692], [-80.203991, 26.427259], [-80.065981, 26.427259], [-80.065981, 26.320692]], 'New York, USA', 'en', 'Prepare for the Draft.\nRussia warns US to stop arming Ukraine, sends formal letter warning | Wo... https://t.co/eEsLGXnbSS via @YouTube']
# ['Nino Brodin', datetime.datetime(2009, 3, 17, 5, 3, 31, tzinfo=datetime.timezone.utc), [[12.453064, 55.613717], [12.453064, 55.731834], [12.652201, 55.731834], [12.652201, 55.613717]], 'London, England', 'en', 'Russia hits Kyiv, Lviv and presses offensive in ruins of Mariupol https://t.co/GBay64g976 via @straits_times']
# ['Thomas Long', datetime.datetime(2010, 12, 19, 11, 30, 28, tzinfo=datetime.timezone.utc), [[-4.360764, 55.901078], [-4.360764, 55.952955], [-4.297106, 55.952955], [-4.297106, 55.901078]], 'BEARSDEN', 'en', 'BECAUSE SHE US THE MOST HATED PERSON IN SCOTLAND.']
# ['American strong', datetime.datetime(2017, 1, 21, 0, 43, 56, tzinfo=datetime.timezone.utc), [[-86.230499, 36.725689], [-86.230499, 36.769551], [-86.168909, 36.769551], [-86.168909, 36.725689]], 'United States', 'en', 'Americans should refuse these actions,the border must be secured and the a budget put in place that addresses our n… https://t.co/8vzgJDX7IG']
# ['Ryan Hendrickson', datetime.datetime(2020, 8, 10, 15, 44, 53, tzinfo=datetime.timezone.utc), [[22.13572, 44.386383], [22.13572, 52.379475], [40.227172, 52.379475], [40.227172, 44.386383]], None, 'en', 'Ukraine Update 026. Seeing western Ukraine and putting in the miles. Driving from Kiev to the Polish border and bac… https://t.co/BB9P8dCYTC']
# ['Oleg Kolosov', datetime.datetime(2010, 12, 25, 22, 59, 31, tzinfo=datetime.timezone.utc), [[-2.829936, 54.020096], [-2.829936, 54.0681], [-2.775624, 54.0681], [-2.775624, 54.020096]], 'Lancaster, UK NorthWest', 'en', '#Ukraine #StopRussiaNOW @NATO @10DowningStreet @POTUS @vonderleyen Ukraine NEEDS fighter planes NOW, what is the pr… https://t.co/FxyqlbIglO']
# ['WICH Radio', datetime.datetime(2015, 10, 28, 23, 24, 7, tzinfo=datetime.timezone.utc), [[-73.727776, 40.950918], [-73.727776, 42.050588], [-71.786994, 42.050588], [-71.786994, 40.950918]], 'Norwich, CT', 'en', 'Jews, Christians and Muslims mark major holidays as war in Ukraine continues https://t.co/OFfLKQAZ1Q']
# ['2024PRESIDENT47TH Guy C Erdmann', datetime.datetime(2020, 2, 3, 16, 58, 55, tzinfo=datetime.timezone.utc), [[-71.084335, 42.917127], [-71.084335, 47.459687], [-66.885075, 47.459687], [-66.885075, 42.917127]], None, 'en', '@newsmax TAP SCREEN FULL READ! IMMEDIAT ACTION IS NEEDED BY ALL LAW ENFORCEMENT !MILLITARY GENERALS  REPUBLICANS IN… https://t.co/K5tFhXacxV']

# %% [markdown]
# You can double press `I` to stop the streaming (there is no better way to do it...). Before starting a new streaming, you need to disconnect the streaming.

# %%
streamer.disconnect()
