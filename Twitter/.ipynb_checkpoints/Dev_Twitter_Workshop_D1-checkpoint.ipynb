# %% [markdown]
# ## Spatial Data Science (GIS6307/GEO4930)
#
#
# <br>
# Instructor: Yi Qiang (qiangy@usf.edu)<br>
# Teaching Assistant: Jinwen Xu (jinwenxu@usf.edu)
#
# ---
#
# # Workshop on Spatial Analysis of Twitter (Day 1)
#
# This workshop will help you to get started with the acquisition, processing, and analysis of Twitter data using data science techniques. Specifically, you will learn:
#
# - Streaming real-time tweets using Twitter Developer APIs.
# - Processing the raw tweets into an analyzable form.
# - Basic mapping, spatial analysis and natural language processing for Twitter data.
#
# ### Prerequisites
# - Install Anaconda in your computer.
# - Activation of Twitter Developer Account and approved **Elevated Access** before the workshop.
# - Basic programming skills are recommended, but not required.

# %% [markdown]
# ## 1. Install Python Libraries
#
# First, we need to install a few libraries that will be used this lab. Please do the following steps to install the libarries.
#
# 1. Open or create a new conda environment `geo`.
# - For students in courses GIS6307 and GEO4930, please open Anaconda Prompt, and use the command `conda activate geo` to activate the "geo" environment that you created in the previous lab.
#
# - For workshop participatns, please run the following code to create a new conda environment `geo` and then activate it.
#
#     - `conda create --name geo`
#
#     - `conda activate geo`
#
# 2. Install tweepy, folium and Jupyter Lab using the following command (GIS6307/GEO4930 students only need to install tweepy and folium):
#
#     `conda install -c conda-forge tweepy folium jupyterlab matplotlib`
#
#
# 3. Install pandas and nltk using the following command (GIS6307/GEO4930 students only need to install nltk):
#
#     `conda install -c anaconda pandas nltk`
#
#
# 4. Launch Jupyter Notebook using the following command:
#
#     `jupyter notebook`
#
#
# 5. Open the Twitter_Workshop_D1.ipynb that you just downloaded. Run the following code to import the installed libraries. If the code runs through, the libraries are installed successfully.

# %%
import tweepy
import folium
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Getting to Know Jupyter Notebook
#
# Keyboard shortcuts will save you lots of time. Jupyter stores a list of keybord shortcuts under the menu at the top: Help > Keyboard Shortcuts, or by pressing `H` in command mode (more on that later). It’s worth checking this each time you update Jupyter, as more shortcuts are added all the time.
#
# Another way to access keyboard shortcuts, and a handy way to learn them is to use the command palette: `Cmd + Shift + P` (or `Ctrl + Shift + P` on Linux and Windows). This dialog box helps you run any command by name – useful if you don’t know the keyboard shortcut for an action or if what you want to do does not have a keyboard shortcut. The functionality is similar to Spotlight search on a Mac, and once you start using it you’ll wonder how you lived without it!
#
# Some of my favorite shortcuts (in command mode):
#
# - `ESC`: exit cell editing and enter to command mode
# - `A`: add a cell above the current cell
# - `B`: add a cell below the current cell
# - `C`: copy the current cell
# - `X`: cut the current cell
# - `V`: paste the copied cell below the current cell
# - `DD`: delete the current cell
# - `M`: change cell to MarkDown code (must exit editing first)
# - `Y`: change cell to Python code (must exit editing first)
# - `Ctrl + Enter`: Run code in the current cell.
# - `Shift + Enter`: Run code in the current cell and move to the next cell.

# %% [markdown]
# ## 3. Set-Up Connection to Twitter
#
# Go to Twitter Developer Portal (https://developer.twitter.com/en/apps). Click the App you created in account activation.
#
# If you haven't created an App when you created the account, you can create one in the project.
#
# Click `Set up` to set up User authentification settings.
#
# ![](https://raw.githubusercontent.com/qiang-yi/spatial_data_science/main/image/twitter/signup3.jpg)
#
# Turn on `OAuth 1.0a` and keep `OAuth 2.0` off.
#
# ![](https://raw.githubusercontent.com/qiang-yi/spatial_data_science/main/image/twitter/OAuth.jpg)
#
# Select "Read and write and Direct message". You can use "http://127.0.0.1:8080" as Callback URL. Add any website as the website URL (e.g. your personal website or https://twitter.com).
#
# ![](https://raw.githubusercontent.com/qiang-yi/spatial_data_science/main/image/twitter/setting.jpg)
#
# Copy the API keys you have saved when you activated your Developer account, and paste them to replace "......" below. If you can't find them, you can **regenerate** the keys and tokens in your Developer Portal.
#
# ![](https://raw.githubusercontent.com/qiang-yi/spatial_data_science/main/image/twitter/keys2.jpg)
#
# Copy and paste your API key, API key secret, Access Token and Access Token Secret to replace "......" below.

# %%
API_key = 'As0PGxFkLLgXKyqnGCre08UNz'
API_key_secret = '6rzlzIBqgURxZd2PKjo4QTj4iYNiwINHDWDCMWW3zlxUU9xr23'
access_token = '1509606550134038533-TpQM7b6U3nlvewate1hJqqbMuHSl5p'
access_token_secret = 'jTMIxiyKndnxMAI1vJScVC8diddUgHO2EJvNbb4nozU8L'

# %% [markdown]
# Set up for Twitter authentication.

# %%
auth = tweepy.OAuthHandler(API_key, API_key_secret)
auth.set_access_token(access_token, access_token_secret)

# %% [markdown]
# Set up tweepy API and set rate limit to be true.

# %%
api = tweepy.API(auth, wait_on_rate_limit = True)

# %% [markdown]
# ---

# %% [markdown]
# ## 4. Simple Operation with Twitter APIs
#
# Now, your working environment is set up for Twitter analysis. Let's first try a few simple operations to acquire Twitter data in a programmatic way.
#
# The full functionalities of Twitter API and Tweepy can be found in:
#
# - [Twitter APIs](https://developer.twitter.com/en/docs.html)
# - [Tweepy documentation](http://docs.tweepy.org/en/v4.8.0/)

# %% [markdown]
# ### 4.1 Posting/Deleting a Tweet
#
# First, let's post a message in your Twitter account.
#
# **Note**: if you don't want to disturb your followers with a meanless tweet, don't run the following block of code.

# %%
# Post a tweet from Python
test_tweet = api.update_status("DRILL: I'm creating a robot to tweet!")

# %% [markdown]
# Check your Twitter account, and you'll see the above message is posted.
#
# ![](https://raw.githubusercontent.com/qiang-yi/spatial_data_science/main/image/twitter/tweet.jpg)
#
# Tweets are encoded in a JSON (JavaScript Object Notation) format. You can run the following code to check the content of the tweet you just posted.

# %%
test_tweet._json
# Out:
# {'created_at': 'Tue Apr 19 14:14:49 +0000 2022',
#  'id': 1516420055457832970,
#  'id_str': '1516420055457832970',
#  'text': "DRILL: I'm creating a robot to tweet!",
#  'truncated': False,
#  'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []},
#  'source': '<a href="https://twitter.com" rel="nofollow">twitter_workshop2</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 1509606550134038533,
#   'id_str': '1509606550134038533',
#   'name': 'Alex Zhang',
#   'screen_name': 'AlexZha37291293',
#   'location': '',
#   'description': 'Data scientist',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 0,
#   'friends_count': 1,
#   'listed_count': 0,
#   'created_at': 'Thu Mar 31 19:00:34 +0000 2022',
#   'favourites_count': 0,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 1,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#   'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': True,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none',
#   'withheld_in_countries': []},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'is_quote_status': False,
#  'retweet_count': 0,
#  'favorite_count': 0,
#  'favorited': False,
#  'retweeted': False,
#  'lang': 'en'}

# %% [markdown]
# `_json` returns a dictionary object. So you could access specific attributes using keys in the dictionary. The code below gets the posting time of the tweets.

# %%
test_tweet._json['created_at']
# Out:
# 'Tue Apr 19 14:14:49 +0000 2022'

# %% [markdown]
# Alternative, you can also use the built-in attribute of the tweepy status object to access the attribute. All attributes of a tweet can be found [here](https://developer.twitter.com/en/docs/twitter-api/v1/data-dictionary/object-model/tweet).

# %%
test_tweet.created_at
# Out:
# datetime.datetime(2022, 4, 19, 14, 14, 49, tzinfo=datetime.timezone.utc)

# %% [markdown]
# You can run the following code to delete the drill tweet you just posted.

# %%
api.destroy_status(test_tweet.id_str)
# Out:
# Status(_api=<tweepy.api.API object at 0x0000017F1FA30400>, _json={'created_at': 'Tue Apr 19 14:14:49 +0000 2022', 'id': 1516420055457832970, 'id_str': '1516420055457832970', 'text': "DRILL: I'm creating a robot to tweet!", 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://twitter.com" rel="nofollow">twitter_workshop2</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1509606550134038533, 'id_str': '1509606550134038533', 'name': 'Alex Zhang', 'screen_name': 'AlexZha37291293', 'location': '', 'description': 'Data scientist', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 0, 'friends_count': 1, 'listed_count': 0, 'created_at': 'Thu Mar 31 19:00:34 +0000 2022', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 1, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': True, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2022, 4, 19, 14, 14, 49, tzinfo=datetime.timezone.utc), id=1516420055457832970, id_str='1516420055457832970', text="DRILL: I'm creating a robot to tweet!", truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, source='twitter_workshop2', source_url='https://twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x0000017F1FA30400>, _json={'id': 1509606550134038533, 'id_str': '1509606550134038533', 'name': 'Alex Zhang', 'screen_name': 'AlexZha37291293', 'location': '', 'description': 'Data scientist', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 0, 'friends_count': 1, 'listed_count': 0, 'created_at': 'Thu Mar 31 19:00:34 +0000 2022', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 1, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': True, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': [ ...

# %% [markdown]
# ### 4.2 Getting Trending Tweets

# %% [markdown]
# In Twitter, you can find trends in different places in the Explore tab.
#
# ![](https://raw.githubusercontent.com/qiang-yi/spatial_data_science/main/image/twitter/trends.jpg)
#
# Next, we are going to retrieve trends in Python. The following code get a list of places where trends are available. These places include countries and cities.

# %%
place_ls = api.available_trends()

# %% [markdown]
# Convert the list (in JSON format) into a dataframe (i.e. a table). Print the number of cities where trends are available.

# %%
df_place = pd.DataFrame(place_ls)

print (str(len(df_place)) + " places have trends.")
# Out:
# 467 places have trends.

# %% [markdown]
# Preview 10 places where trends are available

# %%
df_place.head(10)
# Out:
#          name                          placeType  \
# 0   Worldwide  {'code': 19, 'name': 'Supername'}
# 1    Winnipeg        {'code': 7, 'name': 'Town'}
# 2      Ottawa        {'code': 7, 'name': 'Town'}
# 3      Quebec        {'code': 7, 'name': 'Town'}
# 4    Montreal        {'code': 7, 'name': 'Town'}
# 5     Toronto        {'code': 7, 'name': 'Town'}
# 6    Edmonton        {'code': 7, 'name': 'Town'}
# 7     Calgary        {'code': 7, 'name': 'Town'}
# 8   Vancouver        {'code': 7, 'name': 'Town'}
# 9  Birmingham        {'code': 7, 'name': 'Town'}
#
#                                          url  parentid         country  woeid  \
# 0      http://where.yahooapis.com/v1/place/1         0                      1
# 1   http://where.yahooapis.com/v1/place/2972  23424775          Canada   2972
# 2   http://where.yahooapis.com/v1/place/3369  23424775          Canada   3369
# 3   http://where.yahooapis.com/v1/place/3444  23424775          Canada   3444
# 4   http://where.yahooapis.com/v1/place/3534  23424775          Canada   3534
# 5   http://where.yahooapis.com/v1/place/4118  23424775          Canada   4118
# 6   http://where.yahooapis.com/v1/place/8676  23424775          Canada   8676
# 7   http://where.yahooapis.com/v1/place/8775  23424775          Canada   8775
# 8   http://where.yahooapis.com/v1/place/9807  23424775          Canada   9807
# 9  http://where.yahooapis.com/v1/place/12723  23424975  United Kingdom  12723
#
#   countryCode
# 0        None
# 1          CA
# 2          CA
# 3          CA
# 4          CA
# 5          CA
# 6          CA
# 7          CA
# 8          CA
# 9          GB

# %% [markdown]
# Get the record of Tampa. The `woeid` is a unique ID for each place.

# %%
df_place[df_place['name']=='New York']
# Out:
#          name                    placeType  \
# 373  New York  {'code': 7, 'name': 'Town'}
#
#                                              url  parentid        country  \
# 373  http://where.yahooapis.com/v1/place/2459115  23424977  United States
#
#        woeid countryCode
# 373  2459115          US

# %% [markdown]
# Store the `woeid` of Tampa in tampa_id.

# %%
tampa_id = df_place[df_place['name']=='Tampa']['woeid']

# %% [markdown]
# Return the trends in Tampa.
#
# Note: you need to convert the city_id from a pandas series object into an integer.

# %%
# make Tampa as an example
trends_tampa = api.get_place_trends(int(tampa_id))

# %% [markdown]
# Print the trends in JSON format

# %%
# print the top 20 trends in Tampa
trends_tampa[0:20]
# Out:
# [{'trends': [{'name': 'Wordle 304 X',
#     'url': 'http://twitter.com/search?q=%22Wordle+304+X%22',
#     'promoted_content': None,
#     'query': '%22Wordle+304+X%22',
#     'tweet_volume': 22370},
#    {'name': 'Taylor Lorenz',
#     'url': 'http://twitter.com/search?q=%22Taylor+Lorenz%22',
#     'promoted_content': None,
#     'query': '%22Taylor+Lorenz%22',
#     'tweet_volume': 41612},
#    {'name': 'Libs of TikTok',
#     'url': 'http://twitter.com/search?q=%22Libs+of+TikTok%22',
#     'promoted_content': None,
#     'query': '%22Libs+of+TikTok%22',
#     'tweet_volume': 16535},
#    {'name': 'Xenoblade 3',
#     'url': 'http://twitter.com/search?q=%22Xenoblade+3%22',
#     'promoted_content': None,
#     'query': '%22Xenoblade+3%22',
#     'tweet_volume': None},
#    {'name': '#tuesdayvibe',
#     'url': 'http://twitter.com/search?q=%23tuesdayvibe',
#     'promoted_content': None,
#     'query': '%23tuesdayvibe',
#     'tweet_volume': 10642},
#    {'name': 'Daily Quordle 85',
#     'url': 'http://twitter.com/search?q=%22Daily+Quordle+85%22',
#     'promoted_content': None,
#     'query': '%22Daily+Quordle+85%22',
#     'tweet_volume': None},
#    {'name': 'Dark MAGA',
#     'url': 'http://twitter.com/search?q=%22Dark+MAGA%22',
#     'promoted_content': None,
#     'query': '%22Dark+MAGA%22',
#     'tweet_volume': None},
#    {'name': 'DJ Envy',
#     'url': 'http://twitter.com/search?q=%22DJ+Envy%22',
#     'promoted_content': None,
#     'query': '%22DJ+Envy%22',
#     'tweet_volume': None},
#    {'name': '#tuesdaymotivations',
#     'url': 'http://twitter.com/search?q=%23tuesdaymotivations',
#     'promoted_content': None,
#     'query': '%23tuesdaymotivations',
#     'tweet_volume': 30739},
#    {'name': 'Splatoon 3',
#     'url': 'http://twitter.com/search?q=%22Splatoon+3%22',
#     'promoted_content': None,
#     'query': '%22Splatoon+3%22',
#     'tweet_volume': None},
#    {'name': '#WeRemember',
#     'url': 'http://twitter.com/search?q=%23WeRemember',
#     'promoted_content': None,
#     'query': '%23WeRemember',
#     'tweet_volume': None},
#    {'name': '#ThingsYouShouldNeverDoAtHome',
#     'url': 'http://twitter.com/search?q=%23ThingsYouShouldNeverDoAtHome',
#     'promoted_content': None,
#     'query': '%23ThingsYouShouldNeverDoAtHome',
#     'tweet_volume': None},
#    {'name': 'WaPo',
#     'url': 'http://twitter.com/search?q=WaPo',
#     'promoted_content': None,
#     'query': 'WaPo',
#     'tweet_volume': 25003},
#    {'name': 'Chaya Raichik',
#     'url': 'http://twitter.com/search?q=%22Chaya+Raichik%22',
#     'promoted_content': None,
#     'query': '%22Chaya+Raichik%22',
#     'tweet_volume': None},
#    {'name': 'Good Tuesday',
#     'url': 'http://twitter.com/search?q=%22Good+Tuesday%22',
#     'promoted_content': None,
#     'query': '%22Good+Tuesday%22',
#     'tweet_volume': 27669},
#    {'name': 'NY State of Mind',
#     'url': 'http://twitter.com/search?q=%22NY+State+of+Mind%22',
#     'promoted_content': None,
#     'query': '%22NY+State+of+Mind%22',
#     'tweet_volume': None},
#    {'name': 'LOTT',
#     'url': 'http://twitter.com/search?q=LOTT',
#     'promoted_content': None,
#     'query': 'LOTT',
#     'tweet_volume': None},
#    {'name': '#TuesdayFeeling',
#     'url': 'http://twitter.com/search?q=%23TuesdayFeeling',
#     'promoted_content': None,
#     'query': '%23TuesdayFeeling',
#     'tweet_volume': 11326},
#    {'name': 'Masks',
#     'url': 'http://twitter.com/search?q=Masks',
#     'promoted_content': None,
#     'query': 'Masks',
#     'tweet_volume': 314503},
#    {'name': 'Crazy Taxi',
#     'url': 'http://twitter.com/search?q=%22Crazy+Taxi%22',
#     'promoted_content': None,
#     'query': '%22Crazy+Taxi%22',
#     'tweet_volume': None},
#    {'name': 'Monolith Soft',
#     'url': 'http://twitter.com/search?q=%22Monolith+Soft%22',
#     'promoted_content': None,
#     'query': '%22Monolith+Soft%22',
#     'tweet_volume': None},
#    {'name': 'Joe Kahn',
#     'url': 'http://twitter.com/search?q=%22Joe+Kahn%22',
#     'promoted_content': None,
#     'query': '%22Joe+Kahn%22',
#     'tweet_volume': None},
#    {'name': 'Mero',
#     'url': 'http://twitter.com/search?q=Mero',
#     'promoted_content': None,
#     'query': 'Mero',
#     'tweet_volume': 15057},
#    {'name': 'Doxxing',
#     'url': 'http://twitter.com/search?q=Doxxing',
#     'promoted_content': None,
#     'query': 'Doxxing',
#     'tweet_volume': 20851},
#    {'name': 'Reposting',
#     'url': 'http://twitter.com/search?q=Reposting',
#     'promoted_content': None,
#     'query': 'Reposting',
#     'tweet_volume': 11831},
#    {'name': 'jay park',
#     'url': 'http://twitter.com/search?q=%22jay+park%22',
#     'promoted_content': None,
#     'query': '%22jay+park%22',
#     'tweet_volume': 159589},
#    {'name': "It Ain't Hard to Tell",
#     'url': 'http://twitter.com/search?q=%22It+Ain%27t+Hard+to+Tell%22',
#     'promoted_content': None,
#     'query': '%22It+Ain%27t+Hard+to+Tell%22',
#     'tweet_volume': None},
#    {'name': 'Nintendo Store',
#     'url': 'http://twitter.com/search?q=%22Nintendo+Store%22',
#     'promoted_content': None,
#     'query': '%22Nintendo+Store%22',
#     'tweet_volume': None},
#    {'name': 'The World Is Yours',
#     'url': 'http://twitter.com/search?q=%22The+World+Is+Yours%22',
#     'promoted_content': None,
#     'query': '%22The+World+Is+Yours%22',
#     'tweet_volume': None},
#    {'name': 'Jet Set Radio',
#     'url': 'http://twitter.com/search?q=%22Jet+Set+Radio%22',
#     'promoted_content': None,
#     'query': '%22Jet+Set+Radio%22',
#     'tweet_volume': None},
#    {'name': 'MONSTA X ORIGINALITY',
#     'url': 'http://twitter.com/search?q=%22MONSTA+X+ORIGINALITY%22',
#     'promoted_content': None,
#     'query': '%22MONSTA+X+ORIGINALITY%22',
#     'tweet_volume': 74943},
#    {'name': 'World of Warcraft',
#     'url': 'http://twitter.com/search?q=%22World+of+Warcraft%22',
#     'promoted_content': None,
#     'query': '%22World+of+Warcraft%22',
#     'tweet_volume': None},
#    {'name': 'Live A Live',
#     'url': 'http://twitter.com/search?q=%22Live+A+Live%22',
#     'promoted_content': None,
#     'query': '%22Live+A+Live%22',
#     'tweet_volume': 456960},
#    {'name': 'Delta',
#     'url': 'http://twitter.com/search?q=Delta',
#     'promoted_content': None,
#     'query': 'Delta',
#     'tweet_volume': 102313},
#    {'name': 'Reedy Creek',
#     'url': 'http://twitter.com/search?q=%22Reedy+Creek%22',
#     'promoted_content': None,
#     'query': '%22Reedy+Creek%22',
#     'tweet_volume': None},
#    {'name': 'Oklahoma City',
#     'url': 'http://twitter.com/search?q=%22Oklahoma+City%22',
#     'promoted_content': None,
#     'query': '%22Oklahoma+City%22',
#     'tweet_volume': None},
#    {'name': 'Nate Silver',
#     'url': 'http://twitter.com/search?q=%22Nate+Silver%22',
#     'promoted_content': None,
#     'query': '%22Nate+Silver%22',
#     'tweet_volume': None},
#    {'name': 'Dean Baquet',
#     'url': 'http://twitter.com/search?q=%22Dean+Baquet%22',
#     'promoted_content': None,
#     'query': '%22Dean+Baquet%22',
#     'tweet_volume': None},
#    {'name': 'Malcolm Nance',
#     'url': 'http://twitter.com/search?q=%22Malcolm+Nance%22',
#     'promoted_content': None,
#     'query': '%22Malcolm+Nance%22',
#     'tweet_volume': 44470},
#    {'name': 'jungkook',
#     'url': 'http://twitter.com/search?q=jungkook',
#     'promoted_content': None,
#     'query': 'jungkook',
#     'tweet_volume': 943058},
#    {'name': 'Orthodox Jew',
#     'url': 'http://twitter.com/search?q=%22Orthodox+Jew%22',
#     'promoted_content': None,
#     'query': '%22Orthodox+Jew%22',
#     'tweet_volume': None},
#    {'name': 'Kwon',
#     'url': 'http://twitter.com/search?q=Kwon',
#     'promoted_content': None,
#     'query': 'Kwon',
#     'tweet_volume': 11982},
#    {'name': 'Terrific Tuesday',
#     'url': 'http://twitter.com/search?q=%22Terrific+Tuesday%22',
#     'promoted_content': None,
#     'query': '%22Terrific+Tuesday%22',
#     'tweet_volume': None},
#    {'name': 'Memory Lane',
#     'url': 'http://twitter.com/search?q=%22Memory+Lane%22',
#     'promoted_content': None,
#     'query': '%22Memory+Lane%22',
#     'tweet_volume': None},
#    {'name': 'Hazara',
#     'url': 'http://twitter.com/search?q=Hazara',
#     'promoted_content': None,
#     'query': 'Hazara',
#     'tweet_volume': None},
#    {'name': 'AutoExpreso',
#     'url': 'http://twitter.com/search?q=AutoExpreso',
#     'promoted_content': None,
#     'query': 'AutoExpreso',
#     'tweet_volume': None},
#    {'name': 'Senior Night',
#     'url': 'http://twitter.com/search?q=%22Senior+Night%22',
#     'promoted_content': None,
#     'query': '%22Senior+Night%22',
#     'tweet_volume': None},
#    {'name': 'Big Mouth',
#     'url': 'http://twitter.com/search?q=%22Big+Mouth%22',
#     'promoted_content': None,
#     'query': '%22Big+Mouth%22',
#     'tweet_volume': None}],
#   'as_of': '2022-04-19T14:14:50Z',
#   'created_at': '2022-04-18T12:35:53Z',
#   'locations': [{'name': 'Tampa', 'woeid': 2503863}]}]

# %% [markdown]
# Organize the Tampa trends in a dataframe.

# %%
# Get trend name, URL, and tweet volume from the JSON data, and store them in a list
trends_tampa_ls = [[trend['name'], trend['url'], trend['tweet_volume']] for trend in trends_tampa[0]['trends']]

# Convert the list to a dataframe
df_trends = pd.DataFrame(trends_tampa_ls,columns=['name','url','tweet_volume'])

# %% [markdown]
# Sort the trends by tweet volumn in a descending order and print the top 10 trends with the most tweeting volumne.

# %%
# Sort the trends by tweet volumn in a descending order
df_trends.sort_values("tweet_volume", inplace = True, ascending = False)

# Print the top 10 trends ranked by tweet volumne
df_trends.head(10)
# Out:
#                     name                                                url  \
# 39              jungkook               http://twitter.com/search?q=jungkook
# 32           Live A Live      http://twitter.com/search?q=%22Live+A+Live%22
# 18                 Masks                  http://twitter.com/search?q=Masks
# 25              jay park         http://twitter.com/search?q=%22jay+park%22
# 33                 Delta                  http://twitter.com/search?q=Delta
# 30  MONSTA X ORIGINALITY  http://twitter.com/search?q=%22MONSTA+X+ORIGIN...
# 38         Malcolm Nance    http://twitter.com/search?q=%22Malcolm+Nance%22
# 1          Taylor Lorenz    http://twitter.com/search?q=%22Taylor+Lorenz%22
# 8    #tuesdaymotivations  http://twitter.com/search?q=%23tuesdaymotivations
# 14          Good Tuesday     http://twitter.com/search?q=%22Good+Tuesday%22
#
#     tweet_volume
# 39      943058.0
# 32      456960.0
# 18      314503.0
# 25      159589.0
# 33      102313.0
# 30       74943.0
# 38       44470.0
# 1        41612.0
# 8        30739.0
# 14       27669.0

# %% [markdown]
# The table shows the popular topics people are tweeting about in Tampa.

# %% [markdown]
# ---

# %% [markdown]
# ## 5. Acquiring Tweets using the Search API

# %% [markdown]
# ### 5.1 Search Tweets using Keywords
#
# In this step, you will use Python program to search tweets that contain a specific keyword. Next, we will search for Tweets that contain "Football".
#
# You can replace the key words to something you are interesting. Please try to choose a popular one so that you can collect sufficient tweets.

# %%
tweets = api.search_tweets("Football", count=100)

print("Total retweet retrieved: "+ str(len(tweets)))
# Out:
# Total retweet retrieved: 100

# %% [markdown]
# Store the user name, user location, posting time, and tweet text in a Pandas dataframe.

# %%
tweets_pd = pd.DataFrame([[tweet.user.name, tweet.user.location,tweet.created_at, tweet.text] for tweet in tweets], 
                         columns = ['user_name','user_loc','creation_time','text'])

tweets_pd
# Out:
#                   user_name                        user_loc  \
# 0                  Chapster  West Yorkshire but work in MCR
# 1                   Jourdan
# 2                Beardo Saz                       Metaverse
# 3                   Ollie🇺🇲           Fort Leonard Wood, MO
# 4            FÃÇTØS BRÃCÉ😎💰
# ..                      ...                             ...
# 95                👑ADINKRA😇                          Earth🌎
# 96  Kriss gin Nuñez Carazas
# 97  Ireland against Fascism                         Ireland
# 98      🅒︎🅡︎7 Ⓕ︎Ⓐ︎Ⓝ︎ 🅑︎🅞︎🅨︎                   Kerala, India
# 99                   Kofi J      Somewhere in the Universe
#
#                creation_time  \
# 0  2022-04-16 21:19:22+00:00
# 1  2022-04-16 21:19:21+00:00
# 2  2022-04-16 21:19:21+00:00
# 3  2022-04-16 21:19:21+00:00
# 4  2022-04-16 21:19:21+00:00
# ..                       ...
# 95 2022-04-16 21:18:44+00:00
# 96 2022-04-16 21:18:44+00:00
# 97 2022-04-16 21:18:43+00:00
# 98 2022-04-16 21:18:43+00:00
# 99 2022-04-16 21:18:42+00:00
#
#                                                  text
# 0   @LedwardAndy @tommo2510 I have said it before ...
# 1   @TFG_Football I would be if playoff basketball...
# 2   RT @IAmENISA: Going to my first Football game ...
# 3   Dudes a fucking 🤡\nOther than catching a footb...
# 4   RT @SaddickAdams: I'm honestly not sure if any...
# ..                                                ...
# 95  RT @Listo_Mens: HT’ Ahly 2-1 Raja Casablanca \...
# 96  RT @blue_roses35: Louis getting given a Belgiu...
# 97  As we've seen since the individual was charged...
# 98  RT @sistoney67: Manchester United 3-2 Norwich ...
# 99  RT @Malachians: Enjoy him now, we'll miss him ...
#
# [100 rows x 4 columns]

# %% [markdown]
# The `search_tweets` funciton can retrieve max 100 tweets at a time. If you want to get more tweets, you can use a `cursor`.
#
# The following code use a cursor to retrieve more tweets containing a keyword. Here we still retrieve 100 tweets to save your search quota for the following steps. You could increase the `num` variable if you want to get more tweets.
#
# > Note: Twitter only allows you to retrieve a limited number of tweets per 15 minutes. If the retrieved tweets exceed the limit, the program will pause for a certain amount time. If you can't wait, you can doublepress `i` on your keyboard to interrupt the process.

# %%
# Number of tweets to be retrieved.
num = 100

# define the search keyword
keyword = "Football"

# use cursor to send your request with parameters
tweets = tweepy.Cursor(api.search_tweets,
                   q = keyword,
                   count = num,
                   lang="en").items(num)

# restore the results as a list
tweet_ls = [[tweet.user.name, tweet.user.location,tweet.created_at, tweet.text] for tweet in tweets]

# Store the retrieved tweets in a dataframe
tweets_pd_full = pd.DataFrame(tweet_ls, 
                         columns = ['user_name','user_loc','creation_time','text'])

# Print the dataframe
tweets_pd_full
# Out:
#                           user_name  \
# 0                        Sam Minton
# 1          aterg; harry’s house era
# 2                         scarlet88
# 3                         KervSells
# 4            Holy Cross JV Football
# ..                              ...
# 95                          carl00z
# 96                          Torch 💎
# 97           The Arseholics Podcast
# 98                     tim fenander
# 99  Carol ☕ || Late Night Talking 💚
#
#                                              user_loc  \
# 0                                         Peabody, MA
# 1   she ¡! they (any pronouns)\n˗ˋˏsandy milkovich...
# 2
# 3
# 4                             Francis Lewis Boulevard
# ..                                                ...
# 95
# 96                                            Nigeria
# 97
# 98
# 99
#
#                creation_time  \
# 0  2022-04-16 21:19:38+00:00
# 1  2022-04-16 21:19:38+00:00
# 2  2022-04-16 21:19:38+00:00
# 3  2022-04-16 21:19:37+00:00
# 4  2022-04-16 21:19:37+00:00
# ..                       ...
# 95 2022-04-16 21:18:48+00:00
# 96 2022-04-16 21:18:48+00:00
# 97 2022-04-16 21:18:47+00:00
# 98 2022-04-16 21:18:47+00:00
# 99 2022-04-16 21:18:46+00:00
#
#                                                  text
# 0   I don’t want to alarm anyone and I’ll take pic...
# 1   RT @HLDTour: Louis signed a football shirt for...
# 2   RT @AWardSports: In my opinion, C.J. Stroud an...
# 3   RT @pinestbreakers: 🚨PRE-SALE LIVE ON DISCORD🚨...
# 4   🟢⚔️💛⚔️🟢\n•\nWishing a Happy Easter to all our ...
# ..                                                ...
# 95  RT @drgoatz: @football_muscIe @therealtyquendo...
# 96  The Vice Chancellor of the University of Footb...
# 97  RT @northbankninja: At a Craig David concert, ...
# 98  RT @NBCSEdgeFB: Jadeveon Clowney expected to r...
# 99  RT @HLDTour: Louis getting given a Belgium foo...
#
# [100 rows x 4 columns]

# %% [markdown]
# ### 5.2 Filter out Retweets
# The retrieved tweets include both original tweets and retweets. The content of retweets are almost identical and carry little information. You can set up a filter to eliminate the retweets and keep only the original tweets.
#
# To filter out retweets, you can simply add `-filter:retweets` in the search keyword.

# %%
new_keyword = "Football" + " -filter:retweets"
new_keyword
# Out:
# 'Football -filter:retweets'

# %% [markdown]
# The following code retrieve only original tweets that contain the keyword "Football".

# %%
# Number of tweets to be retrieved.
num = 100

# use cursor to send your request with parameters
tweets = tweepy.Cursor(api.search_tweets,
                   q = new_keyword,
                   count = num,
                   lang="en").items(num)

# restore the results as a list
tweet_ls = [[tweet.user.name, tweet.user.location,tweet.created_at, tweet.text] for tweet in tweets]

# Store the retrieved tweets in a dataframe
tweets_pd_full = pd.DataFrame(tweet_ls, 
                         columns = ['user_name','user_loc','creation_time','text'])

# Print the dataframe
tweets_pd_full
# Out:
#                                  user_name                           user_loc  \
# 0                              Obuseh Jude                            Nigeria
# 1                               bethastin✨                 Costa Del Rochdale
# 2                           pruno penandes                      inceltic park
# 3   Alabama Crimson Tide Football Alliance                     Tuscaloosa, AL
# 4                        freddie stevenson                            Purpose
# ..                                     ...                                ...
# 95                         KyleZoomZumbach                  Bullhead City, AZ
# 96                             Jonny Alves  Saint Helier, Bailiwick of Jersey
# 97                     Pennsylvania Sports                  Pennsylvania, USA
# 98                                freedumb                      ur moms house
# 99                      The Soccer Factory
#
#                creation_time  \
# 0  2022-04-16 21:23:44+00:00
# 1  2022-04-16 21:23:43+00:00
# 2  2022-04-16 21:23:37+00:00
# 3  2022-04-16 21:23:35+00:00
# 4  2022-04-16 21:23:34+00:00
# ..                       ...
# 95 2022-04-16 21:21:56+00:00
# 96 2022-04-16 21:21:54+00:00
# 97 2022-04-16 21:21:52+00:00
# 98 2022-04-16 21:21:50+00:00
# 99 2022-04-16 21:21:50+00:00
#
#                                                  text
# 0   @SuperSportTV Whether naysayers want to accept...
# 1   No matter the result football will never spoil...
# 2   @VincentEPhiri @ManCity You really don't know ...
# 3   LOOK: Top images from Alabama Football's A-Day...
# 4   All the @fcflio football games are at the Pull...
# ..                                                ...
# 95  I found it interesting there a ton of HS that ...
# 96  Clearly Portimonense didn’t fancy playing foot...
# 97  Alabama honors university’s first Black footba...
# 98  apparently i have astigmatism really bad and s...
# 99  Coach @keimar.clarke providing the details in ...
#
# [100 rows x 4 columns]

# %% [markdown]
# ### 5.3 Search Tweets using locations
#
# You can also search for tweets around a certain location. The spatial query is based on geotags and/or user locations of the tweets.
#
# The following code will retrieve 200 tweets containing "Football" within a 20 mile radius from USF (28.0619,-82.4146).

# %%
# Number of tweets to be retrieved.
num = 200

# define the search keyword
keyword = "Football"

# use cursor to send your request with parameters
tweets = tweepy.Cursor(api.search_tweets,
                   q=keyword,
                   geocode = "28.0619,-82.4146,20mi",
                   count = num,
                   lang="en").items(num)

# restore the results as a list
tweet_ls = [[tweet.user.name, tweet.user.location, tweet.place, tweet.created_at, tweet.text] for tweet in tweets]

# Store the retrieved tweets in a dataframe
tweets_pd_geo = pd.DataFrame(tweet_ls, 
                         columns = ['user_name','user_loc','geotag','creation_time','text'])

# Print the dataframe
tweets_pd_geo
# Out:
#                      user_name        user_loc  \
# 0                    Rob Maier   Clearwater,Fl
# 1              BADGIRL MELISSA       Tampa, FL
# 2                 Phillybuster  Clearwater, FL
# 3                        Kh813       Tampa, FL
# 4                    Mikey2CTA       Tampa, FL
# ..                         ...             ...
# 195           Thechosenone3488
# 196  Strawberry Crest Football       Dover, FL
# 197        #Fantasy #SKOL Dave       Tampa, FL
# 198                Bruce Wayne       Tampa, FL
# 199            Luke Easterling       Tampa, FL
#
#                                                 geotag  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 195  Place(_api=<tweepy.api.API object at 0x000001E...
# 196                                               None
# 197                                               None
# 198                                               None
# 199                                               None
#
#                 creation_time  \
# 0   2022-04-16 21:22:33+00:00
# 1   2022-04-16 21:18:03+00:00
# 2   2022-04-16 21:03:19+00:00
# 3   2022-04-16 20:56:27+00:00
# 4   2022-04-16 20:53:53+00:00
# ..                        ...
# 195 2022-04-14 18:38:05+00:00
# 196 2022-04-14 18:35:18+00:00
# 197 2022-04-14 18:27:32+00:00
# 198 2022-04-14 18:26:44+00:00
# 199 2022-04-14 18:16:05+00:00
#
#                                                   text
# 0    @ethanhub_ @UCF_Football @CoachHand @CoachGusM...
# 1    So ready for some football @usflonfox opening ...
# 2    🗓 Today (4/16) from 🕓 6pm-9pm\n📍 Womens Footba...
# 3    @ArmyWP_Football He’s Army Strong! A leader wi...
# 4    @NBA Love nba basketball…. Especially playoffs...
# ..                                                 ...
# 195  @DCarr75 @derekcarrqb My dream is lose 130 joi...
# 196  2022 Crest Football Schedule\n@TheSCHSChargers...
# 197  @jstockfive @Official_ACG Yea bro stick to foo...
# 198  @william_nixonTD @UW_Football @KalenDeBoer @Co...
# 199  2022 NFL draft: Nick Cross scouting report htt...
#
# [200 rows x 5 columns]

# %% [markdown]
# Next, we are going to map the tweets using their geotags. However, only a very small proportion (1-2%) of tweets have a geotag. We first check how many of the 200 tweets have a  geotag.

# %%
all = len(tweets_pd_geo[tweets_pd_geo['geotag'].notna()]) # all retrieved tweets
geo = len(tweets_pd_geo) # tweets that actually have geotags.

print("%s out of the %s retrieved tweets actually have a geotag" % (all, geo))
# Out:
# 23 out of the 200 retrieved tweets actually have a geotag

# %% [markdown]
# #### Copy tweets with geotags to a new dataframe called "geotags"

# %%
geo_tweets = tweets_pd_geo.loc[tweets_pd_geo['geotag'].notna()].copy()

# %% [markdown]
# Check detailed data in a geotag. The location of the geotag is in a bounding box defined by the four coordinate pairs.

# %%
geo_tweets.iloc[0].geotag
# Out:
# Place(_api=<tweepy.api.API object at 0x000001E1A0FD4400>, id='07d9df966e080000', url='https://api.twitter.com/1.1/geo/id/07d9df966e080000.json', place_type='poi', name='Tampa Bay Florida', full_name='Tampa Bay Florida', country_code='US', country='United States', contained_within=[], bounding_box=BoundingBox(_api=<tweepy.api.API object at 0x000001E1A0FD4400>, type='Polygon', coordinates=[[[-82.34978505052312, 28.030923683079468], [-82.34978505052312, 28.030923683079468], [-82.34978505052312, 28.030923683079468], [-82.34978505052312, 28.030923683079468]]]), attributes={})

# %% [markdown]
# Get coordinates of the bounding box

# %%
geo_tweets.iloc[0].geotag.bounding_box.coordinates
# Out:
# [[[-82.34978505052312, 28.030923683079468],
#   [-82.34978505052312, 28.030923683079468],
#   [-82.34978505052312, 28.030923683079468],
#   [-82.34978505052312, 28.030923683079468]]]

# %% [markdown]
# Create a column in the dataframe to store coordinates of the bounding boxes

# %%
# store bounding box coordinates to a new column
geo_tweets['bounding_box'] = geo_tweets.geotag.apply(lambda s:s.bounding_box.coordinates[0])

# print the geotag
geo_tweets.head()
# Out:
#                    user_name           user_loc  \
# 10  Sadarian *Yachty* Austin          Tampa, FL
# 16                     Shawn
# 35           BrandonSpikes55      Charlotte, NC
# 43            Xavier Porter🖤          Tampa, FL
# 52                Maggi Cook  St Petersburg, FL
#
#                                                geotag  \
# 10  Place(_api=<tweepy.api.API object at 0x000001E...
# 16  Place(_api=<tweepy.api.API object at 0x000001E...
# 35  Place(_api=<tweepy.api.API object at 0x000001E...
# 43  Place(_api=<tweepy.api.API object at 0x000001E...
# 52  Place(_api=<tweepy.api.API object at 0x000001E...
#
#                creation_time  \
# 10 2022-04-16 19:32:21+00:00
# 16 2022-04-16 18:16:37+00:00
# 35 2022-04-16 14:06:05+00:00
# 43 2022-04-16 12:42:41+00:00
# 52 2022-04-16 10:00:19+00:00
#
#                                                  text  \
# 10  Light weights during the baseball season getti...
# 16  @JamesPalmerTV @wyo_football @nflnetwork Hes g...
# 35  Lmao that league shit was wayyyyyy 2 easy 🤣🤣🤣 ...
# 43  I will be at The University of Central Florida...
# 52  If this was your family member wouldn't you be...
#
#                                          bounding_box
# 10  [[-82.34978505052312, 28.030923683079468], [-8...
# 16  [[-82.712772, 27.977811], [-82.675347, 27.9778...
# 35  [[-82.620093, 27.821353], [-82.2652945, 27.821...
# 43  [[-82.2679052, 27.930926], [-82.0556591, 27.93...
# 52  [[-82.369079, 27.755502], [-82.2443655, 27.755...

# %% [markdown]
# For mapping purpose, we will simplify the bounding boxes to their centroids (points). In such a way, each tweet will be pinned to the centroid of the bounding box in the geotag.
#
# The following code calculate the lat, lon of centroids and store them in two new columns.

# %%
geo_tweets['point']  = geo_tweets['bounding_box'].apply(lambda s: [(s[0][1]+s[2][1])/2,(s[0][0]+s[2][0])/2])

geo_tweets['lat']  = geo_tweets['bounding_box'].apply(lambda s: (s[0][1]+s[2][1])/2)

geo_tweets['lon']  = geo_tweets['bounding_box'].apply(lambda s: (s[0][0]+s[2][0])/2)

# %% [markdown]
# Print to see the dataframe again. You'll see the centroids, latitude, and longitude are added as columns in the dataframe.
#
# Note: the point column is an redundancy of the lat and lon columns. We create all these columns just in case you want to convert the dataframe to a geodataframe (geometry).

# %%
geo_tweets.head()
# Out:
#                    user_name           user_loc  \
# 10  Sadarian *Yachty* Austin          Tampa, FL
# 16                     Shawn
# 35           BrandonSpikes55      Charlotte, NC
# 43            Xavier Porter🖤          Tampa, FL
# 52                Maggi Cook  St Petersburg, FL
#
#                                                geotag  \
# 10  Place(_api=<tweepy.api.API object at 0x000001E...
# 16  Place(_api=<tweepy.api.API object at 0x000001E...
# 35  Place(_api=<tweepy.api.API object at 0x000001E...
# 43  Place(_api=<tweepy.api.API object at 0x000001E...
# 52  Place(_api=<tweepy.api.API object at 0x000001E...
#
#                creation_time  \
# 10 2022-04-16 19:32:21+00:00
# 16 2022-04-16 18:16:37+00:00
# 35 2022-04-16 14:06:05+00:00
# 43 2022-04-16 12:42:41+00:00
# 52 2022-04-16 10:00:19+00:00
#
#                                                  text  \
# 10  Light weights during the baseball season getti...
# 16  @JamesPalmerTV @wyo_football @nflnetwork Hes g...
# 35  Lmao that league shit was wayyyyyy 2 easy 🤣🤣🤣 ...
# 43  I will be at The University of Central Florida...
# 52  If this was your family member wouldn't you be...
#
#                                          bounding_box  \
# 10  [[-82.34978505052312, 28.030923683079468], [-8...
# 16  [[-82.712772, 27.977811], [-82.675347, 27.9778...
# 35  [[-82.620093, 27.821353], [-82.2652945, 27.821...
# 43  [[-82.2679052, 27.930926], [-82.0556591, 27.93...
# 52  [[-82.369079, 27.755502], [-82.2443655, 27.755...
#
#                                        point        lat        lon
# 10  [28.030923683079468, -82.34978505052312]  28.030924 -82.349785
# 16  [28.013468500000002, -82.69405950000001]  28.013469 -82.694060
# 35          [27.9965945, -82.44269374999999]  27.996595 -82.442694
# 43                [28.0121671, -82.16178215]  28.012167 -82.161782
# 52        [27.827367000000002, -82.30672225]  27.827367 -82.306722

# %% [markdown]
# ---

# %% [markdown]
# ## 6. Mapping Geotagged Tweets

# %% [markdown]
# Finally, we will use folium to create an interactive map for the geotagged tweets.

# %%
# Create a base map
maptweet = folium.Map()

# Add the tweets into the basemap
for i, row in geo_tweets.iterrows():
    folium.Marker(row.point,popup = row.text).add_to(maptweet)
    
# Zoom to the bounding box including the tweets
maptweet.fit_bounds([[min(geo_tweets.lat),min(geo_tweets.lon)],[max(geo_tweets.lat),max(geo_tweets.lon)]])

# Show the map
display(maptweet)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_fa3b9aa19dd3443d853b7d3c8a09e8ae%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_fa3b9aa19dd3443d853b7d3c8a09e8ae%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_fa3b9aa19dd3443d853b7d3c8a09e8ae%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_fa3b9aa19dd3443d853b7d3c8a09e8ae%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B0%2C%200%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs%3A%2 ...

# %% [markdown]
# ## 7. Streaming Tweets
#
# Unlike the Search API, the Streaming API utilizes Twitter's HTTP protocol to deliver data through an open, streaming API connection. A single streaming connection is opened between your app and the API, with new results being sent through that connection whenever new matches occur. This results in a low-latency delivery mechanism that can support very high throughput. For further information, see https://developer.twitter.com/en/docs/tutorials/consuming-streaming-data.
#
# Depending on the filter (the speed of retrieval), the streaming API is also subject to a limit per 15 minutes. If the retrieved tweets exceed the limit, your program will pause for the next 15 minutes cycle.
#
# Run the following code to start streaming. The text messages are printed. You can double press `I` to interrupt the streaming.

# %%
import tweepy
import csv

# paste your API keys and tokens to replace ......
API_key = 'As0PGxFkLLgXKyqnGCre08UNz'
API_key_secret = '6rzlzIBqgURxZd2PKjo4QTj4iYNiwINHDWDCMWW3zlxUU9xr23'
access_token = '1509606550134038533-TpQM7b6U3nlvewate1hJqqbMuHSl5p'
access_token_secret = 'jTMIxiyKndnxMAI1vJScVC8diddUgHO2EJvNbb4nozU8L'

auth = tweepy.OAuthHandler(API_key, API_key_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth, wait_on_rate_limit = True)

# %% [markdown]
# You can run the follow code to stream real-time tweets and save them in a CSV file in your computer.

# %%
# Define path and name of output file
output_file = "tweets_putin.csv"

# Open a file to write in streamed tweets
with open(output_file, "w", encoding="utf-8",newline='') as f:
    writer = csv.writer(f)
    
    # Write the headers in the first row
    writer.writerow(["username","created_at", "geotag", "user_location", "lang","tweet"])
    
    # Define a sub-object of tweepy.Stream
    class stream_csv(tweepy.Stream):
        def on_status(self, status):
            # Skip retweets and collect only geotagged tweets
            if (not status.retweeted) and ('RT @' not in status.text) and (status.place is not None):
                # Organize attributes of a tweet in a list
                line = [status.user.name, status.user.created_at, status.place.bounding_box.coordinates[0], status.user.location, status.lang, status.text]
                print(line) # Print the line
                writer.writerow(line) # write the line to csv file

    streamer = stream_csv(API_key, API_key_secret, access_token, access_token_secret)
    streamer.filter(languages=["en"], track=["putin"])
    streamer.sample()
# Out:
# ['Eugene B Douglas', datetime.datetime(2015, 5, 18, 10, 8, 36, tzinfo=datetime.timezone.utc), [[-74.026675, 40.683935], [-74.026675, 40.877483], [-73.910408, 40.877483], [-73.910408, 40.683935]], 'Poud NYCier/speck IN universe', 'en', 'Good deal 🇺🇦‼️Slava Ukraini 💪🤬🖖🗽⚖️🙏‼️🆘🤔👊🇺🇸💙🌀🌊🤜💥🤛‼️']
# ['Linda Marie Garcia', datetime.datetime(2022, 2, 12, 14, 30, 50, tzinfo=datetime.timezone.utc), [[-104.69356, 38.200638], [-104.69356, 38.338462], [-104.551992, 38.338462], [-104.551992, 38.200638]], None, 'en', '@visegrad24 @joncoopertweets It is about time.  Ukraine needs to become a member of NATO ASAP. This is something th… https://t.co/TGXfi9zO7d']
# ['ひろ free paper 真実は一つ', datetime.datetime(2022, 3, 11, 2, 31, 28, tzinfo=datetime.timezone.utc), [[135.191003, 34.683056], [135.191003, 34.768661], [135.259763, 34.768661], [135.259763, 34.683056]], None, 'en', 'I feel this war is by\nputin for putin putin waa!']
# ['Antonio García Martínez (agm.eth) 🇺🇦', datetime.datetime(2007, 12, 27, 22, 26, 57, tzinfo=datetime.timezone.utc), [[-124.482003, 32.528832], [-124.482003, 42.009519], [-114.131212, 42.009519], [-114.131212, 32.528832]], 'High Desert Nevada', 'en', 'Curious how this view is shared by most Ukrainians and Westerners who’ve seen the conflict in person, while the opp… https://t.co/9lfFsosFb3']
# ['Antonio José Ramos', datetime.datetime(2013, 6, 12, 9, 22, 4, tzinfo=datetime.timezone.utc), [[-2.181299, 38.672083], [-2.181299, 39.186567], [-1.62259, 39.186567], [-1.62259, 38.672083]], 'Albacete... de momento.', 'en', '@JohnKerry, please, stop taking drugs 😂😂😂']
# ['Edward Caddis', datetime.datetime(2019, 5, 26, 14, 50, 13, tzinfo=datetime.timezone.utc), [[-4.526533, 55.578898], [-4.526533, 55.644806], [-4.467026, 55.644806], [-4.467026, 55.578898]], 'Scotland, United Kingdom', 'en', 'Russia’s War of Terror on Ukraine🇺🇦must never be forgotten! We must keep,Putin out!of the,Free World🌍Putin is not t… https://t.co/OwCex5XkuT']
# ['Linda Marie Garcia', datetime.datetime(2022, 2, 12, 14, 30, 50, tzinfo=datetime.timezone.utc), [[-104.69356, 38.200638], [-104.69356, 38.338462], [-104.551992, 38.338462], [-104.551992, 38.200638]], None, 'en', '@cnni Do what Putin would not expect.  Admit Ukraine to NATO.']
# ['Paul Palandri', datetime.datetime(2018, 9, 21, 10, 55, 25, tzinfo=datetime.timezone.utc), [[-87.852247, 42.15223], [-87.852247, 42.223334], [-87.759091, 42.223334], [-87.759091, 42.15223]], None, 'en', "I agree with you about Putin. But anyone who would prop up the likes of Pieces of Shit DA's Foxx, Gascon, Boudin an… https://t.co/Uh1WylC873"]
# ['Stephanie Reed', datetime.datetime(2019, 1, 20, 17, 37, 1, tzinfo=datetime.timezone.utc), [[-84.820309, 38.403186], [-84.820309, 42.327133], [-80.518626, 42.327133], [-80.518626, 38.403186]], None, 'en', 'Own it you butt head!!  Quit blaming inflation on Putin, it’s a result of YOUR sanctions on Putin and his ruble is… https://t.co/ksBrfCW6eh']
# ['the OLD MAN', datetime.datetime(2018, 5, 29, 11, 47, 49, tzinfo=datetime.timezone.utc), [[34.266924, 29.393973], [34.266924, 33.290533], [35.669933, 33.290533], [35.669933, 29.393973]], 'Metaverse', 'en', '@AFP There’s is no place for Putin on this earth anymore']
# ['Mario Antone Monroe', datetime.datetime(2011, 10, 17, 3, 57, 45, tzinfo=datetime.timezone.utc), [[-118.668404, 33.704538], [-118.668404, 34.337041], [-118.155409, 34.337041], [-118.155409, 33.704538]], 'Los Angeles, CA USA', 'en', 'Putin is short little angry murderous dictator complicit to rape and gay abashing because along with this small lit… https://t.co/nZCWn0V3A1']
# ['Doug Abrams', datetime.datetime(2009, 8, 30, 14, 31, 29, tzinfo=datetime.timezone.utc), [[-78.818343, 35.715805], [-78.818343, 35.972158], [-78.497331, 35.972158], [-78.497331, 35.715805]], 'iPhone: 35.848959,-78.692313', 'en', '@ArchieMcMurdo @NatashaBertrand Putin is Hitler. US/NATO will provide to Ukraine those weapons.']
# ['Cecilie Holter', datetime.datetime(2014, 1, 19, 11, 52, 25, tzinfo=datetime.timezone.utc), [[-0.21607, 51.509879], [-0.21607, 51.539792], [-0.13016, 51.539792], [-0.13016, 51.509879]], 'Planet Earth', 'en', 'And yet not once calling out the perpetrator Putin by name. That’s not good enough. Yes, to keep channels open with… https://t.co/B6AKk5MHVx']
# ['CodeBlue Stands with Ukraine 🇺🇦🌻', datetime.datetime(2014, 7, 30, 13, 56, 28, tzinfo=datetime.timezone.utc), [[-82.681852, 35.421216], [-82.681852, 35.656929], [-82.452163, 35.656929], [-82.452163, 35.421216]], None, 'en', 'And still we watch and “impose sanctions”. Putin is holding the world hostage.']
# ['moveebuff', datetime.datetime(2011, 11, 14, 18, 50, 43, tzinfo=datetime.timezone.utc), [[-79.639319, 43.403221], [-79.639319, 43.855401], [-78.90582, 43.855401], [-78.90582, 43.403221]], 'Planet Earth', 'en', '@MrKovalenko So everyone is dead 🤬Don’t #Russians know that this war against #Ukraine️ is for #Putin ..Humans don’t… https://t.co/nxcbmLKpSh']
# ['Mario Antone Monroe', datetime.datetime(2011, 10, 17, 3, 57, 45, tzinfo=datetime.timezone.utc), [[-118.668404, 33.704538], [-118.668404, 34.337041], [-118.155409, 34.337041], [-118.155409, 33.704538]], 'Los Angeles, CA USA', 'en', "Instead sanctions how about repossessing Putin' s stolen fortune from the Russian people the keeps just barely abov… https://t.co/DHwvkCGaKg"]
# ['Meindl 🌏🌍🌎🛡️☮️', datetime.datetime(2011, 2, 3, 8, 58, 10, tzinfo=datetime.timezone.utc), [[12.653988, 48.507314], [12.653988, 48.614949], [12.779027, 48.614949], [12.779027, 48.507314]], 'Bayern Bavaria Bavière Бавария', 'en', '#Europe is now firmly back under American control.\n#Germany prepares well.\nGas + oil from #Russia are absolutely ev… https://t.co/bMMG589jSs']
# ['Widow’s Son', datetime.datetime(2013, 8, 24, 1, 27, 22, tzinfo=datetime.timezone.utc), [[-82.396441, 34.881534], [-82.396441, 34.996401], [-82.26651, 34.996401], [-82.26651, 34.881534]], 'Upstate South Carolina', 'en', '@visegrad24 Is that the same medal former US Secretary of State @RexTillersonWH was awarded by Putin?']
# ['TRACEY SWANN', datetime.datetime(2021, 7, 21, 21, 4, 13, tzinfo=datetime.timezone.utc), [[-86.785881, 34.578426], [-86.785881, 34.833627], [-86.436941, 34.833627], [-86.436941, 34.578426]], None, 'en', 'MR.PRESIDENT MORE TAN SANCATION take him out']
# ['Pjoyfarrar🌊🌊', datetime.datetime(2010, 9, 14, 21, 34, 17, tzinfo=datetime.timezone.utc), [[-118.250227, 33.732905], [-118.250227, 33.885438], [-118.063194, 33.885438], [-118.063194, 33.732905]], 'Long Beach, CA', 'en', 'By 2:00 today @SenMikeLee @GOP will have shut down all texting in this country claiming it’s been hacked.\nMedia and… https://t.co/CzvOiHDw47']
# ['Giovanni Zanutta', datetime.datetime(2011, 4, 24, 18, 15, 49, tzinfo=datetime.timezone.utc), [[27.982994, -26.136266], [27.982994, -25.98115], [28.138232, -25.98115], [28.138232, -26.136266]], 'S.A. ', 'en', "Putin's spokesman Dmitry Peskov on Ukraine and the West: 'Don't push us ... https://t.co/2O0MfWM6jp via @YouTube"]
# ['Stephen McKenzie', datetime.datetime(2019, 4, 30, 15, 15, 39, tzinfo=datetime.timezone.utc), [[-1.528385, 51.775425], [-1.528385, 51.799774], [-1.459266, 51.799774], [-1.459266, 51.775425]], 'Cotswolds, England. ', 'en', '@cornercroftart @JenniIn603 @AseyevStanislav NATO has an obligation, EU has an obligation, Britain has an obligatio… https://t.co/MRZwi4LGlZ']
# ['Christopher Larkin', datetime.datetime(2013, 6, 25, 16, 29, 39, tzinfo=datetime.timezone.utc), [[-1.278461, 54.528279], [-1.278461, 54.59055], [-1.166542, 54.59055], [-1.166542, 54.528279]], 'Middlesbrough, England', 'en', "This'll stop Putin in his tracks."]
# ['Jo Anne Foley', datetime.datetime(2017, 5, 19, 16, 18, 20, tzinfo=datetime.timezone.utc), [[-86.178184, 42.812004], [-86.178184, 42.866339], [-86.11236, 42.866339], [-86.11236, 42.812004]], 'West Michigan, USA ', 'en', "Yes ! Now ! Before it's too late and more Ukrainians are killed."]
# ['Lisa Against Fascism🇨🇦Slava Ukraini 🇺🇦', datetime.datetime(2015, 10, 21, 13, 4, 2, tzinfo=datetime.timezone.utc), [[-79.530928, 44.063506], [-79.530928, 44.223301], [-79.276168, 44.223301], [-79.276168, 44.063506]], 'East Gwillimbury, Ontario', 'en', 'Putin and that brigade all need to die horribly 🤬🤬🤬🤬🤬🤬']
# ['Piotr Turek', datetime.datetime(2013, 2, 24, 15, 56, 26, tzinfo=datetime.timezone.utc), [[19.79343, 49.967561], [19.79343, 50.124963], [20.217962, 50.124963], [20.217962, 49.967561]], 'Cracow, Poland, The Earth', 'en', "Uncomfortable truth: He may be less corrupt and more handsome but Navalny's proven to be is just as much of a Russi… https://t.co/ZUzWJi1Pcx"]
# ['living in present moment permanently', datetime.datetime(2010, 9, 8, 14, 32, 15, tzinfo=datetime.timezone.utc), [[103.817833, 1.334355], [103.817833, 1.432041], [103.931418, 1.432041], [103.931418, 1.334355]], None, 'en', 'Imagine Putin play Truth or dare with Xi Jinping at Winter Olympics and Xi Jinping dare Putin to invade  Ukraine']
# ['Tammy Gorali', datetime.datetime(2009, 4, 15, 10, 56, tzinfo=datetime.timezone.utc), [[34.266924, 29.393973], [34.266924, 33.290533], [35.669933, 33.290533], [35.669933, 29.393973]], 'Tel Aviv', 'en', 'According to somebody on FB- this is the new warning in Ukrain not to smoke so you can get to see Putin die. True? https://t.co/ryR889iMqW']
# ['swepal', datetime.datetime(2022, 1, 26, 16, 3, 18, tzinfo=datetime.timezone.utc), [[17.760132, 59.227138], [17.760132, 59.440204], [18.199986, 59.440204], [18.199986, 59.227138]], 'Stockholm, Sweden', 'en', '#Austrian Chancellor: #Putin "Believes He Is Winning The #War"\n\n“[Putin] thinks the war is necessary for security g… https://t.co/PZPYLZ29JJ']
# ['Michael G. MacKay', datetime.datetime(2009, 9, 29, 21, 13, 56, tzinfo=datetime.timezone.utc), [[-69.052647, 44.397161], [-69.052647, 48.21148], [-63.681007, 48.21148], [-63.681007, 44.397161]], 'Fredericton, New Brunswick.', 'en', 'Putin demands Russia gain control of Jerusalem church as promised https://t.co/dtu2mXaGHt']
# ['Mario Antone Monroe', datetime.datetime(2011, 10, 17, 3, 57, 45, tzinfo=datetime.timezone.utc), [[-118.668404, 33.704538], [-118.668404, 34.337041], [-118.155409, 34.337041], [-118.155409, 33.704538]], 'Los Angeles, CA USA', 'en', '@Plaid_Putin Vladimir Putin Burn in eternal hell but first die a painful and lonely death you angry little man. I h… https://t.co/N3bXUYMvck']
# ['Lisa Against Fascism🇨🇦Slava Ukraini 🇺🇦', datetime.datetime(2015, 10, 21, 13, 4, 2, tzinfo=datetime.timezone.utc), [[-79.530928, 44.063506], [-79.530928, 44.223301], [-79.276168, 44.223301], [-79.276168, 44.063506]], 'East Gwillimbury, Ontario', 'en', 'Well, I already worry about Orban’s  Hungary being in NATO - I’m quite sure he’s passing info to his Russian master… https://t.co/9NWWhKH8H3']
# ['Luc Ménard', datetime.datetime(2010, 10, 16, 15, 16, 53, tzinfo=datetime.timezone.utc), [[-76.353876, 44.961937], [-76.353876, 45.535645], [-75.246407, 45.535645], [-75.246407, 44.961937]], 'Ottawa', 'en', 'I will give you absolution, I always wish Trump will drop dead now.']
# ['Titus', datetime.datetime(2009, 5, 18, 23, 14, 51, tzinfo=datetime.timezone.utc), [[-118.668404, 33.704538], [-118.668404, 34.337041], [-118.155409, 34.337041], [-118.155409, 33.704538]], None, 'en', 'It’s odd how people perceive things, our media, even lefty media keeps slamming Biden’s poll ratings, this is with… https://t.co/ngLlUyTcw6']
# ['Titus', datetime.datetime(2009, 5, 18, 23, 14, 51, tzinfo=datetime.timezone.utc), [[-118.668404, 33.704538], [-118.668404, 34.337041], [-118.155409, 34.337041], [-118.155409, 33.704538]], None, 'en', 'Putin started a war, Trump made a deal with Saudi to CUT oil production, https://t.co/STIC5s8HC4 it’s still current… https://t.co/Ebl544VOGS']
# ['𝙱𝚞𝚌𝚔𝚕𝚎𝚄𝚙𝙱𝚞𝚝𝚝𝚎𝚛𝚌𝚞𝚙‼️', datetime.datetime(2008, 8, 7, 22, 27, 1, tzinfo=datetime.timezone.utc), [[-73.998004, 40.80643], [-73.998004, 40.834379], [-73.976837, 40.834379], [-73.976837, 40.80643]], 'NJ/NY USA', 'en', 'Putin stay away from @chefjoseandres or you will be sorry. -America.']
# ['Michael Breslin 🇮🇹 🇪🇺 ☮ 🏴\U000e0067\U000e0062\U000e0073\U000e0063\U000e0074\U000e007f', datetime.datetime(2012, 2, 26, 14, 39, 18, tzinfo=datetime.timezone.utc), [[-4.983894, 55.861911], [-4.983894, 55.873557], [-4.976053, 55.873557], [-4.976053, 55.861911]], 'Toward, Scotland', 'en', 'This is very interesting.\n\nHave a read and if you feel you can support this campaign, please do.\n\nThe basis is that… https://t.co/hd4moVkrQK']
# ['Lynn', datetime.datetime(2022, 3, 25, 12, 40, 29, tzinfo=datetime.timezone.utc), [[6.625719, 51.332916], [6.625719, 51.56007], [6.830312, 51.56007], [6.830312, 51.332916]], 'Recklinghausen, Germany', 'en', 'Facebook Vegans be like: "YOU\'RE NOT VEGAN?! HOW DARE YOU!! YOU ARE WORSE THAN PUTIN! YOU MONSTER!"']
# ['Dave Carr 🇪🇪', datetime.datetime(2021, 4, 30, 15, 3, 34, tzinfo=datetime.timezone.utc), [[10.988242, 49.331892], [10.988242, 49.548082], [11.282478, 49.548082], [11.282478, 49.331892]], 'Tallinn, Estonia', 'en', '@EvanCull @tonyali3005 @nash_aaron @jeremycorbyn Who else shares that opinion apart from you, Andrew Murray, Putin… https://t.co/RyIUSa3Lyi']
# ['Andrew4America', datetime.datetime(2017, 5, 9, 17, 58, 47, tzinfo=datetime.timezone.utc), [[-84.330162, 33.688117], [-84.330162, 33.724667], [-84.299422, 33.724667], [-84.299422, 33.688117]], 'United States', 'en', '@repdarrellissa You also stand with Putin.  Very telling.']
# ['Jill Marie O’Brien', datetime.datetime(2010, 5, 11, 2, 9, 55, tzinfo=datetime.timezone.utc), [[-118.668404, 33.704538], [-118.668404, 34.337041], [-118.155409, 34.337041], [-118.155409, 33.704538]], 'Southern California', 'en', '@stengel @Seajay603 We need to stop spewing words that make Putin sound like some kind of victor. He is a thief. Killer.']
# ['Titus', datetime.datetime(2009, 5, 18, 23, 14, 51, tzinfo=datetime.timezone.utc), [[-118.668404, 33.704538], [-118.668404, 34.337041], [-118.155409, 34.337041], [-118.155409, 33.704538]], None, 'en', 'Putin started a war,Trump made a deal with Saudi to CUT oil production,https://t.co/oOjwmW9GZj… it’s still current,… https://t.co/vZnFQs35Y5']
# ['Alf Coates Amorim Palhinha Campeão Kerensky🦁💚⚽🏐', datetime.datetime(2009, 9, 30, 19, 41, 9, tzinfo=datetime.timezone.utc), [[-9.229826, 38.691375], [-9.229826, 38.795853], [-9.090164, 38.795853], [-9.090164, 38.691375]], 'Casa das Modalidades', 'en', '@SpencerGuard @ruiptsporting @latimes @LiamSCollins Probably why Putin has been hard at work undermining the stabil… https://t.co/Wwte7vBM5K']
# ['Danny Vandal', datetime.datetime(2021, 4, 23, 23, 9, 9, tzinfo=datetime.timezone.utc), [[-5.844369, 35.751753], [-5.844369, 35.779101], [-5.803855, 35.779101], [-5.803855, 35.751753]], None, 'en', "@dijkhoff Title: Live Updates | Putin: West's sanctions 'blitz' has failed | News10 ABC"]
# ['Rebecca Boren', datetime.datetime(2011, 12, 9, 4, 49, 48, tzinfo=datetime.timezone.utc), [[-124.482003, 32.528832], [-124.482003, 42.009519], [-114.131212, 42.009519], [-114.131212, 32.528832]], 'Spring Valley, San Diego, CA', 'en', "@DouglasDubhGlas @noohacat @YoHereAgain @Challis20201 It's not a contest of which is  more evil. All Nazism is. I'm… https://t.co/RJzoIOv0aX"]
# ['🌙💅🏾', datetime.datetime(2018, 11, 26, 1, 24, 12, tzinfo=datetime.timezone.utc), [[-80.47561, 20.912263], [-80.47561, 27.237671], [-72.712276, 27.237671], [-72.712276, 20.912263]], 'Bahamas', 'en', 'Girl what- chile pls wha https://t.co/As2H7vSIWl']
# ['Eugene B Douglas', datetime.datetime(2015, 5, 18, 10, 8, 36, tzinfo=datetime.timezone.utc), [[-74.026675, 40.683935], [-74.026675, 40.877483], [-73.910408, 40.877483], [-73.910408, 40.683935]], 'Poud NYCier/speck IN universe', 'en', 'If you support Putin you are a traitor to the Germany, EU, NATO, UKRAINE, AND THE FREE WORLD‼️… https://t.co/AFjCqScbLZ']
# ['Michael Chang', datetime.datetime(2014, 12, 17, 10, 28, 46, tzinfo=datetime.timezone.utc), [[-115.209254, 35.984784], [-115.209254, 36.137145], [-115.061076, 36.137145], [-115.061076, 35.984784]], 'Nevada', 'en', 'himars with atacms. @RepHorsford']
# ['LibertyBea', datetime.datetime(2015, 7, 7, 10, 45, 21, tzinfo=datetime.timezone.utc), [[12.618004, 41.408414], [12.618004, 41.539743], [12.777768, 41.539743], [12.777768, 41.408414]], 'Nettuno, Lazio', 'en', '@OryjieSPb @lifenews_ru Great Oliver Stone and @KremlinRussia_E ✌️🇺🇸✌️🇷🇺✌️ in a friendly, sincere and often brutal… https://t.co/xv4JeVASt3']
# ['Shari Comiter', datetime.datetime(2018, 6, 12, 15, 59, 57, tzinfo=datetime.timezone.utc), [[-81.276412, 28.510068], [-81.276412, 28.539293], [-81.252405, 28.539293], [-81.252405, 28.510068]], None, 'en', 'Biden sent weapons to late and invasion of Ukraine would not have taken place as push over with Putin if acted soon… https://t.co/UcfmuJxGcy']
# ['Vince Sheetz', datetime.datetime(2022, 3, 16, 5, 22, 43, tzinfo=datetime.timezone.utc), [[-117.146102, 33.057782], [-117.146102, 33.182936], [-116.998535, 33.182936], [-116.998535, 33.057782]], None, 'en', 'NOT "Putin price hike" https://t.co/ncTDg8PRiR']
# ['Hanief Haider', datetime.datetime(2011, 12, 9, 7, 41, 34, tzinfo=datetime.timezone.utc), [[18.318033, -34.35839], [18.318033, -33.884925], [18.66009, -33.884925], [18.66009, -34.35839]], 'Cape Town,SouthAfrica', 'en', 'Interesting thoughts re: Alistair Crooke.\nThose videos of neo-Nazis mutilating Russian corpses did not go well in R… https://t.co/SGYR7HdBA8']
# ['Adrian Robinson 🇪🇺🇺🇦', datetime.datetime(2021, 2, 13, 8, 10, 19, tzinfo=datetime.timezone.utc), [[11.261087, 49.113391], [11.261087, 49.255337], [11.400941, 49.255337], [11.400941, 49.113391]], 'Bavaria, Germany', 'en', "@johnsweeneyroar @STWuk It's the same approach as CND - unilateralism has never worked, is not working now and will… https://t.co/zwu6Zxssh9"]
# ['Jennone Bezgin', datetime.datetime(2019, 3, 30, 21, 37, 54, tzinfo=datetime.timezone.utc), [[-115.384091, 36.129459], [-115.384091, 36.336371], [-115.062159, 36.336371], [-115.062159, 36.129459]], 'North Las Vegas, Nevada', 'en', "Naw; you don't want to see that, just knowing that it shall take place should safice !."]
# ['Cherie Dillon (Mrs V Putin) - honeymoon pending', datetime.datetime(2014, 9, 29, 17, 56, 32, tzinfo=datetime.timezone.utc), [[153.186552, -28.200317], [153.186552, -27.708126], [153.552171, -27.708126], [153.552171, -28.200317]], 'Gold Coast, QLD. Australia', 'en', 'Putin ally held in Ukraine suggests prisoner swap for Mariupol force.  Fake prisoner.  He probably has other pawns.… https://t.co/gXxrIqkMGN']
# ['Older_GF', datetime.datetime(2018, 10, 11, 15, 48, 56, tzinfo=datetime.timezone.utc), [[12.234427, 41.655874], [12.234427, 42.140959], [12.855864, 42.140959], [12.855864, 41.655874]], 'Rome, Italy', 'en', 'Strengthening of the offensive group is happening due to the transfer of additional Russian units. The most intense… https://t.co/dD1y52vmw4']
# ['Thomas', datetime.datetime(2022, 4, 15, 6, 59, 37, tzinfo=datetime.timezone.utc), [[-0.684687, 51.383072], [-0.684687, 51.410898], [-0.614535, 51.410898], [-0.614535, 51.383072]], None, 'en', 'Everytime #hotspot goes off #putin #kgb Russians will get marked up!!#MAFIA']
# ['trevor tuffin', datetime.datetime(2012, 8, 1, 1, 19, 45, tzinfo=datetime.timezone.utc), [[-1.706057, 53.736369], [-1.706057, 53.867543], [-1.424923, 53.867543], [-1.424923, 53.736369]], None, 'en', 'WHO DOES THIS GUY FOR THE U.N. HUMANTARIAN QUEST THINK HE IS DEALING WITH PUTIN IS A ARSEHOLE A COLD BLOODED KILLER… https://t.co/uvTTyWIyXB']
# ['Sandy🌊vote blue 💙', datetime.datetime(2015, 11, 30, 17, 15, 7, tzinfo=datetime.timezone.utc), [[-90.135782, 34.994192], [-90.135782, 35.272849], [-89.708276, 35.272849], [-89.708276, 34.994192]], None, 'en', 'Stop putin @NATO stop putin now @NATOinUkraine please someone anyone stop putin now @POTUS @ZelenskyyUa @VP… https://t.co/elgbtTt7U6']
# ['LibertyBea', datetime.datetime(2015, 7, 7, 10, 45, 21, tzinfo=datetime.timezone.utc), [[12.618004, 41.408414], [12.618004, 41.539743], [12.777768, 41.539743], [12.777768, 41.408414]], 'Nettuno, Lazio', 'en', '@OryjieSPb @lifenews_ru Another best video on Twitter✌️🤩✌️ Obama terrorized near Putin😱😱😱😂😂😂😂😱😱😱😱 And in Friendship… https://t.co/JOpK6Es18s']
# ['Carlos', datetime.datetime(2010, 3, 18, 2, 20, 19, tzinfo=datetime.timezone.utc), [[-67.106172, 18.070822], [-67.106172, 18.089251], [-67.081202, 18.089251], [-67.081202, 18.070822]], 'Puerto Rico, USA', 'en', '@KyivIndependent Putin tea?']
# ['Linda Marie Garcia', datetime.datetime(2022, 2, 12, 14, 30, 50, tzinfo=datetime.timezone.utc), [[-104.69356, 38.200638], [-104.69356, 38.338462], [-104.551992, 38.338462], [-104.551992, 38.200638]], None, 'en', '@business Anything that Putin says cannot be deemed as creditable. He plays war games with the lives of people for… https://t.co/3SpBcXW4LM']
# ['Marilyn 🌊 🌊 🌊#ResistersUnitedVote2022 🇨🇦', datetime.datetime(2009, 4, 27, 22, 17, 26, tzinfo=datetime.timezone.utc), [[-108.350898, 52.709485], [-108.350898, 52.766867], [-108.273759, 52.766867], [-108.273759, 52.709485]], 'Canada', 'en', 'Putin honors brigade accused of mass killings and other atrocities in Bucha https://t.co/BrkZFiDykC']
# ['Susie Mossman', datetime.datetime(2016, 11, 23, 19, 58, 49, tzinfo=datetime.timezone.utc), [[-109.050173, 31.332176], [-109.050173, 37.000294], [-103.002065, 37.000294], [-103.002065, 31.332176]], None, 'en', '@GOP I think GOP should think twice about being Putin’s propaganda voice.']
# ['Susie Mossman', datetime.datetime(2016, 11, 23, 19, 58, 49, tzinfo=datetime.timezone.utc), [[-109.050173, 31.332176], [-109.050173, 37.000294], [-103.002065, 37.000294], [-103.002065, 31.332176]], None, 'en', '@GOP Biden economy going great! GOP embarrassed by Jan 6 effort to overthrow democracy, now speaks for Putin on FOX.']
# ['Анжелика Карпухина', datetime.datetime(2022, 3, 4, 13, 54, 39, tzinfo=datetime.timezone.utc), [[22.13572, 44.386383], [22.13572, 52.379475], [40.227172, 52.379475], [40.227172, 44.386383]], None, 'en', '@Pontifex Save the people of Mariupol with your helicopter! Putin will not dare to shoot at your helicopter, he wil… https://t.co/BoUdibiTQi']
# ['say no to fascism', datetime.datetime(2011, 4, 1, 4, 43, 29, tzinfo=datetime.timezone.utc), [[-115.384091, 36.129459], [-115.384091, 36.336371], [-115.062159, 36.336371], [-115.062159, 36.129459]], None, 'en', '@StephenKing The odifference between Trump &amp; Putin is when someone in the media offends Putin something bad usually… https://t.co/Bhd6dF1zLd']
# ['Анжелика Карпухина', datetime.datetime(2022, 3, 4, 13, 54, 39, tzinfo=datetime.timezone.utc), [[22.13572, 44.386383], [22.13572, 52.379475], [40.227172, 52.379475], [40.227172, 44.386383]], None, 'en', '@Pontifex @Pontifex Save the people of Mariupol 💔 with your helicopter!🙏 Putin will not dare to shoot at your helic… https://t.co/3oAEjG3BfO']
# ['James Jay Carafano', datetime.datetime(2008, 8, 30, 1, 38, 35, tzinfo=datetime.timezone.utc), [[-77.119401, 38.801826], [-77.119401, 38.99538], [-76.909396, 38.99538], [-76.909396, 38.801826]], 'Washington, DC', 'en', 'Putin just bombed Jose Andres food kitchen Ukraine. For real.']
# ['Aron Goldman', datetime.datetime(2008, 3, 20, 19, 29, 6, tzinfo=datetime.timezone.utc), [[-80.139419, 25.880816], [-80.139419, 25.894483], [-80.128202, 25.894483], [-80.128202, 25.880816]], 'Miami Beach, Florida', 'en', '@RepKinzinger “Some are using their platforms to provoke…outrage on Disney…stoking…cultural anger &amp; division for th… https://t.co/tTbexJZD8J']
# ["Schrödinger's Zen...(or Roger)", datetime.datetime(2011, 8, 27, 4, 55, 11, tzinfo=datetime.timezone.utc), [[-105.148074, 40.47168], [-105.148074, 40.656701], [-104.979811, 40.656701], [-104.979811, 40.47168]], 'Fort Collins, Colorado', 'en', "@KyivIndependent @DaGodfather59 Terminal case of Putin's ego..."]
# ['Анжелика Карпухина', datetime.datetime(2022, 3, 4, 13, 54, 39, tzinfo=datetime.timezone.utc), [[22.13572, 44.386383], [22.13572, 52.379475], [40.227172, 52.379475], [40.227172, 44.386383]], None, 'en', '@EmmanuelMacron @EmmanuelMacron Save the people of Mariupol with your helicopter! Putin will not dare to shoot at y… https://t.co/zY3csyQPW0']
# ['Susie Mossman', datetime.datetime(2016, 11, 23, 19, 58, 49, tzinfo=datetime.timezone.utc), [[-109.050173, 31.332176], [-109.050173, 37.000294], [-103.002065, 37.000294], [-103.002065, 31.332176]], None, 'en', '@GOP Biden’s numbers rising due to approved  handling of Putin’s efforts to overtake uktraine.']
# ['Анжелика Карпухина', datetime.datetime(2022, 3, 4, 13, 54, 39, tzinfo=datetime.timezone.utc), [[22.13572, 44.386383], [22.13572, 52.379475], [40.227172, 52.379475], [40.227172, 44.386383]], None, 'en', '@EmmanuelMacron @EmmanuelMacron Save the people of Mariupol with your helicopter! Putin will not dare to shoot at y… https://t.co/2pxSZNblG4']
# ['Jonathan Parker', datetime.datetime(2021, 9, 19, 12, 24, 32, tzinfo=datetime.timezone.utc), [[-86.348441, 39.631677], [-86.348441, 39.927448], [-85.937404, 39.927448], [-85.937404, 39.631677]], None, 'en', "@StevePesce12 @CheriJacobus It's bull crap. All of the Republicans had improper campaign interaction with the Russi… https://t.co/wfdnrprlBj"]
# ['Retired OLB', datetime.datetime(2021, 8, 28, 16, 54, 33, tzinfo=datetime.timezone.utc), [[-119.953849, 39.350749], [-119.953849, 39.674123], [-119.700515, 39.674123], [-119.700515, 39.350749]], None, 'en', "Can you immagine hooking your wagon to the putin horse I can't but guess who did lukashenko this has to be the dumb… https://t.co/O1rNaxzY8g"]
# ['izuchukwu ezenwanagu', datetime.datetime(2020, 7, 12, 20, 28, 17, tzinfo=datetime.timezone.utc), [[8.970557, 7.29695], [8.970557, 7.360567], [9.028567, 7.360567], [9.028567, 7.29695]], None, 'en', 'May God help us😢🙏\n#OrluIsBleeding \n#Putin \n#UN #UK #AU https://t.co/PzH2TbCOHA']
# ["Jamie O'Brien", datetime.datetime(2013, 4, 17, 19, 2, 31, tzinfo=datetime.timezone.utc), [[-74.026675, 40.683935], [-74.026675, 40.877483], [-73.910408, 40.877483], [-73.910408, 40.683935]], 'New York, NY', 'en', "@BetoORourke @POTUS @VP @WHCOS @samstein @JonLemire @ProjectLincoln @TheRickWilson Question: If it isn't ok for Put… https://t.co/TMtnexpPHr"]
# ['Benedetto Altieri', datetime.datetime(2012, 2, 11, 16, 48, 22, tzinfo=datetime.timezone.utc), [[8.802574, 40.525786], [8.802574, 41.31321], [9.778981, 41.31321], [9.778981, 40.525786]], 'Milano', 'en', '@TheEconomist Yes they will.\nWe should stop Putin, before it will be too late.']
# ['Randall Cobb', datetime.datetime(2019, 8, 4, 5, 45, 42, tzinfo=datetime.timezone.utc), [[-86.709501, 33.6188], [-86.709501, 33.676838], [-86.629573, 33.676838], [-86.629573, 33.6188]], 'Center Point. , AL', 'en', '@nypost If Putin gets a. Kick out of killing\nInnocent people. What will he do \nNext . Think. Hard. People.']
# ['Robert Paul aka Mr. Discovery', datetime.datetime(2017, 7, 1, 2, 31, 18, tzinfo=datetime.timezone.utc), [[-79.088521, 43.573543], [-79.088521, 43.92266], [-78.807896, 43.92266], [-78.807896, 43.573543]], 'Toronto, Ontario', 'en', '@VulgarScott @TxPatriot4Life @canalzone68 At 8 billion on the planet,  when is enough enough...Mother Nature takes… https://t.co/yBGbS1Wu13']
# ['Cherie Dillon (Mrs V Putin) - honeymoon pending', datetime.datetime(2014, 9, 29, 17, 56, 32, tzinfo=datetime.timezone.utc), [[153.186552, -28.200317], [153.186552, -27.708126], [153.552171, -27.708126], [153.552171, -28.200317]], 'Gold Coast, QLD. Australia', 'en', 'There is nothing to forgive.  I am Team Russia and President Putin is sexy glamorous and he is going to smash all n… https://t.co/pKlTfcQpZg']
# ['trevor tuffin', datetime.datetime(2012, 8, 1, 1, 19, 45, tzinfo=datetime.timezone.utc), [[-1.706057, 53.736369], [-1.706057, 53.867543], [-1.424923, 53.867543], [-1.424923, 53.736369]], None, 'en', 'THE WEST INCLUDING EUROPE ARE THICK STUPID AND OBTUSE DO THEY HONESTLY THINK THAT PUTIN IS GOING TO STOP AT UKRAINE… https://t.co/7k9A0xTdQ5']
# ['Paul Zak', datetime.datetime(2009, 6, 20, 21, 15, 33, tzinfo=datetime.timezone.utc), [[-120.981748, 37.707792], [-120.981748, 37.768288], [-120.882789, 37.768288], [-120.882789, 37.707792]], 'California, USA', 'en', 'Could not agree more. Biden is a good guy doing a good job.']
# ['Christian Kuhtz 🌻', datetime.datetime(2010, 10, 21, 20, 16, 23, tzinfo=datetime.timezone.utc), [[-121.999644, 47.601086], [-121.999644, 47.648513], [-121.938598, 47.648513], [-121.938598, 47.601086]], 'Redmondia in Pacific Northwest', 'en', '@andersostlund @brooklynmarie They’re all members of the SPD. Not that other parties are without fault but there’s… https://t.co/w57loRE9lR']
# ['Sarah Ashton-Cirillo', datetime.datetime(2015, 12, 8, 8, 34, 24, tzinfo=datetime.timezone.utc), [[22.13572, 44.386383], [22.13572, 52.379475], [40.227172, 52.379475], [40.227172, 44.386383]], 'Kharkiv', 'en', 'More Putin pouting: https://t.co/0NptVRQ5gs']
# ['Augustanus 🕊️ 🇺🇲🇺🇦 🏳️\u200d🌈❤️🐈 🐕🦆🌲⚛️☯️🕉️', datetime.datetime(2022, 1, 5, 22, 42, 27, tzinfo=datetime.timezone.utc), [[-122.253717, 47.423263], [-122.253717, 47.539933], [-122.135079, 47.539933], [-122.135079, 47.423263]], 'Seattle WA area', 'en', 'Putin: tough man!\n#PutinWarCriminal \n#PutinWarCrimes \n#Putin https://t.co/ZZdhFXOEA5']
# ['christophe fournier', datetime.datetime(2012, 6, 12, 7, 41, 40, tzinfo=datetime.timezone.utc), [[6.945492, 46.166696], [6.945492, 46.225303], [7.034593, 46.225303], [7.034593, 46.166696]], None, 'en', '#TikTok https://t.co/sO8563isU1.    After the invasion of Poland and Slovak Czechoslovakia, Adolf Hitler continued… https://t.co/2Msldk9HVS']
# ['Inna Yehorova', datetime.datetime(2021, 1, 8, 19, 30, 11, tzinfo=datetime.timezone.utc), [[22.13572, 44.386383], [22.13572, 52.379475], [40.227172, 52.379475], [40.227172, 44.386383]], None, 'en', 'Uncovered evidence of crimes against humanity...\n#StopRussia #StandWithUkraine️']
# ['Pradheep J. Shanker', datetime.datetime(2009, 2, 12, 23, 4, 34, tzinfo=datetime.timezone.utc), [[-83.18921, 40.067746], [-83.18921, 40.182801], [-83.089352, 40.182801], [-83.089352, 40.067746]], 'United States', 'en', "Not just Ukraine.\n\nNATO has a new mission, one it hasn't had since George H.W. Bush."]
# ['Just A Goose 12', datetime.datetime(2021, 10, 6, 21, 39, 56, tzinfo=datetime.timezone.utc), [[-0.644511, 51.494664], [-0.644511, 51.500866], [-0.628219, 51.500866], [-0.628219, 51.494664]], None, 'en', "What a great day. I've just been called a 'Putin Apologist' in the pub by some old duffer because I told him to thi… https://t.co/ROkCTGBFFK"]
# ['Doug Dolde', datetime.datetime(2022, 3, 1, 15, 53, 18, tzinfo=datetime.timezone.utc), [[-116.480488, 34.076028], [-116.480488, 34.165915], [-116.364729, 34.165915], [-116.364729, 34.076028]], 'Yucca Valley, CA', 'en', '@KyivIndependent The real accomplishment will be to destroy Putin']
# ['Sandy Hendry', datetime.datetime(2014, 3, 5, 7, 41, 6, tzinfo=datetime.timezone.utc), [[-0.254269, 51.379947], [-0.254269, 51.441804], [-0.124309, 51.441804], [-0.124309, 51.379947]], 'London', 'en', '@Marl6M @ex0du5_5utu7e @PelmeniPusha Ros Atkins dismantles that Russian propaganda with facts.\n\nhttps://t.co/uVkO7uSLxC']
# ['Arthur O Hara', datetime.datetime(2009, 4, 28, 12, 29, 7, tzinfo=datetime.timezone.utc), [[-10.619545, 51.419215], [-10.619545, 55.382852], [-5.995732, 55.382852], [-5.995732, 51.419215]], 'Ireland', 'en', 'Danish Documentary. \n#VladimirPutin #Z &amp; the #Mafia:-\n\nhttps://t.co/SqZxI9bWeF']
# ['Just A Goose 12', datetime.datetime(2021, 10, 6, 21, 39, 56, tzinfo=datetime.timezone.utc), [[-0.644511, 51.494664], [-0.644511, 51.500866], [-0.628219, 51.500866], [-0.628219, 51.494664]], None, 'en', "What a great day. I've just been called a 'Putin Apologist' in the pub by some old duffer because I told him to thi… https://t.co/ktLeYhv5N8"]
# ['Rasta Chap', datetime.datetime(2018, 1, 26, 19, 15, 38, tzinfo=datetime.timezone.utc), [[-4.235979, 51.001527], [-4.235979, 51.029653], [-4.202107, 51.029653], [-4.202107, 51.001527]], 'UK', 'en', "@bubbalouis78 Wor took him so fucking long?\nAn why ain't  he done shit ?\nPutin, Johnson"]
# ['Susie Mossman', datetime.datetime(2016, 11, 23, 19, 58, 49, tzinfo=datetime.timezone.utc), [[-109.050173, 31.332176], [-109.050173, 37.000294], [-103.002065, 37.000294], [-103.002065, 31.332176]], None, 'en', '@GOP Is it possible that Fox News does not want it known that Putin installed Trump in the presidency?']
# ['Truth | Freedom', datetime.datetime(2021, 12, 27, 0, 50, 41, tzinfo=datetime.timezone.utc), [[-79.639319, 43.403221], [-79.639319, 43.855401], [-78.90582, 43.855401], [-78.90582, 43.403221]], 'Tkaronto / Toronto, Canada ', 'en', ".@AyOdeh @AOC @wolfblitzer I've thought similarly re @netanyahu! He's not so different from Putin, Trump,… https://t.co/8IyX0nOpzd"]
# ['Travis | El Quisling 🇪🇸🇯🇲', datetime.datetime(2019, 1, 31, 17, 32, 24, tzinfo=datetime.timezone.utc), [[-0.432545, 39.278381], [-0.432545, 39.566588], [-0.272513, 39.566588], [-0.272513, 39.278381]], 'Valencia, Spain', 'en', 'FBPE cranks are STILL trying to use dead Ukrainian bodies to scavenge back their middle-class European hall pass\n\nA… https://t.co/vNaH5voHjf']
# ['Vika_Mashinson', datetime.datetime(2021, 10, 26, 17, 48, 2, tzinfo=datetime.timezone.utc), [[-96.234587, 41.175884], [-96.234587, 41.375558], [-95.872275, 41.375558], [-95.872275, 41.175884]], None, 'en', '#Ukrainian Marine commander sends open letter to Pope Francis: Mariupol is "hell on Earth" https://t.co/3v6otjSkWq… https://t.co/pZtutMXYpu']
# ['Anna Maksymova', datetime.datetime(2012, 3, 2, 10, 8, 51, tzinfo=datetime.timezone.utc), [[2.224101, 48.815521], [2.224101, 48.902146], [2.469905, 48.902146], [2.469905, 48.815521]], 'Paris, France', 'en', 'Each day I am telling myself that it could not get worse, each day 🇷🇺 proves that there are no limits to their sava… https://t.co/12ydigoGmB']
# ['remus bowman', datetime.datetime(2013, 1, 15, 23, 17, 47, tzinfo=datetime.timezone.utc), [[-90.137908, 29.889574], [-90.137908, 30.075628], [-89.884108, 30.075628], [-89.884108, 29.889574]], 'New Orleans, LA', 'en', 'the republicans have changed they was always pro American 🇺🇸 and pro democracy now they have become something diffe… https://t.co/zHLX0bJ8OB']
# ['Анжелика Карпухина', datetime.datetime(2022, 3, 4, 13, 54, 39, tzinfo=datetime.timezone.utc), [[22.13572, 44.386383], [22.13572, 52.379475], [40.227172, 52.379475], [40.227172, 44.386383]], None, 'en', '@priyankachopra Save the people of Mariupol with your helicopter! Putin will not dare to shoot at your helicopter,… https://t.co/FqCpHkCWD0']
# ['Robert Neal', datetime.datetime(2011, 12, 10, 16, 52, 56, tzinfo=datetime.timezone.utc), [[6.478003, 51.285112], [6.478003, 51.405505], [6.706183, 51.405505], [6.706183, 51.285112]], 'Germany', 'en', '@DomVbfktm @Kifaranga16 @Boba12340769066 @visegrad24 Apparently you’re Russian. A serf of Putin who lets himself be… https://t.co/Y73KIgSg3d']
# ['Truth | Freedom', datetime.datetime(2021, 12, 27, 0, 50, 41, tzinfo=datetime.timezone.utc), [[-79.639319, 43.403221], [-79.639319, 43.855401], [-78.90582, 43.855401], [-78.90582, 43.403221]], 'Tkaronto / Toronto, Canada ', 'en', '[Putin, Trump, @netanyahu, @stephenharper] use the same playbook. @YuliEdelstein @IsraelinToronto @davidfrum… https://t.co/Ux8FfoCtl3']
# ['AUTOCRATIC _ BREAKDOWN', datetime.datetime(2011, 12, 8, 18, 43, 56, tzinfo=datetime.timezone.utc), [[3.575364, 51.467949], [3.575364, 51.535224], [3.746955, 51.535224], [3.746955, 51.467949]], '* Middelburg-Zld Netherlands', 'en', '@Independent (ICC) ON HIGH ALERT\n\nINTERNATIONAL CRIMINAL COURT\n\nUN CONVENTION ON GENOCIDE ?\n\nPAST 1.5 DECADE _THESE… https://t.co/4TIy8DYQk5']
# ['AUTOCRATIC _ BREAKDOWN', datetime.datetime(2011, 12, 8, 18, 43, 56, tzinfo=datetime.timezone.utc), [[3.575364, 51.467949], [3.575364, 51.535224], [3.746955, 51.535224], [3.746955, 51.467949]], '* Middelburg-Zld Netherlands', 'en', '@Independent (ICC) ON HIGH ALERT\n\nINTERNATIONAL CRIMINAL COURT\n\nUN CONVENTION ON GENOCIDE ?\n\nPAST 1.5 DECADE _THESE… https://t.co/IRdyjRJNj4']
# ['Irish Emergency Logistics Team 🇮🇪', datetime.datetime(2014, 8, 1, 2, 44, 52, tzinfo=datetime.timezone.utc), [[35.586899, 32.309434], [35.586899, 37.31861], [42.375382, 37.31861], [42.375382, 32.309434]], 'Ireland', 'en', "@rimaanabtawi @Baddiel I need to up my 'harrassing Putin' game.\n\nWhich I'm going to struggle to do considering what… https://t.co/52VpzCPcsv"]
# ['JohnCB500', datetime.datetime(2013, 12, 1, 16, 53, 10, tzinfo=datetime.timezone.utc), [[-2.754906, 52.032905], [-2.754906, 52.082833], [-2.671399, 52.082833], [-2.671399, 52.032905]], None, 'en', 'Sorry guys, \n\nTo much at stake']
# ['Sunil KASHYAP', datetime.datetime(2019, 4, 5, 6, 5, 41, tzinfo=datetime.timezone.utc), [[73.675735, 14.752028], [73.675735, 15.799589], [74.335602, 15.799589], [74.335602, 14.752028]], 'BANDRA', 'en', "The WAR didn't go as VLADIMIR Putin planned but it's NOT getting OVER EITHER !\nhttps://t.co/OSK2sXmS8r"]
# ['Josh DO 🇺🇦', datetime.datetime(2011, 4, 17, 20, 50, 49, tzinfo=datetime.timezone.utc), [[-90.135782, 34.994192], [-90.135782, 35.272849], [-89.708276, 35.272849], [-89.708276, 34.994192]], 'Memphis, TN', 'en', "@btharris93 My guess with Hitchens is that he's on the track of Putin being the savior of Western Christendom from the cultural left"]
# ['Patrick M Andendall', datetime.datetime(2012, 9, 1, 15, 6, 27, tzinfo=datetime.timezone.utc), [[-73.713112, 40.805231], [-73.713112, 40.853977], [-73.651629, 40.853977], [-73.651629, 40.805231]], 'New York', 'en', '@DaveKrikorian @ElijahWere247 @EddyPiedra @KatjeriKathy @garyblack00 @elonmusk A Putin loving moron tweets.']
# ['Eli Stokols', datetime.datetime(2009, 9, 21, 2, 38, 16, tzinfo=datetime.timezone.utc), [[-77.119401, 38.801826], [-77.119401, 38.99538], [-76.909396, 38.99538], [-76.909396, 38.801826]], 'Washington, DC', 'en', 'One of the senators who is closest to Biden — questioning POTUS’ red line on Ukraine:']
# ['Alexia Pirpiris', datetime.datetime(2021, 6, 5, 3, 53, 12, tzinfo=datetime.timezone.utc), [[144.593742, -38.433859], [144.593742, -37.511274], [145.512529, -37.511274], [145.512529, -38.433859]], 'Melbourne, Victoria', 'en', 'Elon Musk Made A PEACE DEAL With Russia And Vladimir Putin https://t.co/aE0RcHuVjk via @YouTube❤️❤️❤️']
# ['Andrew Chakhoyan 🇺🇦', datetime.datetime(2015, 10, 18, 18, 10, 23, tzinfo=datetime.timezone.utc), [[4.7289, 52.278227], [4.7289, 52.431229], [5.079207, 52.431229], [5.079207, 52.278227]], 'Amsterdam, The Netherlands', 'en', '#StandUpForUkraine \nWords won’t stop #WarCrimes \nAppeasement didn’t stop Hitler and it won’t stop #WarCriminalPutin… https://t.co/Kk8PzepJSt']
# ['Анжелика Карпухина', datetime.datetime(2022, 3, 4, 13, 54, 39, tzinfo=datetime.timezone.utc), [[22.13572, 44.386383], [22.13572, 52.379475], [40.227172, 52.379475], [40.227172, 44.386383]], None, 'en', '@xtina Save Mariupol residents with your helicopter! Putin will not dare to shoot at your helicopter, he will not r… https://t.co/0DtaDOinaW']
# ['Jānis Meirāns', datetime.datetime(2011, 10, 6, 8, 39, 48, tzinfo=datetime.timezone.utc), [[23.932583, 56.857067], [23.932583, 57.085918], [24.32473, 57.085918], [24.32473, 56.857067]], 'Riga, Latvia', 'en', '@FlorianPost @MelnykAndrij I guess that is what SPD expects to hear from Putin, one sincere : Spasibo, comrade Shol… https://t.co/z3JzOtfCNz']
# ['Jonathan Parker', datetime.datetime(2021, 9, 19, 12, 24, 32, tzinfo=datetime.timezone.utc), [[-86.348441, 39.631677], [-86.348441, 39.927448], [-85.937404, 39.927448], [-85.937404, 39.631677]], None, 'en', "@StevePesce12 @CheriJacobus Again, it's a report by Republicans. It should not be believed. They are in Putin's poc… https://t.co/UJhXLnD3G6"]
# ['Gerrit H. 🇨🇦', datetime.datetime(2011, 3, 11, 17, 52, 18, tzinfo=datetime.timezone.utc), [[-122.671484, 49.167283], [-122.671484, 49.353125], [-122.406655, 49.353125], [-122.406655, 49.167283]], 'British Columbia, Canada 🇨🇦', 'en', "@AnarrestiAnarch @ve6dpa Real and violent Genocide is today being practiced in Ukraine by Putin's lackies. Concentr… https://t.co/tJL6qu2wts"]
# ['Truth | Freedom', datetime.datetime(2021, 12, 27, 0, 50, 41, tzinfo=datetime.timezone.utc), [[-79.639319, 43.403221], [-79.639319, 43.855401], [-78.90582, 43.855401], [-78.90582, 43.403221]], 'Tkaronto / Toronto, Canada ', 'en', ".@ZelenskyyUa @IsraeliPM @POTUS @Pontifex As strange as this sound, I'll need @stephenharper to anchor me, otherwis… https://t.co/25rtdlL2rr"]
# ['Conroy Delouche', datetime.datetime(2009, 8, 7, 18, 37, 49, tzinfo=datetime.timezone.utc), [[-85.292144, 38.161763], [-85.292144, 38.23781], [-85.142788, 38.23781], [-85.142788, 38.161763]], 'Louisville, KY', 'en', 'McConnell cont’d: attack on Ukraine was unprovoked. “No rational basis for this war other than (Putin’s) desire for… https://t.co/5Qvd0wSs84']
# ['TORATI', datetime.datetime(2020, 4, 23, 17, 11, 48, tzinfo=datetime.timezone.utc), [[39.008111, -7.190649], [39.008111, -6.566974], [39.55667, -6.566974], [39.55667, -7.190649]], 'DaresSalaam| Mbeya | Makambako', 'en', 'Call your Avengers friends Go and save Ukraine 😂😂😂 our hero black panther knew this and left early']
# ['Linda Pearson - STARMER FOR PM. POWER TO THE RNLI.', datetime.datetime(2018, 12, 28, 11, 46, 51, tzinfo=datetime.timezone.utc), [[0.498362, 51.821214], [0.498362, 51.835825], [0.51563, 51.835825], [0.51563, 51.821214]], None, 'en', "@Dunglishman It didn't have to be,  Putin chose it for his people."]
# ['Amber Christiansen', datetime.datetime(2020, 10, 2, 14, 55, 39, tzinfo=datetime.timezone.utc), [[-97.293831, 32.779549], [-97.293831, 32.861171], [-97.236256, 32.861171], [-97.236256, 32.779549]], None, 'en', '@POTUS @VP  And y’all can’t do anymore to help??? This world is a fucked up place and y’all are allowing Putin to c… https://t.co/vnQFmqkdAS']
# ['Myron Wasylyk', datetime.datetime(2019, 12, 11, 6, 25, 54, tzinfo=datetime.timezone.utc), [[18.97503, 47.625215], [18.97503, 47.728328], [19.090942, 47.728328], [19.090942, 47.625215]], 'Kyiv', 'en', 'Sickening!']
# ['Jan  Letchford', datetime.datetime(2009, 1, 30, 14, 16, 5, tzinfo=datetime.timezone.utc), [[2.823289, 43.259835], [2.823289, 43.294734], [2.866051, 43.294734], [2.866051, 43.259835]], None, 'en', "This is Marine Le Pen's way of dealing with a non violent protestor holding up a heart shaped sign with a picture o… https://t.co/WskQ3688SE"]
# ['Shreoshi Bhattacharyya', datetime.datetime(2012, 4, 18, 5, 54, 1, tzinfo=datetime.timezone.utc), [[88.094457, 22.269493], [88.094457, 22.955918], [88.610027, 22.955918], [88.610027, 22.269493]], 'Kolkata', 'en', "Mother fucker make Bush, Cheney, Henry Kissinger, Bill Clinton, Obama, and Biden face justice first\n\nDon't forget N… https://t.co/6GxFZXvDm5"]
# ['suka_tattoo_holodno', datetime.datetime(2021, 12, 2, 18, 42, 55, tzinfo=datetime.timezone.utc), [[22.13572, 44.386383], [22.13572, 52.379475], [40.227172, 52.379475], [40.227172, 44.386383]], 'Украина', 'en', '@CanadaRossot @myth_250580 Instead of shouting about "Russophobia" they would better join in to stop the war, stop… https://t.co/pplMNuftQy']
# ['curious corn, gilded cage', datetime.datetime(2008, 12, 6, 0, 22, 57, tzinfo=datetime.timezone.utc), [[4.7289, 52.278227], [4.7289, 52.431229], [5.079207, 52.431229], [5.079207, 52.278227]], 'Amsterdam', 'en', '@Tannenberg1914 @TheStanislawski No no, let’s be clear: they’re Nazi. Definitely Nazi. Thus we need to support Zele… https://t.co/INBfZKoZvc']
# ['Ben Stults', datetime.datetime(2014, 1, 18, 12, 45, 21, tzinfo=datetime.timezone.utc), [[-84.386548, 30.365093], [-84.386548, 30.587338], [-84.1458, 30.587338], [-84.1458, 30.365093]], 'he/him', 'en', 'the cruelty is the point']
# ['new name profile2', datetime.datetime(2018, 10, 3, 23, 13, 28, tzinfo=datetime.timezone.utc), [[-111.697866, 43.948628], [-111.697866, 43.978799], [-111.665604, 43.978799], [-111.665604, 43.948628]], 'Eugene, OR', 'en', 'Putin throws a kid in a well and we are pissed off the media fires up. We throw a kids head on top of the chopping… https://t.co/objfu5bx6l']
# ['Peter Thomson 🇺🇦🏴\U000e0067\U000e0062\U000e0073\U000e0063\U000e0074\U000e007f', datetime.datetime(2013, 12, 11, 4, 34, 42, tzinfo=datetime.timezone.utc), [[22.13572, 44.386383], [22.13572, 52.379475], [40.227172, 52.379475], [40.227172, 44.386383]], 'Ukraine', 'en', 'Navalny is as much of a russian Chauvinist as putin, matvienko, or any other kremlin lackey']
# ['Pinkelephantauctions', datetime.datetime(2019, 6, 11, 22, 19, 47, tzinfo=datetime.timezone.utc), [[-80.131529, 25.900463], [-80.131529, 25.957656], [-80.118613, 25.957656], [-80.118613, 25.900463]], 'Miami, FL', 'en', 'POTUS needs to shutdown the Internet on Putin NOW &amp; Biden can\n\n#ukraine #potus #Biden #democrat #war #tactics… https://t.co/2vKeEi88sI']
# ['Truth | Freedom', datetime.datetime(2021, 12, 27, 0, 50, 41, tzinfo=datetime.timezone.utc), [[-79.639319, 43.403221], [-79.639319, 43.855401], [-78.90582, 43.855401], [-78.90582, 43.403221]], 'Tkaronto / Toronto, Canada ', 'en', '.@ZelenskyyUa @IsraeliPM @RTErdogan Both @Pontifex &amp; I helped @POTUS deal with #China. Unlike @stephenharper &amp; Chin… https://t.co/t09G6JsnI4']
# ['Hayden A↙️TX', datetime.datetime(2022, 3, 9, 19, 30, 6, tzinfo=datetime.timezone.utc), [[-97.928935, 30.127892], [-97.928935, 30.518799], [-97.580513, 30.518799], [-97.580513, 30.127892]], 'Austin, TX', 'en', "@badlydrawnface @GuntherEagleman If you're referring to Nick Fuentes, yes! He describes himself as a white national… https://t.co/T5RZ88onf8"]
# ['Rob', datetime.datetime(2017, 8, 12, 15, 25, 23, tzinfo=datetime.timezone.utc), [[-87.634643, 24.396308], [-87.634643, 31.001056], [-79.974307, 31.001056], [-79.974307, 24.396308]], 'EC Florida, USA', 'en', 'Me too.']
# ['Bianca Lee', datetime.datetime(2021, 11, 30, 12, 55, 15, tzinfo=datetime.timezone.utc), [[18.318033, -34.35839], [18.318033, -33.884925], [18.66009, -33.884925], [18.66009, -34.35839]], 'Cape Town, South Africa', 'en', 'I support President Putin and anything that goes against the World Economic Forum!']
# ['Dan Miller', datetime.datetime(2008, 9, 19, 19, 30, 51, tzinfo=datetime.timezone.utc), [[-97.928935, 30.127892], [-97.928935, 30.518799], [-97.580513, 30.518799], [-97.580513, 30.127892]], 'Cedar Park, TX', 'en', 'We have lost our collective mind']
# ['Travis | El Quisling 🇪🇸🇯🇲', datetime.datetime(2019, 1, 31, 17, 32, 24, tzinfo=datetime.timezone.utc), [[-0.432545, 39.278381], [-0.432545, 39.566588], [-0.272513, 39.566588], [-0.272513, 39.278381]], 'Valencia, Spain', 'en', '@humphreys_dad @eyejosh @alexhallhall I like how soon as the ukraine was escalated the discourse went from “russia”… https://t.co/ZZKPdLmXaD']
# ['Shreoshi Bhattacharyya', datetime.datetime(2012, 4, 18, 5, 54, 1, tzinfo=datetime.timezone.utc), [[88.094457, 22.269493], [88.094457, 22.955918], [88.610027, 22.955918], [88.610027, 22.269493]], 'Kolkata', 'en', 'Mother fucker make Bush, Cheney, Henry Kissinger, Bill Clinton, Obama, Condoleezza Rice, &amp; Biden face justice first… https://t.co/L22qpQgT6T']
# ['Vlad Gheorghe', datetime.datetime(2019, 3, 11, 5, 21, 14, tzinfo=datetime.timezone.utc), [[4.347341, 50.800721], [4.347341, 50.84062], [4.403387, 50.84062], [4.403387, 50.800721]], 'Bucharest, Romania', 'en', 'Can you imagine those barbaric murderers were awarded honorary titles? Can you imagine the parallel world they live… https://t.co/1MWYDQRP1A']
# ['Jacstraw/NY/NJ/CT✌🎶🌏⚡', datetime.datetime(2016, 2, 26, 12, 57, 32, tzinfo=datetime.timezone.utc), [[-73.502636, 41.055206], [-73.502636, 41.257357], [-73.379243, 41.257357], [-73.379243, 41.055206]], 'Norwalk, CT', 'en', '@DrGJackBrown #Putin master of war\n\nLike The Russia of old\nYou lie and deceive\nA world war can be won\nYou want me t… https://t.co/tYgQ4MmKvm']
# ['PERVOUS BADILISHAMWALIMU', datetime.datetime(2019, 12, 25, 21, 40, 20, tzinfo=datetime.timezone.utc), [[-82.644739, 37.201483], [-82.644739, 40.638802], [-77.71893, 40.638802], [-77.71893, 37.201483]], None, 'en', 'PRESIDENT/-V. ZELENSKI--YOUR PEOPLE HAVE SUFFERED TOO MUCH TO ALLOW "DICTATOR PUTIN"-TO HAVE ANY LAND CLAIM "UKRAIN… https://t.co/NHPs2zVuMQ']
# ...
# ['Andreia Rodrigues Garcia', datetime.datetime(2021, 3, 19, 11, 49, 10, tzinfo=datetime.timezone.utc), [[-46.842073, -23.369262], [-46.842073, -23.257252], [-46.635847, -23.257252], [-46.635847, -23.369262]], None, 'en', 'The Asia  works have Was.....@']
# ['Kiron Reid', datetime.datetime(2012, 10, 16, 10, 5, 20, tzinfo=datetime.timezone.utc), [[-3.008791, 53.36489], [-3.008791, 53.474867], [-2.822063, 53.474867], [-2.822063, 53.36489]], 'Bujanovac, Serbia /Liverpool', 'en', '@DaisyEFish @chucktheyak @delhi_dave Mary is right 1. No. 2. Yes. 3, Like 2 - Ukraine elected a pro Russian pro pea… https://t.co/xD23pSDZAB']
# ['Jonas Parello-Plesner', datetime.datetime(2012, 10, 26, 7, 32, 10, tzinfo=datetime.timezone.utc), [[12.498566, 55.721499], [12.498566, 55.780335], [12.602507, 55.780335], [12.602507, 55.721499]], 'Copenhagen, Denmark', 'en', '👇important thread. Just read it now.']
# ['Cecilie Holter', datetime.datetime(2014, 1, 19, 11, 52, 25, tzinfo=datetime.timezone.utc), [[-0.21607, 51.509879], [-0.21607, 51.539792], [-0.13016, 51.539792], [-0.13016, 51.509879]], 'Planet Earth', 'en', 'It’s vile, tragic, senseless and infuriating.']
# ['Daniel Kurland', datetime.datetime(2012, 12, 31, 21, 10, 53, tzinfo=datetime.timezone.utc), [[-77.174052, 38.806003], [-77.174052, 38.842565], [-77.134838, 38.842565], [-77.134838, 38.806003]], None, 'en', '@BaddCompani Suicided, Putin style.']
# ['Melissa', datetime.datetime(2021, 11, 17, 13, 48, 25, tzinfo=datetime.timezone.utc), [[-86.869446, 35.939893], [-86.869446, 36.05065], [-86.686525, 36.05065], [-86.686525, 35.939893]], 'Nashville, TN', 'en', '@SenCoonsOffice so for 60 days we keep watching🧐']
# ['Chalky', datetime.datetime(2012, 1, 10, 2, 58, 25, tzinfo=datetime.timezone.utc), [[-82.562995, 27.465078], [-82.562995, 27.488095], [-82.529205, 27.488095], [-82.529205, 27.465078]], 'bradenton fl', 'en', '@olex_scherba I hope Putin dies soon.\nFight to the End \nGive them nothing.\n#SlavaUkraine']
# ['🇺🇦🇵🇸𝙚𝙭𝙞𝙩 𝙨𝙩𝙖𝙜𝙚 𝙡𝙚𝙛𝙩𝙞𝙨𝙩 𓅰𓁿', datetime.datetime(2020, 1, 8, 1, 49, 29, tzinfo=datetime.timezone.utc), [[-2.659936, 51.399367], [-2.659936, 51.516387], [-2.510844, 51.516387], [-2.510844, 51.399367]], 'Bristol, England', 'en', 'The second major phase of Putin’s war, the battle for Eastern Ukraine has just started, with artillery shelling rep… https://t.co/V3LNF5rSrL']
# ['Gay Frog', datetime.datetime(2022, 2, 12, 13, 59, 25, tzinfo=datetime.timezone.utc), [[-121.576613, 38.43792], [-121.576613, 38.685524], [-121.362715, 38.685524], [-121.362715, 38.43792]], None, 'en', '@Hari2Seldon @RT_com If you really want to be gas lit look at the slow encirclement of Ukrainian forces in the sout… https://t.co/H5jiqLHPeb']
# ['Mike X', datetime.datetime(2021, 5, 25, 8, 32, 41, tzinfo=datetime.timezone.utc), [[-81.507905, 28.388218], [-81.507905, 28.615139], [-81.22764, 28.615139], [-81.22764, 28.388218]], None, 'en', '@mousephantbooks @FiteVern trump sold out America claiming it was just business. putin put him up to it with rules… https://t.co/18AofkCtcX']
# ['damiano’s wife', datetime.datetime(2021, 9, 11, 17, 39, 43, tzinfo=datetime.timezone.utc), [[22.13572, 44.386383], [22.13572, 52.379475], [40.227172, 52.379475], [40.227172, 44.386383]], None, 'en', 'FUCK PUTIN!! I’M PROUD TO BE UKRAINIAN!!🇺🇦\n@thisismaneskin thanks for your support💙💛\n@daviddamiano99 https://t.co/SvCYrk9tjQ']
# ['🇺🇦🇵🇸𝙚𝙭𝙞𝙩 𝙨𝙩𝙖𝙜𝙚 𝙡𝙚𝙛𝙩𝙞𝙨𝙩 𓅰𓁿', datetime.datetime(2020, 1, 8, 1, 49, 29, tzinfo=datetime.timezone.utc), [[-2.659936, 51.399367], [-2.659936, 51.516387], [-2.510844, 51.516387], [-2.510844, 51.399367]], 'Bristol, England', 'en', 'The second major phase of Putin’s war, the battle for Eastern Ukraine, has just started, with artillery shelling re… https://t.co/hP5iGhQbaq']
# ['Jonathan Swift', datetime.datetime(2021, 1, 9, 20, 26, 19, tzinfo=datetime.timezone.utc), [[-4.824808, 55.631237], [-4.824808, 55.659611], [-4.771057, 55.659611], [-4.771057, 55.631237]], 'Scotland, United Kingdom', 'en', "@LinWoodsHorse @Kerr__cow__ You are banned for criticizing Putin's murderous war? What the hell is wrong with Twitter? 😡"]
# ['Corie Dohn', datetime.datetime(2011, 1, 30, 13, 16, 12, tzinfo=datetime.timezone.utc), [[-81.508635, 28.420712], [-81.508635, 28.493573], [-81.474987, 28.493573], [-81.474987, 28.420712]], None, 'en', 'Save Mariupol, send in planes, tanks, ammo, close the skies- save these brace soldiers.  WTF is the problem?  Stop… https://t.co/n0cC6ku0v1']
# ['Susan Kochan', datetime.datetime(2013, 8, 7, 15, 18, 14, tzinfo=datetime.timezone.utc), [[-79.989014, 40.360263], [-79.989014, 40.385779], [-79.96236, 40.385779], [-79.96236, 40.360263]], None, 'en', '@JoaJuan2 @IAPonomarenko Bless all the children. Shame on Putin. May he rot in hell for all eternity.']
# ['HENRY BAKER', datetime.datetime(2021, 12, 18, 4, 3, 20, tzinfo=datetime.timezone.utc), [[-84.045724, 33.624919], [-84.045724, 33.702968], [-83.927994, 33.702968], [-83.927994, 33.624919]], None, 'en', '@GlammaHunny @OccupyDemocrats Partially agreed, send to the friend that he admires so much or drop him into Ukraine… https://t.co/WyKrXpknXc']
# ['Marcus Romer', datetime.datetime(2008, 6, 1, 19, 41, 23, tzinfo=datetime.timezone.utc), [[-0.46006, 54.24378], [-0.46006, 54.306477], [-0.372699, 54.306477], [-0.372699, 54.24378]], 'Scarborough', 'en', 'Hey Bot machine / your spell check and Grammar rules have not been  updated.']
# ['Robert Neal', datetime.datetime(2011, 12, 10, 16, 52, 56, tzinfo=datetime.timezone.utc), [[6.478003, 51.285112], [6.478003, 51.405505], [6.706183, 51.405505], [6.706183, 51.285112]], 'Germany', 'en', "@freeWorld2 @msirish0077yah1 @weejockmaley Meet the Russian Siloviki - Putin's inner circle https://t.co/bXVRsOJSDi via @YouTube"]
# ['sandra myers', datetime.datetime(2011, 9, 13, 1, 11, 59, tzinfo=datetime.timezone.utc), [[-87.634643, 24.396308], [-87.634643, 31.001056], [-79.974307, 31.001056], [-79.974307, 24.396308]], 'jacksonville fl', 'en', 'A dictatorship is going on  just like in Ukraine we need help this is a.SOS for the people of Florida with Trump Ro… https://t.co/3Nlv4Xotps']
# ['EBM', datetime.datetime(2014, 8, 30, 13, 18, 14, tzinfo=datetime.timezone.utc), [[-72.754915, 40.814013], [-72.754915, 40.844882], [-72.70876, 40.844882], [-72.70876, 40.814013]], 'Eastern Long Island New York', 'en', '@turkeytwisterrr @OccupyDemocrats You have to understand that Putin, Will not stop at Ukraine...']
# ['Namrata singh ✈️ Lisbon', datetime.datetime(2008, 5, 7, 22, 42, 45, tzinfo=datetime.timezone.utc), [[-82.244556, 27.829894], [-82.244556, 27.887894], [-82.171581, 27.887894], [-82.171581, 27.829894]], '27.811873,-82.315487', 'en', 'Ukraine doing god’s work for the world. World must step up. And Russia is losing everyday']
# ['christophe fournier', datetime.datetime(2012, 6, 12, 7, 41, 40, tzinfo=datetime.timezone.utc), [[6.945492, 46.166696], [6.945492, 46.225303], [7.034593, 46.225303], [7.034593, 46.166696]], None, 'en', '#TikTok https://t.co/kghUe4CqMX.     After the invasion of Poland and Slovak Czechoslovakia, Adolf Hitler continued… https://t.co/8L4738HHWh']
# ['christophe fournier', datetime.datetime(2012, 6, 12, 7, 41, 40, tzinfo=datetime.timezone.utc), [[6.945492, 46.166696], [6.945492, 46.225303], [7.034593, 46.225303], [7.034593, 46.166696]], None, 'en', '#TikTok https://t.co/nw1y9lLdy8.      After the invasion of Poland and Slovak Czechoslovakia, Adolf Hitler continue… https://t.co/TIWlMcebYN']
# ['Dr. LezAnne Edmond', datetime.datetime(2009, 8, 24, 1, 35, 15, tzinfo=datetime.timezone.utc), [[-74.026675, 40.683935], [-74.026675, 40.877483], [-73.910408, 40.877483], [-73.910408, 40.683935]], None, 'en', '@msnbc @cnn I knw may nt lk this, but much of wht is happ in this cntry politically &amp; w/COVID &amp; in t/world in terms… https://t.co/pSIShPkYYK']
# ['greg montano', datetime.datetime(2014, 3, 19, 13, 45, tzinfo=datetime.timezone.utc), [[-118.170429, 33.90245], [-118.170429, 33.972897], [-118.090423, 33.972897], [-118.090423, 33.90245]], None, 'en', '@RoArquette We need to take out Putin’s kitchen in that palace of his']
# ['Thomas dale Hopewell jr', datetime.datetime(2021, 12, 12, 8, 54, 20, tzinfo=datetime.timezone.utc), [[-84.576827, 33.647503], [-84.576827, 33.886886], [-84.289385, 33.886886], [-84.289385, 33.647503]], None, 'en', '@AC360 and another part of the story is if President Putin took the time and I stayed the time to climb a ballad ha… https://t.co/P2pq1MqDdt']
# ['νιηςεητ ωειδεπαη', datetime.datetime(2010, 8, 6, 18, 7, 35, tzinfo=datetime.timezone.utc), [[6.101208, 52.217635], [6.101208, 52.321166], [6.382117, 52.321166], [6.382117, 52.217635]], 'Deventer', 'en', 'Fuck Putin']
# ['Brian Ford', datetime.datetime(2009, 5, 1, 23, 40, 29, tzinfo=datetime.timezone.utc), [[-111.960775, 33.435864], [-111.960775, 33.842816], [-111.756022, 33.842816], [-111.756022, 33.435864]], 'Scottsdale, AZ', 'en', 'Everyone Hates Biden🤡🤡🤡🤡 #fjb #fraud #pedojoe #LaptopFromHell #HunterBidenLaptop #LetsGoBrandon']
# ['Giovanni Zanutta', datetime.datetime(2011, 4, 24, 18, 15, 49, tzinfo=datetime.timezone.utc), [[27.982994, -26.136266], [27.982994, -25.98115], [28.138232, -25.98115], [28.138232, -26.136266]], 'S.A. ', 'en', 'Reporter asks Putin why his political opponents are ‘dead, in prison, or... https://t.co/cFpBmAnl9t via @YouTube']
# ['@geincolo', datetime.datetime(2010, 11, 28, 7, 32, 47, tzinfo=datetime.timezone.utc), [[-105.147267, 39.894185], [-105.147267, 40.000314], [-104.997195, 40.000314], [-104.997195, 39.894185]], 'Broomfield, Colorado', 'en', 'EU leaders set to take on Hungary’s Viktor Orban, the ‘Trojan horse of the Putin regime’\n\nRussia’s invasion of Ukra… https://t.co/TfxCINzspQ']
# ['𝙱𝚞𝚌𝚔𝚕𝚎𝚄𝚙𝙱𝚞𝚝𝚝𝚎𝚛𝚌𝚞𝚙‼️', datetime.datetime(2008, 8, 7, 22, 27, 1, tzinfo=datetime.timezone.utc), [[-73.998004, 40.80643], [-73.998004, 40.834379], [-73.976837, 40.834379], [-73.976837, 40.80643]], 'NJ/NY USA', 'en', '@mingo_sierra If you’re polling Putin’s family. You believe these polls? Come on']
# ['randomthoughts', datetime.datetime(2020, 8, 24, 23, 33, 14, tzinfo=datetime.timezone.utc), [[-104.69356, 38.200638], [-104.69356, 38.338462], [-104.551992, 38.338462], [-104.551992, 38.200638]], 'Pueblo, CO', 'en', '@joncoopertweets Good question! I think Putin, he is a dictator, very intelligent, a killer of anybody that opposes… https://t.co/Pure5Nz8S9']
# ['Dan Sudarsan', datetime.datetime(2009, 6, 21, 2, 19, 28, tzinfo=datetime.timezone.utc), [[-81.507905, 28.388218], [-81.507905, 28.615139], [-81.22764, 28.615139], [-81.22764, 28.388218]], 'New York', 'en', '@carman_upshaw @NicoleM64390573 @jmvasquez1974 Just being Americans and former military still collecting VA benefit… https://t.co/0bzd2kTDMS']
# ['JOE SAYRE 🐉🦄🌈🌈🌈 Justice Democrat', datetime.datetime(2016, 7, 30, 1, 32, 11, tzinfo=datetime.timezone.utc), [[-97.928935, 30.127892], [-97.928935, 30.518799], [-97.580513, 30.518799], [-97.580513, 30.127892]], 'Austin!', 'en', '@redtailredux I suppose we could, but it is mistaken to believe it would be easy. And yes, Putin would sacrifice hi… https://t.co/0J7cHqYyHf']
# ['Daryl Ball', datetime.datetime(2010, 1, 22, 1, 3, 38, tzinfo=datetime.timezone.utc), [[0.224409, 53.155447], [0.224409, 53.169268], [0.251405, 53.169268], [0.251405, 53.155447]], None, 'en', '@ChunkyChipper @jerseyruss65 @bobruss46 @gletherby @jeremycorbyn Achieved nothing? He said Putin was not to be trus… https://t.co/jq8QEBtLKU']
# ['Trystan 🌻', datetime.datetime(2009, 2, 14, 18, 53, 1, tzinfo=datetime.timezone.utc), [[-77.519387, 38.270129], [-77.519387, 38.326001], [-77.447189, 38.326001], [-77.447189, 38.270129]], 'Fredericksburg, Va', 'en', 'Anyone cross reference the list with GOP congressmen?']
# ['Jimmy', datetime.datetime(2022, 2, 22, 20, 40, 5, tzinfo=datetime.timezone.utc), [[-81.597501, 46.195652], [-81.597501, 46.972711], [-80.557314, 46.972711], [-80.557314, 46.195652]], 'Greater Sudbury / Grand Sudbur', 'en', "@DarthPutinKGB NATO says its okay as long as Putin doesn't use chemical or nuclear weapons. Pathetic!"]
# ['Olemar Ferrer', datetime.datetime(2010, 11, 14, 20, 46, 37, tzinfo=datetime.timezone.utc), [[-46.826039, -24.008814], [-46.826039, -23.356792], [-46.365052, -23.356792], [-46.365052, -24.008814]], 'São Paulo - Brasil', 'en', '@olgatokariuk Ukraine urgently needs fighter planes to fight Russian genocide. Putin must pay dearly for this accou… https://t.co/E6M7JdHyxj']
# ['Juan Diego Lobo', datetime.datetime(2010, 1, 11, 16, 6, 56, tzinfo=datetime.timezone.utc), [[-74.483289, 3.717432], [-74.483289, 4.807135], [-74.004053, 4.807135], [-74.004053, 3.717432]], 'Bogotá D.C.', 'en', 'Dear @OlafScholz, could you olease stop being complicent with modern day russian nazis? What have they got on you t… https://t.co/Ghmq0u7H9J']
# ['Brian Booter Taylor 🇺🇦🇺🇦', datetime.datetime(2011, 8, 6, 9, 42, 14, tzinfo=datetime.timezone.utc), [[-8.194179, 54.022718], [-8.194179, 55.311686], [-5.432841, 55.311686], [-5.432841, 54.022718]], 'Magherafelt, Northern Ireland', 'en', 'Wile Putin 🇷🇺 sits in his gold palace with all the protection in the world ! He sends young men to kill Ukrainian… https://t.co/dXqZQWt4S0']
# ['Shari P Thweatt', datetime.datetime(2017, 1, 25, 4, 21, 23, tzinfo=datetime.timezone.utc), [[-97.044681, 32.985088], [-97.044681, 33.099786], [-96.938975, 33.099786], [-96.938975, 32.985088]], 'Lewisville, TX', 'en', '@LangmanVince Putin']
# ['Ablebodiedseaman', datetime.datetime(2022, 2, 26, 19, 29, 15, tzinfo=datetime.timezone.utc), [[-76.608815, 38.953693], [-76.608815, 39.03047], [-76.502639, 39.03047], [-76.502639, 38.953693]], 'Any Ocean Anytime ', 'en', 'Trump Supporters are \n  Putin Supporters\nFull Stop 🛑']
# ['11,780 Votes 🇺🇦 7 hours 37 Minutes', datetime.datetime(2019, 4, 21, 12, 11, 7, tzinfo=datetime.timezone.utc), [[-80.519851, 39.719801], [-80.519851, 42.516072], [-74.689517, 42.516072], [-74.689517, 39.719801]], 'Bucks County, PA', 'en', 'The Trump  administration:   The cruelty is the point.\nThe Putin    administration:   The cruelty is the point.']
# ['The Fan That Jane Likes (Hayley)', datetime.datetime(2010, 5, 13, 21, 12, 41, tzinfo=datetime.timezone.utc), [[152.668523, -27.767441], [152.668523, -26.996845], [153.31787, -26.996845], [153.31787, -27.767441]], 'SE Queendsland, Australia', 'en', 'What the actual fu*k? @chefjoseandres I hope you are all ok? You’re all doing incredible work 🙏']
# ['Penny Timms', datetime.datetime(2010, 2, 18, 23, 14, 28, tzinfo=datetime.timezone.utc), [[150.520929, -34.118347], [150.520929, -33.578141], [151.343021, -33.578141], [151.343021, -34.118347]], 'Sydney, New South Wales', 'en', 'Ukraine-Russia war live: Volodomyr Zelenskyy says Russian troops have finally begun their offensive to take control… https://t.co/13N8JGrHzt']
# ['𝙱𝚞𝚌𝚔𝚕𝚎𝚄𝚙𝙱𝚞𝚝𝚝𝚎𝚛𝚌𝚞𝚙‼️', datetime.datetime(2008, 8, 7, 22, 27, 1, tzinfo=datetime.timezone.utc), [[-73.998004, 40.80643], [-73.998004, 40.834379], [-73.976837, 40.834379], [-73.976837, 40.80643]], 'NJ/NY USA', 'en', '@ShanRussell72 No. Putin isn’t Russia']
# ['🍁 Ian Irving 🍁', datetime.datetime(2008, 4, 29, 17, 5, 6, tzinfo=datetime.timezone.utc), [[-79.639319, 43.403221], [-79.639319, 43.855401], [-78.90582, 43.855401], [-78.90582, 43.403221]], 'Toronto, Canada', 'en', 'Currently snowing in Toronto.. W T actual F happened to spring!  Is this Putin? https://t.co/nSmPjdgpgD']
# ['Cameron Yow', datetime.datetime(2011, 7, 2, 17, 36, 52, tzinfo=datetime.timezone.utc), [[-80.386249, 25.761172], [-80.386249, 25.783404], [-80.320416, 25.783404], [-80.320416, 25.761172]], 'Doral, FL', 'en', '@MilesTaylorUSA Excellent observation on @DeadlineWH that Putin initiated the authoritarian war on Western democrac… https://t.co/GKkd63OFo3']
# ['George Kahn', datetime.datetime(2022, 2, 26, 16, 6, 8, tzinfo=datetime.timezone.utc), [[-76.448383, 36.66], [-76.448383, 36.866431], [-76.143408, 36.866431], [-76.143408, 36.66]], 'Great Dismal Swamp', 'en', '@RandyRRQuaid @elonmusk I Hate Putin! Now you know where I stand. You can attack me if you want. It feels good to say what on your mind.']

# %% [markdown]
# You can double press `I` to stop the streaming (there is no better way to do it...). Before starting a new streaming, you need to disconnect the streaming.

# %%
streamer.disconnect()
