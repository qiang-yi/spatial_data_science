# %% [markdown]
# ## Spatial Data Science (GIS6307/GEO4930)
#
#
# <br>
# Instructor: Yi Qiang (qiangy@usf.edu)<br>
# Teaching Assistant: Jinwen Xu (jinwenxu@usf.edu)
#
# ---
#
# # Workshop on Spatial Analysis of Twitter (Day 1)
#
# This workshop will help you to get started with the acquisition, processing, and analysis of Twitter data using data science techniques. Specifically, you will learn:
#
# - Streaming real-time tweets using Twitter Developer APIs.
# - Processing the raw tweets into an analyzable form.
# - Basic mapping, spatial analysis and natural language processing for Twitter data.
#
# ### Prerequisite
# - Install Anaconda in your computer.
# - Activation of Twitter Developer Account and approved **Elevated Access** before the workshop.
# - Basic programming skills are recommended, but not required.

# %% [markdown]
# ## 1. Install Python Libraries
#
# We will need two new libraries [tweepy](https://www.tweepy.org/) and [folium](https://plotly.com/python/) for this lab. Please do the following steps to install these two libarries.
#
# 1. Open or create a new conda environment `geo`.
# - For students in courses GIS6307 and GEO4930, please open Anaconda Prompt, and use the command `conda activate geo` to activate the "geo" environment that you created in the previous lab.
#
# - For workshop participatns, please run the following code to create a new conda environment `geo` and then activate it.
#
#     - `conda create --name geo`
#
#     - `conda activate geo`
#
# 2. Install tweepy, folium and Jupyter Lab using the following command (GIS6307/GEO4930 students only need to install tweepy):
#
#     `conda install -c conda-forge tweepy folium jupyterlab matplotlib`
#
#
# 3. Install pandas and nltk using the following command (GIS6307/GEO4930 students only need to install nltk):
#
#     `conda install -c anaconda pandas nltk`
#
#
# 4. Launch Jupyter Notebook using the following command:
#
#     `jupyter notebook`
#
#
# 5. Create a code cell in Jupyter Notebook. Copy and paste the following code in the cell. Run the cell import the installed libraries and other needed libraries. If the code runs through, the libraries are installed successfully.

# %%
# Run the following lines if there is an error loading basemap
# import os
# os.environ['PROJ_LIB'] = '~your anaconda 3 path/Anaconda3/Library/share/'

import tweepy
import folium
import pandas as pd

#from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Getting to Know Jupyter Notebook
#
# Keyboard shortcuts will save you lots of time. Jupyter stores a list of keybord shortcuts under the menu at the top: Help > Keyboard Shortcuts, or by pressing `H` in command mode (more on that later). It’s worth checking this each time you update Jupyter, as more shortcuts are added all the time.
#
# Another way to access keyboard shortcuts, and a handy way to learn them is to use the command palette: `Cmd + Shift + P` (or `Ctrl + Shift + P` on Linux and Windows). This dialog box helps you run any command by name – useful if you don’t know the keyboard shortcut for an action or if what you want to do does not have a keyboard shortcut. The functionality is similar to Spotlight search on a Mac, and once you start using it you’ll wonder how you lived without it!
#
# Some of my favorite shortcuts (in command mode):
#
# - `ESC`: exit cell editing and enter to command mode
# - `A`: add a cell above the current cell
# - `B`: add a cell below the current cell
# - `C`: copy the current cell
# - `X`: cut the current cell
# - `V`: paste the copied cell below the current cell
# - `DD`: delete the current cell
# - `M`: change cell to MarkDown code (must exit editing first)
# - `Y`: change cell to Python code (must exit editing first)
# - `Ctrl + Enter`: Run code in the current cell.
# - `Shift + Enter`: Run code in the current cell and move to the next cell.

# %% [markdown]
# ## 3. Set-Up the Connection to Twitter
#
# Go to Twitter Developer Portal (https://developer.twitter.com/en/apps). Click the App you created in account activation.
#
# If you haven't created an App when you created the account, you can create one in the project.
#
# Click `Set up` to set up User authentification settings.
#
# ![](https://raw.githubusercontent.com/qiang-yi/spatial_data_science/main/image/twitter/signup3.jpg)
#
# Turn on `OAuth 1.0a` and keep `OAuth 2.0` off.
#
# ![](https://raw.githubusercontent.com/qiang-yi/spatial_data_science/main/image/twitter/OAuth.jpg)
#
# Select "Read and write and Direct message". You can use "http://127.0.0.1:8080" as Callback URL. Add any website as the website URL (e.g. your personal website or https://twitter.com).
#
# ![](https://raw.githubusercontent.com/qiang-yi/spatial_data_science/main/image/twitter/setting.jpg)
#
# Copy the API keys you have saved when you activated your Developer account, and paste them to replace "......" below. If you can't find them, you can **regenerate** the keys and tokens in your Developer Portal.
#
# ![](https://raw.githubusercontent.com/qiang-yi/spatial_data_science/main/image/twitter/keys2.jpg)
#
# Generate your Access Token and Secret and paste them below.

# %%
API_key = 'As0PGxFkLLgXKyqnGCre08UNz'
API_key_secret = '6rzlzIBqgURxZd2PKjo4QTj4iYNiwINHDWDCMWW3zlxUU9xr23'
access_token = '1509606550134038533-TpQM7b6U3nlvewate1hJqqbMuHSl5p'
access_token_secret = 'jTMIxiyKndnxMAI1vJScVC8diddUgHO2EJvNbb4nozU8L'

# %% [markdown]
# Set up for Twitter authentication.

# %%
auth = tweepy.OAuthHandler(API_key, API_key_secret)
auth.set_access_token(access_token, access_token_secret)

# %% [markdown]
# Set up tweepy API and set rate limit to be true.

# %%
api = tweepy.API(auth, wait_on_rate_limit = True)

# %% [markdown]
# ---

# %% [markdown]
# ## 4. Simple Operation with Twitter APIs
#
# Now, your working environment is set up for Twitter analysis. Let's first try a few simple operations to acquire Twitter data in a programmatic way.
#
# The full functionalities of Twitter API and Tweepy can be found in:
#
# - [Twitter APIs](https://developer.twitter.com/en/docs.html)
# - [Tweepy documentation](http://docs.tweepy.org/en/v4.8.0/)

# %% [markdown]
# ### 4.1 Posting/Deleting a Tweet
#
# First, let's post a message in your Twitter account.
#
# **Note**: if you don't want to disturb your followers with a meanless tweet, don't run the following block of code.

# %%
# Post a tweet from Python
test_tweet = api.update_status("DRILL: I'm creating a robot to tweet!")

# %% [markdown]
# Check your Twitter account, and you'll see the above message is posted.
#
# ![](https://raw.githubusercontent.com/qiang-yi/spatial_data_science/main/image/twitter/tweet.jpg)
#
# Tweets are encoded in a JSON (JavaScript Object Notation) format. You can run the following code to check the content of the tweet you just posted.

# %%
test_tweet._json
# Out:
# {'created_at': 'Sat Apr 16 21:14:12 +0000 2022',
#  'id': 1515438433849774086,
#  'id_str': '1515438433849774086',
#  'text': "DRILL: I'm creating a robot to tweet!",
#  'truncated': False,
#  'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []},
#  'source': '<a href="https://twitter.com" rel="nofollow">twitter_workshop2</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 1509606550134038533,
#   'id_str': '1509606550134038533',
#   'name': 'Alex Zhang',
#   'screen_name': 'AlexZha37291293',
#   'location': '',
#   'description': 'Data scientist',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 0,
#   'friends_count': 1,
#   'listed_count': 0,
#   'created_at': 'Thu Mar 31 19:00:34 +0000 2022',
#   'favourites_count': 0,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 1,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#   'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': True,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none',
#   'withheld_in_countries': []},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'is_quote_status': False,
#  'retweet_count': 0,
#  'favorite_count': 0,
#  'favorited': False,
#  'retweeted': False,
#  'lang': 'en'}

# %% [markdown]
# `_json` returns a dictionary object. So you could access specific attributes using keys in the dictionary. The code below gets the posting time of the tweets.

# %%
test_tweet._json['created_at']
# Out:
# 'Sat Apr 16 21:14:12 +0000 2022'

# %% [markdown]
# Alternative, you can also use the built-in attribute of the tweepy status object to access the attribute. All attributes of a tweet can be found [here](https://developer.twitter.com/en/docs/twitter-api/v1/data-dictionary/object-model/tweet).

# %%
test_tweet.created_at
# Out:
# datetime.datetime(2022, 4, 16, 21, 14, 12, tzinfo=datetime.timezone.utc)

# %% [markdown]
# You can run the following code to delete the drill tweet you just posted.

# %%
api.destroy_status(test_tweet.id_str)
# Out:
# Status(_api=<tweepy.api.API object at 0x000001E1A0FD4400>, _json={'created_at': 'Sat Apr 16 21:14:12 +0000 2022', 'id': 1515438433849774086, 'id_str': '1515438433849774086', 'text': "DRILL: I'm creating a robot to tweet!", 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://twitter.com" rel="nofollow">twitter_workshop2</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1509606550134038533, 'id_str': '1509606550134038533', 'name': 'Alex Zhang', 'screen_name': 'AlexZha37291293', 'location': '', 'description': 'Data scientist', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 0, 'friends_count': 1, 'listed_count': 0, 'created_at': 'Thu Mar 31 19:00:34 +0000 2022', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 1, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': True, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2022, 4, 16, 21, 14, 12, tzinfo=datetime.timezone.utc), id=1515438433849774086, id_str='1515438433849774086', text="DRILL: I'm creating a robot to tweet!", truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, source='twitter_workshop2', source_url='https://twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x000001E1A0FD4400>, _json={'id': 1509606550134038533, 'id_str': '1509606550134038533', 'name': 'Alex Zhang', 'screen_name': 'AlexZha37291293', 'location': '', 'description': 'Data scientist', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 0, 'friends_count': 1, 'listed_count': 0, 'created_at': 'Thu Mar 31 19:00:34 +0000 2022', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 1, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': True, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': [ ...

# %% [markdown]
# ### 4.2 Getting Trending Tweets

# %% [markdown]
# In Twitter, you can find trends in different places in the Explore tab.
#
# ![](https://raw.githubusercontent.com/qiang-yi/spatial_data_science/main/image/twitter/trends.jpg)
#
# Next, we are going to retrieve trends in Python. The following code get a list of places where trends are available. These places include countries and cities.

# %%
place_ls = api.available_trends()

# %% [markdown]
# Convert the list (in JSON format) into a dataframe (i.e. a table). Print the number of cities where trends are available.

# %%
df_place = pd.DataFrame(place_ls)

print (str(len(df_place)) + " places have trends.")
# Out:
# 467 places have trends.

# %% [markdown]
# Preview 10 places where trends are available

# %%
df_place.head(10)
# Out:
#          name                          placeType  \
# 0   Worldwide  {'code': 19, 'name': 'Supername'}
# 1    Winnipeg        {'code': 7, 'name': 'Town'}
# 2      Ottawa        {'code': 7, 'name': 'Town'}
# 3      Quebec        {'code': 7, 'name': 'Town'}
# 4    Montreal        {'code': 7, 'name': 'Town'}
# 5     Toronto        {'code': 7, 'name': 'Town'}
# 6    Edmonton        {'code': 7, 'name': 'Town'}
# 7     Calgary        {'code': 7, 'name': 'Town'}
# 8   Vancouver        {'code': 7, 'name': 'Town'}
# 9  Birmingham        {'code': 7, 'name': 'Town'}
#
#                                          url  parentid         country  woeid  \
# 0      http://where.yahooapis.com/v1/place/1         0                      1
# 1   http://where.yahooapis.com/v1/place/2972  23424775          Canada   2972
# 2   http://where.yahooapis.com/v1/place/3369  23424775          Canada   3369
# 3   http://where.yahooapis.com/v1/place/3444  23424775          Canada   3444
# 4   http://where.yahooapis.com/v1/place/3534  23424775          Canada   3534
# 5   http://where.yahooapis.com/v1/place/4118  23424775          Canada   4118
# 6   http://where.yahooapis.com/v1/place/8676  23424775          Canada   8676
# 7   http://where.yahooapis.com/v1/place/8775  23424775          Canada   8775
# 8   http://where.yahooapis.com/v1/place/9807  23424775          Canada   9807
# 9  http://where.yahooapis.com/v1/place/12723  23424975  United Kingdom  12723
#
#   countryCode
# 0        None
# 1          CA
# 2          CA
# 3          CA
# 4          CA
# 5          CA
# 6          CA
# 7          CA
# 8          CA
# 9          GB

# %% [markdown]
# Get the record of Tampa. The `woeid` is a unique ID for each place.

# %%
df_place[df_place['name']=='New York']
# Out:
#          name                    placeType  \
# 373  New York  {'code': 7, 'name': 'Town'}
#
#                                              url  parentid        country  \
# 373  http://where.yahooapis.com/v1/place/2459115  23424977  United States
#
#        woeid countryCode
# 373  2459115          US

# %% [markdown]
# Store the `woeid` of Tampa in tampa_id.

# %%
tampa_id = df_place[df_place['name']=='Tampa']['woeid']

# %% [markdown]
# Return the trends in Tampa.
#
# Note: you need to convert the city_id from a pandas series object into an integer.

# %%
# make Tampa as an example
trends_tampa = api.get_place_trends(int(tampa_id))

# %% [markdown]
# Print the trends in JSON format

# %%
# print the top 20 trends in Tampa
trends_tampa[0:20]
# Out:
# [{'trends': [{'name': 'Anthony Edwards',
#     'url': 'http://twitter.com/search?q=%22Anthony+Edwards%22',
#     'promoted_content': None,
#     'query': '%22Anthony+Edwards%22',
#     'tweet_volume': None},
#    {'name': 'Minnesota',
#     'url': 'http://twitter.com/search?q=Minnesota',
#     'promoted_content': None,
#     'query': 'Minnesota',
#     'tweet_volume': 16084},
#    {'name': 'Spring Game',
#     'url': 'http://twitter.com/search?q=%22Spring+Game%22',
#     'promoted_content': None,
#     'query': '%22Spring+Game%22',
#     'tweet_volume': 20390},
#    {'name': '#ChargeOn',
#     'url': 'http://twitter.com/search?q=%23ChargeOn',
#     'promoted_content': None,
#     'query': '%23ChargeOn',
#     'tweet_volume': None},
#    {'name': 'Steffen',
#     'url': 'http://twitter.com/search?q=Steffen',
#     'promoted_content': None,
#     'query': 'Steffen',
#     'tweet_volume': 31756},
#    {'name': '#gocanes',
#     'url': 'http://twitter.com/search?q=%23gocanes',
#     'promoted_content': None,
#     'query': '%23gocanes',
#     'tweet_volume': None},
#    {'name': 'Arsenal',
#     'url': 'http://twitter.com/search?q=Arsenal',
#     'promoted_content': None,
#     'query': 'Arsenal',
#     'tweet_volume': 228960},
#    {'name': 'Liverpool',
#     'url': 'http://twitter.com/search?q=Liverpool',
#     'promoted_content': None,
#     'query': 'Liverpool',
#     'tweet_volume': 251861},
#    {'name': 'Gators',
#     'url': 'http://twitter.com/search?q=Gators',
#     'promoted_content': None,
#     'query': 'Gators',
#     'tweet_volume': None},
#    {'name': 'Warriors',
#     'url': 'http://twitter.com/search?q=Warriors',
#     'promoted_content': None,
#     'query': 'Warriors',
#     'tweet_volume': 82302},
#    {'name': '#AMEC2022',
#     'url': 'http://twitter.com/search?q=%23AMEC2022',
#     'promoted_content': None,
#     'query': '%23AMEC2022',
#     'tweet_volume': None},
#    {'name': 'ESPN',
#     'url': 'http://twitter.com/search?q=ESPN',
#     'promoted_content': None,
#     'query': 'ESPN',
#     'tweet_volume': 81693},
#    {'name': 'Grizzlies',
#     'url': 'http://twitter.com/search?q=Grizzlies',
#     'promoted_content': None,
#     'query': 'Grizzlies',
#     'tweet_volume': 27104},
#    {'name': 'Mavs',
#     'url': 'http://twitter.com/search?q=Mavs',
#     'promoted_content': None,
#     'query': 'Mavs',
#     'tweet_volume': 28302},
#    {'name': 'Memphis',
#     'url': 'http://twitter.com/search?q=Memphis',
#     'promoted_content': None,
#     'query': 'Memphis',
#     'tweet_volume': 27406},
#    {'name': 'Luka',
#     'url': 'http://twitter.com/search?q=Luka',
#     'promoted_content': None,
#     'query': 'Luka',
#     'tweet_volume': 52967},
#    {'name': '#MINvsMEM',
#     'url': 'http://twitter.com/search?q=%23MINvsMEM',
#     'promoted_content': None,
#     'query': '%23MINvsMEM',
#     'tweet_volume': None},
#    {'name': 'Stephen A',
#     'url': 'http://twitter.com/search?q=%22Stephen+A%22',
#     'promoted_content': None,
#     'query': '%22Stephen+A%22',
#     'tweet_volume': 17528},
#    {'name': 'Ja Morant',
#     'url': 'http://twitter.com/search?q=%22Ja+Morant%22',
#     'promoted_content': None,
#     'query': '%22Ja+Morant%22',
#     'tweet_volume': None},
#    {'name': 'Wolves',
#     'url': 'http://twitter.com/search?q=Wolves',
#     'promoted_content': None,
#     'query': 'Wolves',
#     'tweet_volume': 30724},
#    {'name': 'Jazz',
#     'url': 'http://twitter.com/search?q=Jazz',
#     'promoted_content': None,
#     'query': 'Jazz',
#     'tweet_volume': 79549},
#    {'name': 'Donovan Mitchell',
#     'url': 'http://twitter.com/search?q=%22Donovan+Mitchell%22',
#     'promoted_content': None,
#     'query': '%22Donovan+Mitchell%22',
#     'tweet_volume': None},
#    {'name': 'Gobert',
#     'url': 'http://twitter.com/search?q=Gobert',
#     'promoted_content': None,
#     'query': 'Gobert',
#     'tweet_volume': 11782},
#    {'name': 'Happy Easter',
#     'url': 'http://twitter.com/search?q=%22Happy+Easter%22',
#     'promoted_content': None,
#     'query': '%22Happy+Easter%22',
#     'tweet_volume': 235151},
#    {'name': 'Lugo',
#     'url': 'http://twitter.com/search?q=Lugo',
#     'promoted_content': None,
#     'query': 'Lugo',
#     'tweet_volume': None},
#    {'name': 'Chomsky',
#     'url': 'http://twitter.com/search?q=Chomsky',
#     'promoted_content': None,
#     'query': 'Chomsky',
#     'tweet_volume': 19365},
#    {'name': 'Brunson',
#     'url': 'http://twitter.com/search?q=Brunson',
#     'promoted_content': None,
#     'query': 'Brunson',
#     'tweet_volume': None},
#    {'name': 'Glen Taylor',
#     'url': 'http://twitter.com/search?q=%22Glen+Taylor%22',
#     'promoted_content': None,
#     'query': '%22Glen+Taylor%22',
#     'tweet_volume': None},
#    {'name': 'Emoni Bates',
#     'url': 'http://twitter.com/search?q=%22Emoni+Bates%22',
#     'promoted_content': None,
#     'query': '%22Emoni+Bates%22',
#     'tweet_volume': None},
#    {'name': 'Tyus Jones',
#     'url': 'http://twitter.com/search?q=%22Tyus+Jones%22',
#     'promoted_content': None,
#     'query': '%22Tyus+Jones%22',
#     'tweet_volume': None},
#    {'name': 'Steven Adams',
#     'url': 'http://twitter.com/search?q=%22Steven+Adams%22',
#     'promoted_content': None,
#     'query': '%22Steven+Adams%22',
#     'tweet_volume': None},
#    {'name': 'Richard Jefferson',
#     'url': 'http://twitter.com/search?q=%22Richard+Jefferson%22',
#     'promoted_content': None,
#     'query': '%22Richard+Jefferson%22',
#     'tweet_volume': None},
#    {'name': 'Utah',
#     'url': 'http://twitter.com/search?q=Utah',
#     'promoted_content': None,
#     'query': 'Utah',
#     'tweet_volume': 39145},
#    {'name': 'Naz Reid',
#     'url': 'http://twitter.com/search?q=%22Naz+Reid%22',
#     'promoted_content': None,
#     'query': '%22Naz+Reid%22',
#     'tweet_volume': None},
#    {'name': 'Chuck Todd',
#     'url': 'http://twitter.com/search?q=%22Chuck+Todd%22',
#     'promoted_content': None,
#     'query': '%22Chuck+Todd%22',
#     'tweet_volume': 18085},
#    {'name': 'Greeny',
#     'url': 'http://twitter.com/search?q=Greeny',
#     'promoted_content': None,
#     'query': 'Greeny',
#     'tweet_volume': None},
#    {'name': 'Tucker',
#     'url': 'http://twitter.com/search?q=Tucker',
#     'promoted_content': None,
#     'query': 'Tucker',
#     'tweet_volume': 51636},
#    {'name': 'Dinwiddie',
#     'url': 'http://twitter.com/search?q=Dinwiddie',
#     'promoted_content': None,
#     'query': 'Dinwiddie',
#     'tweet_volume': None},
#    {'name': 'Dillon Brooks',
#     'url': 'http://twitter.com/search?q=%22Dillon+Brooks%22',
#     'promoted_content': None,
#     'query': '%22Dillon+Brooks%22',
#     'tweet_volume': None},
#    {'name': 'Dallas',
#     'url': 'http://twitter.com/search?q=Dallas',
#     'promoted_content': None,
#     'query': 'Dallas',
#     'tweet_volume': 40181},
#    {'name': 'Will Anderson',
#     'url': 'http://twitter.com/search?q=%22Will+Anderson%22',
#     'promoted_content': None,
#     'query': '%22Will+Anderson%22',
#     'tweet_volume': None},
#    {'name': 'Ant Edwards',
#     'url': 'http://twitter.com/search?q=%22Ant+Edwards%22',
#     'promoted_content': None,
#     'query': '%22Ant+Edwards%22',
#     'tweet_volume': None},
#    {'name': 'Royce',
#     'url': 'http://twitter.com/search?q=Royce',
#     'promoted_content': None,
#     'query': 'Royce',
#     'tweet_volume': None},
#    {'name': 'Columbiana Mall',
#     'url': 'http://twitter.com/search?q=%22Columbiana+Mall%22',
#     'promoted_content': None,
#     'query': '%22Columbiana+Mall%22',
#     'tweet_volume': None},
#    {'name': 'Starling Marte',
#     'url': 'http://twitter.com/search?q=%22Starling+Marte%22',
#     'promoted_content': None,
#     'query': '%22Starling+Marte%22',
#     'tweet_volume': None},
#    {'name': 'Jose Ruiz',
#     'url': 'http://twitter.com/search?q=%22Jose+Ruiz%22',
#     'promoted_content': None,
#     'query': '%22Jose+Ruiz%22',
#     'tweet_volume': None},
#    {'name': 'North Wilkesboro',
#     'url': 'http://twitter.com/search?q=%22North+Wilkesboro%22',
#     'promoted_content': None,
#     'query': '%22North+Wilkesboro%22',
#     'tweet_volume': None},
#    {'name': 'Jahmyr Gibbs',
#     'url': 'http://twitter.com/search?q=%22Jahmyr+Gibbs%22',
#     'promoted_content': None,
#     'query': '%22Jahmyr+Gibbs%22',
#     'tweet_volume': None},
#    {'name': 'Taylor Walls',
#     'url': 'http://twitter.com/search?q=%22Taylor+Walls%22',
#     'promoted_content': None,
#     'query': '%22Taylor+Walls%22',
#     'tweet_volume': None}],
#   'as_of': '2022-04-16T21:14:14Z',
#   'created_at': '2022-04-13T11:48:02Z',
#   'locations': [{'name': 'Tampa', 'woeid': 2503863}]}]

# %% [markdown]
# Organize the Tampa trends in a dataframe.

# %%
# Get trend name, URL, and tweet volume from the JSON data, and store them in a list
trends_tampa_ls = [[trend['name'], trend['url'], trend['tweet_volume']] for trend in trends_tampa[0]['trends']]

# Convert the list to a dataframe
df_trends = pd.DataFrame(trends_tampa_ls,columns=['name','url','tweet_volume'])

# %% [markdown]
# Sort the trends by tweet volumn in a descending order and print the top 10 trends with the most tweeting volumne.

# %%
# Sort the trends by tweet volumn in a descending order
df_trends.sort_values("tweet_volume", inplace = True, ascending = False)

# Print the top 10 trends ranked by tweet volumne
df_trends.head(10)
# Out:
#             name                                             url  tweet_volume
# 7      Liverpool           http://twitter.com/search?q=Liverpool      251861.0
# 23  Happy Easter  http://twitter.com/search?q=%22Happy+Easter%22      235151.0
# 6        Arsenal             http://twitter.com/search?q=Arsenal      228960.0
# 9       Warriors            http://twitter.com/search?q=Warriors       82302.0
# 11          ESPN                http://twitter.com/search?q=ESPN       81693.0
# 20          Jazz                http://twitter.com/search?q=Jazz       79549.0
# 15          Luka                http://twitter.com/search?q=Luka       52967.0
# 36        Tucker              http://twitter.com/search?q=Tucker       51636.0
# 39        Dallas              http://twitter.com/search?q=Dallas       40181.0
# 32          Utah                http://twitter.com/search?q=Utah       39145.0

# %% [markdown]
# The table shows the popular topics people are tweeting about in Tampa.

# %% [markdown]
# ### Question 1: Please modify the code above to get the top 20 trending topics in New York City.

# %%
# ......

# %% [markdown]
# ---

# %% [markdown]
# ## 5. Acquiring Tweets using the Search API

# %% [markdown]
# ### 5.1 Search Tweets using Keywords
#
# In this step, you will use Python program to search tweets that contain a specific keyword. Next, we will search for Tweets that contain "Football".
#
# You can replace the key words to something you are interesting. Please try to choose a popular one so that you can collect sufficient tweets.

# %%
tweets = api.search_tweets("Football", count=100)

print("Total retweet retrieved: "+ str(len(tweets)))
# Out:
# Total retweet retrieved: 100

# %% [markdown]
# Store the user name, user location, posting time, and tweet text in a Pandas dataframe.

# %%
tweets_pd = pd.DataFrame([[tweet.user.name, tweet.user.location,tweet.created_at, tweet.text] for tweet in tweets], 
                         columns = ['user_name','user_loc','creation_time','text'])

tweets_pd
# Out:
#                   user_name                        user_loc  \
# 0                  Chapster  West Yorkshire but work in MCR
# 1                   Jourdan
# 2                Beardo Saz                       Metaverse
# 3                   Ollie🇺🇲           Fort Leonard Wood, MO
# 4            FÃÇTØS BRÃCÉ😎💰
# ..                      ...                             ...
# 95                👑ADINKRA😇                          Earth🌎
# 96  Kriss gin Nuñez Carazas
# 97  Ireland against Fascism                         Ireland
# 98      🅒︎🅡︎7 Ⓕ︎Ⓐ︎Ⓝ︎ 🅑︎🅞︎🅨︎                   Kerala, India
# 99                   Kofi J      Somewhere in the Universe
#
#                creation_time  \
# 0  2022-04-16 21:19:22+00:00
# 1  2022-04-16 21:19:21+00:00
# 2  2022-04-16 21:19:21+00:00
# 3  2022-04-16 21:19:21+00:00
# 4  2022-04-16 21:19:21+00:00
# ..                       ...
# 95 2022-04-16 21:18:44+00:00
# 96 2022-04-16 21:18:44+00:00
# 97 2022-04-16 21:18:43+00:00
# 98 2022-04-16 21:18:43+00:00
# 99 2022-04-16 21:18:42+00:00
#
#                                                  text
# 0   @LedwardAndy @tommo2510 I have said it before ...
# 1   @TFG_Football I would be if playoff basketball...
# 2   RT @IAmENISA: Going to my first Football game ...
# 3   Dudes a fucking 🤡\nOther than catching a footb...
# 4   RT @SaddickAdams: I'm honestly not sure if any...
# ..                                                ...
# 95  RT @Listo_Mens: HT’ Ahly 2-1 Raja Casablanca \...
# 96  RT @blue_roses35: Louis getting given a Belgiu...
# 97  As we've seen since the individual was charged...
# 98  RT @sistoney67: Manchester United 3-2 Norwich ...
# 99  RT @Malachians: Enjoy him now, we'll miss him ...
#
# [100 rows x 4 columns]

# %% [markdown]
# The `search_tweets` funciton can retrieve max 100 tweets at a time. If you want to get more tweets, you can use a `cursor`.
#
# The following code use a cursor to retrieve more tweets containing a keyword. Here we still retrieve 100 tweets to save your search quota for the following steps. You could increase the `num` variable if you want to get more tweets.
#
# > Note: Twitter only allows you to retrieve a limited number of tweets per 15 minutes. If the retrieved tweets exceed the limit, the program will pause for a certain amount time. If you can't wait, you can doublepress `i` on your keyboard to interrupt the process.

# %%
# Number of tweets to be retrieved.
num = 100

# define the search keyword
keyword = "Football"

# use cursor to send your request with parameters
tweets = tweepy.Cursor(api.search_tweets,
                   q = keyword,
                   count = num,
                   lang="en").items(num)

# restore the results as a list
tweet_ls = [[tweet.user.name, tweet.user.location,tweet.created_at, tweet.text] for tweet in tweets]

# Store the retrieved tweets in a dataframe
tweets_pd_full = pd.DataFrame(tweet_ls, 
                         columns = ['user_name','user_loc','creation_time','text'])

# Print the dataframe
tweets_pd_full
# Out:
#                           user_name  \
# 0                        Sam Minton
# 1          aterg; harry’s house era
# 2                         scarlet88
# 3                         KervSells
# 4            Holy Cross JV Football
# ..                              ...
# 95                          carl00z
# 96                          Torch 💎
# 97           The Arseholics Podcast
# 98                     tim fenander
# 99  Carol ☕ || Late Night Talking 💚
#
#                                              user_loc  \
# 0                                         Peabody, MA
# 1   she ¡! they (any pronouns)\n˗ˋˏsandy milkovich...
# 2
# 3
# 4                             Francis Lewis Boulevard
# ..                                                ...
# 95
# 96                                            Nigeria
# 97
# 98
# 99
#
#                creation_time  \
# 0  2022-04-16 21:19:38+00:00
# 1  2022-04-16 21:19:38+00:00
# 2  2022-04-16 21:19:38+00:00
# 3  2022-04-16 21:19:37+00:00
# 4  2022-04-16 21:19:37+00:00
# ..                       ...
# 95 2022-04-16 21:18:48+00:00
# 96 2022-04-16 21:18:48+00:00
# 97 2022-04-16 21:18:47+00:00
# 98 2022-04-16 21:18:47+00:00
# 99 2022-04-16 21:18:46+00:00
#
#                                                  text
# 0   I don’t want to alarm anyone and I’ll take pic...
# 1   RT @HLDTour: Louis signed a football shirt for...
# 2   RT @AWardSports: In my opinion, C.J. Stroud an...
# 3   RT @pinestbreakers: 🚨PRE-SALE LIVE ON DISCORD🚨...
# 4   🟢⚔️💛⚔️🟢\n•\nWishing a Happy Easter to all our ...
# ..                                                ...
# 95  RT @drgoatz: @football_muscIe @therealtyquendo...
# 96  The Vice Chancellor of the University of Footb...
# 97  RT @northbankninja: At a Craig David concert, ...
# 98  RT @NBCSEdgeFB: Jadeveon Clowney expected to r...
# 99  RT @HLDTour: Louis getting given a Belgium foo...
#
# [100 rows x 4 columns]

# %% [markdown]
# ### 5.2 Filter out Retweets
# The retrieved tweets include both original tweets and retweets. The content of retweets are almost identical and carry little information. You can set up a filter to eliminate the retweets and keep only the original tweets.
#
# To filter out retweets, you can simply add `-filter:retweets` in the search keyword.

# %%
new_keyword = "Football" + " -filter:retweets"
new_keyword
# Out:
# 'Football -filter:retweets'

# %% [markdown]
# The following code retrieve only original tweets that contain the keyword "Football".

# %%
# Number of tweets to be retrieved.
num = 100

# use cursor to send your request with parameters
tweets = tweepy.Cursor(api.search_tweets,
                   q = new_keyword,
                   count = num,
                   lang="en").items(num)

# restore the results as a list
tweet_ls = [[tweet.user.name, tweet.user.location,tweet.created_at, tweet.text] for tweet in tweets]

# Store the retrieved tweets in a dataframe
tweets_pd_full = pd.DataFrame(tweet_ls, 
                         columns = ['user_name','user_loc','creation_time','text'])

# Print the dataframe
tweets_pd_full
# Out:
#                                  user_name                           user_loc  \
# 0                              Obuseh Jude                            Nigeria
# 1                               bethastin✨                 Costa Del Rochdale
# 2                           pruno penandes                      inceltic park
# 3   Alabama Crimson Tide Football Alliance                     Tuscaloosa, AL
# 4                        freddie stevenson                            Purpose
# ..                                     ...                                ...
# 95                         KyleZoomZumbach                  Bullhead City, AZ
# 96                             Jonny Alves  Saint Helier, Bailiwick of Jersey
# 97                     Pennsylvania Sports                  Pennsylvania, USA
# 98                                freedumb                      ur moms house
# 99                      The Soccer Factory
#
#                creation_time  \
# 0  2022-04-16 21:23:44+00:00
# 1  2022-04-16 21:23:43+00:00
# 2  2022-04-16 21:23:37+00:00
# 3  2022-04-16 21:23:35+00:00
# 4  2022-04-16 21:23:34+00:00
# ..                       ...
# 95 2022-04-16 21:21:56+00:00
# 96 2022-04-16 21:21:54+00:00
# 97 2022-04-16 21:21:52+00:00
# 98 2022-04-16 21:21:50+00:00
# 99 2022-04-16 21:21:50+00:00
#
#                                                  text
# 0   @SuperSportTV Whether naysayers want to accept...
# 1   No matter the result football will never spoil...
# 2   @VincentEPhiri @ManCity You really don't know ...
# 3   LOOK: Top images from Alabama Football's A-Day...
# 4   All the @fcflio football games are at the Pull...
# ..                                                ...
# 95  I found it interesting there a ton of HS that ...
# 96  Clearly Portimonense didn’t fancy playing foot...
# 97  Alabama honors university’s first Black footba...
# 98  apparently i have astigmatism really bad and s...
# 99  Coach @keimar.clarke providing the details in ...
#
# [100 rows x 4 columns]

# %% [markdown]
# ### 5.3 Search Tweets using locations
#
# You can also search for tweets around a certain location. The spatial query is based on geotags and/or user locations of the tweets.
#
# The following code will retrieve 200 tweets containing "Football" within a 20 mile radius from USF (28.0619,-82.4146).

# %%
# Number of tweets to be retrieved.
num = 200

# define the search keyword
keyword = "Football"

# use cursor to send your request with parameters
tweets = tweepy.Cursor(api.search_tweets,
                   q=keyword,
                   geocode = "28.0619,-82.4146,20mi",
                   count = num,
                   lang="en").items(num)

# restore the results as a list
tweet_ls = [[tweet.user.name, tweet.user.location, tweet.place, tweet.created_at, tweet.text] for tweet in tweets]

# Store the retrieved tweets in a dataframe
tweets_pd_geo = pd.DataFrame(tweet_ls, 
                         columns = ['user_name','user_loc','geotag','creation_time','text'])

# Print the dataframe
tweets_pd_geo
# Out:
#                      user_name        user_loc  \
# 0                    Rob Maier   Clearwater,Fl
# 1              BADGIRL MELISSA       Tampa, FL
# 2                 Phillybuster  Clearwater, FL
# 3                        Kh813       Tampa, FL
# 4                    Mikey2CTA       Tampa, FL
# ..                         ...             ...
# 195           Thechosenone3488
# 196  Strawberry Crest Football       Dover, FL
# 197        #Fantasy #SKOL Dave       Tampa, FL
# 198                Bruce Wayne       Tampa, FL
# 199            Luke Easterling       Tampa, FL
#
#                                                 geotag  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 195  Place(_api=<tweepy.api.API object at 0x000001E...
# 196                                               None
# 197                                               None
# 198                                               None
# 199                                               None
#
#                 creation_time  \
# 0   2022-04-16 21:22:33+00:00
# 1   2022-04-16 21:18:03+00:00
# 2   2022-04-16 21:03:19+00:00
# 3   2022-04-16 20:56:27+00:00
# 4   2022-04-16 20:53:53+00:00
# ..                        ...
# 195 2022-04-14 18:38:05+00:00
# 196 2022-04-14 18:35:18+00:00
# 197 2022-04-14 18:27:32+00:00
# 198 2022-04-14 18:26:44+00:00
# 199 2022-04-14 18:16:05+00:00
#
#                                                   text
# 0    @ethanhub_ @UCF_Football @CoachHand @CoachGusM...
# 1    So ready for some football @usflonfox opening ...
# 2    🗓 Today (4/16) from 🕓 6pm-9pm\n📍 Womens Footba...
# 3    @ArmyWP_Football He’s Army Strong! A leader wi...
# 4    @NBA Love nba basketball…. Especially playoffs...
# ..                                                 ...
# 195  @DCarr75 @derekcarrqb My dream is lose 130 joi...
# 196  2022 Crest Football Schedule\n@TheSCHSChargers...
# 197  @jstockfive @Official_ACG Yea bro stick to foo...
# 198  @william_nixonTD @UW_Football @KalenDeBoer @Co...
# 199  2022 NFL draft: Nick Cross scouting report htt...
#
# [200 rows x 5 columns]

# %% [markdown]
# Next, we are going to map the tweets using their geotags. However, only a very small proportion (1-2%) of tweets have a geotag. We first check how many of the 200 tweets havea  geotag.

# %%
all = len(tweets_pd_geo[tweets_pd_geo['geotag'].notna()]) # all retrieved tweets
geo = len(tweets_pd_geo) # tweets that actually have geotags.

print("%s out of the %s retrieved tweets actually have a geotag" % (all, geo))
# Out:
# 23 out of the 200 retrieved tweets actually have a geotag

# %% [markdown]
# #### Copy tweets with geotags to a new dataframe called "geotags"

# %%
geo_tweets = tweets_pd_geo.loc[tweets_pd_geo['geotag'].notna()].copy()

# %% [markdown]
# Check detailed data in a geotag. The location of the geotag is in a bounding box defined by the four coordinate pairs.

# %%
geo_tweets.iloc[0].geotag
# Out:
# Place(_api=<tweepy.api.API object at 0x000001E1A0FD4400>, id='07d9df966e080000', url='https://api.twitter.com/1.1/geo/id/07d9df966e080000.json', place_type='poi', name='Tampa Bay Florida', full_name='Tampa Bay Florida', country_code='US', country='United States', contained_within=[], bounding_box=BoundingBox(_api=<tweepy.api.API object at 0x000001E1A0FD4400>, type='Polygon', coordinates=[[[-82.34978505052312, 28.030923683079468], [-82.34978505052312, 28.030923683079468], [-82.34978505052312, 28.030923683079468], [-82.34978505052312, 28.030923683079468]]]), attributes={})

# %% [markdown]
# Get coordinates of the bounding box

# %%
geo_tweets.iloc[0].geotag.bounding_box.coordinates
# Out:
# [[[-82.34978505052312, 28.030923683079468],
#   [-82.34978505052312, 28.030923683079468],
#   [-82.34978505052312, 28.030923683079468],
#   [-82.34978505052312, 28.030923683079468]]]

# %% [markdown]
# Create a column in the dataframe to store coordinates of the bounding boxes

# %%
# store bounding box coordinates to a new column
geo_tweets['bounding_box'] = geo_tweets.geotag.apply(lambda s:s.bounding_box.coordinates[0])

# print the geotag
geo_tweets.head()
# Out:
#                    user_name           user_loc  \
# 10  Sadarian *Yachty* Austin          Tampa, FL
# 16                     Shawn
# 35           BrandonSpikes55      Charlotte, NC
# 43            Xavier Porter🖤          Tampa, FL
# 52                Maggi Cook  St Petersburg, FL
#
#                                                geotag  \
# 10  Place(_api=<tweepy.api.API object at 0x000001E...
# 16  Place(_api=<tweepy.api.API object at 0x000001E...
# 35  Place(_api=<tweepy.api.API object at 0x000001E...
# 43  Place(_api=<tweepy.api.API object at 0x000001E...
# 52  Place(_api=<tweepy.api.API object at 0x000001E...
#
#                creation_time  \
# 10 2022-04-16 19:32:21+00:00
# 16 2022-04-16 18:16:37+00:00
# 35 2022-04-16 14:06:05+00:00
# 43 2022-04-16 12:42:41+00:00
# 52 2022-04-16 10:00:19+00:00
#
#                                                  text  \
# 10  Light weights during the baseball season getti...
# 16  @JamesPalmerTV @wyo_football @nflnetwork Hes g...
# 35  Lmao that league shit was wayyyyyy 2 easy 🤣🤣🤣 ...
# 43  I will be at The University of Central Florida...
# 52  If this was your family member wouldn't you be...
#
#                                          bounding_box
# 10  [[-82.34978505052312, 28.030923683079468], [-8...
# 16  [[-82.712772, 27.977811], [-82.675347, 27.9778...
# 35  [[-82.620093, 27.821353], [-82.2652945, 27.821...
# 43  [[-82.2679052, 27.930926], [-82.0556591, 27.93...
# 52  [[-82.369079, 27.755502], [-82.2443655, 27.755...

# %% [markdown]
# For mapping purpose, we will simplify the bounding boxes to their centroids (points). In such a way, each tweet will be pinned to the centroid of the bounding box in the geotag.
#
# The following code calculate the lat, lon of centroids and store them in two new columns.

# %%
geo_tweets['point']  = geo_tweets['bounding_box'].apply(lambda s: [(s[0][1]+s[2][1])/2,(s[0][0]+s[2][0])/2])

geo_tweets['lat']  = geo_tweets['bounding_box'].apply(lambda s: (s[0][1]+s[2][1])/2)

geo_tweets['lon']  = geo_tweets['bounding_box'].apply(lambda s: (s[0][0]+s[2][0])/2)

# %% [markdown]
# Print to see the dataframe again. You'll see the centroids, latitude, and longitude are added as columns in the dataframe.
#
# Note: the point column is an redundancy of the lat and lon columns. We create all these columns just in case you want to convert the dataframe to a geodataframe (geometry).

# %%
geo_tweets.head()
# Out:
#                    user_name           user_loc  \
# 10  Sadarian *Yachty* Austin          Tampa, FL
# 16                     Shawn
# 35           BrandonSpikes55      Charlotte, NC
# 43            Xavier Porter🖤          Tampa, FL
# 52                Maggi Cook  St Petersburg, FL
#
#                                                geotag  \
# 10  Place(_api=<tweepy.api.API object at 0x000001E...
# 16  Place(_api=<tweepy.api.API object at 0x000001E...
# 35  Place(_api=<tweepy.api.API object at 0x000001E...
# 43  Place(_api=<tweepy.api.API object at 0x000001E...
# 52  Place(_api=<tweepy.api.API object at 0x000001E...
#
#                creation_time  \
# 10 2022-04-16 19:32:21+00:00
# 16 2022-04-16 18:16:37+00:00
# 35 2022-04-16 14:06:05+00:00
# 43 2022-04-16 12:42:41+00:00
# 52 2022-04-16 10:00:19+00:00
#
#                                                  text  \
# 10  Light weights during the baseball season getti...
# 16  @JamesPalmerTV @wyo_football @nflnetwork Hes g...
# 35  Lmao that league shit was wayyyyyy 2 easy 🤣🤣🤣 ...
# 43  I will be at The University of Central Florida...
# 52  If this was your family member wouldn't you be...
#
#                                          bounding_box  \
# 10  [[-82.34978505052312, 28.030923683079468], [-8...
# 16  [[-82.712772, 27.977811], [-82.675347, 27.9778...
# 35  [[-82.620093, 27.821353], [-82.2652945, 27.821...
# 43  [[-82.2679052, 27.930926], [-82.0556591, 27.93...
# 52  [[-82.369079, 27.755502], [-82.2443655, 27.755...
#
#                                        point        lat        lon
# 10  [28.030923683079468, -82.34978505052312]  28.030924 -82.349785
# 16  [28.013468500000002, -82.69405950000001]  28.013469 -82.694060
# 35          [27.9965945, -82.44269374999999]  27.996595 -82.442694
# 43                [28.0121671, -82.16178215]  28.012167 -82.161782
# 52        [27.827367000000002, -82.30672225]  27.827367 -82.306722

# %% [markdown]
# ---

# %% [markdown]
# ## 6. Mapping Geotagged Tweets

# %% [markdown]
# Finally, we will use folium to create an interactive map for the geotagged tweets.

# %%
# Create a base map
maptweet = folium.Map()

# Add the tweets into the basemap
for i, row in geo_tweets.iterrows():
    folium.Marker(row.point,popup = row.text).add_to(maptweet)
    
# Zoom to the bounding box including the tweets
maptweet.fit_bounds([[min(geo_tweets.lat),min(geo_tweets.lon)],[max(geo_tweets.lat),max(geo_tweets.lon)]])

# Show the map
display(maptweet)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_fa3b9aa19dd3443d853b7d3c8a09e8ae%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_fa3b9aa19dd3443d853b7d3c8a09e8ae%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_fa3b9aa19dd3443d853b7d3c8a09e8ae%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_fa3b9aa19dd3443d853b7d3c8a09e8ae%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B0%2C%200%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs%3A%2 ...

# %% [markdown]
# ## 7. Streaming Tweets
#
# Unlike the Search API, the Streaming API utilizes Twitter's HTTP protocol to deliver data through an open, streaming API connection. A single streaming connection is opened between your app and the API, with new results being sent through that connection whenever new matches occur. This results in a low-latency delivery mechanism that can support very high throughput. For further information, see https://developer.twitter.com/en/docs/tutorials/consuming-streaming-data.
#
# Depending on the filter (the speed of retrieval), the streaming API is also subject to a limit per 15 minutes. If the retrieved tweets exceed the limit, your program will pause for the next 15 minutes cycle.
#
# Run the following code to start streaming. The text messages are printed. You can double press `I` to interrupt the streaming.

# %%
import tweepy
import csv

# paste your API keys and tokens to replace ......
API_key = 'As0PGxFkLLgXKyqnGCre08UNz'
API_key_secret = '6rzlzIBqgURxZd2PKjo4QTj4iYNiwINHDWDCMWW3zlxUU9xr23'
access_token = '1509606550134038533-TpQM7b6U3nlvewate1hJqqbMuHSl5p'
access_token_secret = 'jTMIxiyKndnxMAI1vJScVC8diddUgHO2EJvNbb4nozU8L'

auth = tweepy.OAuthHandler(API_key, API_key_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth, wait_on_rate_limit = True)

# %% [markdown]
# You can run the follow code to stream real-time tweets and save them in a CSV file in your computer.

# %%
# Define path and name of output file
output_file = "tweets_ukraine.csv"

# Open a file to write in streamed tweets
with open(output_file, "w", encoding="utf-8",newline='') as f:
    writer = csv.writer(f)
    
    # Write the headers in the first row
    writer.writerow(["username","created_at", "geotag", "user_location", "lang","tweet"])
    
    # Define a sub-object of tweepy.Stream
    class stream_csv(tweepy.Stream):
        def on_status(self, status):
            # Skip retweets and collect only geotagged tweets
            if (not status.retweeted) and ('RT @' not in status.text) and (status.place is not None):
                # Organize attributes of a tweet in a list
                line = [status.user.name, status.user.created_at, status.place.bounding_box.coordinates[0], status.user.location, status.lang, status.text]
                print(line) # Print the line
                writer.writerow(line) # write the line to csv file

    streamer = stream_csv(API_key, API_key_secret, access_token, access_token_secret)
    streamer.filter(languages=["en"], track=["ukraine"])
    streamer.sample()
# Out:
# ['Alex Gura', datetime.datetime(2012, 1, 13, 1, 21, 21, tzinfo=datetime.timezone.utc), [[-76.952172, 39.215288], [-76.952172, 39.324062], [-76.763767, 39.324062], [-76.763767, 39.215288]], 'Maryland, USA', 'en', 'War criminals participating in the commission of war crimes against the people of Ukraine - military personnel 1237… https://t.co/xlTxvpjRtS']
# ['Alex Gura', datetime.datetime(2012, 1, 13, 1, 21, 21, tzinfo=datetime.timezone.utc), [[-76.952172, 39.215288], [-76.952172, 39.324062], [-76.763767, 39.324062], [-76.763767, 39.215288]], 'Maryland, USA', 'en', '⤴️…For the atrocities committed against the civilian population of Ukraine, all war criminals will be brought to ju… https://t.co/6eZiMwHNB2']
# ['Ashis Basu', datetime.datetime(2012, 7, 14, 23, 49, 49, tzinfo=datetime.timezone.utc), [[-79.810142, 43.373074], [-79.810142, 43.737414], [-79.422004, 43.737414], [-79.422004, 43.373074]], 'Canada', 'en', '+ To the average Russian Putin is carrying out an “operation” to cleanse Ukraine of Nazis. \n\nThis afternoon while s… https://t.co/fsa5zsrmyY']
# ['Rose', datetime.datetime(2019, 2, 14, 1, 52, 15, tzinfo=datetime.timezone.utc), [[-88.257493, 42.183223], [-88.257493, 42.207271], [-88.184835, 42.207271], [-88.184835, 42.183223]], 'Illinois, USA', 'en', 'Poor Putin, No friends, No gifts. *Moscow sent a formal diplomatic note of protest to\xa0warn the United States of “un… https://t.co/uLqvbEXwGG']
# ['Dave Newton', datetime.datetime(2012, 4, 15, 1, 53, 6, tzinfo=datetime.timezone.utc), [[-93.852921, 41.596435], [-93.852921, 41.660369], [-93.718016, 41.660369], [-93.718016, 41.596435]], None, 'en', 'Putin has already stepped over the line, starting in Crimea. Black Flag the MF!']
# ['Dr. Kropotkin', datetime.datetime(2011, 3, 9, 16, 43, 38, tzinfo=datetime.timezone.utc), [[-104.988399, 39.565951], [-104.988399, 39.613203], [-104.922825, 39.613203], [-104.922825, 39.565951]], 'Nowhere Special', 'en', '@thebsktcase Just out of curiosity, if Ukraine does   make a deal with Russia for peace that guarantee autonomy to… https://t.co/TRHE9S4Vgu']
# ['Linda G Comanche Psychic', datetime.datetime(2021, 11, 17, 22, 57, 57, tzinfo=datetime.timezone.utc), [[-122.779239, 38.396779], [-122.779239, 38.507656], [-122.572978, 38.507656], [-122.572978, 38.396779]], 'Napa, CA', 'en', 'God bless the Ukraine https://t.co/Wol49JRmet']
# ['Kevin Baum', datetime.datetime(2017, 1, 19, 11, 56, tzinfo=datetime.timezone.utc), [[-73.658666, 40.647296], [-73.658666, 40.689946], [-73.617647, 40.689946], [-73.617647, 40.647296]], None, 'en', 'To put this into perspective, the US has lost 1 general in 50 years.']
# ['Nastya Zaskalniuk Meow🇺🇦🇵🇭', datetime.datetime(2016, 12, 2, 14, 38, 15, tzinfo=datetime.timezone.utc), [[22.13572, 44.386383], [22.13572, 52.379475], [40.227172, 52.379475], [40.227172, 44.386383]], 'Украина', 'en', 'stop tolerating the russians! they support the war and the genocide of the Ukrainian people. 80% of russians suppor… https://t.co/SAvwttZZO9']
# ['Nuel', datetime.datetime(2019, 1, 12, 18, 31, 48, tzinfo=datetime.timezone.utc), [[29.677136, -0.780423], [29.677136, -0.072155], [30.506584, -0.072155], [30.506584, -0.780423]], 'Wakiso, Uganda', 'en', "But you're winning the war.\n\nYou sunk a Russian Ship!"]
# ['Bazzio101', datetime.datetime(2012, 1, 18, 4, 32, 19, tzinfo=datetime.timezone.utc), [[150.520929, -34.118347], [150.520929, -33.578141], [151.343021, -33.578141], [151.343021, -34.118347]], 'Mount Colah, Sydney', 'en', 'it is written that the status of the Republics was to be negotiated between Kiev and the representatives of the Rep… https://t.co/biB9sO1IrD']
# ['Edward Gregory Jones', datetime.datetime(2015, 9, 25, 2, 59, 2, tzinfo=datetime.timezone.utc), [[-74.026675, 40.683935], [-74.026675, 40.877483], [-73.910408, 40.877483], [-73.910408, 40.683935]], 'New York, NY', 'en', '.#UkraineWar At the end of WW II thousands of Red Ball Express trucks shuttled arms and supplies non-stop 24 hours… https://t.co/we8kRExofn']
# ['CS 🇺🇲🇻🇮🇺🇦', datetime.datetime(2020, 2, 5, 22, 7, 59, tzinfo=datetime.timezone.utc), [[-117.243028, 41.987982], [-117.243028, 49.001121], [-111.043497, 49.001121], [-111.043497, 41.987982]], None, 'en', "@Csdk1111 @KyivIndependent The US isn't flying this equipment to Ukraine. And it just arrived today so if there was… https://t.co/TUN0qIWr2T"]
# ['Oliver Fehlau', datetime.datetime(2015, 3, 1, 23, 34, 58, tzinfo=datetime.timezone.utc), [[-79.810142, 43.373074], [-79.810142, 43.737414], [-79.422004, 43.737414], [-79.422004, 43.373074]], 'Mississauga, Ontario', 'en', '@andersostlund THIS IS FANFUCKENTASTIC NEWS HERE TODAY. I HOPE YOU INCRIMINATE THAT SORRY PIECE OF S--TS A-S IN WHA… https://t.co/US78qDCqF9']
# ['Hassan Saeed', datetime.datetime(2021, 11, 6, 21, 54, 16, tzinfo=datetime.timezone.utc), [[69.328873, 27.708226], [69.328873, 34.019989], [75.382124, 34.019989], [75.382124, 27.708226]], None, 'en', 'When the Ukraine people protect their country with guns against Russians whole world Call it HEROISM But when the p… https://t.co/WXqh1WO4UQ']
# ['Judybluetoo', datetime.datetime(2020, 8, 9, 4, 12, 12, tzinfo=datetime.timezone.utc), [[-84.386548, 30.365093], [-84.386548, 30.587338], [-84.1458, 30.587338], [-84.1458, 30.365093]], 'leave blank', 'en', '@POTUS \nMany of us feel hate toward Putin. He is a bully and only understands force. It is time to meet him with fo… https://t.co/zhsaUVGt38']
# ['Prof Peter Hotez MD PhD', datetime.datetime(2012, 5, 29, 0, 46, 55, tzinfo=datetime.timezone.utc), [[-95.823268, 29.522325], [-95.823268, 30.154665], [-95.069705, 30.154665], [-95.069705, 29.522325]], 'Montrose, Houston TX', 'en', 'Thanks, I know it’s been a while for both good reasons (lower Covid cases) and bad (atrocities in Ukraine), but giv… https://t.co/7qkDAgdDuk']
# ['Amir A. Afkhami', datetime.datetime(2010, 2, 11, 18, 58, 49, tzinfo=datetime.timezone.utc), [[-77.119401, 38.801826], [-77.119401, 38.99538], [-76.909396, 38.99538], [-76.909396, 38.801826]], 'District of Columbia, USA', 'en', '“Psychologists say that the challenge of anxiety is that people worry about things that are out of their control. A… https://t.co/Q6q0VAcAWh']
# ['Jason Blake 🇺🇦', datetime.datetime(2011, 2, 27, 3, 51, 52, tzinfo=datetime.timezone.utc), [[-159.401287, 22.041026], [-159.401287, 22.079548], [-159.344486, 22.079548], [-159.344486, 22.041026]], 'Lihue', 'en', 'It’s the @rudepundit strategy!']
# ['Rico.. #TrumpSpreadCovid and #BidenBeatCovid', datetime.datetime(2017, 1, 20, 20, 42, 29, tzinfo=datetime.timezone.utc), [[-115.384091, 36.129459], [-115.384091, 36.336371], [-115.062159, 36.336371], [-115.062159, 36.129459]], 'American Earth', 'en', 'Dejavu all over again. When the Soviet Union broke up, Reagan and  the US busted their central bank and they were s… https://t.co/bhxM8AqfQc']
# ['Brigid ☘ 🕊 🇺🇦 All views are my own.', datetime.datetime(2020, 4, 30, 12, 34, 16, tzinfo=datetime.timezone.utc), [[-7.344093, 53.38213], [-7.344093, 53.917706], [-6.206774, 53.917706], [-6.206774, 53.38213]], 'Meath, Ireland', 'en', "@AHoliachenko They don't dream Anastasiia, their minds are filled with horrors &amp; nightmares of the pain &amp; suffering… https://t.co/84H0xN7Rik"]
# ['Jay', datetime.datetime(2021, 11, 4, 15, 48, 59, tzinfo=datetime.timezone.utc), [[102.333681, 9.90553], [102.333681, 14.691234], [107.630261, 14.691234], [107.630261, 9.90553]], 'Phnom Penh. Or at the match!', 'en', 'Ukraine football team has to play June first. Anyone not fighting for their nation and freedom is a straight up ric… https://t.co/DtWB6uE5Uy']
# ['Judybluetoo', datetime.datetime(2020, 8, 9, 4, 12, 12, tzinfo=datetime.timezone.utc), [[-84.386548, 30.365093], [-84.386548, 30.587338], [-84.1458, 30.587338], [-84.1458, 30.365093]], 'leave blank', 'en', '@NATO @UnitedNationsTZ @POTUS \n\nSTOP HIM NOW!!!!']
# ['Glen Hellman', datetime.datetime(2009, 2, 11, 14, 45, 14, tzinfo=datetime.timezone.utc), [[-77.395515, 38.863569], [-77.395515, 38.930322], [-77.253414, 38.930322], [-77.253414, 38.863569]], 'Washington DC', 'en', '@RT_com As soon as Russia stops murdering and leaves Ukraine, the war will end.\n\nIf Russia stops fighting there wil… https://t.co/97FJyYvQfF']
# ['Bambee Parker', datetime.datetime(2021, 1, 4, 4, 48, 24, tzinfo=datetime.timezone.utc), [[-118.668404, 33.704538], [-118.668404, 34.337041], [-118.155409, 34.337041], [-118.155409, 33.704538]], 'Culver City, CA', 'en', '@theonlyjasonlee would love to see you get together your Hollywood friends for a fundraiser event for the lovely co… https://t.co/6sqMwbIp41']
# ['Dylan Brody', datetime.datetime(2009, 5, 22, 3, 59, 54, tzinfo=datetime.timezone.utc), [[-118.668404, 33.704538], [-118.668404, 34.337041], [-118.155409, 34.337041], [-118.155409, 33.704538]], 'Los Angeles, CA', 'en', 'As I understand the Russian party line, Ukraine did not sink the Moskva; it was damaged by an accidental fire. For… https://t.co/nLrtoDUny1']
# ['Oliver Fehlau', datetime.datetime(2015, 3, 1, 23, 34, 58, tzinfo=datetime.timezone.utc), [[-79.810142, 43.373074], [-79.810142, 43.737414], [-79.422004, 43.737414], [-79.422004, 43.373074]], 'Mississauga, Ontario', 'en', '@Aviation_Intel OH WELL!!!  THAT MUST REALLY HURT &amp;  BOTHER THAT REINCARNATED HITLER LUNATIC DICTATOR WAR CRIMINAL… https://t.co/wKQlZmqwFL']
# ['pfunk', datetime.datetime(2014, 1, 2, 13, 11, 34, tzinfo=datetime.timezone.utc), [[-79.868276, 40.260066], [-79.868276, 40.319531], [-79.795261, 40.319531], [-79.795261, 40.260066]], 'Back Yard, USA', 'en', '31 bio labs in Ukraine…']
# ['God Bless Our @Potus/@FLOTUS', datetime.datetime(2012, 5, 31, 4, 11, 1, tzinfo=datetime.timezone.utc), [[-89.62277, 40.628142], [-89.62277, 40.661063], [-89.569333, 40.661063], [-89.569333, 40.628142]], 'United States', 'en', 'We will Not Be Threathened By Putin Or Abyone Close To Him Even Our @Gop Here In The U.S.']
# ['Lykeats🇺🇲🇩🇪', datetime.datetime(2013, 5, 27, 8, 52, 36, tzinfo=datetime.timezone.utc), [[-97.676631, 38.768801], [-97.676631, 38.885242], [-97.557719, 38.885242], [-97.557719, 38.768801]], 'Salina', 'en', '...charge!']
# ['Oliver Fehlau', datetime.datetime(2015, 3, 1, 23, 34, 58, tzinfo=datetime.timezone.utc), [[-79.810142, 43.373074], [-79.810142, 43.737414], [-79.422004, 43.737414], [-79.422004, 43.373074]], 'Mississauga, Ontario', 'en', '@andersostlund THIS IS FANFUCKENTASTIC NEWS HERE TODAY... A THANK YOU FOR THE SUPPORTING COUNTRIES IN ASSISTING THE… https://t.co/njEsmwVskK']
# ['Liev Schreiber', datetime.datetime(2012, 2, 25, 4, 24, 6, tzinfo=datetime.timezone.utc), [[22.13572, 44.386383], [22.13572, 52.379475], [40.227172, 52.379475], [40.227172, 44.386383]], None, 'en', 'Just posted a photo @ Lviv, Ukraine https://t.co/b8T1kfU2JQ']
# ['Oliver Fehlau', datetime.datetime(2015, 3, 1, 23, 34, 58, tzinfo=datetime.timezone.utc), [[-79.810142, 43.373074], [-79.810142, 43.737414], [-79.422004, 43.737414], [-79.422004, 43.373074]], 'Mississauga, Ontario', 'en', '@UAWeapons BRAVO UKRAINE SOLDIERS... GREAT JOB HERE TAKING OUT SOME OF THAT RUSSIAN WEAPONERY OUT OF THOSE BRAINWAS… https://t.co/MmecNPBPzl']
# ['Jun W', datetime.datetime(2014, 4, 3, 16, 7, 11, tzinfo=datetime.timezone.utc), [[114.109911, 22.252085], [114.109911, 22.301655], [114.169855, 22.301655], [114.169855, 22.252085]], '香港', 'en', 'The point is not arguing whether the bio lab is True, the point is to Stop it if it is True\n\nRussia might send the… https://t.co/2aumSRMBzE']
# ['Patrick M Andendall', datetime.datetime(2012, 9, 1, 15, 6, 27, tzinfo=datetime.timezone.utc), [[-73.713112, 40.805231], [-73.713112, 40.853977], [-73.651629, 40.853977], [-73.651629, 40.805231]], 'New York', 'en', '@HBVolt @RALee85 Funny how cretins put their idiotic interpretations into other peoples mouths—but since you have a… https://t.co/CjBSgB2osc']
# ['Harvey Conover III', datetime.datetime(2014, 8, 9, 18, 36, 23, tzinfo=datetime.timezone.utc), [[-122.790065, 45.421863], [-122.790065, 45.650941], [-122.471751, 45.650941], [-122.471751, 45.421863]], None, 'en', '@PalmerReport @Maga @GOP @CNN @maddow @Hamptons @MSNBC For people who are not aficionados of Modern Weaponry,they s… https://t.co/JZ99hGEtJq']
# ['Frank Naidoo', datetime.datetime(2012, 11, 3, 12, 26, 31, tzinfo=datetime.timezone.utc), [[28.001059, -25.9449], [28.001059, -25.776862], [28.271222, -25.776862], [28.271222, -25.9449]], 'Pretoria, South Africa', 'en', '@CarlZha Taiwan should help out. Ukraine, the scrap yard of US arms.']
# ['James J. Griffin', datetime.datetime(2009, 6, 6, 16, 58, 56, tzinfo=datetime.timezone.utc), [[-124.482003, 32.528832], [-124.482003, 42.009519], [-114.131212, 42.009519], [-114.131212, 32.528832]], 'San Diego', 'en', '85% of all bitcoin profits go to official @Ukraine #BTC wallet. Buy a shirt. Orange pill some people along the way.… https://t.co/M67HxG1oNh']
# ['Dmytro Varavin 💙💛', datetime.datetime(2021, 6, 9, 14, 41, 5, tzinfo=datetime.timezone.utc), [[-80.321683, 25.70904], [-80.321683, 25.855667], [-80.144974, 25.855667], [-80.144974, 25.70904]], 'Miami, FL', 'en', 'The White House Gift Shop to present its newest addition to the Global Historic Moments of the American.\n100% of al… https://t.co/aTrao5lhCP']
# ['Sharondipity', datetime.datetime(2014, 6, 29, 20, 9, 50, tzinfo=datetime.timezone.utc), [[-82.533964, 28.892606], [-82.533964, 28.963642], [-82.400458, 28.963642], [-82.400458, 28.892606]], 'Florida, USA', 'en', 'Send them all they want.']
# ['Patrick M Andendall', datetime.datetime(2012, 9, 1, 15, 6, 27, tzinfo=datetime.timezone.utc), [[-73.713112, 40.805231], [-73.713112, 40.853977], [-73.651629, 40.853977], [-73.651629, 40.805231]], 'New York', 'en', '@HBVolt @RALee85 Regarding Iraq — war 1 was somewhat legitimate, war 2 was a war crime. All Middle East wars were c… https://t.co/moO5aJPcg6']
# ['Mohammed Musa', datetime.datetime(2020, 3, 29, 8, 34, 28, tzinfo=datetime.timezone.utc), [[7.304554, 8.961887], [7.304554, 9.185441], [7.543634, 9.185441], [7.543634, 8.961887]], 'Abuja, Nigeria', 'en', 'Ameen ya Rabbi']
# ['Howie', datetime.datetime(2013, 8, 7, 21, 12, 24, tzinfo=datetime.timezone.utc), [[-122.581184, 45.40302], [-122.581184, 45.461537], [-122.477198, 45.461537], [-122.477198, 45.40302]], '308 Negra Arroyo Lane', 'en', 'In an effort to stand with Ukraine 🇺🇦, I warmed up last 2 pieces of my Monday pizza tonight https://t.co/HMHKeaodvX']
# ['Mario Vasquez', datetime.datetime(2009, 4, 23, 1, 18, 3, tzinfo=datetime.timezone.utc), [[-115.384091, 36.129459], [-115.384091, 36.336371], [-115.062159, 36.336371], [-115.062159, 36.129459]], None, 'en', '@POTUS there is nothing to verify. Chemical agents have been found. Now implement the nuclear weapons agreement to… https://t.co/kvVDuufSDx']
# ['Vice Admiral Arun Kumar Singh', datetime.datetime(2009, 9, 29, 11, 38, 57, tzinfo=datetime.timezone.utc), [[76.707671, 28.199529], [76.707671, 28.537521], [77.241711, 28.537521], [77.241711, 28.199529]], 'Gurgaon, India', 'en', "2) A 'different pov' about this tragic war. I think, the truth (including how the ' Moskva' was sunk) may emerge on… https://t.co/VRsH2cVn2j"]
# ['Mira Bosso', datetime.datetime(2009, 7, 23, 12, 4, 42, tzinfo=datetime.timezone.utc), [[-106.824954, 52.069634], [-106.824954, 52.230521], [-106.503696, 52.230521], [-106.503696, 52.069634]], 'Saskatoon, Saskatchewan', 'en', '@FahdAlMulla I just heard from a political analyst, that the actual reason for China strict measure is not COVID-19… https://t.co/wO27EkgML5']
# ['Солідарність 🏳️\u200d🌈 & always a 🏳️\u200d⚧️ ally', datetime.datetime(2010, 6, 17, 16, 1, 40, tzinfo=datetime.timezone.utc), [[-0.173706, 50.80835], [-0.173706, 50.872314], [-0.087006, 50.872314], [-0.087006, 50.80835]], 'Brighton, England', 'en', '@borisjohnson @number10gov @trussliz @NATO @EU_Commission @Europarl_EN \n\nDay 53, tens if thousands dead, when will… https://t.co/hHnHCA786J']
# ['Oliver Fehlau', datetime.datetime(2015, 3, 1, 23, 34, 58, tzinfo=datetime.timezone.utc), [[-79.810142, 43.373074], [-79.810142, 43.737414], [-79.422004, 43.737414], [-79.422004, 43.373074]], 'Mississauga, Ontario', 'en', '@RALee85 GOOD, AND SMART ON INDIA IN NOT SUPPORTING THAT REINCARNATED HITLER LUNATIC DICTATOR WAR CRIMINAL PUTIN...… https://t.co/cHRV5yjbSV']
# ['Gaurav Singh Thakur', datetime.datetime(2021, 5, 6, 4, 24, 56, tzinfo=datetime.timezone.utc), [[85.673142, 25.976244], [85.673142, 26.447959], [86.056509, 26.447959], [86.056509, 25.976244]], None, 'en', "@ARanganathan72 Well we talk about genocide being carried out by Russia in Ukraine, but it's high time we start loo… https://t.co/Noh98zRmEs"]
# ['tnasza@outlook.com', datetime.datetime(2016, 4, 6, 21, 7, 39, tzinfo=datetime.timezone.utc), [[41.815344, 12.106866], [41.815344, 18.998648], [54.534186, 18.998648], [54.534186, 12.106866]], 'yemen-sanaa.', 'en', 'God enforce peace in Ukraine. https://t.co/TRxm5GTHMz']
# ['HANSWalterMuller', datetime.datetime(2021, 9, 12, 5, 3, 42, tzinfo=datetime.timezone.utc), [[-123.224215, 49.19854], [-123.224215, 49.316738], [-123.022947, 49.316738], [-123.022947, 49.19854]], None, 'en', 'UKRAINE HAS DONE A SUPERHUMAN JOB DEFENDING THEIR COUNTRY AND EVEN TAKING OUT A RUSSIAN WARSHIP BUT PUTIN WILL DEST… https://t.co/nNKKcbTSYV']
# ['Lee Stranahan 🇷🇺', datetime.datetime(2007, 5, 7, 2, 26, 41, tzinfo=datetime.timezone.utc), [[-96.839502, 43.465641], [-96.839502, 43.616388], [-96.622783, 43.616388], [-96.622783, 43.465641]], 'Sanford Medical Center', 'en', 'Hannity is a full throttle defender or his boss Rupert Murdoch’s']
# ['M. S. M. Saifullah', datetime.datetime(2010, 6, 25, 11, 46, 20, tzinfo=datetime.timezone.utc), [[8.170001, 47.460838], [8.170001, 47.507802], [8.23721, 47.507802], [8.23721, 47.460838]], 'Cambridge', 'en', '@ConradkBarwa John Mearsheimer was not the only one who suggested that Ukraine was being led into trouble by the We… https://t.co/DoKFd3Tnby']
# ['101st506th', datetime.datetime(2021, 10, 6, 16, 40, 49, tzinfo=datetime.timezone.utc), [[-106.645646, 25.837092], [-106.645646, 36.500695], [-93.508131, 36.500695], [-93.508131, 25.837092]], 'Austin, TX', 'en', 'Get a load of the sheer number of people with #Ukraine flags and bios talking shit about their own flag in this thr… https://t.co/edLkFGNiTU']
# ['Uncle Kenny 🇺🇸🏴\U000e0067\U000e0062\U000e0073\U000e0063\U000e0074\U000e007f', datetime.datetime(2017, 1, 11, 17, 58, 6, tzinfo=datetime.timezone.utc), [[-84.820309, 38.403186], [-84.820309, 42.327133], [-80.518626, 42.327133], [-80.518626, 38.403186]], 'Ohio, USA', 'en', '@Troubl37 They should be singing in Ukraine maybe that would help save the people.']
# ['HANSWalterMuller', datetime.datetime(2021, 9, 12, 5, 3, 42, tzinfo=datetime.timezone.utc), [[-123.224215, 49.19854], [-123.224215, 49.316738], [-123.022947, 49.316738], [-123.022947, 49.19854]], None, 'en', 'BUT ASIDE FROM LEAVING UKRAINE IN A PILE OF RUBBLE, THE POSSIBILITY IS GREAT THAT PUTIN WILL USE A NUCLEAR WEAPON, TO DETER THE WEST!']
# ['Wilco Achterberg', datetime.datetime(2010, 1, 12, 21, 9, 22, tzinfo=datetime.timezone.utc), [[5.11956, 51.9595], [5.11956, 52.05664], [5.271228, 52.05664], [5.271228, 51.9595]], 'Houten', 'en', '@zenit_spb Stop the war in Ukraine!']
# ['Mario Vasquez', datetime.datetime(2009, 4, 23, 1, 18, 3, tzinfo=datetime.timezone.utc), [[-115.384091, 36.129459], [-115.384091, 36.336371], [-115.062159, 36.336371], [-115.062159, 36.129459]], None, 'en', "WHAT? Russian TV is saying get out of Ukraine. They don't need another Afghanistan?  WOW!\nCheck out ImNoCat's video… https://t.co/pdC5RYECZN"]
# ['Terry Bojarski', datetime.datetime(2021, 9, 30, 5, 4, 53, tzinfo=datetime.timezone.utc), [[-119.61697, 49.423628], [-119.61697, 49.555611], [-119.515299, 49.555611], [-119.515299, 49.423628]], 'Penticton, British Columbia', 'en', '@SkyNews If he is wearing the Ukraine flag he is a soldier for the Ukraine / still a prisoner of war']
# ['Evita Teterovska Official', datetime.datetime(2022, 4, 14, 8, 21, 25, tzinfo=datetime.timezone.utc), [[-74.026675, 40.683935], [-74.026675, 40.877483], [-73.910408, 40.877483], [-73.910408, 40.683935]], None, 'en', 'I was so honored to sing the Ukrainian Anthem and Recital for such a prestigious audience! Thanks🇺🇦… https://t.co/Gg0GNQl4Pe']
# ['Kitty Cybernat', datetime.datetime(2011, 5, 8, 15, 45, 51, tzinfo=datetime.timezone.utc), [[-3.967301, 56.080348], [-3.967301, 56.134948], [-3.899881, 56.134948], [-3.899881, 56.080348]], 'Bonny Scotland', 'en', 'Mercenaries UK has no army']
# ['Lee Stranahan 🇷🇺', datetime.datetime(2007, 5, 7, 2, 26, 41, tzinfo=datetime.timezone.utc), [[-96.839502, 43.465641], [-96.839502, 43.616388], [-96.622783, 43.616388], [-96.622783, 43.465641]], 'Sanford Medical Center', 'en', 'And working with Brett Kimberlin']
# ['Dave Ladouceur 🇺🇦', datetime.datetime(2013, 10, 24, 18, 32, 24, tzinfo=datetime.timezone.utc), [[-105.109815, 39.614151], [-105.109815, 39.812975], [-104.734372, 39.812975], [-104.734372, 39.614151]], 'Denver, CO', 'en', 'Stop talking .. Putin the war criminal has killed tens of thousands of citizens in the last 15 years for his gas st… https://t.co/DCc0WKV3nt']
# ['M. S. M. Saifullah', datetime.datetime(2010, 6, 25, 11, 46, 20, tzinfo=datetime.timezone.utc), [[8.170001, 47.460838], [8.170001, 47.507802], [8.23721, 47.507802], [8.23721, 47.460838]], 'Cambridge', 'en', '@ConradkBarwa On the peace initiative in Ukraine, the US had been not be too helpful. In fact, it made matters wors… https://t.co/J1GxFJu10Q']
# ['Evita Teterovska Official', datetime.datetime(2022, 4, 14, 8, 21, 25, tzinfo=datetime.timezone.utc), [[-74.026675, 40.683935], [-74.026675, 40.877483], [-73.910408, 40.877483], [-73.910408, 40.683935]], None, 'en', 'Thank you @Eduar_Marin for coming to my Recital!\n#StandWithUkraine️ #Ukraine️']
# ['FIGHTING for our CHILDRENS FUTURE', datetime.datetime(2019, 11, 9, 3, 32, 12, tzinfo=datetime.timezone.utc), [[-1.308003, 53.490755], [-1.308003, 53.504157], [-1.263121, 53.504157], [-1.263121, 53.490755]], None, 'en', 'Putin offers Mariupol  who are making a last  STAND to save DEMOCRACY in Ukraine NO HARM  if they surrendered.\nWith… https://t.co/4fLbeXXdpM']
# ['coolblue2000', datetime.datetime(2020, 6, 30, 15, 1, 18, tzinfo=datetime.timezone.utc), [[97.387161, 26.033886], [97.387161, 34.250275], [110.17804, 34.250275], [110.17804, 26.033886]], '湖南, 中华人民共和国', 'en', 'Quickly, these are the stuff Ukraine need!']
# ['Tom Elliott', datetime.datetime(2009, 3, 7, 23, 20, 25, tzinfo=datetime.timezone.utc), [[-80.519851, 39.719801], [-80.519851, 42.516072], [-74.689517, 42.516072], [-74.689517, 39.719801]], None, 'en', '@DanHankemeier "Old useless weapons?" I don\'t think so. How do you know what weapons we are giving them? It must pa… https://t.co/4UkvPALLKz']
# ['Graham LeggStoker', datetime.datetime(2012, 1, 14, 9, 57, 54, tzinfo=datetime.timezone.utc), [[144.593742, -38.433859], [144.593742, -37.511274], [145.512529, -37.511274], [145.512529, -38.433859]], 'Melbourne AUSTRALIA', 'en', 'Olena, it is fine to say GERMANY, lets call them out properly']
# ['Stigmabase | NORDIC', datetime.datetime(2010, 9, 15, 15, 55, 47, tzinfo=datetime.timezone.utc), [[-73.487336, 45.610005], [-73.487336, 45.748945], [-73.323658, 45.748945], [-73.323658, 45.610005]], 'Ireland | Scotland | Inuit | Skandinavien', 'en', 'Fighting Stigma : Tech giants urged to back Ukraine Schools app with laptops and tablets for refugee schoolchildren… https://t.co/FrWfc4ZMUN']
# ['Real', datetime.datetime(2020, 2, 5, 14, 42, 43, tzinfo=datetime.timezone.utc), [[-84.576827, 33.647503], [-84.576827, 33.886886], [-84.289385, 33.886886], [-84.289385, 33.647503]], 'Atlanta, GA', 'en', 'Russia really fuckin Ukraine up 🥴']
# ['Jennifer M.', datetime.datetime(2010, 6, 30, 3, 6, 17, tzinfo=datetime.timezone.utc), [[-82.681852, 35.421216], [-82.681852, 35.656929], [-82.452163, 35.656929], [-82.452163, 35.421216]], 'Charlotte, NC', 'en', 'Thank you to the @wta from Ukraine and USA for a great qualifying event.  USA 🇺🇸 is on to the @billiejeankingcup  f… https://t.co/2OB6bbl29n']
# ['M. S. M. Saifullah', datetime.datetime(2010, 6, 25, 11, 46, 20, tzinfo=datetime.timezone.utc), [[8.170001, 47.460838], [8.170001, 47.507802], [8.23721, 47.507802], [8.23721, 47.460838]], 'Cambridge', 'en', '@ConradkBarwa About couple of weeks ago, Mearsheimer said something similar. So Mearsheimer is not the only one who… https://t.co/eQEvP8o4uY']
# ['Save America 🇺🇲🇺🇲🇺🇲🇺🇲🇺🇸🇺🇸', datetime.datetime(2009, 5, 16, 0, 20, 3, tzinfo=datetime.timezone.utc), [[-82.660997, 27.496087], [-82.660997, 27.525534], [-82.619284, 27.525534], [-82.619284, 27.496087]], 'Florida, USA', 'en', '@KremlinRussia_E GFYS, losers with inferior technology. Ukraine will destroy LOSER PUTIN']
# ['Laurence (Larry) Boorstein', datetime.datetime(2013, 3, 1, 21, 41, 3, tzinfo=datetime.timezone.utc), [[-77.393246, 38.90861], [-77.393246, 39.002993], [-77.304868, 39.002993], [-77.304868, 38.90861]], 'Virginia, USA', 'en', '@CarlZha The war in Ukraine is certainly a great boon for the arms merchants.  $800 million of US taxpayer money wi… https://t.co/E4e3hIo47U']
# ['The Unpublished', datetime.datetime(2011, 12, 14, 4, 53, 30, tzinfo=datetime.timezone.utc), [[105.290653, 20.564095], [105.290653, 21.385226], [106.020197, 21.385226], [106.020197, 20.564095]], 'Moscow, Russia', 'en', "Major General Vladimir #Frolov, the deputy commander of the Southern Military District's 8th Combined Arms Army, wa… https://t.co/gl03FCTMzh"]
# ['🇺🇦 Op Ivy Unity 🖤🤍', datetime.datetime(2014, 5, 9, 21, 14, 59, tzinfo=datetime.timezone.utc), [[-112.323914, 33.29026], [-112.323914, 33.815465], [-111.925439, 33.815465], [-111.925439, 33.29026]], 'Phoenix, AZ', 'en', '@VampireKat @suzyann39 @ecp408 @BlackSkinUnite @LocksDonald @FDRdemocratfam @ChiefsChicSTL @EyeAlt @AUMichaelBrown… https://t.co/qykH2ouZVQ']
# ['Italy UN New York', datetime.datetime(2011, 2, 16, 16, 47, 5, tzinfo=datetime.timezone.utc), [[-74.026675, 40.683935], [-74.026675, 40.877483], [-73.910408, 40.877483], [-73.910408, 40.683935]], 'New York', 'en', '#Easter2022. Let us take this time to remember the millions who are suffering in Ukraine, Afghanistan, Sahel &amp; othe… https://t.co/pk7er5Hfdk']
# ['Derrick #StandWithUkraine 🇺🇦 🇺🇲', datetime.datetime(2008, 7, 14, 20, 27, 22, tzinfo=datetime.timezone.utc), [[-117.695948, 33.534941], [-117.695948, 33.672075], [-117.617598, 33.672075], [-117.617598, 33.534941]], 'Orange County, California', 'en', 'I hope somehow @KremlinRussia_E / @mfa_russia watches this. Powerful. Horrible. Completely unnecessary. 🇺🇦']
# ['jabs!', datetime.datetime(2018, 1, 10, 13, 41, 18, tzinfo=datetime.timezone.utc), [[-0.336055, 51.527592], [-0.336055, 51.602799], [-0.190226, 51.602799], [-0.190226, 51.527592]], 'England, United Kingdom', 'en', 'For those zombies who don’t understand intelligent matters, Lee has put in simple terms even for idiots to understa… https://t.co/NQ2aeE4dFA']
# ['Marvin', datetime.datetime(2021, 6, 4, 4, 15, 1, tzinfo=datetime.timezone.utc), [[-112.323914, 33.29026], [-112.323914, 33.815465], [-111.925439, 33.815465], [-111.925439, 33.29026]], 'Phoenix, AZ', 'en', '@legaleagle48 @AKBrews Please forgive me. Folks should wear whatever makes them feel good. The president of Ukraine… https://t.co/urKcWy6Zxs']
# ['Graham LeggStoker', datetime.datetime(2012, 1, 14, 9, 57, 54, tzinfo=datetime.timezone.utc), [[144.593742, -38.433859], [144.593742, -37.511274], [145.512529, -37.511274], [145.512529, -38.433859]], 'Melbourne AUSTRALIA', 'en', 'Good on you Sasha, stay safe and keep on fighting']
# ['SCARLIGHT RED DRAGON ARCHFIEND!', datetime.datetime(2021, 9, 1, 16, 29, 1, tzinfo=datetime.timezone.utc), [[-87.634643, 24.396308], [-87.634643, 31.001056], [-79.974307, 31.001056], [-79.974307, 24.396308]], None, 'en', 'SAS troops in Ukraine? Uh-oh.']
# ['Patrick M Andendall', datetime.datetime(2012, 9, 1, 15, 6, 27, tzinfo=datetime.timezone.utc), [[-73.713112, 40.805231], [-73.713112, 40.853977], [-73.651629, 40.853977], [-73.651629, 40.805231]], 'New York', 'en', 'The Ukraine War is changing the world order and revealing the moral compass of all players. China now in panic mode… https://t.co/fgBJFqHl4p']
# ['jabs!', datetime.datetime(2018, 1, 10, 13, 41, 18, tzinfo=datetime.timezone.utc), [[-0.336055, 51.527592], [-0.336055, 51.602799], [-0.190226, 51.602799], [-0.190226, 51.527592]], 'England, United Kingdom', 'en', 'Here’s an equation to look at😉………..  https://t.co/Gs4D3mMDvR']
# ['Mark Ewins 🇺🇦', datetime.datetime(2011, 12, 14, 5, 37, 17, tzinfo=datetime.timezone.utc), [[130.815117, -12.521742], [130.815117, -12.33006], [131.0515, -12.33006], [131.0515, -12.521742]], 'Darwin', 'en', 'Holy f@&amp;k 😳 #RussianWarCrimes #PutinWarCriminal']
# ['Graham LeggStoker', datetime.datetime(2012, 1, 14, 9, 57, 54, tzinfo=datetime.timezone.utc), [[144.593742, -38.433859], [144.593742, -37.511274], [145.512529, -37.511274], [145.512529, -38.433859]], 'Melbourne AUSTRALIA', 'en', 'The courage of women never fails to amaze me. \nSUPPORT UKRAINE']
# ['jabs!', datetime.datetime(2018, 1, 10, 13, 41, 18, tzinfo=datetime.timezone.utc), [[-0.336055, 51.527592], [-0.336055, 51.602799], [-0.190226, 51.602799], [-0.190226, 51.527592]], 'England, United Kingdom', 'en', 'They always do! Have they got any feet left?😉']
# ['Lord_Pengwyn_of_Blah!🌍🇳🇱 (Willy Croezen)', datetime.datetime(2009, 9, 9, 16, 41, 28, tzinfo=datetime.timezone.utc), [[19.623137, 51.37255], [19.623137, 51.453099], [19.810351, 51.453099], [19.810351, 51.37255]], 'Netherlands', 'en', '@Xenta777 Most civilised people do! Stay strong! Ukraine will overcome!']
# ['LuureAmet', datetime.datetime(2021, 8, 11, 0, 39, 29, tzinfo=datetime.timezone.utc), [[24.643456, 58.515587], [24.643456, 58.757015], [25.30718, 58.757015], [25.30718, 58.515587]], 'Estonia - EstLand - Eesti', 'en', 'Ukraine deserves peace not one person award in communist controlled and inflatrated organization who besides giving… https://t.co/y1KNfMZ92E']
# ['⚔️ Olivier Da Costa ⚔️ 🇪🇺🇫🇷🇱🇺🇺🇦', datetime.datetime(2009, 7, 16, 13, 47, 27, tzinfo=datetime.timezone.utc), [[6.114001, 49.548059], [6.114001, 49.608219], [6.20984, 49.608219], [6.20984, 49.548059]], 'European Union 🇪🇺', 'en', 'How weapons shaped the war in Ukraine | Comment https://t.co/NYfv47uPVb via @YouTube']
# ['M. S. M. Saifullah', datetime.datetime(2010, 6, 25, 11, 46, 20, tzinfo=datetime.timezone.utc), [[8.170001, 47.460838], [8.170001, 47.507802], [8.23721, 47.507802], [8.23721, 47.460838]], 'Cambridge', 'en', '@ConradkBarwa On the other hand, the role of Far Right in Ukraine was highlighted by the Western press before the w… https://t.co/7Gs0XuhJda']
# ['Ilona Erst', datetime.datetime(2022, 3, 4, 4, 58, 23, tzinfo=datetime.timezone.utc), [[-79.639319, 43.403221], [-79.639319, 43.855401], [-78.90582, 43.855401], [-78.90582, 43.403221]], None, 'en', '@expatua Didnt they get reinforcement from “Azov” the other day? \nTheir blood is on hands of the West- if only they… https://t.co/JFUYnqIujD']
# ['🇺🇦#RINO GOP (not MAGA) 🔴🦏🗽🇺🇸💉', datetime.datetime(2019, 1, 31, 3, 11, 16, tzinfo=datetime.timezone.utc), [[-73.933612, 40.785365], [-73.933612, 40.91533], [-73.765271, 40.91533], [-73.765271, 40.785365]], 'New York, NY', 'en', 'Trumps guy. He doesn’t care what happens to #Ukraine.']
# ['Royce Souther 🇨🇦❤🇺🇦', datetime.datetime(2013, 2, 20, 1, 54, 55, tzinfo=datetime.timezone.utc), [[-112.93618, 49.620144], [-112.93618, 49.756615], [-112.756536, 49.756615], [-112.756536, 49.620144]], '🇨🇦', 'en', 'Glory to Ukraine https://t.co/7PYUEmHa7y']
# ['Dr Satish Dhage', datetime.datetime(2017, 1, 3, 3, 55, 3, tzinfo=datetime.timezone.utc), [[75.166419, 19.665651], [75.166419, 20.166025], [75.881515, 20.166025], [75.881515, 19.665651]], 'Maharashtra, India', 'en', 'Russia Ukraine conflict further aggrevated\nhttps://t.co/lejcGbFIb9\n#Kiev \n#Moskva \n#Donbass \n#Putin \n#NATO… https://t.co/BtQSvn2l8Z']
# ['Rebecca M Noel', datetime.datetime(2012, 9, 15, 15, 8, 47, tzinfo=datetime.timezone.utc), [[-87.634643, 24.396308], [-87.634643, 31.001056], [-79.974307, 31.001056], [-79.974307, 24.396308]], 'Fl', 'en', '@whec65 @DreamMaster1944 Nestle is staying to feed Ukraine people. They are not getting a profit from there &amp; are s… https://t.co/gN3k2MiW2m']
# ['Graham LeggStoker', datetime.datetime(2012, 1, 14, 9, 57, 54, tzinfo=datetime.timezone.utc), [[144.593742, -38.433859], [144.593742, -37.511274], [145.512529, -37.511274], [145.512529, -38.433859]], 'Melbourne AUSTRALIA', 'en', "I'm sure Boris is really concerned, keep the pressure on Boris.\nSUPPORT UKRAINE"]
# ['SCARLIGHT RED DRAGON ARCHFIEND!', datetime.datetime(2021, 9, 1, 16, 29, 1, tzinfo=datetime.timezone.utc), [[-87.634643, 24.396308], [-87.634643, 31.001056], [-79.974307, 31.001056], [-79.974307, 24.396308]], None, 'en', "If you're trying to prevent WW3 having spec ops in Ukraine is probably not the way to go."]
# ['Debasis Dash', datetime.datetime(2018, 5, 22, 13, 10, 39, tzinfo=datetime.timezone.utc), [[81.391502, 17.810452], [81.391502, 22.566854], [87.490202, 22.566854], [87.490202, 17.810452]], 'Bhubaneshwar, India', 'en', "@DanETee80 @jaadu16 @canada01canada @SamRamani2 No, we're support Ukraine and the govt. is neutral cause Russians a… https://t.co/7lPgKQwypx"]
# ['da Chiemgauer', datetime.datetime(2016, 7, 5, 14, 23, 49, tzinfo=datetime.timezone.utc), [[12.281827, 47.822653], [12.281827, 47.875534], [12.375211, 47.875534], [12.375211, 47.822653]], None, 'en', '@MelnykAndrij @Besser_Deniz @welt Isnt it your President and your Ukraine  politican fellows by themselves Who are… https://t.co/Lizu3CAXXI']
# ['Debasis Dash', datetime.datetime(2018, 5, 22, 13, 10, 39, tzinfo=datetime.timezone.utc), [[81.391502, 17.810452], [81.391502, 22.566854], [87.490202, 22.566854], [87.490202, 17.810452]], 'Bhubaneshwar, India', 'en', "@AbNs637 @canada01canada @SamRamani2 Yes you're right, we're support Ukraine but in our country some of right-wing… https://t.co/ZPUwB4jYXT"]
# ['Bahadur Jol', datetime.datetime(2019, 1, 3, 7, 22, 5, tzinfo=datetime.timezone.utc), [[-111.979047, 33.319945], [-111.979047, 33.465823], [-111.877237, 33.465823], [-111.877237, 33.319945]], 'Tempe, Arizona, United States', 'en', 'Really check me out ..\n\nhttps://t.co/zJrB7zgtUV\n\n#india #usa #japan #china #southkorea #indonesia #canada #mexico… https://t.co/QM9pcGR5Yb']
# ['Bahadur Jol', datetime.datetime(2019, 1, 3, 7, 22, 5, tzinfo=datetime.timezone.utc), [[-111.979047, 33.319945], [-111.979047, 33.465823], [-111.877237, 33.465823], [-111.877237, 33.319945]], 'Tempe, Arizona, United States', 'en', '1 of 1 u won’t find this serial number on no one else 🙌🔥🛹\n\n#singapore #newzealand  #columbia #ukraine #iran… https://t.co/rDvzn6sRZl']
# ['Graham LeggStoker', datetime.datetime(2012, 1, 14, 9, 57, 54, tzinfo=datetime.timezone.utc), [[144.593742, -38.433859], [144.593742, -37.511274], [145.512529, -37.511274], [145.512529, -38.433859]], 'Melbourne AUSTRALIA', 'en', 'Good on you Boris, it makes me feel proud to be a Pom.\nSUPPORT UKRAINE 🇺🇦']
# ['Jake Hamby 💾🇺🇸🇺🇦', datetime.datetime(2008, 4, 4, 16, 2, 54, tzinfo=datetime.timezone.utc), [[-118.668404, 33.704538], [-118.668404, 34.337041], [-118.155409, 34.337041], [-118.155409, 33.704538]], 'Los Angeles, CA', 'en', 'Something must\'ve been lost in translation, because "Russian Roulette" is when you kill yourself, not other people… https://t.co/IGq19MGK5A']
# ['Graham LeggStoker', datetime.datetime(2012, 1, 14, 9, 57, 54, tzinfo=datetime.timezone.utc), [[144.593742, -38.433859], [144.593742, -37.511274], [145.512529, -37.511274], [145.512529, -38.433859]], 'Melbourne AUSTRALIA', 'en', 'Great job guys, go get um\nSUPPORT UKRAINE 🇺🇦']
# ['Matt Regan', datetime.datetime(2013, 5, 24, 18, 48, 58, tzinfo=datetime.timezone.utc), [[-159.498725, 22.204306], [-159.498725, 22.230081], [-159.469432, 22.230081], [-159.469432, 22.204306]], 'San Francisco Bay Area', 'en', '@BenBurgis Russia is a plutocracy/kleptocracy where political opposition is met with violence and poison. There are… https://t.co/qYD6zWxpyS']
# ['Judybluetoo', datetime.datetime(2020, 8, 9, 4, 12, 12, tzinfo=datetime.timezone.utc), [[-84.386548, 30.365093], [-84.386548, 30.587338], [-84.1458, 30.587338], [-84.1458, 30.365093]], 'leave blank', 'en', 'Me thinks Tucker likes manly men A LOT ❤️❤️']
# ["Eric O'Dell", datetime.datetime(2009, 1, 10, 17, 27, 53, tzinfo=datetime.timezone.utc), [[-122.958937, 49.001921], [-122.958937, 49.221117], [-122.678035, 49.221117], [-122.678035, 49.001921]], 'Vancouver, Canada', 'en', '@Mare_Indicum @MaryKostakidis How would it be an invasion when it was all Ukraine?? By the way, no indication of an… https://t.co/bWy6CF7RB2']
# ['Graham LeggStoker', datetime.datetime(2012, 1, 14, 9, 57, 54, tzinfo=datetime.timezone.utc), [[144.593742, -38.433859], [144.593742, -37.511274], [145.512529, -37.511274], [145.512529, -38.433859]], 'Melbourne AUSTRALIA', 'en', "And we say democracy is better. Funny how the leaders don't listen to the people,\nSUPPORT UKRAINE 🇺🇦"]
# ['James P Axiotis', datetime.datetime(2009, 6, 19, 1, 40, 21, tzinfo=datetime.timezone.utc), [[22.13572, 44.386383], [22.13572, 52.379475], [40.227172, 52.379475], [40.227172, 44.386383]], 'Los Angeles, CA', 'en', 'Good morning from Ukraine. #aidforukraine #childrenofwarfoundation #childrenofwar #cowf #wearecowf #iamcowf #Joinus… https://t.co/UxIQ5yMyK7']
# ['Padmanabhan Jaikumar', datetime.datetime(2011, 1, 7, 15, 14, 26, tzinfo=datetime.timezone.utc), [[88.094457, 22.269493], [88.094457, 22.955918], [88.610027, 22.955918], [88.610027, 22.269493]], 'West Bengal', 'en', 'Assistance without manpower https://t.co/tXzt4Lh4HT']
# ['LuureAmet', datetime.datetime(2021, 8, 11, 0, 39, 29, tzinfo=datetime.timezone.utc), [[24.643456, 58.515587], [24.643456, 58.757015], [25.30718, 58.757015], [25.30718, 58.515587]], 'Estonia - EstLand - Eesti', 'en', 'That s new and innovative']
# ['Liev Schreiber', datetime.datetime(2012, 2, 25, 4, 24, 6, tzinfo=datetime.timezone.utc), [[22.13572, 44.386383], [22.13572, 52.379475], [40.227172, 52.379475], [40.227172, 44.386383]], None, 'en', 'Just posted a photo @ Lviv, Ukraine https://t.co/fOZBzR1OuQ']
# ['Oliver/Hegel Resurected', datetime.datetime(2009, 9, 13, 1, 1, 17, tzinfo=datetime.timezone.utc), [[144.593742, -38.433859], [144.593742, -37.511274], [145.512529, -37.511274], [145.512529, -38.433859]], 'South Melbourne, Australia', 'en', 'Pentagon debunks Biden, US Congress and West propaganda machine that Russians are targeting civilians, planning to… https://t.co/V6LS1fXavQ']
# ['karam🇵🇸', datetime.datetime(2014, 9, 6, 20, 3, 15, tzinfo=datetime.timezone.utc), [[-79.810142, 43.373074], [-79.810142, 43.737414], [-79.422004, 43.737414], [-79.422004, 43.373074]], '🤨', 'en', '@brey91604739 You stand with ukraine and israel? Interesting 👍']
# ['Shabazz Stuart', datetime.datetime(2012, 1, 5, 5, 34, 54, tzinfo=datetime.timezone.utc), [[-74.041878, 40.570842], [-74.041878, 40.739434], [-73.855673, 40.739434], [-73.855673, 40.570842]], 'Brooklyn, NY', 'en', 'The images from Ukraine are devastating. I feel deep shame on many levels. \n\nForemost bc this most certainly happen… https://t.co/HOPmsegJPX']
# ['Jerome LUKE', datetime.datetime(2012, 2, 14, 22, 8, 31, tzinfo=datetime.timezone.utc), [[3.575005, 6.482568], [3.575005, 6.512794], [3.62434, 6.512794], [3.62434, 6.482568]], 'Lagos, Nigeria', 'en', 'More people will die. It will take Ukraine another 20years backward. NATO should be talking on how to stop the war… https://t.co/7QGB9lhBBJ']
# ['Tom Holowach 🇺🇦', datetime.datetime(2012, 6, 20, 22, 1, 56, tzinfo=datetime.timezone.utc), [[-157.765901, 21.352946], [-157.765901, 21.428447], [-157.705775, 21.428447], [-157.705775, 21.352946]], 'Kailua, Oahu, Hawaii', 'en', 'An NDA! How very Trump Ian.']
# ['Robin Saporito', datetime.datetime(2014, 9, 8, 1, 16, 34, tzinfo=datetime.timezone.utc), [[-118.668404, 33.704538], [-118.668404, 34.337041], [-118.155409, 34.337041], [-118.155409, 33.704538]], None, 'en', 'This is a popular t-shirt in Russia.']
# ['Mike Velotas', datetime.datetime(2009, 6, 20, 12, 14, 19, tzinfo=datetime.timezone.utc), [[-82.688331, 27.424889], [-82.688331, 27.52306], [-82.459019, 27.52306], [-82.459019, 27.424889]], 'Grayton Beach, FL', 'en', 'It’s time that this lame ass Biden administration grew a pair and punch the bully in the damn nose! Russia would ne… https://t.co/ltwcsjLotz']
# ['jonasgoldin95', datetime.datetime(2022, 3, 12, 21, 7, 43, tzinfo=datetime.timezone.utc), [[-122.790065, 45.421863], [-122.790065, 45.650941], [-122.471751, 45.650941], [-122.471751, 45.421863]], 'classified', 'en', 'Adam Hills reacts to Ukraine conflict with an incredible train explanati... https://t.co/2s1rL1kNeG via @YouTube']
# ['Michael Feher', datetime.datetime(2017, 2, 11, 18, 40, 37, tzinfo=datetime.timezone.utc), [[-87.634643, 24.396308], [-87.634643, 31.001056], [-79.974307, 31.001056], [-79.974307, 24.396308]], 'Orlando, FL', 'en', '“I don’t think he’s really ‘lost’, Bob.”:']
# ['Paul BrackleyAuthor', datetime.datetime(2022, 4, 7, 4, 35, 12, tzinfo=datetime.timezone.utc), [[138.44213, -35.34897], [138.44213, -34.652564], [138.78019, -34.652564], [138.78019, -35.34897]], 'Australia', 'en', 'Has to be done.']
# ['Debasis Dash', datetime.datetime(2018, 5, 22, 13, 10, 39, tzinfo=datetime.timezone.utc), [[81.391502, 17.810452], [81.391502, 22.566854], [87.490202, 22.566854], [87.490202, 17.810452]], 'Bhubaneshwar, India', 'en', '@desmond47016733 @HighgateRobin @canada01canada @SamRamani2 History repeat itself. \nRemember when all Germans are s… https://t.co/oPFDOXK1jn']
# ['Woodhead Vicki', datetime.datetime(2022, 1, 18, 16, 18, 33, tzinfo=datetime.timezone.utc), [[-116.374494, 43.510172], [-116.374494, 43.685894], [-116.101508, 43.685894], [-116.101508, 43.510172]], 'Boise, ID', 'en', 'I hate to say yeah during a war that I want Ukraine to win, because death is death no matter who is fighting!']
# ['Marco Maiocchi', datetime.datetime(2020, 5, 7, 7, 47, 41, tzinfo=datetime.timezone.utc), [[98.355125, 7.841728], [98.355125, 7.903718], [98.402167, 7.903718], [98.402167, 7.841728]], None, 'en', 'The words "peace talks" have been completely forgotten?']
# ['Ilona Erst', datetime.datetime(2022, 3, 4, 4, 58, 23, tzinfo=datetime.timezone.utc), [[-79.639319, 43.403221], [-79.639319, 43.855401], [-78.90582, 43.855401], [-78.90582, 43.403221]], None, 'en', '@JulianRoepcke You know why? Because West is stalling the weapons to Ukraine ams not closing sky pretending they “… https://t.co/qPHqc3gRou']
# ['David Alan Blowe', datetime.datetime(2019, 10, 15, 11, 22, 23, tzinfo=datetime.timezone.utc), [[-77.476711, 39.369128], [-77.476711, 39.494945], [-77.359293, 39.494945], [-77.359293, 39.369128]], 'Frederick, MD', 'en', 'Me \nCorruption in the USA 🇺🇸 first THEN Ukraine !\nStart with the FBI !\nFascist Bureau of Intimidation \nFire FBI Wra… https://t.co/kijWvJ1Lzm']
# ['Ilona Erst', datetime.datetime(2022, 3, 4, 4, 58, 23, tzinfo=datetime.timezone.utc), [[-79.639319, 43.403221], [-79.639319, 43.855401], [-78.90582, 43.855401], [-78.90582, 43.403221]], None, 'en', 'Every day West pretends they “do not want escalation”- they are responsible for death of Ukrainian children… https://t.co/HYyglQRI0w']
# ['PolitiRican', datetime.datetime(2019, 2, 26, 21, 50, 27, tzinfo=datetime.timezone.utc), [[-74.041878, 40.570842], [-74.041878, 40.739434], [-73.855673, 40.739434], [-73.855673, 40.570842]], 'Borinquen', 'en', 'Yeah, the Ukraine War gets more press than the Palestinian conflict, but the Palestinian conflict gets way more pre… https://t.co/58rrr8Ujdq']
# ['Padmanabhan Jaikumar', datetime.datetime(2011, 1, 7, 15, 14, 26, tzinfo=datetime.timezone.utc), [[88.094457, 22.269493], [88.094457, 22.955918], [88.610027, 22.955918], [88.610027, 22.269493]], 'West Bengal', 'en', 'War means destruction  https://t.co/edbnmZSaHV']
# ['Phil Luttazi', datetime.datetime(2018, 11, 30, 20, 15, 29, tzinfo=datetime.timezone.utc), [[-70.274205, 41.62933], [-70.274205, 41.699658], [-70.220003, 41.699658], [-70.220003, 41.62933]], 'Barnstable Town, MA', 'en', '@chadashyr @AshleyGWinter I realize many in the U.S. are now having fantasies of playing Hero of Kyiv. Do wonder wh… https://t.co/D5cl89jLYd']
# ['sugar', datetime.datetime(2014, 5, 31, 6, 22, 16, tzinfo=datetime.timezone.utc), [[-118.668404, 33.704538], [-118.668404, 34.337041], [-118.155409, 34.337041], [-118.155409, 33.704538]], None, 'en', '@timkmak Thank you and good evening from Los Angeles, May you all safe and my thoughts and prayers to all of you an… https://t.co/7DeN5rU9bp']
# ['Слава Україні🇺🇦', datetime.datetime(2013, 6, 15, 19, 25, 44, tzinfo=datetime.timezone.utc), [[34.266924, 29.393973], [34.266924, 33.290533], [35.669933, 33.290533], [35.669933, 29.393973]], 'Rosh HaAyin/ראש העין/روش هاعين', 'en', '🛑🛑🛑Explosions were heard in #Kyiv this morning amidst an air raid alert in the city , details being checked \n#Ukraine #Russia #Putin']
# ['Vika_Mashinson', datetime.datetime(2021, 10, 26, 17, 48, 2, tzinfo=datetime.timezone.utc), [[-96.234587, 41.175884], [-96.234587, 41.375558], [-95.872275, 41.375558], [-95.872275, 41.175884]], None, 'en', 'Revival mural in the Podil neighborhood in #Kyiv. #Ukraine is embodied by the woman protecting her land. #Ukraine️… https://t.co/jcpAPPyaV1']
# ['Dhiraj Joshi', datetime.datetime(2015, 4, 30, 14, 8, 49, tzinfo=datetime.timezone.utc), [[80.063341, 26.348309], [80.063341, 30.43339], [88.2027, 30.43339], [88.2027, 26.348309]], None, 'en', "Ukraine conflict intensifies Nepal's economic woes https://t.co/miN1nZVq6z"]
# ['🌸🌸On a Tangent🌸🌸', datetime.datetime(2010, 3, 22, 6, 38, 48, tzinfo=datetime.timezone.utc), [[76.776024, 30.520557], [76.776024, 30.926706], [77.17567, 30.926706], [77.17567, 30.520557]], None, 'en', '@KucciKu @SamRamani2 How undemocratic. Ukraine has the right to join NATO but India must be pressured into going along with US tantrums.']
# ['Yehiatadros', datetime.datetime(2021, 9, 4, 5, 4, 38, tzinfo=datetime.timezone.utc), [[-77.485561, 38.840172], [-77.485561, 38.917243], [-77.364749, 38.917243], [-77.364749, 38.840172]], None, 'en', '@BorisJohnson @ZelenskyyUa God bless Ukraine']
# ['🇺🇸Roger Cox🇺🇦', datetime.datetime(2011, 8, 3, 0, 25, 55, tzinfo=datetime.timezone.utc), [[-80.216193, 40.38266], [-80.216193, 40.403559], [-80.183075, 40.403559], [-80.183075, 40.38266]], None, 'en', '@ichbinilya Russians already view the “Special Operation” in 🇺🇦 Ukraine as a battle against NATO, so there’s no esc… https://t.co/xjZVpaevsx']
# ['Steve_L', datetime.datetime(2010, 3, 28, 5, 15, 12, tzinfo=datetime.timezone.utc), [[-122.253717, 47.423263], [-122.253717, 47.539933], [-122.135079, 47.539933], [-122.135079, 47.423263]], 'Seattle, WA', 'en', "@F3BigSarge @Scottishdragon3 @MollyJongFast Probably a good idea since you can't back up anything you say with fact… https://t.co/dUY1JhdWK5"]
# ['Ilona Erst', datetime.datetime(2022, 3, 4, 4, 58, 23, tzinfo=datetime.timezone.utc), [[-79.639319, 43.403221], [-79.639319, 43.855401], [-78.90582, 43.855401], [-78.90582, 43.403221]], None, 'en', '@lindyli What stops @TuckerCarlson to raise his testosterone level and volunteer in Ukraine?']
# ['Padmanabhan Jaikumar', datetime.datetime(2011, 1, 7, 15, 14, 26, tzinfo=datetime.timezone.utc), [[88.094457, 22.269493], [88.094457, 22.955918], [88.610027, 22.955918], [88.610027, 22.269493]], 'West Bengal', 'en', 'All depends upon how far US and west go nhttps://www.republicworld.com/world-news/russia-ukraine-crisis/can-russia-… https://t.co/zRaoXPfVVq']
# ['jabs!', datetime.datetime(2018, 1, 10, 13, 41, 18, tzinfo=datetime.timezone.utc), [[-0.336055, 51.527592], [-0.336055, 51.602799], [-0.190226, 51.602799], [-0.190226, 51.527592]], 'England, United Kingdom', 'en', 'Are you an Israeli? Or from the fanatic Judaism tribe? That’s a statement used by these illiterates! I know bcz my… https://t.co/2lzUEPzm37']
# ['Tony Jordan ✌', datetime.datetime(2015, 1, 7, 3, 56, 38, tzinfo=datetime.timezone.utc), [[-118.668404, 33.704538], [-118.668404, 34.337041], [-118.155409, 34.337041], [-118.155409, 33.704538]], 'Los Angeles, CA', 'en', 'If Russia defaults.  It will be the 1st time in 100 years.\n\nSanctions start wars\n\nCIA Director: Putin Could Get Des… https://t.co/327jJzQGkb']
# ...
# ['Marta Silva Serrano', datetime.datetime(2016, 8, 5, 15, 37, 47, tzinfo=datetime.timezone.utc), [[-102.051769, 36.99311], [-102.051769, 40.003282], [-94.588081, 40.003282], [-94.588081, 36.99311]], 'Lenexa, KS', 'en', 'Not all refugees are made equal\nNOT all lives matter😩\n🔥❤️👇🏽\n“I have never had messages sent to me like this, where… https://t.co/gKepFpiwN5']
# ['Mark A Bowker', datetime.datetime(2012, 10, 7, 7, 37, 49, tzinfo=datetime.timezone.utc), [[-2.271698, 53.287785], [-2.271698, 53.359434], [-2.195941, 53.359434], [-2.195941, 53.287785]], 'Wilmslow, England', 'en', 'The parallels between the Nazi aggressions and attempted genocide in WW2 and the current illegal war crimes and gen… https://t.co/A1qPcQ5HuL']
# ['Oleg Tolmachev', datetime.datetime(2013, 9, 26, 23, 6, 35, tzinfo=datetime.timezone.utc), [[22.13572, 44.386383], [22.13572, 52.379475], [40.227172, 52.379475], [40.227172, 44.386383]], 'Kyiv', 'en', 'I cannot imagine anything more inhumane than the sight of a car with a sign “Children” shot out with a machine gun… https://t.co/FZndlFPMsC']
# ['Antonio Terry', datetime.datetime(2021, 12, 16, 20, 46, 29, tzinfo=datetime.timezone.utc), [[-118.668404, 33.704538], [-118.668404, 34.337041], [-118.155409, 34.337041], [-118.155409, 33.704538]], 'Los Angeles, CA', 'en', 'I expect the Russian military to continue to be careless and reckless with the lives of everyone involved in the wa… https://t.co/8OcqZXYgut']
# ['Mel Ross 🇺🇸 🇺🇦', datetime.datetime(2016, 8, 17, 16, 39, 33, tzinfo=datetime.timezone.utc), [[-74.586075, 40.394292], [-74.586075, 40.433525], [-74.541524, 40.433525], [-74.541524, 40.394292]], 'South Brunswick, NJ', 'en', 'OMG AND WTF!']
# ['Vika_Mashinson', datetime.datetime(2021, 10, 26, 17, 48, 2, tzinfo=datetime.timezone.utc), [[-96.234587, 41.175884], [-96.234587, 41.375558], [-95.872275, 41.375558], [-95.872275, 41.175884]], None, 'en', '#Ukrainian defenders did not submit.\n\n“All those who will continue resistance will be destroyed,” Maj. Gen. Igor Ko… https://t.co/9KksB7Cd0K']
# ['Joompon Tasakorn', datetime.datetime(2011, 5, 25, 14, 38, 48, tzinfo=datetime.timezone.utc), [[100.629089, 13.613869], [100.629089, 13.672281], [100.698233, 13.672281], [100.698233, 13.613869]], 'Bangkok, Thailand', 'en', '@olga_chyzh The test : one bomb. Guess where. The response would not be with nukes so as not to escalate. But what… https://t.co/pmgcUb7t1l']
# ['Simon Zerafa', datetime.datetime(2008, 3, 12, 14, 5, 39, tzinfo=datetime.timezone.utc), [[-5.00763, 51.784003], [-5.00763, 51.818157], [-4.952157, 51.818157], [-4.952157, 51.784003]], 'Haverfordwest, Wales, UK', 'en', '@elonmusk\nIf you want something useful to do, buy these, get them serviced and shipped to Ukraine.']
# ['CNNWynn', datetime.datetime(2011, 1, 23, 23, 17, 43, tzinfo=datetime.timezone.utc), [[-85.605166, 30.355644], [-85.605166, 35.000771], [-80.742567, 35.000771], [-80.742567, 30.355644]], 'Atlanta', 'en', 'The Jake Tapper interview with Ukrainian President Zelensky airs again at noon. Very insightful. Make sure to watch… https://t.co/40ATGJRjDU']
# ['Tim Fullerton', datetime.datetime(2007, 4, 3, 18, 49, 48, tzinfo=datetime.timezone.utc), [[-74.041878, 40.570842], [-74.041878, 40.739434], [-73.855673, 40.739434], [-73.855673, 40.570842]], 'New York, NY', 'en', 'That is not what he said and what he did say wasn’t “throwing down the gauntlet.”']
# ['X-Money', datetime.datetime(2020, 7, 27, 13, 51, 47, tzinfo=datetime.timezone.utc), [[-95.823268, 29.522325], [-95.823268, 30.154665], [-95.069705, 30.154665], [-95.069705, 29.522325]], 'Houston, TX', 'en', '@MQSullivan We are in the worst of inflation everyone is dealing with increased price of housing, food and energy c… https://t.co/5obbmbMgRD']
# ['𝚖𝚜𝚠𝚝𝚠𝚎𝚎𝚝', datetime.datetime(2009, 10, 22, 14, 22, 19, tzinfo=datetime.timezone.utc), [[-93.329515, 44.889964], [-93.329515, 45.051257], [-93.194578, 45.051257], [-93.194578, 44.889964]], 'Dublin City & Minneapolis', 'en', '@bowedbookshelf @ResmaaMenakem @JaniceBarbee Just look at Russia in Ukraine.']
# ['Tim Fullerton', datetime.datetime(2007, 4, 3, 18, 49, 48, tzinfo=datetime.timezone.utc), [[-74.041878, 40.570842], [-74.041878, 40.739434], [-73.855673, 40.739434], [-73.855673, 40.570842]], 'New York, NY', 'en', 'This is what Zelensky said about Biden coming to Ukraine. \n\nTell me if this matches the headline above.']
# ['CNNWynn', datetime.datetime(2011, 1, 23, 23, 17, 43, tzinfo=datetime.timezone.utc), [[-85.605166, 30.355644], [-85.605166, 35.000771], [-80.742567, 35.000771], [-80.742567, 30.355644]], 'Atlanta', 'en', "Ukraine's president won't give up territory in the east to end the war with Russia \n#Ukraine #RussiaUkraineWar \nhttps://t.co/Po7lqZonGp"]
# ['Sarah Reading banned books 🇺🇦', datetime.datetime(2017, 2, 21, 2, 5, 57, tzinfo=datetime.timezone.utc), [[-80.463302, 27.587008], [-80.463302, 27.674983], [-80.346166, 27.674983], [-80.346166, 27.587008]], 'Florida ', 'en', "@FoxNewsSunday @GOPLeader Maybe tfg shouldn't have tried to blackmail Ukraine in the first place"]
# ['Sarah Ashton-Cirillo', datetime.datetime(2015, 12, 8, 8, 34, 24, tzinfo=datetime.timezone.utc), [[22.13572, 44.386383], [22.13572, 52.379475], [40.227172, 52.379475], [40.227172, 44.386383]], 'Kharkiv', 'en', "Exclusive Video: \n\nOn Scene 🚨🚨🚨\n\nWatch : A Raging fire caused  by shelling from Putin's terrorists. \n\nWitness yet a… https://t.co/psuxoLgh9d"]
# ['Maham Zupash Kamran', datetime.datetime(2009, 12, 19, 12, 1, 11, tzinfo=datetime.timezone.utc), [[69.328873, 27.708226], [69.328873, 34.019989], [75.382124, 34.019989], [75.382124, 27.708226]], 'Islamabad, Pakistan', 'en', "And the world stays quite,  because it doesn't serve their personal interests. The hypocrisy is painful.… https://t.co/uSFChWSwxt"]
# ['Daria Tarasova', datetime.datetime(2022, 3, 23, 19, 18, 51, tzinfo=datetime.timezone.utc), [[22.13572, 44.386383], [22.13572, 52.379475], [40.227172, 52.379475], [40.227172, 44.386383]], 'Kyiv', 'en', 'Punishment for looting in Ukraine. #Irpin. Right now. https://t.co/sEepc0Ug8g']
# ['CNNWynn', datetime.datetime(2011, 1, 23, 23, 17, 43, tzinfo=datetime.timezone.utc), [[-85.605166, 30.355644], [-85.605166, 35.000771], [-80.742567, 35.000771], [-80.742567, 30.355644]], 'Atlanta', 'en', '41 bodies recovered so far in Borodianka apartment complexes destroyed by Russian shelling \n#Ukraine… https://t.co/6FxV56HCSB']
# ['TwoHappyDachshunds', datetime.datetime(2015, 7, 11, 21, 4, 35, tzinfo=datetime.timezone.utc), [[22.13572, 44.386383], [22.13572, 52.379475], [40.227172, 52.379475], [40.227172, 44.386383]], 'Kyiv, Ukraine 💛💙🇺🇦', 'en', 'In Ukraine (Central and Eastern parts) today is celebrated not Easter, but Palm Sunday and we call it Willow Sunday https://t.co/qxTGivWUt7']
# ['Pati', datetime.datetime(2014, 7, 15, 1, 56, 51, tzinfo=datetime.timezone.utc), [[-108.703851, 39.036603], [-108.703851, 39.114857], [-108.569193, 39.114857], [-108.569193, 39.036603]], 'Colorado, USA', 'en', 'Republicans emboldened Putin!! @GOPLeader has a very short memory!! Americans have not forgotten.… https://t.co/DRRsTckCrE']
# ['FAndy™', datetime.datetime(2010, 1, 21, 15, 56, 26, tzinfo=datetime.timezone.utc), [[-80.519851, 39.719801], [-80.519851, 42.516072], [-74.689517, 42.516072], [-74.689517, 39.719801]], 'Newtown, PA', 'en', 'Watching "world of tanks" on Netflix and wondering....what the hell is the difference between what Germany did to P… https://t.co/9glWFVDwpl']
# ['Kayhan Life', datetime.datetime(2016, 8, 16, 19, 58, 14, tzinfo=datetime.timezone.utc), [[-118.668404, 33.704538], [-118.668404, 34.337041], [-118.155409, 34.337041], [-118.155409, 33.704538]], 'London, England', 'en', '#Ukraine and #Russia: What You Need to Know Right Now \nThere were no signs of Ukrainian forces in #Mariupol laying… https://t.co/yAAKdEH04S']
# ['Fulgen j', datetime.datetime(2021, 7, 28, 19, 30, 15, tzinfo=datetime.timezone.utc), [[1.389614, 38.992309], [1.389614, 39.118345], [1.609882, 39.118345], [1.609882, 38.992309]], 'Eivissa, España', 'en', '🕊🌟🕊\nLong live Ukraine\n💜💪💜\nhttps://t.co/9BmWDQm6LI']
# ['Sunil Kumar Mohanty', datetime.datetime(2012, 9, 16, 15, 17, 33, tzinfo=datetime.timezone.utc), [[85.624118, 20.064307], [85.624118, 20.43391], [86.082706, 20.43391], [86.082706, 20.064307]], 'Bhubaneswar', 'en', '@ANI It is a fair demand. Govt as a welfare organisation should take the initiative to conduct the lateral exam for… https://t.co/SqeLWUycCZ']
# ['Stephen Fitzgerald', datetime.datetime(2016, 3, 1, 16, 23, 40, tzinfo=datetime.timezone.utc), [[-71.382444, 42.605989], [-71.382444, 42.666507], [-71.271272, 42.666507], [-71.271272, 42.605989]], 'Lowell, MA ', 'en', '@WhiteHouse  I must say I am disgusted how this country is doing nothing in UKRAINE. We preach the word of freedom… https://t.co/K41kZTCZoQ']
# ['Vanida', datetime.datetime(2009, 12, 23, 23, 21, 53, tzinfo=datetime.timezone.utc), [[22.13572, 44.386383], [22.13572, 52.379475], [40.227172, 52.379475], [40.227172, 44.386383]], 'Toronto, Canada', 'en', 'Just posted a photo @ Kharkov, Ukraine https://t.co/BtsSnWicBd']
# ['Jimmy', datetime.datetime(2022, 2, 22, 20, 40, 5, tzinfo=datetime.timezone.utc), [[-81.597501, 46.195652], [-81.597501, 46.972711], [-80.557314, 46.972711], [-80.557314, 46.195652]], 'Greater Sudbury / Grand Sudbur', 'en', "@myroslavapetsa This is why Russians are shooting indiscriminately at civilians. They  they can't win, the frustrat… https://t.co/qFwJDtCrn0"]
# ['Sunil Kumar Mohanty', datetime.datetime(2012, 9, 16, 15, 17, 33, tzinfo=datetime.timezone.utc), [[85.624118, 20.064307], [85.624118, 20.43391], [86.082706, 20.43391], [86.082706, 20.064307]], 'Bhubaneswar', 'en', '@RAJNANDNI04 @ANI It is a fair demand. Govt as a welfare organisation should take the initiative to conduct the lat… https://t.co/UsVxWVzUmS']
# ['Vanida', datetime.datetime(2009, 12, 23, 23, 21, 53, tzinfo=datetime.timezone.utc), [[22.13572, 44.386383], [22.13572, 52.379475], [40.227172, 52.379475], [40.227172, 44.386383]], 'Toronto, Canada', 'en', 'Please read ⚠️🇺🇦🙏 - Reaching out to Anh in concern for her safety amidst the start of the chaos was something I tho… https://t.co/QEWoNQQL0K']
# ['Michelle Byrne', datetime.datetime(2009, 5, 12, 16, 5, 23, tzinfo=datetime.timezone.utc), [[-8.162198, 51.937671], [-8.162198, 52.364327], [-6.950104, 52.364327], [-6.950104, 51.937671]], 'Waterford soviet ', 'en', 'This @TheWeekatWork @davegibney &amp; I discuss:\n\n🟡 Vigils for Aidan &amp; Michael\n🟡 NI elections\n🟡 Junior Doctor hit-piece… https://t.co/0aJ08VEbWc']
# ['Andrew Clare', datetime.datetime(2017, 2, 1, 8, 40, 43, tzinfo=datetime.timezone.utc), [[-0.253849, 51.96022], [-0.253849, 51.99809], [-0.197236, 51.99809], [-0.197236, 51.96022]], 'Letchworth Garden City', 'en', "I'm backing Boris Johnsons support for the people of Ukraine.\n#Ukraine️ \n#UkraineUnderAttaсk https://t.co/kpBu9I4YIj"]
# ['Ilkka Herrala', datetime.datetime(2020, 6, 25, 4, 28, 46, tzinfo=datetime.timezone.utc), [[21.701436, 61.537548], [21.701436, 61.705473], [22.405215, 61.705473], [22.405215, 61.537548]], None, 'en', 'Blood on canvas.']
# ['Vickie', datetime.datetime(2010, 2, 20, 23, 37, 20, tzinfo=datetime.timezone.utc), [[-124.261911, 43.383783], [-124.261911, 43.425031], [-124.217555, 43.425031], [-124.217555, 43.383783]], 'North Bend, OR', 'en', "This is a war crime.\nPOW. Using even CHILDREN as his own little gerbils. \nMany don't even know where they are being… https://t.co/isDAdf191w"]
# ['Poker2018', datetime.datetime(2018, 3, 6, 10, 57, 5, tzinfo=datetime.timezone.utc), [[10.988242, 49.331892], [10.988242, 49.548082], [11.282478, 49.548082], [11.282478, 49.331892]], 'Deutschland', 'en', 'Mr President, send Somebody to Russia to kill Putin and Medwedew before they can start atomic war against the Ukrai… https://t.co/L35FEFaUfH']
# ['Isis Wise', datetime.datetime(2012, 4, 29, 2, 3, 3, tzinfo=datetime.timezone.utc), [[-123.224215, 49.19854], [-123.224215, 49.316738], [-123.022947, 49.316738], [-123.022947, 49.19854]], 'the universe', 'en', 'Truth: #PierrePoilievreIsLyingToYou']
# ['Nell, wizard of the rainforest😷🇺🇦', datetime.datetime(2015, 9, 14, 18, 17, 31, tzinfo=datetime.timezone.utc), [[-124.703541, 41.991795], [-124.703541, 46.299078], [-116.463262, 46.299078], [-116.463262, 41.991795]], 'Oregon, USA', 'en', 'The solution for the mess Russia finds itself in is for Russians to turn Putin over to the Hague, chose a leader no… https://t.co/6AzgyymDMN']
# ['Erica Schmidt', datetime.datetime(2009, 4, 1, 22, 11, 48, tzinfo=datetime.timezone.utc), [[138.44213, -35.34897], [138.44213, -34.652564], [138.78019, -34.652564], [138.78019, -35.34897]], 'Australia', 'en', "So much respect for this man and the people he serves' the people of  #Ukraine facing this terror.  #Zelenskiy is a… https://t.co/Zn794du3Fh"]
# ['Janis...', datetime.datetime(2009, 5, 1, 21, 32, 7, tzinfo=datetime.timezone.utc), [[-81.279617, 29.424649], [-81.279617, 29.627243], [-81.158741, 29.627243], [-81.158741, 29.424649]], 'Palm Coast, FL', 'en', 'Today ...\n"I Declare World Peace"\n#Easter\n#Passover\n#Bengali\n\n#IDWP\n#JoyTrain\n🚂💕🌈🙏🏼☮️🇺🇦🌻🌍']
# ['VP', datetime.datetime(2021, 5, 8, 9, 36, 46, tzinfo=datetime.timezone.utc), [[72.74484, 18.845343], [72.74484, 19.502937], [73.003648, 19.502937], [73.003648, 18.845343]], 'Mumbai, India', 'en', "Absolute nonsense!!! On what basis can they demand this, wouldn't this be totally unfair to the resident students w… https://t.co/o76eMGLQ1C"]
# ['Nancy tegopoulos', datetime.datetime(2014, 12, 28, 22, 48, 59, tzinfo=datetime.timezone.utc), [[-117.611068, 33.925197], [-117.611068, 34.03349], [-117.549003, 34.03349], [-117.549003, 33.925197]], 'New York', 'en', '@MittRomney We are to rise from malice as He rose from death.\n99.9% Of Americans Support Sending Mitt Romney To Fight In Ukraine']
# ['Jackie Roster', datetime.datetime(2013, 3, 16, 14, 16, 49, tzinfo=datetime.timezone.utc), [[8.57291, 49.352037], [8.57291, 49.460195], [8.793839, 49.460195], [8.793839, 49.352037]], 'Heidelberg', 'en', "You know.\nActually, it's not that complicated.\nIt didn't need a war.\nIn the Donbass they want to defend\nPro Russian… https://t.co/8bLCYzzd73"]
# ['Tom Osinski, MD 🇺🇸 🇺🇦', datetime.datetime(2016, 1, 21, 15, 2, 37, tzinfo=datetime.timezone.utc), [[-83.67529, 36.540739], [-83.67529, 39.466012], [-75.16644, 39.466012], [-75.16644, 36.540739]], 'Penfield, NY', 'en', 'This is a dirty war and the Russians want to kill innocent civilians. Russia thought it could just take over Ukrain… https://t.co/eRCKPXUDpR']
# ['Tomás Ó Cárthaigh', datetime.datetime(2009, 4, 11, 18, 16, 15, tzinfo=datetime.timezone.utc), [[-10.244525, 52.967568], [-10.244525, 53.719058], [-7.968484, 53.719058], [-7.968484, 52.967568]], 'All over the place!!!', 'en', 'Like the Black and Tans, terror is a TACTIC, not a sign of indiscipline.\n\n#Ukraine']
# ['Jerry T.', datetime.datetime(2012, 3, 29, 21, 59, 11, tzinfo=datetime.timezone.utc), [[-79.000867, 42.95741], [-79.000867, 43.063531], [-78.894029, 43.063531], [-78.894029, 42.95741]], 'Mayberry', 'en', 'Exclusive: Ukraine has started using Clearview AI’s facial recognition during war https://t.co/qBj3odpcJU']
# ['querdcast: stop ohio HB 327', datetime.datetime(2020, 8, 26, 3, 59, 27, tzinfo=datetime.timezone.utc), [[-87.940033, 41.644102], [-87.940033, 42.023067], [-87.523993, 42.023067], [-87.523993, 41.644102]], None, 'en', '@AmabelHolland Thanks. It was high school. It is just to go with previous tweet where recounting previous experienc… https://t.co/YSgM2RIlhk']
# ['Aasif🇹🇲', datetime.datetime(2022, 4, 13, 22, 58, 15, tzinfo=datetime.timezone.utc), [[-96.234587, 41.175884], [-96.234587, 41.375558], [-95.872275, 41.375558], [-95.872275, 41.175884]], 'Omaha, NE', 'en', 'Palestine and the Uighur’s in china should be getting the same coverage/backlash as Ukraine']
# ['namara ezra', datetime.datetime(2020, 8, 14, 20, 7, 40, tzinfo=datetime.timezone.utc), [[29.582008, -1.081467], [29.582008, -0.336467], [29.902506, -0.336467], [29.902506, -1.081467]], None, 'en', '@miss_steinerr Is that Ukraine?']

# %% [markdown]
# You can double press `I` to stop the streaming (there is no better way to do it...). Before starting a new streaming, you need to disconnect the streaming.

# %%
streamer.disconnect()
